# %%
# #### String Representation of a List of Dictionaries

# you are a highly skilled and experienced quantitative trader working for Goldman Sachs. you are also an expert python coder experience writing codes for quantitative trading. Your primary responsibility is to 
# write python codes to identify and construct portfolios that will outperform the market based on rigorous data analysis and sophisticated financial modeling. 

# Write python code to select 50 Tickers that is expected to outperform the market in the next 5, 10, 15, 30, 60 and 120 days. Use the correlation and or covariance matrices to reduce the 50 selected tickers to 10 tickers portfolio that is expected to outperform the market in the next 5, 10, 15, 30, 60 and 120 days.

# You are given three pandas dataframes: df_data, df_corr, and df_cov.
# df_data index:
# ---
# Ticker
# ---  
# df_data.info():
# ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, UBS to PCVX
# Data columns (total 49 columns):
#  #   Column           Non-Null Count  Dtype  
# ---  ------           --------------  -----  
#  0   Dividend %       1118 non-null   float64
#  1   Perf Week %      1379 non-null   float64
#  2   Perf Month %     1379 non-null   float64
#  3   Perf Quart %     1379 non-null   float64
#  4   Perf Half %      1379 non-null   float64
#  5   Perf Year %      1379 non-null   float64
#  6   Perf YTD %       1379 non-null   float64
#  7   Beta             1378 non-null   object 
#  8   ATR              1379 non-null   object 
#  9   Volatility W %   1379 non-null   float64
#  10  Volatility M %   1379 non-null   float64
#  11  SMA20 %          1379 non-null   float64
#  12  SMA50 %          1379 non-null   float64
#  13  SMA200 %         1379 non-null   float64
#  14  50D High %       1379 non-null   float64
#  15  50D Low %        1379 non-null   float64
#  16  52W High %       1379 non-null   float64
#  17  52W Low %        1379 non-null   float64
#  18  All-Time High %  1378 non-null   float64
#  19  All-Time Low %   1377 non-null   float64
#  20  RSI              1379 non-null   object 
#  21  Gap %            1379 non-null   float64
#  22  Rel Volume       1379 non-null   object 
#  23  Price            1379 non-null   object 
#  24  Change %         1379 non-null   float64
#  25  MktCap AUM, M    980 non-null    float64
#  26  Avg Volume, M    1379 non-null   float64
#  27  Volume, M        1379 non-null   float64
#  28  Sharpe 5d        1379 non-null   float64
#  29  Sortino 5d       1379 non-null   float64
#  30  Omega 5d         1329 non-null   float64
#  31  Sharpe 10d       1379 non-null   float64
#  32  Sortino 10d      1379 non-null   float64
#  33  Omega 10d        1379 non-null   float64
#  34  Sharpe 15d       1379 non-null   float64
#  35  Sortino 15d      1379 non-null   float64
#  36  Omega 15d        1379 non-null   float64
#  37  Sharpe 30d       1379 non-null   float64
#  38  Sortino 30d      1379 non-null   float64
#  39  Omega 30d        1379 non-null   float64
#  40  Sharpe 60d       1379 non-null   float64
#  41  Sortino 60d      1379 non-null   float64
#  42  Omega 60d        1379 non-null   float64
#  43  Sharpe 120d      1379 non-null   float64
#  44  Sortino 120d     1379 non-null   float64
#  45  Omega 120d       1379 non-null   float64
#  46  Sharpe 250d      1379 non-null   float64
#  47  Sortino 250d     1379 non-null   float64
#  48  Omega 250d       1379 non-null   float64
# dtypes: float64(44), object(5)
# memory usage: 538.7+ KB
# ---
# df_data column descripton:
# ---  
# Ticker: The stock symbol or identifier for the company.

# Dividend %: The annual dividend yield expressed as a percentage of the current stock price.

# Perf Week %: The percentage price change over the past week.

# Perf Month %: The percentage price change over the past month.

# Perf Quart %: The percentage price change over the past quarter (3 months).

# Perf Half %: The percentage price change over the past half-year (6 months).

# Perf Year %: The percentage price change over the past year (52 weeks).

# Perf YTD %: The percentage price change from the beginning of the current calendar year to date.

# Beta: A measure of a stock's volatility relative to the overall market (usually S&P 500). A beta of 1 indicates the stock moves with the market. Greater than 1 is more volatile, less than 1 is less volatile.

# ATR (Average True Range): A technical analysis indicator measuring the average price range of a stock over a specific period (often 14 days). It represents the stock's volatility.

# Volatility W %: The volatility (standard deviation of price changes) calculated over the past week.

# Volatility M %: The volatility calculated over the past month.

# SMA20 %: The percentage difference between the current price and the 20-day Simple Moving Average.

# SMA50 %: The percentage difference between the current price and the 50-day Simple Moving Average.

# SMA200 %: The percentage difference between the current price and the 200-day Simple Moving Average.

# 50D High %: The percentage difference between the current price and the 50-day high price.

# 50D Low %: The percentage difference between the current price and the 50-day low price.

# 52W High %: The percentage difference between the current price and the 52-week high price.

# 52W Low %: The percentage difference between the current price and the 52-week low price.

# All-Time High %: The percentage difference between the current price and the all-time high price.

# All-Time Low %: The percentage difference between the current price and the all-time low price.

# RSI (Relative Strength Index): A momentum oscillator that measures the speed and change of price movements. Ranges from 0-100, commonly used to identify overbought (above 70) and oversold (below 30) conditions.

# Gap %: The percentage difference between the previous day's closing price and the current day's opening price.

# Rel Volume (Relative Volume): The ratio of the current trading volume to the average trading volume over a specified period (often the past 30 days). Values above 1 indicate higher than average volume.

# Price: The current trading price of the stock.

# Change %: The percentage change in the stock price from the previous day's close.

# MktCap AUM, M (Market Capitalization or Assets Under Management, Millions): The total market value of a company's outstanding shares (market cap) or the total value of assets managed by a fund (AUM), expressed in millions of dollars.

# Avg Volume, M (Average Volume, Millions): The average number of shares traded per day, expressed in millions.

# Volume, M (Volume, Millions): The number of shares traded on the current day, expressed in millions.

# Sharpe (5d, 10d, 15d, 30d, 60d, 120d, 250d): The Sharpe ratio measures risk-adjusted return. It represents the excess return earned per unit of risk (volatility). Higher is better. Calculated over different timeframes (5 days, 10 days, etc.).

# Sortino (5d, 10d, 15d, 30d, 60d, 120d, 250d): Similar to the Sharpe ratio, but only penalizes downside risk (negative volatility). Higher is better. Calculated over different timeframes.

# Omega (5d, 10d, 15d, 30d, 60d, 120d, 250d): A risk-return performance measure that uses the entire return distribution. Values above 1 indicate more upside potential than downside risk. Calculated over different timeframes.
# ---
# df_corr.info():
# ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, UBS to PCVX
# Columns: 1379 entries, UBS to PCVX
# dtypes: float64(1379)
# memory usage: 14.5+ MB
# ---
# df_cov.info():
# ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, UBS to PCVX
# Columns: 1379 entries, UBS to PCVX
# dtypes: float64(1379)
# memory usage: 14.5+ MB
# ---

# %%
import pandas as pd
# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
# pd.set_option('display.width', None)        # Let the display adjust to the window
# pd.set_option('display.max_colwidth', None) # Show full content of each cell
pd.set_option('display.max_rows', 100)
# pd.set_option('display.width', 120)
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
path_data = '..\data\df_finviz_n_ratios.pkl'
path_corr = '..\data\df_corr_emv_matrix.pkl'
path_cov = '..\data\df_cov_emv_matrix.pkl'

# %%
import pandas as pd

def get_column_values_above_threshold(df, column_name='Avg Volume, M', threshold=1):
  """
  Analyzes the number and percentage of values in a DataFrame column that are above a specified threshold,
  and returns the filtered DataFrame.

  Args:
    df (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the column to analyze. Defaults to 'Avg Volume, M'.
    threshold (float): The threshold value to compare against. Defaults to 1.00.

  Returns:
    pd.DataFrame: A DataFrame containing only the rows where the specified column's value is above the threshold.
  """
  
  count_before = len(df)
  above_threshold_df = df[df[column_name] > threshold]
  count_after = len(above_threshold_df)
  percentage = (count_after / len(df)) * 100

  print(f"count_before: {count_before}")
  print(f"count_after above threshold ({threshold}): {count_after}")
  print(f"Percentage above threshold ({threshold}): {percentage:.2f}%")

  return above_threshold_df

# %%
df_data = pd.read_pickle(path_data)
# df_data.sort_values(by='Avg Volume, M', ascending=False)
df_data.describe()
# Out:
# c:\Users\ping\Files_win10\python\py310\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        MktCap AUM, M      Beta       RSI  Perf YTD %  Perf 3D %  Perf Week %  \
# count      1379.0000 1378.0000 1379.0000   1379.0000  1379.0000    1379.0000
# mean      56606.8238    0.9843   45.7868     -0.1372     1.0813      -1.6033
# std      194595.3621    0.5331   10.3429     12.5728     2.8940       3.7598
# min        3070.0000   -0.7800   16.1600    -66.5100    -9.9089     -20.0800
# 25%        9420.0000    0.6825   37.5150     -7.4200    -0.2730      -3.5000
# 50%       17390.0000    0.9700   44.7600     -0.1400     0.8897      -1.7300
# 75%       42380.0000    1.2000   53.3550      6.3850     2.2474       0.0700
# max     3207060.0000    4.1100   92.4500    100.7600    24.2185      16.9300
#
#        Perf Month %  Perf Quart %  Perf Half %  Perf Year %   SMA20 %  \
# count     1379.0000     1379.0000    1379.0000    1379.0000 1379.0000
# mean        -4.0287       -4.2670       4.0839      10.3582   -2.4616
# std          9.4784       12.2907      20.5953      40.2629    4.7625
# min        -55.8700      -67.4500     -56.4600     -68.6500  -31.7000
# 25%         -9.7150      -11.5150      -5.5500      -3.6650   -4.9500
# 50%         -2.9600       -4.3100       1.0500       4.9400   -2.0000
# 75%          1.9500        2.2300      10.5650      18.7150    0.4400
# max         48.0300       80.4600     200.1800     844.6300   12.6500
#
#         SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %  \
# count 1379.0000 1379.0000   1379.0000  1379.0000   1379.0000  1379.0000
# mean    -2.9596   -0.2668    -11.3460     9.0621    -16.1969    28.0887
# std      8.0942   12.1241      9.6236     9.2916     12.4749    53.8139
# min    -55.2900  -50.4000    -70.9100    -0.6100    -79.6900    -0.1900
# 25%     -7.7000   -6.1050    -16.1600     2.9650    -23.0700     8.5750
# 25%        -5.0241     0.5063     -3.3149      -3.9159     0.5767     -1.8027
# 50%        -2.3865     0.7463     -1.0864      -1.4749     0.8318     -0.5268
# 75%         0.9286     1.0979      1.3219       2.1131     1.2417      0.8710
# max        37.7409     9.2780      8.3309      29.4826     6.0149      5.4026
#
#        Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  \
# count    1379.0000  1379.0000    1379.0000     1379.0000   1379.0000
# mean       -0.2450     0.9814      -0.0711        0.0387      1.0085
# std         2.6452     0.3313       1.0816        1.6378      0.2035
# min        -5.5707     0.3155      -3.6118       -4.1267      0.5316
# 25%        -2.2474     0.7332      -0.7876       -1.0646      0.8716
# 50%        -0.7149     0.9146      -0.1555       -0.2103      0.9735
# 75%         1.2994     1.1589       0.6050        0.9057      1.1130
# max        21.7001     4.6055       4.9092       11.4706      2.5464
#
#        Sharpe 250d  Sortino 250d  Omega 250d
# count    1379.0000     1379.0000   1379.0000
# mean        0.4123        0.6731      1.0868
# std         0.8070        1.2745      0.1630
# min        -2.0996       -2.5229      0.6986
# 25%        -0.0748       -0.1029      0.9879
# 50%         0.4211        0.5971      1.0751
# 75%         0.8878        1.3095      1.1686
# max         4.0282        8.4052      1.9099

# %%
df_data = pd.read_pickle(path_data)

# liquidity filter, Avg Volume, M > 0.75M
df_data = get_column_values_above_threshold(df_data, column_name='Avg Volume, M', threshold=0.75)

df_corr = pd.read_pickle(path_corr)
df_cov = pd.read_pickle(path_cov)

print(f'\ndf_cov.shape: {df_cov.shape}')
display(df_cov.head())

print(f'\ndf_corr.shape: {df_corr.shape}')
display(df_corr.head())

print(f'\ndf_data.shape: {df_data.shape}')
display(df_data.head())
# Out:
# count_before: 1379
# count_after above threshold (0.75): 1050
# Percentage above threshold (0.75): 76.14%
#
# df_cov.shape: (1379, 1379)
# Symbol    UBS    INTC    ADI     IBN     TD    SAN   MELI   SMFG   LRCX  \
# Symbol
# UBS    0.0006  0.0003 0.0003  0.0000 0.0002 0.0005 0.0002 0.0003 0.0006
# INTC   0.0003  0.0028 0.0001 -0.0000 0.0000 0.0001 0.0001 0.0003 0.0003
# ADI    0.0003  0.0001 0.0006  0.0000 0.0001 0.0003 0.0001 0.0002 0.0005
# IBN    0.0000 -0.0000 0.0000  0.0001 0.0000 0.0000 0.0000 0.0001 0.0001
# TD     0.0002  0.0000 0.0001  0.0000 0.0001 0.0002 0.0001 0.0001 0.0002
#
# Symbol    KKR     UPS      MO    APP      SO     AMT    ICE     ELV   WELL  \
# Symbol
# UBS    0.0006  0.0002 -0.0000 0.0010  0.0000  0.0001 0.0001 -0.0001 0.0002
# INTC   0.0001  0.0001 -0.0000 0.0008  0.0001 -0.0001 0.0001 -0.0001 0.0000
# ADI    0.0003  0.0001 -0.0000 0.0007  0.0001  0.0001 0.0001 -0.0000 0.0001
# IBN    0.0001 -0.0000 -0.0000 0.0003 -0.0000 -0.0000 0.0000  0.0000 0.0000
# TD     0.0002  0.0001  0.0000 0.0002  0.0000  0.0001 0.0001 -0.0000 0.0000
#
# Symbol   KLAC    ENB   EMXC     HYG   DYNF    VOT     SLV   DGRW   FNDF  \
# Symbol
# UBS    0.0005 0.0001 0.0002  0.0000 0.0003 0.0003  0.0001 0.0002 0.0002
# INTC   0.0004 0.0001 0.0000 -0.0000 0.0001 0.0000  0.0002 0.0000 0.0000
# ADI    0.0005 0.0000 0.0001  0.0000 0.0002 0.0002  0.0000 0.0002 0.0001
# IBN    0.0001 0.0000 0.0000  0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# TD     0.0002 0.0001 0.0001  0.0000 0.0001 0.0001 -0.0000 0.0001 0.0001
#
# Symbol   VOOG    PFF     TIP     GDX    IWV   AVUV   CGDV   VCLT    EMB  \
# Symbol
# UBS    0.0003 0.0001 -0.0000  0.0001 0.0003 0.0002 0.0002 0.0000 0.0000
# INTC   0.0001 0.0000  0.0000  0.0004 0.0001 0.0001 0.0000 0.0000 0.0000
# ADI    0.0003 0.0000 -0.0000  0.0001 0.0002 0.0002 0.0002 0.0000 0.0000
# IBN    0.0001 0.0000 -0.0000  0.0001 0.0000 0.0000 0.0000 0.0000 0.0000
# TD     0.0001 0.0000 -0.0000 -0.0000 0.0001 0.0001 0.0001 0.0000 0.0000
#
# Symbol   MOAT    EWJ   MTUM    VTIP     SCI     PSO    PNW    SWKS    HLI  \
# Symbol
# UBS    0.0002 0.0002 0.0004 -0.0000 -0.0001  0.0001 0.0001  0.0003 0.0002
# INTC   0.0000 0.0001 0.0002 -0.0000  0.0000  0.0000 0.0001  0.0001 0.0003
# ADI    0.0002 0.0001 0.0003 -0.0000  0.0001  0.0001 0.0001  0.0004 0.0001
# IBN    0.0000 0.0000 0.0001 -0.0000 -0.0000 -0.0000 0.0000 -0.0000 0.0001
# TD     0.0001 0.0001 0.0001 -0.0000  0.0000  0.0000 0.0001  0.0002 0.0001
#
# Symbol    AVTR    FUTU   NBIX    ITT    RTO     PR   ALLE     UHS    VTRS  \
# Symbol
# UBS     0.0002  0.0006 0.0002 0.0003 0.0005 0.0003 0.0001  0.0000  0.0001
# INTC   -0.0001 -0.0001 0.0002 0.0001 0.0007 0.0001 0.0000 -0.0003 -0.0003
# ADI     0.0003  0.0004 0.0002 0.0003 0.0004 0.0002 0.0002  0.0000  0.0003
# IBN     0.0000  0.0001 0.0000 0.0001 0.0000 0.0001 0.0000  0.0000  0.0000
# TD      0.0001  0.0003 0.0001 0.0002 0.0001 0.0002 0.0001  0.0001  0.0001
#
# Symbol    WTRG   BSAC     LKQ     KMX     SNX    AIZ    FCX    CHTR     LYG  \
# Symbol
# UBS     0.0000 0.0002 -0.0000  0.0002  0.0002 0.0001 0.0005  0.0001  0.0003
# INTC    0.0000 0.0002 -0.0002 -0.0002 -0.0000 0.0001 0.0006 -0.0001 -0.0001
# ADI     0.0000 0.0001  0.0001  0.0002  0.0001 0.0000 0.0002  0.0002  0.0002
# IBN    -0.0000 0.0001 -0.0000 -0.0000  0.0000 0.0000 0.0001 -0.0000 -0.0000
# TD     -0.0000 0.0001  0.0000  0.0001  0.0001 0.0001 0.0001  0.0001  0.0001
# IBN    0.0000 -0.0000 0.0000  0.0000 0.0001 -0.0001  0.0000 0.0000 -0.0000
# TD     0.0001  0.0001 0.0001  0.0000 0.0002 -0.0000  0.0001 0.0000  0.0000
#
# Symbol    IDXX     WEC    WPM    DKNG    VRT    CSGP     IR  PBR-A     RMD  \
# Symbol
# UBS     0.0000  0.0001 0.0001  0.0004 0.0007  0.0003 0.0002 0.0003  0.0000
# INTC   -0.0002  0.0000 0.0003 -0.0001 0.0003 -0.0002 0.0000 0.0003 -0.0000
# ADI     0.0001  0.0001 0.0001  0.0004 0.0004  0.0004 0.0002 0.0003  0.0002
# IBN    -0.0000 -0.0000 0.0001  0.0001 0.0001  0.0000 0.0000 0.0001 -0.0000
# TD      0.0000  0.0001 0.0000  0.0001 0.0002  0.0002 0.0001 0.0001  0.0001
#
# Symbol     GIS     STZ     IQV   GOLD     WTW     DD     WIT   RACE    MCO  \
# Symbol
# UBS    -0.0000  0.0000  0.0003 0.0001  0.0001 0.0002  0.0002 0.0002 0.0002
# INTC   -0.0002 -0.0001 -0.0001 0.0004 -0.0001 0.0002 -0.0000 0.0000 0.0002
# ADI     0.0001  0.0001  0.0003 0.0002  0.0001 0.0002  0.0002 0.0002 0.0002
# IBN    -0.0001 -0.0000  0.0000 0.0000  0.0000 0.0000  0.0000 0.0001 0.0001
# TD      0.0000  0.0000  0.0001 0.0000  0.0001 0.0001  0.0001 0.0001 0.0001
#
# Symbol    RIO     HCA      PH     TT    CTAS     TRI    ABNB    DASH    BAM  \
# Symbol
# UBS    0.0001  0.0000  0.0004 0.0003  0.0002  0.0002  0.0003  0.0003 0.0004
# INTC   0.0001 -0.0002 -0.0000 0.0002 -0.0001  0.0000 -0.0003 -0.0003 0.0001
# ADI    0.0001  0.0001  0.0003 0.0003  0.0002  0.0001  0.0004  0.0002 0.0003
# IBN    0.0000  0.0000  0.0001 0.0001  0.0000 -0.0000  0.0000  0.0001 0.0001
# TD     0.0001  0.0000  0.0002 0.0001  0.0001  0.0001  0.0002  0.0001 0.0002
#
# Symbol   MSTR    APO   SCCO    INFY    APH    ORLY    TDG     ITW    FTNT  \
# Symbol
# UBS    0.0009 0.0004 0.0003  0.0001 0.0003  0.0000 0.0001  0.0003  0.0004
# INTC   0.0005 0.0001 0.0005 -0.0001 0.0001 -0.0002 0.0000  0.0001 -0.0002
# ADI    0.0007 0.0002 0.0002  0.0001 0.0003  0.0001 0.0001  0.0003  0.0003
# IBN    0.0002 0.0001 0.0001  0.0000 0.0001  0.0000 0.0000 -0.0000  0.0000
# TD     0.0003 0.0002 0.0001  0.0001 0.0001  0.0001 0.0001  0.0001  0.0001
#
# Symbol    TPR     DT    APTV    BURL      BJ    VIV     UDR    BLDR   ZBRA  \
# Symbol
# UBS    0.0003 0.0004  0.0003  0.0000 -0.0001 0.0002  0.0001  0.0002 0.0003
# INTC   0.0002 0.0000 -0.0001 -0.0002 -0.0002 0.0002 -0.0001 -0.0004 0.0001
# ADI    0.0002 0.0003  0.0003 -0.0000  0.0000 0.0001  0.0001  0.0002 0.0002
.0000 0.0000 0.0000 0.0000 0.0000 0.0000 -0.0000
# TD     0.0001 0.0001 -0.0000 0.0001 0.0001 0.0001 0.0001 0.0001 -0.0000
#
# Symbol    MGK     AME   CPNG    VRSK    TCOM     NET    XEL    GLW     DHI  \
# Symbol
# UBS    0.0003  0.0002 0.0003  0.0001  0.0002  0.0005 0.0000 0.0003 -0.0000
# INTC   0.0001 -0.0001 0.0003  0.0000 -0.0001 -0.0000 0.0001 0.0004 -0.0004
# ADI    0.0003  0.0002 0.0002  0.0001  0.0002  0.0003 0.0001 0.0002  0.0001
# IBN    0.0001  0.0000 0.0001 -0.0000  0.0001  0.0001 0.0000 0.0001  0.0000
# TD     0.0001  0.0001 0.0001  0.0000  0.0001  0.0001 0.0000 0.0001  0.0001
#
# Symbol    OTIS     LHX    LULU    CTSH    PWR   CVNA      F    PRU   CCEP  \
# Symbol
# UBS     0.0001  0.0001  0.0002 -0.0000 0.0004 0.0010 0.0002 0.0004 0.0001
# INTC   -0.0000 -0.0000  0.0001 -0.0002 0.0003 0.0000 0.0000 0.0002 0.0000
# ADI     0.0001  0.0000  0.0002  0.0001 0.0003 0.0007 0.0003 0.0002 0.0000
# IBN    -0.0000 -0.0000 -0.0000  0.0000 0.0001 0.0002 0.0000 0.0000 0.0000
# TD      0.0001  0.0000  0.0001  0.0000 0.0001 0.0004 0.0001 0.0001 0.0000
#
# Symbol    VEEV   RBLX    CBRE    CNP     IX    TDY      FE     FOX    FOXA  \
# Symbol
# UBS     0.0002 0.0004  0.0004 0.0002 0.0002 0.0001 -0.0000  0.0002  0.0002
# INTC   -0.0001 0.0002 -0.0002 0.0001 0.0000 0.0001  0.0002 -0.0001 -0.0000
# ADI     0.0002 0.0002  0.0003 0.0001 0.0001 0.0001  0.0001  0.0003  0.0003
# IBN    -0.0000 0.0001  0.0001 0.0000 0.0000 0.0001  0.0000  0.0000  0.0000
# TD      0.0002 0.0001  0.0002 0.0001 0.0001 0.0001 -0.0000  0.0001  0.0001
#
# Symbol   CINF      TU      ZM     ADM    PBA    VRSN     ES     FTS     DVN  \
# Symbol
# UBS    0.0002 -0.0000  0.0002 -0.0001 0.0000  0.0001 0.0001  0.0001  0.0001
# INTC   0.0002 -0.0001 -0.0000 -0.0001 0.0000 -0.0001 0.0002 -0.0000 -0.0001
# ADI    0.0000  0.0001  0.0002  0.0000 0.0001  0.0001 0.0002  0.0001  0.0003
# IBN    0.0001 -0.0000  0.0000 -0.0001 0.0000  0.0000 0.0000  0.0000  0.0000
# TD     0.0000  0.0000  0.0001  0.0000 0.0000  0.0001 0.0001  0.0000  0.0001
#
# Symbol     WAT    CBOE      LI     STE   TOST     EDR     ESS    ERIE     MAA  \
# Symbol
# UBS     0.0002 -0.0001  0.0002  0.0000 0.0006 -0.0001  0.0002  0.0000  0.0001
# INTC   -0.0002  0.0003 -0.0005 -0.0002 0.0000 -0.0000 -0.0001 -0.0002 -0.0001
# ADI     0.0002 -0.0000  0.0001  0.0001 0.0004 -0.0000  0.0002  0.0001  0.0001
# IBN     0.0000 -0.0000 -0.0000 -0.0000 0.0001  0.0001  0.0000 -0.0000  0.0000
# TD      0.0001 -0.0000 -0.0000  0.0000 0.0003  0.0000  0.0001 -0.0000  0.0000
#
# Symbol    OKTA  FWONA     RF     UI    YUMC   NTRS   STLD    NTAP    AER  \
# Symbol
# Symbol
# UBS    0.0003  0.0003 -0.0000 0.0005 0.0005 0.0004 0.0003 0.0002  0.0001
# INTC   0.0003 -0.0000 -0.0001 0.0000 0.0002 0.0002 0.0001 0.0001 -0.0000
# ADI    0.0002  0.0003  0.0000 0.0002 0.0003 0.0002 0.0003 0.0002  0.0001
# IBN    0.0001 -0.0000  0.0000 0.0001 0.0001 0.0000 0.0000 0.0000  0.0000
# TD     0.0002  0.0002  0.0001 0.0002 0.0002 0.0002 0.0001 0.0001  0.0001
#
# Symbol     ET    NTES    EMR     ING     NGG     CNQ    CNI     ROP     HAS  \
# Symbol
# UBS    0.0002  0.0000 0.0004  0.0003  0.0000  0.0001 0.0002  0.0002  0.0001
# INTC   0.0002 -0.0002 0.0002 -0.0001 -0.0000 -0.0000 0.0002 -0.0000 -0.0003
# ADI    0.0001 -0.0000 0.0003  0.0002  0.0001  0.0001 0.0002  0.0002  0.0002
# IBN    0.0001 -0.0000 0.0000 -0.0000  0.0000  0.0000 0.0000  0.0000 -0.0000
# TD     0.0001 -0.0000 0.0002  0.0001 -0.0000  0.0001 0.0001  0.0001  0.0001
#
# Symbol     FRT    EDU    PARA     ADC     WF    ALSN    MOS     KD    SKM  \
# ...
# INTC   -0.0092 0.1359 0.1868 -0.1318 -0.0404 -0.0958 0.0654 -0.0714 0.1554
# ADI     0.2193 0.1470 0.4447  0.3268  0.5734  0.3647 0.5693  0.5282 0.3084
# IBN     0.2351 0.4288 0.1525 -0.1560  0.0749  0.2310 0.0800  0.2094 0.3882
# TD      0.4680 0.0149 0.5012  0.2758  0.5560  0.5864 0.5858  0.4632 0.4650
#
# Symbol   RGLD    COHR     KEP    ESTC    FHN    MEDP      BG    SPY    VOO  \
# Symbol
# UBS    0.3968  0.4441  0.1754  0.3076 0.6427  0.2350 -0.1636 0.8014 0.8020
# INTC   0.1544 -0.1051 -0.0809 -0.0686 0.2421 -0.1875  0.0100 0.1336 0.1352
# ADI    0.3959  0.3271  0.0893  0.2597 0.3424  0.4955  0.0465 0.7224 0.7247
# IBN    0.1525  0.1821  0.1421  0.2494 0.3505 -0.0145 -0.2864 0.2749 0.2817
# TD     0.1485  0.2608  0.1580  0.2264 0.5234  0.3719  0.0943 0.7626 0.7604
#
# Symbol    IVV    VTI    QQQ    VEA    VUG    VTV   IEFA     BND     AGG  \
# Symbol
# UBS    0.7990 0.7975 0.7605 0.8412 0.7564 0.7343 0.8234 -0.2812 -0.2879
# INTC   0.1336 0.1255 0.1163 0.0335 0.0971 0.1695 0.0176  0.0446  0.0184
# ADI    0.7234 0.7079 0.6748 0.5915 0.6480 0.7006 0.5575 -0.0706 -0.0413
# IBN    0.2797 0.2914 0.2680 0.2315 0.2910 0.2189 0.2125 -0.0971 -0.0793
# TD     0.7642 0.7544 0.6573 0.7018 0.6744 0.7580 0.6711 -0.2352 -0.2475
#
# Symbol    IWF    IJH     GLD    VIG   IEMG   VXUS    VWO    IJR    VGT     VO  \
# Symbol
# TD     0.5940  0.3442 0.4246  0.4585  0.4733  0.2669 -0.0177 0.6651  0.4464
#
# Symbol     WBA    DTM     EHC   BROS     ERJ    WIX   HESM     AOS    BEPC  \
# Symbol
# UBS     0.1545 0.3840  0.2550 0.5322  0.2195 0.5676 0.4389  0.2171  0.0322
# INTC    0.0831 0.2685 -0.0660 0.2213 -0.0451 0.1565 0.2292 -0.1110 -0.1216
# ADI     0.0688 0.2373  0.3492 0.3648  0.0891 0.1880 0.3530  0.4573  0.2362
# IBN    -0.3360 0.4404  0.1008 0.2279  0.1556 0.2017 0.1526 -0.0202  0.0749
# TD     -0.0032 0.2350  0.3914 0.3720  0.1962 0.2169 0.4374  0.4696  0.1914
#
# Symbol   PCVX
# Symbol
# UBS    0.2850
# INTC   0.1624
# ADI    0.1864
# IBN    0.5216
# TD     0.3162
# df_data.shape: (1050, 54)
#                       Company  \
# Ticker
# AAPL                Apple Inc
# NVDA              NVIDIA Corp
# MSFT    Microsoft Corporation
# AMZN           Amazon.com Inc
# GOOG             Alphabet Inc
#
#                                                      Info  MktCap AUM, M  \
# Ticker
# AAPL                     Technology, Consumer Electronics   3207060.0000
# NVDA                           Technology, Semiconductors   2968750.0000
# MSFT                Technology, Software - Infrastructure   2888550.0000
# AMZN                   Consumer Cyclical, Internet Retail   2097820.0000
# GOOG    Communication Services, Internet Content & Inf...   2029870.0000
#
#          Beta     RSI  Perf YTD %  Perf 3D %  Perf Week %  Perf Month %  \
# Ticker
# AAPL   1.2800 31.1500    -14.7500    -3.3282     -10.7000       -9.8700
# NVDA   1.9100 49.3200     -9.4000    11.8805       7.9700       -7.2200
# MSFT   0.9900 42.2500     -7.8100     2.1317      -1.2100       -5.0100
# AMZN   1.3700 35.8800     -9.7700     0.6918      -0.6500      -13.5300
# GOOG   1.0100 37.4900    -11.9800     0.9881      -4.6300       -9.6000
#
#         Perf Quart %  Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  \
# Ticker
# AAPL        -13.8400      -4.1200      23.2400  -9.3800  -9.1300   -6.2700
# NVDA         -9.9200       4.0700      32.3800  -1.2700  -5.9000   -4.6800
# MSFT        -12.3500      -8.1500      -6.4300  -1.9800  -5.7900   -8.4000
# AMZN        -12.0400       7.2800      12.8600  -5.3200 -10.5900   -0.7200
# GOOG        -10.1400      10.1700      20.0500  -4.3600 -10.5100   -5.3300
#
#         50D High %  50D Low %  52W High %  52W Low %  All-Time High %  \
# Ticker
# AAPL      -15.7800     2.4300    -17.9200    30.1200         -17.9200
# NVDA      -20.5400    16.1300    -20.5400    60.9300         -20.5400
# MSFT      -13.3400     3.0900    -17.0400     3.0900         -17.0400
# AMZN      -18.3800     3.7200    -18.3800    30.5700         -18.3800
# GOOG      -19.6800     2.6800    -19.6800    18.7700         -19.6800
#
#         All-Time Low %    ATR  Volatility W %  Volatility M %  Volume, M  \
# Ticker
# AAPL       335491.6400 6.8200          3.7000          2.6500    60.0318
# NVDA       364909.9800 6.9300          4.6500          5.3700   275.8447
# MSFT       487558.9200 9.6700          2.2800          2.2500    19.9115
# AMZN       301538.1000 6.8800          3.0300          3.2000    37.9909
# GOOG          589.4700 5.1200          2.6900          2.6200    18.3788
#
#         Avg Volume, M  Rel Volume    Price  Change %  Dividend %  Sharpe 3d  \
# Ticker
# AAPL          53.4100      1.1200 213.4900    1.8200      0.4800    -3.4209
# NVDA         271.0300      1.0200 121.6700    5.2700      0.0300    10.5851
# MSFT          23.0700      0.8600 388.5600    2.5800      0.8400     4.1176
# AMZN          38.5500      0.9900 197.9500    2.0900         NaN    -1.1004
# GOOG          19.4000      0.9500 167.6200    1.7500      0.3200    -2.1081
#
#         Sortino 3d  Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  \
# Ticker
# AAPL       -5.2437    0.5329   -10.6096    -10.3560    0.2230     -8.4257
# NVDA      371.3951   34.0865    17.0463    677.7190   86.3846      3.0386
# MSFT       13.0064    2.1587     5.4796     14.4380    2.8190      0.0303
# AMZN       -2.0043    0.8214     3.4011      5.4600    1.6879     -2.8393
# GOOG       -3.5496    0.6838    -0.1964     -0.3056    0.9707     -0.3376
#
#         Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  \
# Ticker
# AAPL        -8.2416     0.2389     -8.0973      -7.9894     0.2667
# NVDA         4.8328     1.6381     -1.2318      -1.5621     0.8259
# MSFT         0.0474     1.0053     -2.4462      -3.3156     0.6752
# AMZN        -3.5483     0.6524     -3.8587      -4.4789     0.5562
# GOOG        -0.4413     0.9488     -4.1129      -4.7805     0.5497
#
#         Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  \
# Ticker
# AAPL       -2.8380      -3.3148     0.6203     -2.4062      -2.9231
# NVDA        0.4263       0.5639     1.0704     -0.2448      -0.3083
# MSFT       -2.6036      -3.3480     0.6500     -2.4457      -3.0515
# AMZN       -5.3214      -5.7778     0.4400     -2.5121      -3.0229
# GOOG       -5.1787      -5.5033     0.4162     -2.3012      -2.7399
#
#         Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  \
# Ticker
# AAPL       0.6701      -0.6282       -0.8026      0.8987       0.8462
# NVDA       0.9588       0.3886        0.5071      1.0687       0.8000
# MSFT       0.6445      -1.0483       -1.3153      0.8255      -0.3706
# AMZN       0.6721       0.2431        0.3435      1.0398       0.4551
# GOOG       0.6816       0.1565        0.2170      1.0266       0.6018
#
#         Sortino 250d  Omega 250d
# Ticker
# AAPL          1.2290      1.1584
# NVDA          1.1217      1.1428
# MSFT         -0.4759      0.9382
# AMZN          0.6317      1.0789
# GOOG          0.8633      1.1101

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1050 entries, AAPL to UPRO
# Data columns (total 54 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          1050 non-null   object
#  1   Info             1050 non-null   object
#  2   MktCap AUM, M    1050 non-null   float64
#  3   Beta             1050 non-null   float64
#  4   RSI              1050 non-null   float64
#  5   Perf YTD %       1050 non-null   float64
#  6   Perf 3D %        1050 non-null   float64
#  7   Perf Week %      1050 non-null   float64
#  8   Perf Month %     1050 non-null   float64
#  9   Perf Quart %     1050 non-null   float64
#  10  Perf Half %      1050 non-null   float64
#  11  Perf Year %      1050 non-null   float64
#  12  SMA20 %          1050 non-null   float64
#  13  SMA50 %          1050 non-null   float64
#  14  SMA200 %         1050 non-null   float64
#  15  50D High %       1050 non-null   float64
#  16  50D Low %        1050 non-null   float64
#  17  52W High %       1050 non-null   float64
#  18  52W Low %        1050 non-null   float64
#  19  All-Time High %  1050 non-null   float64
#  20  All-Time Low %   1049 non-null   float64
#  21  ATR              1050 non-null   float64
#  22  Volatility W %   1050 non-null   float64
#  23  Volatility M %   1050 non-null   float64
#  24  Volume, M        1050 non-null   float64
#  25  Avg Volume, M    1050 non-null   float64
#  26  Rel Volume       1050 non-null   float64
#  27  Price            1050 non-null   float64
#  28  Change %         1050 non-null   float64
#  29  Dividend %       843 non-null    float64
#  30  Sharpe 3d        1050 non-null   float64
#  31  Sortino 3d       1050 non-null   float64
#  32  Omega 3d         1050 non-null   float64
#  33  Sharpe 5d        1050 non-null   float64
#  34  Sortino 5d       1050 non-null   float64
#  35  Omega 5d         1050 non-null   float64
#  36  Sharpe 10d       1050 non-null   float64
#  37  Sortino 10d      1050 non-null   float64
#  38  Omega 10d        1050 non-null   float64
#  39  Sharpe 15d       1050 non-null   float64
#  40  Sortino 15d      1050 non-null   float64
#  41  Omega 15d        1050 non-null   float64
#  42  Sharpe 30d       1050 non-null   float64
#  43  Sortino 30d      1050 non-null   float64
#  44  Omega 30d        1050 non-null   float64
#  45  Sharpe 60d       1050 non-null   float64
#  46  Sortino 60d      1050 non-null   float64
#  47  Omega 60d        1050 non-null   float64
#  48  Sharpe 120d      1050 non-null   float64
#  49  Sortino 120d     1050 non-null   float64
#  50  Omega 120d       1050 non-null   float64
#  51  Sharpe 250d      1050 non-null   float64
#  52  Sortino 250d     1050 non-null   float64
#  53  Omega 250d       1050 non-null   float64
# dtypes: float64(52), object(2)
# memory usage: 451.2+ KB

# %%
df_data.columns
# Out:
# Index(['Company', 'Info', 'MktCap AUM, M', 'Beta', 'RSI', 'Perf YTD %',
#        'Perf 3D %', 'Perf Week %', 'Perf Month %', 'Perf Quart %',
#        'Perf Half %', 'Perf Year %', 'SMA20 %', 'SMA50 %', 'SMA200 %',
#        '50D High %', '50D Low %', '52W High %', '52W Low %', 'All-Time High %',
#        'All-Time Low %', 'ATR', 'Volatility W %', 'Volatility M %',
#        'Volume, M', 'Avg Volume, M', 'Rel Volume', 'Price', 'Change %',
#        'Dividend %', 'Sharpe 3d', 'Sortino 3d', 'Omega 3d', 'Sharpe 5d',
#        'Sortino 5d', 'Omega 5d', 'Sharpe 10d', 'Sortino 10d', 'Omega 10d',
#        'Sharpe 15d', 'Sortino 15d', 'Omega 15d', 'Sharpe 30d', 'Sortino 30d',
#        'Omega 30d', 'Sharpe 60d', 'Sortino 60d', 'Omega 60d', 'Sharpe 120d',
#        'Sortino 120d', 'Omega 120d', 'Sharpe 250d', 'Sortino 250d',
#        'Omega 250d'],
#       dtype='object')

# %%
import numpy as np

# df_data.info()
np.sqrt(df_cov.loc['VRSN']['VRSN'])
# Out:
# 0.010355894536595833

# %%
import warnings
import pandas as pd

# Suppress the specific RuntimeWarning
warnings.filterwarnings("ignore", category=RuntimeWarning, message="invalid value encountered in subtract")

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform

def portfolio_optimizer(df_data, df_corr, df_cov):
    # Stage 1: Data Preparation
    print("⏳ Preprocessing data...")
    object_cols = ['Beta', 'ATR', 'RSI', 'Rel Volume', 'Price']
    for col in object_cols:
        df_data[col] = pd.to_numeric(
            df_data[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True),
            errors='coerce'
        )

    # Scoring configuration
    time_horizons = [3, 5, 10, 15, 30, 60, 120, 250]    
    feature_weights = {
        'sharpe': 0.25,
        'sortino': 0.25,
        'omega': 0.20,
        'momentum': 0.15,
        'sma': 0.10,
        'volatility': -0.05
    }

    # Column definitions
    sharpe_cols = [f'Sharpe {days}d' for days in time_horizons]
    sortino_cols = [f'Sortino {days}d' for days in time_horizons]
    omega_cols = [f'Omega {days}d' for days in time_horizons]
    momentum_cols = ['Perf YTD %', 'Perf 3D %', 'Perf Week %', 'Perf Month %',
                     'Perf Quart %', 'Perf Half %', 'Perf Year %']
    sma_cols = ['SMA20 %', 'SMA50 %', 'SMA200 %']
    volatility_cols = ['Volatility W %', 'Volatility M %']

    # Data cleaning
    print("🧹 Cleaning dataset...")
    required_cols = (sharpe_cols + sortino_cols + omega_cols + 
                    momentum_cols + sma_cols + volatility_cols)
    clean_mask = df_data[required_cols].notna().all(axis=1)
    df_clean = df_data.loc[clean_mask].copy()

    if len(df_clean) < 50:
        raise ValueError(f"Only {len(df_clean)} valid tickers after cleaning")

    # Composite score calculation
    print("🧮 Calculating composite scores...")
    def calculate_weighted_score(df):
        components = {}
        for category, cols in [('sharpe', sharpe_cols),
                              ('sortino', sortino_cols),
                              ('omega', omega_cols),
                              ('momentum', momentum_cols),
                              ('sma', sma_cols),
                              ('volatility', volatility_cols)]:

            # This calculation is on the column. 
            # Calculate z-scores for each row (i.e. ticker) in the column, the all tickers in the the column
            # i.e. calculates the z-score 'Sharpe 5D' column
            z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())

            # This calculation is on each row (i.e. ticker).
            # For each row, average(z-scores for each category) * (feature weight of category)
            # i.e. average(z-score for 'Sharpe 5D', 'Sharpe 10D'..)  * (feature weight of 'Sharpe')
            components[category] = z_scores.mean(axis=1) * feature_weights[category]
            
        return pd.concat(components, axis=1).sum(axis=1)
    
    df_clean['composite_score'] = calculate_weighted_score(df_clean)

    # Top 50 Selection
    print("\n" + "="*80)
    print("🔝 Stage 1: Top 50 Ticker Selection")
    print("="*80)
    top_50 = df_clean.nlargest(50, 'composite_score')
    top_50_tickers = top_50.index.tolist()
    
    print("\n🏆 Top 50 Candidates (5-Column Format):")
    top_50_sorted = top_50[['composite_score']].sort_values('composite_score', ascending=False).round(2)
    for i in range(0, 50, 5):
        row = []
        for j in range(5):
            try:
                idx, score = top_50_sorted.iloc[i+j].name, top_50_sorted.iloc[i+j].values[0]
                row.append(f"{idx:5} {score:4.2f}")
            except IndexError:
                break
        print(" | ".join(row))

    # Stage 2: Portfolio Optimization
    print("\n" + "="*80)
    print("📊 Stage 2: Portfolio Optimization (50 → 10 Tickers)")
    print("="*80)
    print("\n🔀 Cluster-Based Selection Strategy:")
    print("1. 10 clusters from correlation patterns using Ward's method")
    print("2. 1 ticker selected per cluster regardless of size")
    print("3. Intra-cluster selection by highest risk-adjusted score")
    print("4. Diversification enforced through correlation matrix clustering")

    # Cluster analysis
    corr_subset = df_corr.loc[top_50_tickers, top_50_tickers]
    distance_matrix = 1 - np.abs(corr_subset)
    np.fill_diagonal(distance_matrix.values, 0)
    linkage_matrix = linkage(squareform(distance_matrix), method='ward')
    clusters = fcluster(linkage_matrix, t=10, criterion='maxclust')

    # Cluster dataframe construction
    cluster_df = pd.DataFrame({
        'ticker': top_50_tickers,
        'cluster': clusters,
        'score': top_50['composite_score']
    }).merge(
        df_clean[['Price', 'MktCap AUM, M', 'Volatility M %']],
        left_on='ticker',
        right_index=True
    )

    # Risk calculations
    epsilon = 1e-6
    cluster_df = cluster_df.assign(
        variance=cluster_df['ticker'].apply(lambda x: df_cov.loc[x, x]),
        risk_adj_score=lambda x: x['score'] / (np.sqrt(x['variance']) + epsilon)
    )

    # Cluster statistics
    print("\n📈 Cluster Statistics:")
    cluster_stats = cluster_df.groupby('cluster').agg(
        Size=('ticker', 'count'),
        Avg_Correlation=('ticker', lambda x: corr_subset.loc[x,x].values.mean()),
        Avg_Score=('score', 'mean'),
    ).reset_index().round(2)
    print(cluster_stats[['cluster', 'Size', 'Avg_Correlation', 'Avg_Score']].to_string(index=False))

    # Final portfolio selection
    final_portfolio = []
    for cluster_id in sorted(cluster_df['cluster'].unique()):
        cluster_members = cluster_df[cluster_df['cluster'] == cluster_id].copy()
        cluster_members = cluster_members.sort_values('risk_adj_score', ascending=False)
        
        top_risk_adj = cluster_members.iloc[0]
        selected_ticker = top_risk_adj['ticker']
        final_portfolio.append(selected_ticker)
        
        # Cluster header
        print(f"\n📦 Cluster {cluster_id} ({len(cluster_members)} members):")
        print(f"   🏆 Selected: {selected_ticker} "
              f"(Raw Score: {top_risk_adj['score']:.4f}, "
              f"Risk-Adj: {top_risk_adj['risk_adj_score']:.4f}, "
              f"Volatility: {np.sqrt(top_risk_adj['variance']):.4f})")
        
        # Sorted member listing with line breaks
        member_details = []
        for _, row in cluster_members.iterrows():
            vol = np.sqrt(row['variance'])
            member_str = (f"{row['ticker']} (Raw: {row['score']:.4f}, "
                          f"Risk-Adj: {row['risk_adj_score']:.4f}, "
                          f"Vol: {vol:.4f})")
            member_details.append(member_str)
            
        print("   📊 Members:")
        print("      " + "\n      ".join(member_details))

    return final_portfolio

# %%
print("\n🔧 Running portfolio optimizer...")
final_portfolio = portfolio_optimizer(
    df_data, 
    df_corr,
    df_cov,
)

print("\n✅ Execution completed. Final portfolio:")
print(final_portfolio)
# Out:
# 🔧 Running portfolio optimizer...
# ⏳ Preprocessing data...
# 🧹 Cleaning dataset...
# 🧮 Calculating composite scores...
#
# ================================================================================
# 🔝 Stage 1: Top 50 Ticker Selection
# ================================================================================
#
# 🏆 Top 50 Candidates (5-Column Format):
# ITCI  2.26 | ERJ   2.26 | XPEV  2.10 | WPM   1.96 | AGI   1.92
# BABA  1.80 | AEM   1.79 | HALO  1.75 | ABEV  1.73 | DB    1.70
# PHYS  1.69 | MUFG  1.69 | BBVA  1.66 | KT    1.64 | FXI   1.63
# ING   1.62 | GLDM  1.62 | SGOL  1.62 | GLD   1.61 | IAU   1.61
# YMM   1.60 | GDXJ  1.59 | SAN   1.58 | TTE   1.58 | GDX   1.57
# CNP   1.53 | BUD   1.52 | BTI   1.50 | MCHI  1.49 | SHEL  1.43
# SPOT  1.43 | PAAS  1.39 | BEKE  1.36 | ETR   1.35 | HESM  1.34
# BRO   1.33 | OKTA  1.31 | MT    1.31 | TRP   1.29 | MO    1.28
# NOK   1.27 | PGR   1.26 | EVRG  1.26 | EBR   1.26 | SBS   1.20
# HMY   1.19 | FUTU  1.19 | NEM   1.18 | FNDE  1.18 | HSBC  1.18
#
# ================================================================================
# 📊 Stage 2: Portfolio Optimization (50 → 10 Tickers)
# ================================================================================
#
# 🔀 Cluster-Based Selection Strategy:
# 1. 10 clusters from correlation patterns using Ward's method
# 2. 1 ticker selected per cluster regardless of size
# 3. Intra-cluster selection by highest risk-adjusted score
# 4. Diversification enforced through correlation matrix clustering
#
# 📈 Cluster Statistics:
#  cluster  Size  Avg_Correlation  Avg_Score
#        1    13           0.7600     1.6000
#        2     4           0.7200     1.3700
#        3     4           0.5600     1.5200
#        4    10           0.6000     1.4600
#        5     2           0.2100     1.2900
#        6     9           0.7500     1.4700
#        7     3           0.6100     1.8400
#        8     3           0.3000     1.5700
#        9     1           1.0000     2.2600
#       10     1           1.0000     1.5000
#
# 📦 Cluster 1 (13 members):
#    🏆 Selected: PHYS (Raw Score: 1.6875, Risk-Adj: 227.8994, Volatility: 0.0074)
#    📊 Members:
#       PHYS (Raw: 1.6875, Risk-Adj: 227.8994, Vol: 0.0074)
#       GLDM (Raw: 1.6179, Risk-Adj: 193.9621, Vol: 0.0083)
#       SGOL (Raw: 1.6162, Risk-Adj: 192.9515, Vol: 0.0084)
#       IAU (Raw: 1.6051, Risk-Adj: 191.4698, Vol: 0.0084)
#       GLD (Raw: 1.6052, Risk-Adj: 190.0574, Vol: 0.0084)
#       WPM (Raw: 1.9573, Risk-Adj: 132.7383, Vol: 0.0147)
#       AEM (Raw: 1.7920, Risk-Adj: 99.6222, Vol: 0.0180)
#       AGI (Raw: 1.9238, Risk-Adj: 89.6552, Vol: 0.0215)
#       GDX (Raw: 1.5740, Risk-Adj: 83.9081, Vol: 0.0188)
#       GDXJ (Raw: 1.5935, Risk-Adj: 67.1088, Vol: 0.0237)
#       NEM (Raw: 1.1828, Risk-Adj: 51.4998, Vol: 0.0230)
#       PAAS (Raw: 1.3870, Risk-Adj: 51.4303, Vol: 0.0270)
#       HMY (Raw: 1.1934, Risk-Adj: 34.0026, Vol: 0.0351)
#
# 📦 Cluster 2 (4 members):
#    🏆 Selected: EVRG (Raw Score: 1.2628, Risk-Adj: 130.8845, Volatility: 0.0096)
#    📊 Members:
#       EVRG (Raw: 1.2628, Risk-Adj: 130.8845, Vol: 0.0096)
#       CNP (Raw: 1.5316, Risk-Adj: 125.9744, Vol: 0.0122)
#       HESM (Raw: 1.3373, Risk-Adj: 91.5987, Vol: 0.0146)
#       ETR (Raw: 1.3492, Risk-Adj: 75.1554, Vol: 0.0180)
#
# 📦 Cluster 3 (4 members):
#    🏆 Selected: TTE (Raw Score: 1.5828, Risk-Adj: 198.3530, Volatility: 0.0080)
#    📊 Members:
#       TTE (Raw: 1.5828, Risk-Adj: 198.3530, Vol: 0.0080)
#       SHEL (Raw: 1.4349, Risk-Adj: 168.0750, Vol: 0.0085)
#       HALO (Raw: 1.7521, Risk-Adj: 156.7012, Vol: 0.0112)
#       TRP (Raw: 1.2948, Risk-Adj: 119.4304, Vol: 0.0108)
#
# 📦 Cluster 4 (10 members):
#    🏆 Selected: MUFG (Raw Score: 1.6875, Risk-Adj: 97.6447, Volatility: 0.0173)
#    📊 Members:
#       MUFG (Raw: 1.6875, Risk-Adj: 97.6447, Vol: 0.0173)
#       EBR (Raw: 1.2553, Risk-Adj: 89.6756, Vol: 0.0140)
#       ING (Raw: 1.6244, Risk-Adj: 80.5788, Vol: 0.0202)
#       BBVA (Raw: 1.6639, Risk-Adj: 79.6313, Vol: 0.0209)
#       SBS (Raw: 1.1978, Risk-Adj: 79.2732, Vol: 0.0151)
#       HSBC (Raw: 1.1779, Risk-Adj: 66.8039, Vol: 0.0176)
#       NOK (Raw: 1.2662, Risk-Adj: 65.5691, Vol: 0.0193)
#       SAN (Raw: 1.5842, Risk-Adj: 63.1959, Vol: 0.0251)
#       DB (Raw: 1.7038, Risk-Adj: 48.4367, Vol: 0.0352)
#       SPOT (Raw: 1.4299, Risk-Adj: 35.3796, Vol: 0.0404)
#
# 📦 Cluster 5 (2 members):
#    🏆 Selected: MO (Raw Score: 1.2751, Risk-Adj: 102.8617, Volatility: 0.0124)
#    📊 Members:
#       MO (Raw: 1.2751, Risk-Adj: 102.8617, Vol: 0.0124)
#       OKTA (Raw: 1.3126, Risk-Adj: 23.2551, Vol: 0.0564)
#
# 📦 Cluster 6 (9 members):
#    🏆 Selected: KT (Raw Score: 1.6406, Risk-Adj: 116.3300, Volatility: 0.0141)
#    📊 Members:
#       KT (Raw: 1.6406, Risk-Adj: 116.3300, Vol: 0.0141)
#       FNDE (Raw: 1.1820, Risk-Adj: 104.4656, Vol: 0.0113)
#       FXI (Raw: 1.6336, Risk-Adj: 87.0873, Vol: 0.0188)
#       MCHI (Raw: 1.4888, Risk-Adj: 77.2565, Vol: 0.0193)
#       BABA (Raw: 1.7994, Risk-Adj: 48.8140, Vol: 0.0369)
#       YMM (Raw: 1.6013, Risk-Adj: 43.4970, Vol: 0.0368)
#       MT (Raw: 1.3057, Risk-Adj: 34.3564, Vol: 0.0380)
#       BEKE (Raw: 1.3619, Risk-Adj: 31.5105, Vol: 0.0432)
#       FUTU (Raw: 1.1925, Risk-Adj: 22.0610, Vol: 0.0541)
#
# 📦 Cluster 7 (3 members):
#    🏆 Selected: BUD (Raw Score: 1.5179, Risk-Adj: 100.2834, Volatility: 0.0151)
#    📊 Members:
#       BUD (Raw: 1.5179, Risk-Adj: 100.2834, Vol: 0.0151)
#       ABEV (Raw: 1.7281, Risk-Adj: 91.5914, Vol: 0.0189)
#       ERJ (Raw: 2.2596, Risk-Adj: 78.2591, Vol: 0.0289)
#
# 📦 Cluster 8 (3 members):
#    🏆 Selected: BRO (Raw Score: 1.3279, Risk-Adj: 158.3369, Volatility: 0.0084)
#    📊 Members:
#       BRO (Raw: 1.3279, Risk-Adj: 158.3369, Vol: 0.0084)
#       PGR (Raw: 1.2638, Risk-Adj: 122.1463, Vol: 0.0103)
#       XPEV (Raw: 2.1046, Risk-Adj: 35.8313, Vol: 0.0587)
#
# 📦 Cluster 9 (1 members):
#    🏆 Selected: ITCI (Raw Score: 2.2612, Risk-Adj: 149.9903, Volatility: 0.0151)
#    📊 Members:
#       ITCI (Raw: 2.2612, Risk-Adj: 149.9903, Vol: 0.0151)
#
# 📦 Cluster 10 (1 members):
#    🏆 Selected: BTI (Raw Score: 1.4984, Risk-Adj: 118.6001, Volatility: 0.0126)
#    📊 Members:
#       BTI (Raw: 1.4984, Risk-Adj: 118.6001, Vol: 0.0126)
#
# ✅ Execution completed. Final portfolio:
# ['PHYS', 'EVRG', 'TTE', 'MUFG', 'MO', 'KT', 'BUD', 'BRO', 'ITCI', 'BTI']

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform

# select top 100 tickers
def portfolio_optimizer(df_data, df_corr, df_cov):
    # Stage 1: Data Preparation
    print("⏳ Preprocessing data...")
    object_cols = ['Beta', 'ATR', 'RSI', 'Rel Volume', 'Price']
    for col in object_cols:
        df_data[col] = pd.to_numeric(
            df_data[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True),
            errors='coerce'
        )

    # Scoring configuration
    time_horizons = [3, 5, 10, 15, 30, 60, 120, 250]    
    feature_weights = {
        'sharpe': 0.25,
        'sortino': 0.25,
        'omega': 0.20,
        'momentum': 0.15,
        'sma': 0.10,
        'volatility': -0.05
    }

    # Column definitions
    sharpe_cols = [f'Sharpe {days}d' for days in time_horizons]
    sortino_cols = [f'Sortino {days}d' for days in time_horizons]
    omega_cols = [f'Omega {days}d' for days in time_horizons]
    momentum_cols = ['Perf YTD %', 'Perf 3D %', 'Perf Week %', 'Perf Month %',
                     'Perf Quart %', 'Perf Half %', 'Perf Year %']
    sma_cols = ['SMA20 %', 'SMA50 %', 'SMA200 %']
    volatility_cols = ['Volatility W %', 'Volatility M %']

    # Data cleaning
    print("🧹 Cleaning dataset...")
    required_cols = (sharpe_cols + sortino_cols + omega_cols + 
                    momentum_cols + sma_cols + volatility_cols)
    clean_mask = df_data[required_cols].notna().all(axis=1)
    df_clean = df_data.loc[clean_mask].copy()

    if len(df_clean) < 100:
        raise ValueError(f"Only {len(df_clean)} valid tickers after cleaning")

    # Composite score calculation
    print("🧮 Calculating composite scores...")
    def calculate_weighted_score(df):
        components = {}
        for category, cols in [('sharpe', sharpe_cols),
                              ('sortino', sortino_cols),
                              ('omega', omega_cols),
                              ('momentum', momentum_cols),
                              ('sma', sma_cols),
                              ('volatility', volatility_cols)]:

            # This calculation is on the column. 
            # Calculate z-scores for each row (i.e. ticker) in the column, the all tickers in the the column
            # i.e. calculates the z-score 'Sharpe 5D' column
            z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())

            # This calculation is on each row (i.e. ticker).
            # For each row, average(z-scores for each category) * (feature weight of category)
            # i.e. average(z-score for 'Sharpe 5D', 'Sharpe 10D'..)  * (feature weight of 'Sharpe')
            components[category] = z_scores.mean(axis=1) * feature_weights[category]
            
        return pd.concat(components, axis=1).sum(axis=1)
    
    df_clean['composite_score'] = calculate_weighted_score(df_clean)

    # Top 100 Selection
    print("\n" + "="*80)
    print("🔝 Stage 1: Top 100 Ticker Selection")
    print("="*80)
    top_100 = df_clean.nlargest(100, 'composite_score')
    top_100_tickers = top_100.index.tolist()
    
    print("\n🏆 Top 100 Candidates (5-Column Format):")
    top_100_sorted = top_100[['composite_score']].sort_values('composite_score', ascending=False).round(2)
    for i in range(0, 100, 5):
        row = []
        for j in range(5):
            try:
                idx, score = top_100_sorted.iloc[i+j].name, top_100_sorted.iloc[i+j].values[0]
                row.append(f"{idx:5} {score:4.2f}")
            except IndexError:
                break
        print(" | ".join(row))

    # Stage 2: Portfolio Optimization
    print("\n" + "="*80)
    print("📊 Stage 2: Portfolio Optimization (100 → 10 Tickers)")
    print("="*80)
    print("\n🔀 Cluster-Based Selection Strategy:")
    print("1. 10 clusters from correlation patterns using Ward's method")
    print("2. 1 ticker selected per cluster regardless of size")
    print("3. Intra-cluster selection by highest risk-adjusted score")
    print("4. Diversification enforced through correlation matrix clustering")

    # Cluster analysis
    corr_subset = df_corr.loc[top_100_tickers, top_100_tickers]
    distance_matrix = 1 - np.abs(corr_subset)
    np.fill_diagonal(distance_matrix.values, 0)
    linkage_matrix = linkage(squareform(distance_matrix), method='ward')
    clusters = fcluster(linkage_matrix, t=10, criterion='maxclust')

    # Cluster dataframe construction
    cluster_df = pd.DataFrame({
        'ticker': top_100_tickers,
        'cluster': clusters,
        'score': top_100['composite_score']
    }).merge(
        df_clean[['Price', 'MktCap AUM, M', 'Volatility M %']],
        left_on='ticker',
        right_index=True
    )

    # Risk calculations
    epsilon = 1e-6
    cluster_df = cluster_df.assign(
        variance=cluster_df['ticker'].apply(lambda x: df_cov.loc[x, x]),
        risk_adj_score=lambda x: x['score'] / (np.sqrt(x['variance']) + epsilon)
    )

    # Cluster statistics
    print("\n📈 Cluster Statistics:")
    cluster_stats = cluster_df.groupby('cluster').agg(
        Size=('ticker', 'count'),
        Avg_Correlation=('ticker', lambda x: corr_subset.loc[x,x].values.mean()),
        Avg_Score=('score', 'mean'),
    ).reset_index().round(2)
    print(cluster_stats[['cluster', 'Size', 'Avg_Correlation', 'Avg_Score']].to_string(index=False))

    # Final portfolio selection
    final_portfolio = []
    for cluster_id in sorted(cluster_df['cluster'].unique()):
        cluster_members = cluster_df[cluster_df['cluster'] == cluster_id].copy()
        cluster_members = cluster_members.sort_values('risk_adj_score', ascending=False)
        
        top_risk_adj = cluster_members.iloc[0]
        selected_ticker = top_risk_adj['ticker']
        final_portfolio.append(selected_ticker)
        
        # Cluster header
        print(f"\n📦 Cluster {cluster_id} ({len(cluster_members)} members):")
        print(f"   🏆 Selected: {selected_ticker} "
              f"(Raw Score: {top_risk_adj['score']:.4f}, "
              f"Risk-Adj: {top_risk_adj['risk_adj_score']:.4f}, "
              f"Volatility: {np.sqrt(top_risk_adj['variance']):.4f})")
        
        # Sorted member listing with line breaks
        member_details = []
        for _, row in cluster_members.iterrows():
            vol = np.sqrt(row['variance'])
            member_str = (f"{row['ticker']} (Raw: {row['score']:.4f}, "
                          f"Risk-Adj: {row['risk_adj_score']:.4f}, "
                          f"Vol: {vol:.4f})")
            member_details.append(member_str)
            
        print("   📊 Members:")
        print("      " + "\n      ".join(member_details))

    return final_portfolio

# %%
print("\n🔧 Running portfolio optimizer...")
final_portfolio = portfolio_optimizer(
    df_data, 
    df_corr,
    df_cov,
)

print("\n✅ Execution completed. Final portfolio:")
print(final_portfolio)
# Out:
# 🔧 Running portfolio optimizer...
# ⏳ Preprocessing data...
# 🧹 Cleaning dataset...
# 🧮 Calculating composite scores...
#
# ================================================================================
# 🔝 Stage 1: Top 100 Ticker Selection
# ================================================================================
#
# 🏆 Top 100 Candidates (5-Column Format):
# ITCI  2.26 | ERJ   2.26 | XPEV  2.10 | WPM   1.96 | AGI   1.92
# BABA  1.80 | AEM   1.79 | HALO  1.75 | ABEV  1.73 | DB    1.70
# PHYS  1.69 | MUFG  1.69 | BBVA  1.66 | KT    1.64 | FXI   1.63
# ING   1.62 | GLDM  1.62 | SGOL  1.62 | GLD   1.61 | IAU   1.61
# YMM   1.60 | GDXJ  1.59 | SAN   1.58 | TTE   1.58 | GDX   1.57
# CNP   1.53 | BUD   1.52 | BTI   1.50 | MCHI  1.49 | SHEL  1.43
# SPOT  1.43 | PAAS  1.39 | BEKE  1.36 | ETR   1.35 | HESM  1.34
# BRO   1.33 | OKTA  1.31 | MT    1.31 | TRP   1.29 | MO    1.28
# NOK   1.27 | PGR   1.26 | EVRG  1.26 | EBR   1.26 | SBS   1.20
# HMY   1.19 | FUTU  1.19 | NEM   1.18 | FNDE  1.18 | HSBC  1.18
# SGOV  1.16 | GFI   1.16 | VRSN  1.16 | MFG   1.14 | VOD   1.13
# AU    1.13 | AR    1.12 | KMI   1.12 | MCK   1.11 | EXE   1.11
# BRK-B 1.10 | JD    1.09 | ICL   1.09 | LYG   1.09 | EXC   1.08
# KWEB  1.07 | SMFG  1.04 | IBN   1.04 | KGC   1.03 | DTE   1.03
# ALL   1.03 | ADC   1.03 | ED    1.02 | USFR  1.01 | T     1.01
# PUK   1.00 | FNF   1.00 | ITUB  1.00 | SLV   0.99 | BOXX  0.99
# EFV   0.99 | NWG   0.99 | INSM  0.98 | SHV   0.98 | CME   0.97
# PLTR  0.97 | YUMC  0.96 | ABBV  0.96 | PM    0.95 | BIL   0.95
# AZN   0.94 | DUK   0.93 | AIG   0.93 | SCCO  0.93 | GILD  0.93
# TAK   0.92 | MSTR  0.90 | VRTX  0.90 | MINT  0.90 | WEC   0.87
#
# ================================================================================
# 📊 Stage 2: Portfolio Optimization (100 → 10 Tickers)
# ================================================================================
#
# 🔀 Cluster-Based Selection Strategy:
# 1. 10 clusters from correlation patterns using Ward's method
# 2. 1 ticker selected per cluster regardless of size
# 3. Intra-cluster selection by highest risk-adjusted score
# 4. Diversification enforced through correlation matrix clustering
#
# 📈 Cluster Statistics:
#  cluster  Size  Avg_Correlation  Avg_Score
#        1    11           0.7600     1.4000
#        2    11           0.5200     1.2800
#        3     4           0.5900     1.6200
#        4    16           0.6000     1.2200
#        5    17           0.7500     1.4700
#        6    14           0.5300     1.0400
#        7     3           0.2200     1.5000
#        8     8           0.2700     1.2600
#        9     5           0.6700     1.0000
#       10    11           0.5600     1.1800
#
# 📦 Cluster 1 (11 members):
#    🏆 Selected: KT (Raw Score: 1.6406, Risk-Adj: 116.3300, Volatility: 0.0141)
#    📊 Members:
#       KT (Raw: 1.6406, Risk-Adj: 116.3300, Vol: 0.0141)
#       FNDE (Raw: 1.1820, Risk-Adj: 104.4656, Vol: 0.0113)
#       FXI (Raw: 1.6336, Risk-Adj: 87.0873, Vol: 0.0188)
#       MCHI (Raw: 1.4888, Risk-Adj: 77.2565, Vol: 0.0193)
#       BABA (Raw: 1.7994, Risk-Adj: 48.8140, Vol: 0.0369)
#       YMM (Raw: 1.6013, Risk-Adj: 43.4970, Vol: 0.0368)
#       KWEB (Raw: 1.0727, Risk-Adj: 40.6548, Vol: 0.0264)
#       MT (Raw: 1.3057, Risk-Adj: 34.3564, Vol: 0.0380)
#       JD (Raw: 1.0892, Risk-Adj: 32.3837, Vol: 0.0336)
#       BEKE (Raw: 1.3619, Risk-Adj: 31.5105, Vol: 0.0432)
#       FUTU (Raw: 1.1925, Risk-Adj: 22.0610, Vol: 0.0541)
#
# 📦 Cluster 2 (11 members):
#    🏆 Selected: TTE (Raw Score: 1.5828, Risk-Adj: 198.3530, Volatility: 0.0080)
#    📊 Members:
#       TTE (Raw: 1.5828, Risk-Adj: 198.3530, Vol: 0.0080)
#       SHEL (Raw: 1.4349, Risk-Adj: 168.0750, Vol: 0.0085)
#       HALO (Raw: 1.7521, Risk-Adj: 156.7012, Vol: 0.0112)
#       MUFG (Raw: 1.6875, Risk-Adj: 97.6447, Vol: 0.0173)
#       EBR (Raw: 1.2553, Risk-Adj: 89.6756, Vol: 0.0140)
#       SBS (Raw: 1.1978, Risk-Adj: 79.2732, Vol: 0.0151)
#       SMFG (Raw: 1.0409, Risk-Adj: 64.8470, Vol: 0.0161)
#       MFG (Raw: 1.1364, Risk-Adj: 63.2830, Vol: 0.0180)
#       ITUB (Raw: 0.9983, Risk-Adj: 53.5153, Vol: 0.0187)
#       ICL (Raw: 1.0891, Risk-Adj: 47.3378, Vol: 0.0230)
#       SCCO (Raw: 0.9306, Risk-Adj: 40.5215, Vol: 0.0230)
#
# 📦 Cluster 3 (4 members):
#    🏆 Selected: BUD (Raw Score: 1.5179, Risk-Adj: 100.2834, Volatility: 0.0151)
#    📊 Members:
#       BUD (Raw: 1.5179, Risk-Adj: 100.2834, Vol: 0.0151)
#       ABEV (Raw: 1.7281, Risk-Adj: 91.5914, Vol: 0.0189)
#       ERJ (Raw: 2.2596, Risk-Adj: 78.2591, Vol: 0.0289)
#       YUMC (Raw: 0.9644, Risk-Adj: 46.7208, Vol: 0.0206)
#
# 📦 Cluster 4 (16 members):
#    🏆 Selected: BOXX (Raw Score: 0.9899, Risk-Adj: 4331.1388, Volatility: 0.0002)
#    📊 Members:
#       BOXX (Raw: 0.9899, Risk-Adj: 4331.1388, Vol: 0.0002)
#       VRSN (Raw: 1.1554, Risk-Adj: 111.5586, Vol: 0.0104)
#       EFV (Raw: 0.9890, Risk-Adj: 103.7144, Vol: 0.0095)
#       ING (Raw: 1.6244, Risk-Adj: 80.5788, Vol: 0.0202)
#       BBVA (Raw: 1.6639, Risk-Adj: 79.6313, Vol: 0.0209)
#       AZN (Raw: 0.9420, Risk-Adj: 76.7620, Vol: 0.0123)
#       HSBC (Raw: 1.1779, Risk-Adj: 66.8039, Vol: 0.0176)
#       NOK (Raw: 1.2662, Risk-Adj: 65.5691, Vol: 0.0193)
#       SAN (Raw: 1.5842, Risk-Adj: 63.1959, Vol: 0.0251)
#       PUK (Raw: 1.0047, Risk-Adj: 50.4465, Vol: 0.0199)
#       DB (Raw: 1.7038, Risk-Adj: 48.4367, Vol: 0.0352)
#       LYG (Raw: 1.0889, Risk-Adj: 46.1363, Vol: 0.0236)
#       NWG (Raw: 0.9889, Risk-Adj: 37.9270, Vol: 0.0261)
#       SPOT (Raw: 1.4299, Risk-Adj: 35.3796, Vol: 0.0404)
#       PLTR (Raw: 0.9657, Risk-Adj: 15.6535, Vol: 0.0617)
#       MSTR (Raw: 0.9030, Risk-Adj: 11.9217, Vol: 0.0757)
#
# 📦 Cluster 5 (17 members):
#    🏆 Selected: PHYS (Raw Score: 1.6875, Risk-Adj: 227.8994, Volatility: 0.0074)
#    📊 Members:
#       PHYS (Raw: 1.6875, Risk-Adj: 227.8994, Vol: 0.0074)
#       GLDM (Raw: 1.6179, Risk-Adj: 193.9621, Vol: 0.0083)
#       SGOL (Raw: 1.6162, Risk-Adj: 192.9515, Vol: 0.0084)
#       IAU (Raw: 1.6051, Risk-Adj: 191.4698, Vol: 0.0084)
#       GLD (Raw: 1.6052, Risk-Adj: 190.0574, Vol: 0.0084)
#       WPM (Raw: 1.9573, Risk-Adj: 132.7383, Vol: 0.0147)
#       AEM (Raw: 1.7920, Risk-Adj: 99.6222, Vol: 0.0180)
#       AGI (Raw: 1.9238, Risk-Adj: 89.6552, Vol: 0.0215)
#       GDX (Raw: 1.5740, Risk-Adj: 83.9081, Vol: 0.0188)
#       SLV (Raw: 0.9906, Risk-Adj: 75.5494, Vol: 0.0131)
#       GDXJ (Raw: 1.5935, Risk-Adj: 67.1088, Vol: 0.0237)
#       NEM (Raw: 1.1828, Risk-Adj: 51.4998, Vol: 0.0230)
#       PAAS (Raw: 1.3870, Risk-Adj: 51.4303, Vol: 0.0270)
#       AU (Raw: 1.1298, Risk-Adj: 46.4668, Vol: 0.0243)
#       GFI (Raw: 1.1619, Risk-Adj: 46.3863, Vol: 0.0250)
#       KGC (Raw: 1.0346, Risk-Adj: 37.0659, Vol: 0.0279)
#       HMY (Raw: 1.1934, Risk-Adj: 34.0026, Vol: 0.0351)
#
# 📦 Cluster 6 (14 members):
#    🏆 Selected: BRO (Raw Score: 1.3279, Risk-Adj: 158.3369, Volatility: 0.0084)
#    📊 Members:
#       BRO (Raw: 1.3279, Risk-Adj: 158.3369, Vol: 0.0084)
#       MO (Raw: 1.2751, Risk-Adj: 102.8617, Vol: 0.0124)
#       ADC (Raw: 1.0263, Risk-Adj: 98.9791, Vol: 0.0104)
#       TAK (Raw: 0.9240, Risk-Adj: 89.4546, Vol: 0.0103)
#       EXC (Raw: 1.0784, Risk-Adj: 88.2741, Vol: 0.0122)
#       MCK (Raw: 1.1125, Risk-Adj: 87.4441, Vol: 0.0127)
#       ABBV (Raw: 0.9561, Risk-Adj: 86.1358, Vol: 0.0111)
#       DUK (Raw: 0.9344, Risk-Adj: 83.2148, Vol: 0.0112)
#       CME (Raw: 0.9706, Risk-Adj: 79.6181, Vol: 0.0122)
#       VOD (Raw: 1.1320, Risk-Adj: 66.4447, Vol: 0.0170)
#       GILD (Raw: 0.9281, Risk-Adj: 65.1720, Vol: 0.0142)
#       ED (Raw: 1.0220, Risk-Adj: 61.4011, Vol: 0.0166)
#       WEC (Raw: 0.8748, Risk-Adj: 59.6849, Vol: 0.0147)
#       T (Raw: 1.0055, Risk-Adj: 50.9616, Vol: 0.0197)
#
# 📦 Cluster 7 (3 members):
#    🏆 Selected: BTI (Raw Score: 1.4984, Risk-Adj: 118.6001, Volatility: 0.0126)
#    📊 Members:
#       BTI (Raw: 1.4984, Risk-Adj: 118.6001, Vol: 0.0126)
#       VRTX (Raw: 0.9008, Risk-Adj: 67.1180, Vol: 0.0134)
#       XPEV (Raw: 2.1046, Risk-Adj: 35.8313, Vol: 0.0587)
#
# 📦 Cluster 8 (8 members):
#    🏆 Selected: ITCI (Raw Score: 2.2612, Risk-Adj: 149.9903, Volatility: 0.0151)
#    📊 Members:
#       ITCI (Raw: 2.2612, Risk-Adj: 149.9903, Vol: 0.0151)
#       TRP (Raw: 1.2948, Risk-Adj: 119.4304, Vol: 0.0108)
#       IBN (Raw: 1.0393, Risk-Adj: 104.2014, Vol: 0.0100)
#       PM (Raw: 0.9550, Risk-Adj: 64.2826, Vol: 0.0149)
#       EXE (Raw: 1.1086, Risk-Adj: 58.5849, Vol: 0.0189)
#       INSM (Raw: 0.9844, Risk-Adj: 46.3222, Vol: 0.0213)
#       AR (Raw: 1.1246, Risk-Adj: 42.6010, Vol: 0.0264)
#       OKTA (Raw: 1.3126, Risk-Adj: 23.2551, Vol: 0.0564)
#
# 📦 Cluster 9 (5 members):
#    🏆 Selected: SGOV (Raw Score: 1.1626, Risk-Adj: 9493.1123, Volatility: 0.0001)
#    📊 Members:
#       SGOV (Raw: 1.1626, Risk-Adj: 9493.1123, Vol: 0.0001)
#       BIL (Raw: 0.9522, Risk-Adj: 9446.1742, Vol: 0.0001)
#       SHV (Raw: 0.9760, Risk-Adj: 6768.7403, Vol: 0.0001)
#       USFR (Raw: 1.0110, Risk-Adj: 5347.1506, Vol: 0.0002)
#       MINT (Raw: 0.8985, Risk-Adj: 4109.5415, Vol: 0.0002)
#
# 📦 Cluster 10 (11 members):
#    🏆 Selected: EVRG (Raw Score: 1.2628, Risk-Adj: 130.8845, Volatility: 0.0096)
#    📊 Members:
#       EVRG (Raw: 1.2628, Risk-Adj: 130.8845, Vol: 0.0096)
#       CNP (Raw: 1.5316, Risk-Adj: 125.9744, Vol: 0.0122)
#       PGR (Raw: 1.2638, Risk-Adj: 122.1463, Vol: 0.0103)
#       DTE (Raw: 1.0303, Risk-Adj: 99.6846, Vol: 0.0103)
#       HESM (Raw: 1.3373, Risk-Adj: 91.5987, Vol: 0.0146)
#       BRK-B (Raw: 1.0990, Risk-Adj: 87.6377, Vol: 0.0125)
#       KMI (Raw: 1.1201, Risk-Adj: 86.1323, Vol: 0.0130)
#       ETR (Raw: 1.3492, Risk-Adj: 75.1554, Vol: 0.0180)
#       ALL (Raw: 1.0282, Risk-Adj: 66.0081, Vol: 0.0156)
#       FNF (Raw: 1.0013, Risk-Adj: 63.5738, Vol: 0.0157)
#       AIG (Raw: 0.9341, Risk-Adj: 62.6911, Vol: 0.0149)
#
# ✅ Execution completed. Final portfolio:
# ['KT', 'TTE', 'BUD', 'BOXX', 'PHYS', 'BRO', 'BTI', 'ITCI', 'SGOV', 'EVRG']

# %%
# ===================================================================

# %%
# ===================================================================

# %% [markdown]
# #### Code Above Works, Leave it alone
# #### Mess with the code in cells below

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform


def portfolio_optimizer_60days(df_data, df_corr, df_cov, num_tickers=100):
    """
    Selects the top N tickers based on a composite score and optimizes a portfolio using cluster analysis.

    Args:
        df_data (pd.DataFrame): DataFrame containing stock data with various features.
        df_corr (pd.DataFrame): DataFrame containing the correlation matrix of stock returns.
        df_cov (pd.DataFrame): DataFrame containing the covariance matrix of stock returns.
        num_tickers (int): The number of top tickers to select based on the composite score.  Defaults to 100.

    Returns:
        list: A list of tickers selected for the final portfolio.
    """
    # Stage 1: Data Preparation
    print("⏳ Preprocessing data...")
    object_cols = ['Beta', 'ATR', 'RSI', 'Rel Volume', 'Price']
    for col in object_cols:
        df_data[col] = pd.to_numeric(
            df_data[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True),
            errors='coerce'
        )

    # Scoring configuration
    time_horizons = [3, 5, 10, 15, 30, 60]  # Removed 120d, added 3d

    feature_weights = {
        'sharpe': 0.20,    # Reduced from 0.25
        'sortino': 0.20,   # Reduced from 0.25
        'omega': 0.15,     # Reduced from 0.20
        'momentum': 0.25,  # Increased from 0.15
        'sma': 0.15,       # Increased from 0.10
        'volatility': -0.10 # Increased penalty
    }  # Adjusted weights to favor momentum and SMA

    # Column definitions
    sharpe_cols = [f'Sharpe {days}d' for days in time_horizons]
    sortino_cols = [f'Sortino {days}d' for days in time_horizons]
    omega_cols = [f'Omega {days}d' for days in time_horizons]

    momentum_cols = ['Perf 3D %', 'Perf Week %', 'Perf Month %', 'Perf Quart %']
    
    sma_cols = ['SMA20 %', 'SMA50 %', 'SMA200 %']
    volatility_cols = ['Volatility W %', 'Volatility M %']

    # Data cleaning
    print("🧹 Cleaning dataset...")
    required_cols = (sharpe_cols + sortino_cols + omega_cols + 
                    momentum_cols + sma_cols + volatility_cols)
    clean_mask = df_data[required_cols].notna().all(axis=1)
    df_clean = df_data.loc[clean_mask].copy()

    if len(df_clean) < num_tickers:
        raise ValueError(f"Only {len(df_clean)} valid tickers after cleaning")

    # Composite score calculation
    print("🧮 Calculating composite scores...")
    def calculate_weighted_score(df):
        components = {}
        
        # Time horizon weights (for features with multiple time periods)
        horizon_weights = {
            'sharpe': [0.25, 0.20, 0.18, 0.15, 0.12, 0.10],  # 6 weights
            'sortino': [0.25, 0.20, 0.18, 0.15, 0.12, 0.10],  # 6 weights
            'omega': [0.25, 0.20, 0.18, 0.15, 0.12, 0.10]     # 6 weights
        }
        
        # Equal weights for non-time series features
        equal_weights = {
            'momentum': [0.25, 0.25, 0.25, 0.25],  # 4 weights for 4 columns
            'sma': [0.4, 0.4, 0.2],                # 3 weights for 3 columns
            'volatility': [0.6, 0.4]                # 2 weights for 2 columns
        }

        for category, cols in [('sharpe', sharpe_cols),
                              ('sortino', sortino_cols),
                              ('omega', omega_cols),
                              ('momentum', momentum_cols),
                              ('sma', sma_cols),
                              ('volatility', volatility_cols)]:
            
            # Validate columns exist
            missing_cols = [col for col in cols if col not in df.columns]
            if missing_cols:
                raise ValueError(f"Missing columns for {category}: {missing_cols}")
            
            # Calculate z-scores, e.g. z_score for tickers in column 'SMA20 %'
            z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())
            
            # # Debug: Identify the problematic category
            # print(f"\n🔍 Processing {category}:")
            # print(f"   - Columns: {cols}")
            # print(f"   - Shape: {z_scores.shape}")
            
            # Validate column/weights alignment
            if category in horizon_weights:
                weights = np.array(horizon_weights[category])
                assert len(cols) == len(weights), \
                    f"{category} has {len(cols)} cols but {len(weights)} weights!"
            else:
                weights = np.array(equal_weights[category])
                assert len(cols) == len(weights), \
                    f"{category} has {len(cols)} cols but {len(weights)} weights!"
            
            # Calculate weighted score
            weighted_z = z_scores @ weights  # compute sum of the dot product
            components[category] = weighted_z * feature_weights[category]
            
        return pd.concat(components, axis=1).sum(axis=1)

    df_clean['composite_score'] = calculate_weighted_score(df_clean)

    # Top N Selection
    print("\n" + "="*80)
    print(f"🔝 Stage 1: Top {num_tickers} Ticker Selection")
    print("="*80)
    print("\n📊 Selection Criteria for Top N:")
    print("- Weighted combination of risk-adjusted returns and momentum factors")
    print(f"- Components: Sharpe({feature_weights['sharpe']}), Sortino({feature_weights['sortino']}), Omega({feature_weights['omega']}), Momentum({feature_weights['momentum']}), SMA({feature_weights['sma']}), Volatility({feature_weights['volatility']})")
    print(f"- Time horizons: {', '.join(map(str, time_horizons))} days")

    top_n = df_clean.nlargest(num_tickers, 'composite_score')
    top_n_tickers = top_n.index.tolist()
    
    print(f"\n🏆 Top {num_tickers} Candidates (5-Column Format):")
    top_n_sorted = top_n[['composite_score']].sort_values('composite_score', ascending=False).round(2)
    for i in range(0, num_tickers, 5):
        row = []
        for j in range(5):
            try:
                idx, score = top_n_sorted.iloc[i+j].name, top_n_sorted.iloc[i+j].values[0]
                row.append(f"{idx:5} {score:4.2f}")
            except IndexError:
                break
        print(" | ".join(row))

    # Stage 2: Portfolio Optimization
    print("\n" + "="*80)
    print("📊 Stage 2: Portfolio Optimization (N → 10 Tickers)")
    print("="*80)
    print("\n🔀 Cluster-Based Selection Strategy:")
    print("1. 10 clusters from correlation patterns using Ward's method")
    print("2. 1 ticker selected per cluster regardless of size")
    print("3. Intra-cluster selection by highest risk-adjusted score")
    print("4. Diversification enforced through correlation matrix clustering")

    # Cluster analysis
    corr_subset = df_corr.loc[top_n_tickers, top_n_tickers]
    distance_matrix = 1 - np.abs(corr_subset)
    np.fill_diagonal(distance_matrix.values, 0)
    linkage_matrix = linkage(squareform(distance_matrix), method='ward')
    clusters = fcluster(linkage_matrix, t=10, criterion='maxclust')

    # Cluster dataframe construction
    cluster_df = pd.DataFrame({
        'ticker': top_n_tickers,
        'cluster': clusters,
        'score': top_n['composite_score']
    }).merge(
        df_clean[['Price', 'MktCap AUM, M', 'Volatility M %']],
        left_on='ticker',
        right_index=True
    )

    # Risk calculations
    epsilon = 1e-6
    cluster_df = cluster_df.assign(
        variance=cluster_df['ticker'].apply(lambda x: df_cov.loc[x, x]),
        risk_adj_score=lambda x: x['score'] / (np.sqrt(x['variance']) + epsilon)
    )

    # Cluster statistics
    print("\n📈 Cluster Statistics:")
    cluster_stats = cluster_df.groupby('cluster').agg(
        Size=('ticker', 'count'),
        Avg_Correlation=('ticker', lambda x: corr_subset.loc[x,x].values.mean()),
        Avg_Score=('score', 'mean'),
    ).reset_index().round(2)
    print(cluster_stats[['cluster', 'Size', 'Avg_Correlation', 'Avg_Score']].to_string(index=False))

    # Modified final selection section with generalized explanations
    print("\n" + "="*80)
    print("🎯 Final Portfolio Selection with Risk Adjustment")
    print("="*80)

    final_portfolio = []
    for cluster_id in sorted(cluster_df['cluster'].unique()):
        cluster_members = cluster_df[cluster_df['cluster'] == cluster_id].copy()
        cluster_members = cluster_members.sort_values('risk_adj_score', ascending=False)
        
        # Get top candidates by different metrics
        top_risk_adj = cluster_members.iloc[0]
        top_raw_score = cluster_members.nlargest(1, 'score').iloc[0]
        
        selected_ticker = top_risk_adj['ticker']
        final_portfolio.append(selected_ticker)
        
        # Cluster header
        print(f"\n📦 Cluster {cluster_id} ({len(cluster_members)} members):")
        print(f"   🏆 Selected: {selected_ticker} "
              f"(Raw Score: {top_risk_adj['score']:.2f}, "
              f"Risk-Adj: {top_risk_adj['risk_adj_score']:.2f}, "
              f"Volatility: {np.sqrt(top_risk_adj['variance']):.2f})")

        # Sorted member listing with line breaks
        member_details = []
        for _, row in cluster_members.iterrows():
            vol = np.sqrt(row['variance'])
            member_str = (f"{row['ticker']} (Raw: {row['score']:.4f}, "
                          f"Risk-Adj: {row['risk_adj_score']:.4f}, "
                          f"Vol: {vol:.4f})")
            member_details.append(member_str)
            
        print("   📊 Members:")
        print("      " + "\n      ".join(member_details))

    return final_portfolio

# %%
print("\n🔧 Running portfolio optimizer...")

final_portfolio = portfolio_optimizer_60days(
    df_data, 
    df_corr,
    df_cov,
    num_tickers=100,
)

print("\n✅ Execution completed. Final portfolio:")
print(final_portfolio)
# Out:
# 🔧 Running portfolio optimizer...
# ⏳ Preprocessing data...
# 🧹 Cleaning dataset...
# 🧮 Calculating composite scores...
#
# ================================================================================
# 🔝 Stage 1: Top 100 Ticker Selection
# ================================================================================
#
# 📊 Selection Criteria for Top N:
# - Weighted combination of risk-adjusted returns and momentum factors
# - Components: Sharpe(0.2), Sortino(0.2), Omega(0.15), Momentum(0.25), SMA(0.15), Volatility(-0.1)
# - Time horizons: 3, 5, 10, 15, 30, 60 days
#
# 🏆 Top 100 Candidates (5-Column Format):
# ERJ   1.84 | ABEV  1.81 | WPM   1.64 | AGI   1.62 | TTE   1.61
# MUFG  1.56 | HALO  1.46 | AEM   1.46 | GDXJ  1.45 | SHEL  1.45
# ITCI  1.45 | XPEV  1.45 | GDX   1.44 | BABA  1.36 | EBR   1.35
# BUD   1.34 | KT    1.33 | GLDM  1.32 | SGOL  1.32 | GLD   1.31
# IAU   1.31 | BBVA  1.29 | CNP   1.29 | DB    1.29 | ING   1.29
# PHYS  1.29 | SBS   1.26 | NEM   1.25 | FXI   1.25 | ITUB  1.25
# INTC  1.24 | TRP   1.23 | HESM  1.23 | PAAS  1.19 | VOD   1.18
# EWZ   1.18 | IBN   1.17 | MCHI  1.17 | SAN   1.17 | SCCO  1.15
# FNDE  1.13 | OKTA  1.10 | YMM   1.09 | SPOT  1.08 | HII   1.07
# MT    1.05 | CCI   1.05 | AR    1.05 | ETR   1.01 | BTI   0.98
# PGR   0.97 | EVRG  0.97 | BEKE  0.96 | ED    0.95 | EXE   0.94
# FCX   0.94 | BRO   0.93 | MO    0.92 | PCG   0.92 | SMFG  0.92
# MFG   0.91 | FNF   0.91 | TECK  0.91 | BRK-B 0.91 | ALL   0.91
# AZN   0.90 | NOK   0.89 | HMY   0.89 | KMI   0.89 | AES   0.88
# AU    0.88 | DTE   0.87 | GSK   0.87 | JD    0.86 | PUK   0.86
# EXC   0.85 | ELV   0.85 | VRTX  0.85 | HMC   0.85 | BBD   0.84
# TAK   0.84 | AIG   0.84 | AWK   0.83 | MCK   0.82 | ADC   0.82
# RKT   0.82 | AMT   0.81 | BP    0.81 | GOLD  0.80 | LYG   0.80
# PDD   0.80 | CB    0.79 | DUK   0.79 | VIV   0.78 | EC    0.78
# OKE   0.77 | SLV   0.76 | RIO   0.76 | GFI   0.76 | FUTU  0.74
#
# ================================================================================
# 📊 Stage 2: Portfolio Optimization (N → 10 Tickers)
# ================================================================================
#
# 🔀 Cluster-Based Selection Strategy:
# 1. 10 clusters from correlation patterns using Ward's method
# 2. 1 ticker selected per cluster regardless of size
# 3. Intra-cluster selection by highest risk-adjusted score
# 4. Diversification enforced through correlation matrix clustering
#
# 📈 Cluster Statistics:
#  cluster  Size  Avg_Correlation  Avg_Score
#        1     8           0.6400     0.9500
#        2    12           0.5800     0.8800
#        3     4           0.6600     1.1000
#        4     8           0.6000     0.9700
#        5     3           0.6100     1.5700
#        6    11           0.0900     1.0800
#        7    17           0.7400     1.2200
#        8    22           0.6400     1.0500
#        9     9           0.7400     1.1200
#       10     6           0.5800     1.1400
#
# ================================================================================
# 🎯 Final Portfolio Selection with Risk Adjustment
# ================================================================================
#
# 📦 Cluster 1 (8 members):
#    🏆 Selected: CNP (Raw Score: 1.29, Risk-Adj: 106.38, Volatility: 0.01)
#    📊 Members:
#       CNP (Raw: 1.2934, Risk-Adj: 106.3801, Vol: 0.0122)
#       PGR (Raw: 0.9711, Risk-Adj: 93.8526, Vol: 0.0103)
#       DTE (Raw: 0.8666, Risk-Adj: 83.8449, Vol: 0.0103)
#       BRK-B (Raw: 0.9111, Risk-Adj: 72.6486, Vol: 0.0125)
#       ALL (Raw: 0.9075, Risk-Adj: 58.2585, Vol: 0.0156)
#       AIG (Raw: 0.8379, Risk-Adj: 56.2367, Vol: 0.0149)
#       CB (Raw: 0.7896, Risk-Adj: 55.6952, Vol: 0.0142)
#       CCI (Raw: 1.0468, Risk-Adj: 33.5401, Vol: 0.0312)
#
# 📦 Cluster 2 (12 members):
#    🏆 Selected: BRO (Raw Score: 0.93, Risk-Adj: 110.39, Volatility: 0.01)
#    📊 Members:
#       BRO (Raw: 0.9258, Risk-Adj: 110.3890, Vol: 0.0084)
#       TAK (Raw: 0.8402, Risk-Adj: 81.3440, Vol: 0.0103)
#       ADC (Raw: 0.8240, Risk-Adj: 79.4656, Vol: 0.0104)
#       MO (Raw: 0.9245, Risk-Adj: 74.5762, Vol: 0.0124)
#       DUK (Raw: 0.7881, Risk-Adj: 70.1878, Vol: 0.0112)
#       EXC (Raw: 0.8543, Risk-Adj: 69.9279, Vol: 0.0122)
#       VOD (Raw: 1.1775, Risk-Adj: 69.1180, Vol: 0.0170)
#       MCK (Raw: 0.8247, Risk-Adj: 64.8224, Vol: 0.0127)
#       GSK (Raw: 0.8664, Risk-Adj: 59.5668, Vol: 0.0145)
#       ED (Raw: 0.9532, Risk-Adj: 57.2647, Vol: 0.0166)
#       AMT (Raw: 0.8125, Risk-Adj: 51.8750, Vol: 0.0157)
#       AWK (Raw: 0.8256, Risk-Adj: 40.2585, Vol: 0.0205)
#
# 📦 Cluster 3 (4 members):
#    🏆 Selected: IBN (Raw Score: 1.17, Risk-Adj: 116.97, Volatility: 0.01)
#    📊 Members:
#       IBN (Raw: 1.1667, Risk-Adj: 116.9717, Vol: 0.0100)
#       TRP (Raw: 1.2309, Risk-Adj: 113.5316, Vol: 0.0108)
#       EXE (Raw: 0.9430, Risk-Adj: 49.8319, Vol: 0.0189)
#       AR (Raw: 1.0462, Risk-Adj: 39.6310, Vol: 0.0264)
#
# 📦 Cluster 4 (8 members):
#    🏆 Selected: EVRG (Raw Score: 0.97, Risk-Adj: 100.46, Volatility: 0.01)
#    📊 Members:
#       EVRG (Raw: 0.9692, Risk-Adj: 100.4567, Vol: 0.0096)
#       HESM (Raw: 1.2277, Risk-Adj: 84.0941, Vol: 0.0146)
#       KMI (Raw: 0.8899, Risk-Adj: 68.4301, Vol: 0.0130)
#       PCG (Raw: 0.9225, Risk-Adj: 60.6558, Vol: 0.0152)
#       FNF (Raw: 0.9126, Risk-Adj: 57.9368, Vol: 0.0157)
#       ETR (Raw: 1.0142, Risk-Adj: 56.4951, Vol: 0.0180)
#       OKE (Raw: 0.7718, Risk-Adj: 41.4466, Vol: 0.0186)
#       SPOT (Raw: 1.0764, Risk-Adj: 26.6338, Vol: 0.0404)
#
# 📦 Cluster 5 (3 members):
#    🏆 Selected: ABEV (Raw Score: 1.81, Risk-Adj: 96.02, Volatility: 0.02)
#    📊 Members:
#       ABEV (Raw: 1.8117, Risk-Adj: 96.0226, Vol: 0.0189)
#       ERJ (Raw: 1.8412, Risk-Adj: 63.7686, Vol: 0.0289)
#       HII (Raw: 1.0682, Risk-Adj: 31.6485, Vol: 0.0338)
#
# 📦 Cluster 6 (11 members):
#    🏆 Selected: ITCI (Raw Score: 1.45, Risk-Adj: 95.96, Volatility: 0.02)
#    📊 Members:
#       ITCI (Raw: 1.4467, Risk-Adj: 95.9599, Vol: 0.0151)
#       BUD (Raw: 1.3433, Risk-Adj: 88.7511, Vol: 0.0151)
#       BTI (Raw: 0.9754, Risk-Adj: 77.2048, Vol: 0.0126)
#       AZN (Raw: 0.9013, Risk-Adj: 73.4439, Vol: 0.0123)
#       VRTX (Raw: 0.8514, Risk-Adj: 63.4353, Vol: 0.0134)
#       ELV (Raw: 0.8532, Risk-Adj: 51.1385, Vol: 0.0167)
#       LYG (Raw: 0.7980, Risk-Adj: 33.8088, Vol: 0.0236)
#       AES (Raw: 0.8842, Risk-Adj: 28.2722, Vol: 0.0313)
#       XPEV (Raw: 1.4450, Risk-Adj: 24.6022, Vol: 0.0587)
#       INTC (Raw: 1.2447, Risk-Adj: 23.4512, Vol: 0.0531)
#       OKTA (Raw: 1.0978, Risk-Adj: 19.4493, Vol: 0.0564)
#
# 📦 Cluster 7 (17 members):
#    🏆 Selected: PHYS (Raw Score: 1.29, Risk-Adj: 173.92, Volatility: 0.01)
#    📊 Members:
#       PHYS (Raw: 1.2878, Risk-Adj: 173.9196, Vol: 0.0074)
#       GLDM (Raw: 1.3238, Risk-Adj: 158.6979, Vol: 0.0083)
#       SGOL (Raw: 1.3184, Risk-Adj: 157.3962, Vol: 0.0084)
#       IAU (Raw: 1.3085, Risk-Adj: 156.0932, Vol: 0.0084)
#       GLD (Raw: 1.3129, Risk-Adj: 155.4579, Vol: 0.0084)
#       WPM (Raw: 1.6351, Risk-Adj: 110.8873, Vol: 0.0147)
#       AEM (Raw: 1.4594, Risk-Adj: 81.1278, Vol: 0.0180)
#       GDX (Raw: 1.4352, Risk-Adj: 76.5050, Vol: 0.0188)
#       AGI (Raw: 1.6240, Risk-Adj: 75.6815, Vol: 0.0215)
#       GDXJ (Raw: 1.4503, Risk-Adj: 61.0779, Vol: 0.0237)
#       SLV (Raw: 0.7586, Risk-Adj: 57.8506, Vol: 0.0131)
#       NEM (Raw: 1.2503, Risk-Adj: 54.4419, Vol: 0.0230)
#       GOLD (Raw: 0.8019, Risk-Adj: 45.3571, Vol: 0.0177)
#       PAAS (Raw: 1.1864, Risk-Adj: 43.9911, Vol: 0.0270)
#       AU (Raw: 0.8823, Risk-Adj: 36.2876, Vol: 0.0243)
#       GFI (Raw: 0.7565, Risk-Adj: 30.2027, Vol: 0.0250)
#       HMY (Raw: 0.8943, Risk-Adj: 25.4803, Vol: 0.0351)
#
# 📦 Cluster 8 (22 members):
#    🏆 Selected: FNDE (Raw Score: 1.13, Risk-Adj: 99.88, Volatility: 0.01)
#    📊 Members:
#       FNDE (Raw: 1.1301, Risk-Adj: 99.8832, Vol: 0.0113)
#       KT (Raw: 1.3285, Risk-Adj: 94.2023, Vol: 0.0141)
#       FXI (Raw: 1.2487, Risk-Adj: 66.5644, Vol: 0.0188)
#       ING (Raw: 1.2881, Risk-Adj: 63.8966, Vol: 0.0202)
#       BBVA (Raw: 1.2943, Risk-Adj: 61.9436, Vol: 0.0209)
#       MCHI (Raw: 1.1666, Risk-Adj: 60.5410, Vol: 0.0193)
#       HMC (Raw: 0.8480, Risk-Adj: 50.9461, Vol: 0.0166)
#       SCCO (Raw: 1.1477, Risk-Adj: 49.9703, Vol: 0.0230)
#       SAN (Raw: 1.1664, Risk-Adj: 46.5291, Vol: 0.0251)
#       NOK (Raw: 0.8947, Risk-Adj: 46.3306, Vol: 0.0193)
#       PUK (Raw: 0.8561, Risk-Adj: 42.9855, Vol: 0.0199)
#       BABA (Raw: 1.3629, Risk-Adj: 36.9721, Vol: 0.0369)
#       DB (Raw: 1.2888, Risk-Adj: 36.6391, Vol: 0.0352)
#       YMM (Raw: 1.0926, Risk-Adj: 29.6791, Vol: 0.0368)
#       TECK (Raw: 0.9123, Risk-Adj: 29.2498, Vol: 0.0312)
#       PDD (Raw: 0.7976, Risk-Adj: 28.2822, Vol: 0.0282)
#       FCX (Raw: 0.9421, Risk-Adj: 27.9236, Vol: 0.0337)
#       MT (Raw: 1.0468, Risk-Adj: 27.5434, Vol: 0.0380)
#       JD (Raw: 0.8636, Risk-Adj: 25.6754, Vol: 0.0336)
#       BEKE (Raw: 0.9634, Risk-Adj: 22.2896, Vol: 0.0432)
#       RKT (Raw: 0.8161, Risk-Adj: 14.4835, Vol: 0.0563)
#       FUTU (Raw: 0.7356, Risk-Adj: 13.6091, Vol: 0.0541)
#
# 📦 Cluster 9 (9 members):
#    🏆 Selected: EBR (Raw Score: 1.35, Risk-Adj: 96.23, Volatility: 0.01)
#    📊 Members:
#       EBR (Raw: 1.3470, Risk-Adj: 96.2266, Vol: 0.0140)
#       MUFG (Raw: 1.5650, Risk-Adj: 90.5573, Vol: 0.0173)
#       SBS (Raw: 1.2611, Risk-Adj: 83.4635, Vol: 0.0151)
#       EWZ (Raw: 1.1774, Risk-Adj: 67.3613, Vol: 0.0175)
#       ITUB (Raw: 1.2463, Risk-Adj: 66.8084, Vol: 0.0187)
#       SMFG (Raw: 0.9212, Risk-Adj: 57.3883, Vol: 0.0161)
#       MFG (Raw: 0.9148, Risk-Adj: 50.9419, Vol: 0.0180)
#       VIV (Raw: 0.7827, Risk-Adj: 39.1050, Vol: 0.0200)
#       BBD (Raw: 0.8428, Risk-Adj: 35.7370, Vol: 0.0236)
#
# 📦 Cluster 10 (6 members):
#    🏆 Selected: TTE (Raw Score: 1.61, Risk-Adj: 201.66, Volatility: 0.01)
#    📊 Members:
#       TTE (Raw: 1.6092, Risk-Adj: 201.6558, Vol: 0.0080)
#       SHEL (Raw: 1.4477, Risk-Adj: 169.5739, Vol: 0.0085)
#       HALO (Raw: 1.4626, Risk-Adj: 130.8058, Vol: 0.0112)
#       RIO (Raw: 0.7581, Risk-Adj: 53.9553, Vol: 0.0140)
#       BP (Raw: 0.8087, Risk-Adj: 51.4106, Vol: 0.0157)
#       EC (Raw: 0.7805, Risk-Adj: 31.6369, Vol: 0.0247)
#
# ✅ Execution completed. Final portfolio:
# ['CNP', 'BRO', 'IBN', 'EVRG', 'ABEV', 'ITCI', 'PHYS', 'FNDE', 'EBR', 'TTE']

# %%
print("\n🔧 Running portfolio optimizer...")

final_portfolio = portfolio_optimizer_60days(
    df_data, 
    df_corr,
    df_cov,
    num_tickers=200,
)

print("\n✅ Execution completed. Final portfolio:")
print(final_portfolio)
# Out:
# 🔧 Running portfolio optimizer...
# ⏳ Preprocessing data...
# 🧹 Cleaning dataset...
# 🧮 Calculating composite scores...
#
# ================================================================================
# 🔝 Stage 1: Top 200 Ticker Selection
# ================================================================================
#
# 📊 Selection Criteria for Top N:
# - Weighted combination of risk-adjusted returns and momentum factors
# - Components: Sharpe(0.2), Sortino(0.2), Omega(0.15), Momentum(0.25), SMA(0.15), Volatility(-0.1)
# - Time horizons: 3, 5, 10, 15, 30, 60 days
#
# 🏆 Top 200 Candidates (5-Column Format):
# ERJ   1.84 | ABEV  1.81 | WPM   1.64 | AGI   1.62 | TTE   1.61
# MUFG  1.56 | HALO  1.46 | AEM   1.46 | GDXJ  1.45 | SHEL  1.45
# ITCI  1.45 | XPEV  1.45 | GDX   1.44 | BABA  1.36 | EBR   1.35
# CI    0.44 | ES    0.44 | MMC   0.43 | WAB   0.43 | AFL   0.43
# KLAC  0.42 | BOXX  0.42 | BCS   0.42 | X     0.42 | HTHT  0.42
# RRC   0.41 | RPRX  0.41 | YUM   0.41 | SCHE  0.41 | GD    0.41
#
# ================================================================================
# 📊 Stage 2: Portfolio Optimization (N → 10 Tickers)
# ================================================================================
#
# 🔀 Cluster-Based Selection Strategy:
# 1. 10 clusters from correlation patterns using Ward's method
# 2. 1 ticker selected per cluster regardless of size
# 3. Intra-cluster selection by highest risk-adjusted score
# 4. Diversification enforced through correlation matrix clustering
#
# 📈 Cluster Statistics:
#  cluster  Size  Avg_Correlation  Avg_Score
#        1    28           0.6000     0.6900
#        2    16           0.7000     0.7000
#        3    16           0.5600     0.7100
#        4    43           0.6000     0.6900
#        5    18           0.7200     0.9400
#        6    16           0.5000     1.0700
#        7    18           0.7400     1.1900
#        8    23           0.0800     0.7300
#        9    10           0.5500     0.9000
#       10    12           0.5200     0.7700
#
# ================================================================================
# 🎯 Final Portfolio Selection with Risk Adjustment
# ================================================================================
#
# 📦 Cluster 1 (28 members):
#    🏆 Selected: ICSH (Raw Score: 0.50, Risk-Adj: 1697.98, Volatility: 0.00)
#    📊 Members:
#       ICSH (Raw: 0.4995, Risk-Adj: 1697.9750, Vol: 0.0003)
#       BRO (Raw: 0.9258, Risk-Adj: 110.3890, Vol: 0.0084)
#       ADC (Raw: 0.8240, Risk-Adj: 79.4656, Vol: 0.0104)
#       MO (Raw: 0.9245, Risk-Adj: 74.5762, Vol: 0.0124)
#       DUK (Raw: 0.7881, Risk-Adj: 70.1878, Vol: 0.0112)
#       EXC (Raw: 0.8543, Risk-Adj: 69.9279, Vol: 0.0122)
#       VOD (Raw: 1.1775, Risk-Adj: 69.1180, Vol: 0.0170)
#       MCK (Raw: 0.8247, Risk-Adj: 64.8224, Vol: 0.0127)
#       ABBV (Raw: 0.6765, Risk-Adj: 60.9418, Vol: 0.0111)
#       GSK (Raw: 0.8664, Risk-Adj: 59.5668, Vol: 0.0145)
#       ED (Raw: 0.9532, Risk-Adj: 57.2647, Vol: 0.0166)
#       COR (Raw: 0.6570, Risk-Adj: 51.9066, Vol: 0.0127)
#       AMT (Raw: 0.8125, Risk-Adj: 51.8750, Vol: 0.0157)
#       MMC (Raw: 0.4304, Risk-Adj: 50.5994, Vol: 0.0085)
#       CMS (Raw: 0.6032, Risk-Adj: 48.0562, Vol: 0.0126)
#       WEC (Raw: 0.6302, Risk-Adj: 42.9991, Vol: 0.0147)
#       CME (Raw: 0.5237, Risk-Adj: 42.9617, Vol: 0.0122)
#       AWK (Raw: 0.8256, Risk-Adj: 40.2585, Vol: 0.0205)
#       AMGN (Raw: 0.5614, Risk-Adj: 38.4244, Vol: 0.0146)
#       AEP (Raw: 0.5790, Risk-Adj: 38.1298, Vol: 0.0152)
#       SO (Raw: 0.5588, Risk-Adj: 37.7863, Vol: 0.0148)
#       WTRG (Raw: 0.6396, Risk-Adj: 37.7295, Vol: 0.0169)
#       MDT (Raw: 0.5362, Risk-Adj: 37.4418, Vol: 0.0143)
#       ZBH (Raw: 0.6023, Risk-Adj: 30.8055, Vol: 0.0196)
#       T (Raw: 0.5797, Risk-Adj: 29.3814, Vol: 0.0197)
#       OHI (Raw: 0.4869, Risk-Adj: 27.5932, Vol: 0.0176)
#       CI (Raw: 0.4372, Risk-Adj: 26.0237, Vol: 0.0168)
#       ES (Raw: 0.4359, Risk-Adj: 23.7943, Vol: 0.0183)
#
# 📦 Cluster 2 (16 members):
#    🏆 Selected: PGR (Raw Score: 0.97, Risk-Adj: 93.85, Volatility: 0.01)
#    📊 Members:
#       PGR (Raw: 0.9711, Risk-Adj: 93.8526, Vol: 0.0103)
#       BRK-B (Raw: 0.9111, Risk-Adj: 72.6486, Vol: 0.0125)
#       ICE (Raw: 0.6565, Risk-Adj: 72.4486, Vol: 0.0091)
#       HIG (Raw: 0.6737, Risk-Adj: 58.2610, Vol: 0.0116)
#       ALL (Raw: 0.9075, Risk-Adj: 58.2585, Vol: 0.0156)
#       FNF (Raw: 0.9126, Risk-Adj: 57.9368, Vol: 0.0157)
#       AIG (Raw: 0.8379, Risk-Adj: 56.2367, Vol: 0.0149)
#       TRV (Raw: 0.7242, Risk-Adj: 55.9250, Vol: 0.0129)
#       CB (Raw: 0.7896, Risk-Adj: 55.6952, Vol: 0.0142)
#       L (Raw: 0.5541, Risk-Adj: 51.8320, Vol: 0.0107)
#       WRB (Raw: 0.5962, Risk-Adj: 47.9790, Vol: 0.0124)
#       RTX (Raw: 0.5885, Risk-Adj: 46.9785, Vol: 0.0125)
#       ORI (Raw: 0.5499, Risk-Adj: 45.0908, Vol: 0.0122)
#       CINF (Raw: 0.6466, Risk-Adj: 42.9374, Vol: 0.0151)
#       ACGL (Raw: 0.5108, Risk-Adj: 41.0666, Vol: 0.0124)
#       AFL (Raw: 0.4278, Risk-Adj: 33.1851, Vol: 0.0129)
#
# 📦 Cluster 3 (16 members):
#    🏆 Selected: VUSB (Raw Score: 0.50, Risk-Adj: 1111.29, Volatility: 0.00)
#    📊 Members:
#       VUSB (Raw: 0.4953, Risk-Adj: 1111.2934, Vol: 0.0004)
#       CNP (Raw: 1.2934, Risk-Adj: 106.3801, Vol: 0.0122)
#       EVRG (Raw: 0.9692, Risk-Adj: 100.4567, Vol: 0.0096)
#       DTE (Raw: 0.8666, Risk-Adj: 83.8449, Vol: 0.0103)
#       PNW (Raw: 0.6996, Risk-Adj: 61.1084, Vol: 0.0114)
#       PCG (Raw: 0.9225, Risk-Adj: 60.6558, Vol: 0.0152)
#       OGE (Raw: 0.6002, Risk-Adj: 57.5221, Vol: 0.0104)
#       ETR (Raw: 1.0142, Risk-Adj: 56.4951, Vol: 0.0180)
#       PPL (Raw: 0.5731, Risk-Adj: 46.0566, Vol: 0.0124)
#       AEE (Raw: 0.5622, Risk-Adj: 46.0293, Vol: 0.0122)
#       TW (Raw: 0.5818, Risk-Adj: 42.4589, Vol: 0.0137)
#       LNT (Raw: 0.4604, Risk-Adj: 39.7014, Vol: 0.0116)
#       XLU (Raw: 0.4518, Risk-Adj: 39.2265, Vol: 0.0115)
#       PBA (Raw: 0.5646, Risk-Adj: 37.3231, Vol: 0.0151)
#       MNST (Raw: 0.4863, Risk-Adj: 32.2095, Vol: 0.0151)
#       AES (Raw: 0.8842, Risk-Adj: 28.2722, Vol: 0.0313)
#
# 📦 Cluster 4 (43 members):
#    🏆 Selected: BOXX (Raw Score: 0.42, Risk-Adj: 1846.14, Volatility: 0.00)
#    📊 Members:
#       BOXX (Raw: 0.4220, Risk-Adj: 1846.1395, Vol: 0.0002)
#       BUD (Raw: 1.3433, Risk-Adj: 88.7511, Vol: 0.0151)
#       EWU (Raw: 0.7255, Risk-Adj: 75.5141, Vol: 0.0096)
#       EFV (Raw: 0.7064, Risk-Adj: 74.0775, Vol: 0.0095)
#       AZN (Raw: 0.9013, Risk-Adj: 73.4439, Vol: 0.0123)
#       ING (Raw: 1.2881, Risk-Adj: 63.8966, Vol: 0.0202)
#       BBVA (Raw: 1.2943, Risk-Adj: 61.9436, Vol: 0.0209)
#       DFIV (Raw: 0.6363, Risk-Adj: 60.9062, Vol: 0.0104)
#       VRSN (Raw: 0.6174, Risk-Adj: 59.6147, Vol: 0.0104)
#       FNDF (Raw: 0.5434, Risk-Adj: 54.0874, Vol: 0.0100)
#       HMC (Raw: 0.8480, Risk-Adj: 50.9461, Vol: 0.0166)
#       DFIC (Raw: 0.5056, Risk-Adj: 48.5437, Vol: 0.0104)
#       DFAX (Raw: 0.4756, Risk-Adj: 48.3004, Vol: 0.0098)
#       SAN (Raw: 1.1664, Risk-Adj: 46.5291, Vol: 0.0251)
#       NOK (Raw: 0.8947, Risk-Adj: 46.3306, Vol: 0.0193)
#       SCZ (Raw: 0.4730, Risk-Adj: 44.5209, Vol: 0.0106)
#       EZU (Raw: 0.6105, Risk-Adj: 43.7257, Vol: 0.0140)
#       IEUR (Raw: 0.5185, Risk-Adj: 43.4162, Vol: 0.0119)
#       PUK (Raw: 0.8561, Risk-Adj: 42.9855, Vol: 0.0199)
#       DFAI (Raw: 0.4374, Risk-Adj: 42.2903, Vol: 0.0103)
#       VGK (Raw: 0.5120, Risk-Adj: 42.1101, Vol: 0.0122)
#       IEFA (Raw: 0.4527, Risk-Adj: 41.4177, Vol: 0.0109)
#       EFA (Raw: 0.4497, Risk-Adj: 40.7967, Vol: 0.0110)
#       FEZ (Raw: 0.5400, Risk-Adj: 38.0784, Vol: 0.0142)
#       DB (Raw: 1.2888, Risk-Adj: 36.6391, Vol: 0.0352)
#       YUMC (Raw: 0.7104, Risk-Adj: 34.4137, Vol: 0.0206)
#       LYG (Raw: 0.7980, Risk-Adj: 33.8088, Vol: 0.0236)
#       CCI (Raw: 1.0468, Risk-Adj: 33.5401, Vol: 0.0312)
#       HSBC (Raw: 0.5405, Risk-Adj: 30.6519, Vol: 0.0176)
#       SPOT (Raw: 1.0764, Risk-Adj: 26.6338, Vol: 0.0404)
#       YUM (Raw: 0.4105, Risk-Adj: 26.3572, Vol: 0.0156)
#       UMC (Raw: 0.5281, Risk-Adj: 24.4499, Vol: 0.0216)
#       CHKP (Raw: 0.4431, Risk-Adj: 22.3503, Vol: 0.0198)
#       HTHT (Raw: 0.4164, Risk-Adj: 21.7721, Vol: 0.0191)
#       SONY (Raw: 0.4680, Risk-Adj: 21.7408, Vol: 0.0215)
#       OKTA (Raw: 1.0978, Risk-Adj: 19.4493, Vol: 0.0564)
#       NWG (Raw: 0.4784, Risk-Adj: 18.3494, Vol: 0.0261)
#       KLAC (Raw: 0.4222, Risk-Adj: 15.9681, Vol: 0.0264)
#       PWR (Raw: 0.4406, Risk-Adj: 15.1315, Vol: 0.0291)
#       MU (Raw: 0.6079, Risk-Adj: 14.4984, Vol: 0.0419)
#       RKT (Raw: 0.8161, Risk-Adj: 14.4835, Vol: 0.0563)
#       BCS (Raw: 0.4219, Risk-Adj: 14.2119, Vol: 0.0297)
#       NVDL (Raw: 0.4407, Risk-Adj: 5.3278, Vol: 0.0827)
#
# 📦 Cluster 5 (18 members):
#    🏆 Selected: FNDE (Raw Score: 1.13, Risk-Adj: 99.88, Volatility: 0.01)
#    📊 Members:
#       FNDE (Raw: 1.1301, Risk-Adj: 99.8832, Vol: 0.0113)
#       KT (Raw: 1.3285, Risk-Adj: 94.2023, Vol: 0.0141)
#       FXI (Raw: 1.2487, Risk-Adj: 66.5644, Vol: 0.0188)
#       MCHI (Raw: 1.1666, Risk-Adj: 60.5410, Vol: 0.0193)
#       SCCO (Raw: 1.1477, Risk-Adj: 49.9703, Vol: 0.0230)
#       BABA (Raw: 1.3629, Risk-Adj: 36.9721, Vol: 0.0369)
#       SCHE (Raw: 0.4098, Risk-Adj: 35.6050, Vol: 0.0115)
#       YMM (Raw: 1.0926, Risk-Adj: 29.6791, Vol: 0.0368)
#       TECK (Raw: 0.9123, Risk-Adj: 29.2498, Vol: 0.0312)
#       PDD (Raw: 0.7976, Risk-Adj: 28.2822, Vol: 0.0282)
#       FCX (Raw: 0.9421, Risk-Adj: 27.9236, Vol: 0.0337)
#       MT (Raw: 1.0468, Risk-Adj: 27.5434, Vol: 0.0380)
#       KWEB (Raw: 0.6861, Risk-Adj: 26.0029, Vol: 0.0264)
#       JD (Raw: 0.8636, Risk-Adj: 25.6754, Vol: 0.0336)
#       BEKE (Raw: 0.9634, Risk-Adj: 22.2896, Vol: 0.0432)
#       VALE (Raw: 0.5146, Risk-Adj: 21.1025, Vol: 0.0244)
#       FUTU (Raw: 0.7356, Risk-Adj: 13.6091, Vol: 0.0541)
#       MSTR (Raw: 0.4895, Risk-Adj: 6.4627, Vol: 0.0757)
#
# 📦 Cluster 6 (16 members):
#    🏆 Selected: EBR (Raw Score: 1.35, Risk-Adj: 96.23, Volatility: 0.01)
#    📊 Members:
#       EBR (Raw: 1.3470, Risk-Adj: 96.2266, Vol: 0.0140)
#       ABEV (Raw: 1.8117, Risk-Adj: 96.0226, Vol: 0.0189)
#       MUFG (Raw: 1.5650, Risk-Adj: 90.5573, Vol: 0.0173)
#       SBS (Raw: 1.2611, Risk-Adj: 83.4635, Vol: 0.0151)
#       EWZ (Raw: 1.1774, Risk-Adj: 67.3613, Vol: 0.0175)
#       ITUB (Raw: 1.2463, Risk-Adj: 66.8084, Vol: 0.0187)
#       ERJ (Raw: 1.8412, Risk-Adj: 63.7686, Vol: 0.0289)
#       SMFG (Raw: 0.9212, Risk-Adj: 57.3883, Vol: 0.0161)
#       MFG (Raw: 0.9148, Risk-Adj: 50.9419, Vol: 0.0180)
#       VIV (Raw: 0.7827, Risk-Adj: 39.1050, Vol: 0.0200)
#       BBD (Raw: 0.8428, Risk-Adj: 35.7370, Vol: 0.0236)
#       MOS (Raw: 0.7241, Risk-Adj: 32.7185, Vol: 0.0221)
#       HII (Raw: 1.0682, Risk-Adj: 31.6485, Vol: 0.0338)
#       ICL (Raw: 0.6655, Risk-Adj: 28.9249, Vol: 0.0230)
#       GD (Raw: 0.4095, Risk-Adj: 25.2039, Vol: 0.0162)
#       PBR-A (Raw: 0.4902, Risk-Adj: 24.3741, Vol: 0.0201)
#
# 📦 Cluster 7 (18 members):
#    🏆 Selected: PHYS (Raw Score: 1.29, Risk-Adj: 173.92, Volatility: 0.01)
#    📊 Members:
#       PHYS (Raw: 1.2878, Risk-Adj: 173.9196, Vol: 0.0074)
#       GLDM (Raw: 1.3238, Risk-Adj: 158.6979, Vol: 0.0083)
#       SGOL (Raw: 1.3184, Risk-Adj: 157.3962, Vol: 0.0084)
#       IAU (Raw: 1.3085, Risk-Adj: 156.0932, Vol: 0.0084)
#       GLD (Raw: 1.3129, Risk-Adj: 155.4579, Vol: 0.0084)
#       WPM (Raw: 1.6351, Risk-Adj: 110.8873, Vol: 0.0147)
#       AEM (Raw: 1.4594, Risk-Adj: 81.1278, Vol: 0.0180)
#       GDX (Raw: 1.4352, Risk-Adj: 76.5050, Vol: 0.0188)
#       AGI (Raw: 1.6240, Risk-Adj: 75.6815, Vol: 0.0215)
#       GDXJ (Raw: 1.4503, Risk-Adj: 61.0779, Vol: 0.0237)
#       SLV (Raw: 0.7586, Risk-Adj: 57.8506, Vol: 0.0131)
#       NEM (Raw: 1.2503, Risk-Adj: 54.4419, Vol: 0.0230)
#       GOLD (Raw: 0.8019, Risk-Adj: 45.3571, Vol: 0.0177)
#       PAAS (Raw: 1.1864, Risk-Adj: 43.9911, Vol: 0.0270)
#       AU (Raw: 0.8823, Risk-Adj: 36.2876, Vol: 0.0243)
#       GFI (Raw: 0.7565, Risk-Adj: 30.2027, Vol: 0.0250)
#       HMY (Raw: 0.8943, Risk-Adj: 25.4803, Vol: 0.0351)
#       KGC (Raw: 0.7078, Risk-Adj: 25.3580, Vol: 0.0279)
#
# 📦 Cluster 8 (23 members):
#    🏆 Selected: BIL (Raw Score: 0.51, Risk-Adj: 5019.44, Volatility: 0.00)
#    📊 Members:
#       BIL (Raw: 0.5060, Risk-Adj: 5019.4396, Vol: 0.0001)
#       SGOV (Raw: 0.5507, Risk-Adj: 4496.3430, Vol: 0.0001)
#       TBIL (Raw: 0.4793, Risk-Adj: 2598.9769, Vol: 0.0002)
#       IBN (Raw: 1.1667, Risk-Adj: 116.9717, Vol: 0.0100)
#       ITCI (Raw: 1.4467, Risk-Adj: 95.9599, Vol: 0.0151)
#       TAK (Raw: 0.8402, Risk-Adj: 81.3440, Vol: 0.0103)
#       BTI (Raw: 0.9754, Risk-Adj: 77.2048, Vol: 0.0126)
#       VRTX (Raw: 0.8514, Risk-Adj: 63.4353, Vol: 0.0134)
#       ELV (Raw: 0.8532, Risk-Adj: 51.1385, Vol: 0.0167)
#       SNY (Raw: 0.6360, Risk-Adj: 48.6491, Vol: 0.0131)
#       RPRX (Raw: 0.4125, Risk-Adj: 39.2799, Vol: 0.0105)
#       EA (Raw: 0.6143, Risk-Adj: 35.8369, Vol: 0.0171)
#       JAZZ (Raw: 0.5503, Risk-Adj: 34.5839, Vol: 0.0159)
#       PM (Raw: 0.4487, Risk-Adj: 30.2049, Vol: 0.0149)
#       PARA (Raw: 0.5128, Risk-Adj: 29.3655, Vol: 0.0175)
#       CVS (Raw: 0.5989, Risk-Adj: 28.5984, Vol: 0.0209)
#       XPEV (Raw: 1.4450, Risk-Adj: 24.6022, Vol: 0.0587)
#       AER (Raw: 0.4842, Risk-Adj: 24.5101, Vol: 0.0198)
#       INTC (Raw: 1.2447, Risk-Adj: 23.4512, Vol: 0.0531)
#       LUV (Raw: 0.5981, Risk-Adj: 21.8273, Vol: 0.0274)
#       BA (Raw: 0.4874, Risk-Adj: 18.9481, Vol: 0.0257)
#       X (Raw: 0.4195, Risk-Adj: 15.2629, Vol: 0.0275)
#       WBA (Raw: 0.5558, Risk-Adj: 15.0060, Vol: 0.0370)
#
# 📦 Cluster 9 (10 members):
#    🏆 Selected: TTE (Raw Score: 1.61, Risk-Adj: 201.66, Volatility: 0.01)
#    📊 Members:
#       TTE (Raw: 1.6092, Risk-Adj: 201.6558, Vol: 0.0080)
#       SHEL (Raw: 1.4477, Risk-Adj: 169.5739, Vol: 0.0085)
#       HALO (Raw: 1.4626, Risk-Adj: 130.8058, Vol: 0.0112)
#       GUNR (Raw: 0.6820, Risk-Adj: 78.8704, Vol: 0.0086)
#       RIO (Raw: 0.7581, Risk-Adj: 53.9553, Vol: 0.0140)
#       BP (Raw: 0.8087, Risk-Adj: 51.4106, Vol: 0.0157)
#       CVX (Raw: 0.4993, Risk-Adj: 34.3598, Vol: 0.0145)
#       EC (Raw: 0.7805, Risk-Adj: 31.6369, Vol: 0.0247)
#       EQNR (Raw: 0.5417, Risk-Adj: 27.3363, Vol: 0.0198)
#       CTRA (Raw: 0.4479, Risk-Adj: 23.7839, Vol: 0.0188)
#
# 📦 Cluster 10 (12 members):
#    🏆 Selected: TRP (Raw Score: 1.23, Risk-Adj: 113.53, Volatility: 0.01)
#    📊 Members:
#       TRP (Raw: 1.2309, Risk-Adj: 113.5316, Vol: 0.0108)
#       HESM (Raw: 1.2277, Risk-Adj: 84.0941, Vol: 0.0146)
#       KMI (Raw: 0.8899, Risk-Adj: 68.4301, Vol: 0.0130)
#       EXE (Raw: 0.9430, Risk-Adj: 49.8319, Vol: 0.0189)
#       OKE (Raw: 0.7718, Risk-Adj: 41.4466, Vol: 0.0186)
#       AR (Raw: 1.0462, Risk-Adj: 39.6310, Vol: 0.0264)
#       ENB (Raw: 0.4474, Risk-Adj: 34.0062, Vol: 0.0132)
#       INSM (Raw: 0.6984, Risk-Adj: 32.8632, Vol: 0.0213)
#       AM (Raw: 0.5236, Risk-Adj: 30.9729, Vol: 0.0169)
#       WAB (Raw: 0.4290, Risk-Adj: 24.7434, Vol: 0.0173)
#       RRC (Raw: 0.4143, Risk-Adj: 16.7191, Vol: 0.0248)
#       SMMT (Raw: 0.5971, Risk-Adj: 10.7353, Vol: 0.0556)
#
# ✅ Execution completed. Final portfolio:
# ['ICSH', 'PGR', 'VUSB', 'BOXX', 'FNDE', 'EBR', 'PHYS', 'BIL', 'TTE', 'TRP']

# %%
print("\n🔧 Running portfolio optimizer...")

final_portfolio = portfolio_optimizer_60days(
    df_data, 
    df_corr,
    df_cov,
    num_tickers=600,
)

print("\n✅ Execution completed. Final portfolio:")
print(final_portfolio)
# Out:
# 🔧 Running portfolio optimizer...
# ⏳ Preprocessing data...
# 🧹 Cleaning dataset...
# 🧮 Calculating composite scores...
#
# ================================================================================
# 🔝 Stage 1: Top 600 Ticker Selection
# ================================================================================
#
# 📊 Selection Criteria for Top N:
# - Weighted combination of risk-adjusted returns and momentum factors
# - Components: Sharpe(0.2), Sortino(0.2), Omega(0.15), Momentum(0.25), SMA(0.15), Volatility(-0.1)
# - Time horizons: 3, 5, 10, 15, 30, 60 days
#
# 🏆 Top 600 Candidates (5-Column Format):
# ERJ   1.84 | ABEV  1.81 | WPM   1.64 | AGI   1.62 | TTE   1.61
# MUFG  1.56 | HALO  1.46 | AEM   1.46 | GDXJ  1.45 | SHEL  1.45
# ITCI  1.45 | XPEV  1.45 | GDX   1.44 | BABA  1.36 | EBR   1.35
# BUD   1.34 | KT    1.33 | GLDM  1.32 | SGOL  1.32 | GLD   1.31
# IAU   1.31 | BBVA  1.29 | CNP   1.29 | DB    1.29 | ING   1.29
# PHYS  1.29 | SBS   1.26 | NEM   1.25 | FXI   1.25 | ITUB  1.25
# INTC  1.24 | TRP   1.23 | HESM  1.23 | PAAS  1.19 | VOD   1.18
# EWZ   1.18 | IBN   1.17 | MCHI  1.17 | SAN   1.17 | SCCO  1.15
# FNDE  1.13 | OKTA  1.10 | YMM   1.09 | SPOT  1.08 | HII   1.07
# MT    1.05 | CCI   1.05 | AR    1.05 | ETR   1.01 | BTI   0.98
# PGR   0.97 | EVRG  0.97 | BEKE  0.96 | ED    0.95 | EXE   0.94
# FCX   0.94 | BRO   0.93 | MO    0.92 | PCG   0.92 | SMFG  0.92
# MFG   0.91 | FNF   0.91 | TECK  0.91 | BRK-B 0.91 | ALL   0.91
# AZN   0.90 | NOK   0.89 | HMY   0.89 | KMI   0.89 | AES   0.88
# AU    0.88 | DTE   0.87 | GSK   0.87 | JD    0.86 | PUK   0.86
# EMXC  0.11 | O     0.11 | DE    0.10 | ALLE  0.10 | TMUS  0.10
# SCHW  0.10 | BMRN  0.10 | LRCX  0.10 | EXEL  0.10 | LHX   0.10
# CHRW  0.10 | GWRE  0.09 | CRL   0.09 | SPLV  0.09 | ROIV  0.09
# DG    0.08 | HYD   0.08 | CHD   0.08 | JNPR  0.08 | TAP   0.07
# VCLT  0.07 | PRMB  0.07 | HYG   0.07 | PLTR  0.07 | NTNX  0.07
# HYLB  0.07 | DOW   0.07 | UBS   0.07 | EQH   0.06 | AMAT  0.06
# XP    0.06 | OVV   0.06 | BMY   0.06 | INTU  0.06 | BINC  0.06
# INDA  0.06 | USHY  0.05 | QSR   0.05 | SHYG  0.05 | PEP   0.05
# TSN   0.05 | FANG  0.05 | FPE   0.05 | SPHY  0.05 | STLD  0.05
# KVUE  0.05 | SJNK  0.04 | DHR   0.04 | NRG   0.04 | USMV  0.04
# SE    0.03 | MFC   0.03 | JNK   0.03 | GM    0.03 | SJM   0.03
# AXON  0.03 | MSI   0.03 | JAAA  0.03 | MDLZ  0.02 | ASML  0.02
# PFF   0.02 | LI    0.02 | BDX   0.01 | ALC   0.01 | TMF   0.01
# NYT   0.01 | TT    0.01 | SMCI  0.00 | APG   0.00 | ELS   -0.01
# ARE   -0.01 | BERY  -0.01 | DOCS  -0.01 | BKLN  -0.01 | TRMB  -0.01
# AMH   -0.01 | BNDX  -0.02 | GPC   -0.02 | CP    -0.02 | XLV   -0.02
# UDR   -0.02 | NUE   -0.02 | PFG   -0.02 | REXR  -0.02 | CWB   -0.02
# DVN   -0.03 | SPYD  -0.03 | MKC   -0.03 | VT    -0.03 | LDOS  -0.03
# IBM   -0.03 | VTEB  -0.03 | SPGI  -0.03 | AMX   -0.03 | BKR   -0.03
# HUM   -0.03 | SCHD  -0.04 | ACWI  -0.04 | CVE   -0.04 | CRBG  -0.04
# EWT   -0.04 | CIBR  -0.04 | TEVA  -0.04 | NFLX  -0.04 | RDY   -0.04
# CGDV  -0.05 | MET   -0.05 | CRH   -0.05 | ETN   -0.05 | IBB   -0.05
# UPS   -0.05 | LBRDK -0.05 | VRSK  -0.05 | XLB   -0.05 | CX    -0.05
# TFI   -0.06 | MLI   -0.06 | MPC   -0.06 | VTV   -0.06 | STZ   -0.06
# QGEN  -0.06 | SMH   -0.06 | NOBL  -0.06 | MPWR  -0.06 | IYR   -0.06
# FAST  -0.06 | AS    -0.06 | BSX   -0.06 | AOS   -0.06 | JCI   -0.07
# XBI   -0.07 | APTV  -0.07 | EOG   -0.07 | XLRE  -0.07 | SCHH  -0.07
# SRLN  -0.07 | SUI   -0.07 | PLNT  -0.07 | CGGO  -0.07 | FI    -0.07
# GRMN  -0.07 | CTVA  -0.07 | VNQ   -0.08 | TMO   -0.08 | BALL  -0.08
# SCHV  -0.08 | PFE   -0.08 | TU    -0.08 | LSCC  -0.08 | BUFR  -0.09
# STM   -0.09 | VYM   -0.09 | PAYX  -0.09 | VFLO  -0.10 | IWD   -0.10
# PANW  -0.10 | CPT   -0.10 | RCI   -0.10 | TCOM  -0.10 | VONV  -0.10
# QCOM  -0.10 | UNP   -0.10 | MCD   -0.10 | XLF   -0.10 | TEL   -0.10
# JEPI  -0.10 | SYY   -0.10 | SAP   -0.11 | AA    -0.11 | TXT   -0.11
# FOXA  -0.11 | TCAF  -0.11 | OXY   -0.11 | CSCO  -0.11 | DGRO  -0.11
# XLI   -0.11 | DD    -0.12 | V     -0.12 | GGG   -0.12 | WY    -0.12
# RBA   -0.12 | SPMO  -0.12 | CNC   -0.12 | WFC   -0.13 | MMYT  -0.13
# PG    -0.13 | WMG   -0.13 | DRI   -0.13 | WYNN  -0.14 | CUBE  -0.14
#
# ================================================================================
# 📊 Stage 2: Portfolio Optimization (N → 10 Tickers)
# ================================================================================
#
# 🔀 Cluster-Based Selection Strategy:
# 1. 10 clusters from correlation patterns using Ward's method
# 2. 1 ticker selected per cluster regardless of size
# 3. Intra-cluster selection by highest risk-adjusted score
# 4. Diversification enforced through correlation matrix clustering
#
# 📈 Cluster Statistics:
#  cluster  Size  Avg_Correlation  Avg_Score
#        1    47           0.4700     0.3500
#        2    41           0.1500     0.4000
#        3    75           0.5500     0.1300
#        4   107           0.6100     0.3400
#        5    18           0.7400     1.1900
#        6    62           0.4900     0.6100
#        7    60           0.8000     0.1900
#        8    78           0.4800     0.3900
#        9    63           0.4800     0.3800
#       10    49           0.4700     0.1400
#
# ================================================================================
# 🎯 Final Portfolio Selection with Risk Adjustment
# ================================================================================
#
# 📦 Cluster 1 (47 members):
#    🏆 Selected: TRP (Raw Score: 1.23, Risk-Adj: 113.53, Volatility: 0.01)
#    📊 Members:
#       TRP (Raw: 1.2309, Risk-Adj: 113.5316, Vol: 0.0108)
#       HESM (Raw: 1.2277, Risk-Adj: 84.0941, Vol: 0.0146)
#       KMI (Raw: 0.8899, Risk-Adj: 68.4301, Vol: 0.0130)
#       BP (Raw: 0.8087, Risk-Adj: 51.4106, Vol: 0.0157)
#       EXE (Raw: 0.9430, Risk-Adj: 49.8319, Vol: 0.0189)
#       OKE (Raw: 0.7718, Risk-Adj: 41.4466, Vol: 0.0186)
#       AR (Raw: 1.0462, Risk-Adj: 39.6310, Vol: 0.0264)
#       XLU (Raw: 0.4518, Risk-Adj: 39.2265, Vol: 0.0115)
#       CVX (Raw: 0.4993, Risk-Adj: 34.3598, Vol: 0.0145)
#       IGF (Raw: 0.3082, Risk-Adj: 34.0559, Vol: 0.0090)
#       ENB (Raw: 0.4474, Risk-Adj: 34.0062, Vol: 0.0132)
#       AM (Raw: 0.5236, Risk-Adj: 30.9729, Vol: 0.0169)
#       AMLP (Raw: 0.3163, Risk-Adj: 30.4569, Vol: 0.0104)
#       EQNR (Raw: 0.5417, Risk-Adj: 27.3363, Vol: 0.0198)
#       MPLX (Raw: 0.3309, Risk-Adj: 26.0107, Vol: 0.0127)
#       EPD (Raw: 0.2708, Risk-Adj: 24.9432, Vol: 0.0109)
#       CTRA (Raw: 0.4479, Risk-Adj: 23.7839, Vol: 0.0188)
#       PEG (Raw: 0.3355, Risk-Adj: 23.1471, Vol: 0.0145)
#       WMB (Raw: 0.3956, Risk-Adj: 22.0532, Vol: 0.0179)
#       CNQ (Raw: 0.3729, Risk-Adj: 20.6143, Vol: 0.0181)
#       PDBC (Raw: 0.1189, Risk-Adj: 20.5214, Vol: 0.0058)
#       PAGP (Raw: 0.2706, Risk-Adj: 20.0779, Vol: 0.0135)
#       XOM (Raw: 0.3283, Risk-Adj: 19.8318, Vol: 0.0166)
#       HES (Raw: 0.3124, Risk-Adj: 19.2603, Vol: 0.0162)
#       XLE (Raw: 0.2613, Risk-Adj: 18.0783, Vol: 0.0145)
#       WES (Raw: 0.3347, Risk-Adj: 17.0473, Vol: 0.0196)
#       RRC (Raw: 0.4143, Risk-Adj: 16.7191, Vol: 0.0248)
#       COP (Raw: 0.3633, Risk-Adj: 15.8475, Vol: 0.0229)
#       SU (Raw: 0.2819, Risk-Adj: 15.5873, Vol: 0.0181)
#       PAA (Raw: 0.2304, Risk-Adj: 14.9828, Vol: 0.0154)
#       EQT (Raw: 0.4089, Risk-Adj: 14.5488, Vol: 0.0281)
#       VLO (Raw: 0.2847, Risk-Adj: 13.3457, Vol: 0.0213)
#       DTM (Raw: 0.2528, Risk-Adj: 11.0354, Vol: 0.0229)
#       PSX (Raw: 0.2058, Risk-Adj: 10.2703, Vol: 0.0200)
#       SLB (Raw: 0.1609, Risk-Adj: 8.3802, Vol: 0.0192)
#       ET (Raw: 0.1679, Risk-Adj: 8.2056, Vol: 0.0205)
#       LNG (Raw: 0.1303, Risk-Adj: 6.1201, Vol: 0.0213)
#       TRGP (Raw: 0.1178, Risk-Adj: 5.1198, Vol: 0.0230)
#       PR (Raw: 0.1123, Risk-Adj: 3.5833, Vol: 0.0313)
#       FANG (Raw: 0.0498, Risk-Adj: 2.3043, Vol: 0.0216)
#       OVV (Raw: 0.0604, Risk-Adj: 1.9916, Vol: 0.0303)
#       DVN (Raw: -0.0254, Risk-Adj: -1.1218, Vol: 0.0226)
#       CVE (Raw: -0.0372, Risk-Adj: -1.4054, Vol: 0.0264)
#       MPC (Raw: -0.0574, Risk-Adj: -2.7063, Vol: 0.0212)
#       EOG (Raw: -0.0670, Risk-Adj: -3.7329, Vol: 0.0180)
#       MMYT (Raw: -0.1260, Risk-Adj: -4.2537, Vol: 0.0296)
#       OXY (Raw: -0.1132, Risk-Adj: -5.8300, Vol: 0.0194)
#
# 📦 Cluster 2 (41 members):
#    🏆 Selected: ALTR (Raw Score: 0.29, Risk-Adj: 185.03, Volatility: 0.00)
#    📊 Members:
#       ALTR (Raw: 0.2950, Risk-Adj: 185.0337, Vol: 0.0016)
#       IBN (Raw: 1.1667, Risk-Adj: 116.9717, Vol: 0.0100)
#       FYBR (Raw: 0.2314, Risk-Adj: 97.8562, Vol: 0.0024)
#       BTI (Raw: 0.9754, Risk-Adj: 77.2048, Vol: 0.0126)
#       VRTX (Raw: 0.8514, Risk-Adj: 63.4353, Vol: 0.0134)
#       ELV (Raw: 0.8532, Risk-Adj: 51.1385, Vol: 0.0167)
#       CME (Raw: 0.5237, Risk-Adj: 42.9617, Vol: 0.0122)
#       JAZZ (Raw: 0.5503, Risk-Adj: 34.5839, Vol: 0.0159)
#       INSM (Raw: 0.6984, Risk-Adj: 32.8632, Vol: 0.0213)
#       PM (Raw: 0.4487, Risk-Adj: 30.2049, Vol: 0.0149)
#       ICL (Raw: 0.6655, Risk-Adj: 28.9249, Vol: 0.0230)
#       CVS (Raw: 0.5989, Risk-Adj: 28.5984, Vol: 0.0209)
#       UL (Raw: 0.3268, Risk-Adj: 28.1742, Vol: 0.0116)
#       KDP (Raw: 0.3965, Risk-Adj: 26.6623, Vol: 0.0149)
#       WAB (Raw: 0.4290, Risk-Adj: 24.7434, Vol: 0.0173)
#       XPEV (Raw: 1.4450, Risk-Adj: 24.6022, Vol: 0.0587)
#       AER (Raw: 0.4842, Risk-Adj: 24.5101, Vol: 0.0198)
#       INTC (Raw: 1.2447, Risk-Adj: 23.4512, Vol: 0.0531)
#       LUV (Raw: 0.5981, Risk-Adj: 21.8273, Vol: 0.0274)
#       AJG (Raw: 0.2840, Risk-Adj: 20.6480, Vol: 0.0138)
#       BA (Raw: 0.4874, Risk-Adj: 18.9481, Vol: 0.0257)
#       UNH (Raw: 0.2987, Risk-Adj: 16.7343, Vol: 0.0178)
#       HDB (Raw: 0.1854, Risk-Adj: 16.2923, Vol: 0.0114)
#       X (Raw: 0.4195, Risk-Adj: 15.2629, Vol: 0.0275)
#       CBOE (Raw: 0.2431, Risk-Adj: 13.8637, Vol: 0.0175)
#       CCEP (Raw: 0.1538, Risk-Adj: 11.3696, Vol: 0.0135)
#       SMMT (Raw: 0.5971, Risk-Adj: 10.7353, Vol: 0.0556)
#       BEPC (Raw: 0.2188, Risk-Adj: 10.4377, Vol: 0.0210)
#       ACI (Raw: 0.2001, Risk-Adj: 10.2449, Vol: 0.0195)
#       FIS (Raw: 0.1570, Risk-Adj: 7.7619, Vol: 0.0202)
#       NIO (Raw: 0.3246, Risk-Adj: 5.6615, Vol: 0.0573)
#       ROIV (Raw: 0.0908, Risk-Adj: 4.9303, Vol: 0.0184)
#       MSI (Raw: 0.0295, Risk-Adj: 2.0561, Vol: 0.0143)
#       AUR (Raw: 0.1231, Risk-Adj: 1.6407, Vol: 0.0750)
#       LI (Raw: 0.0163, Risk-Adj: 0.3285, Vol: 0.0496)
#       SMCI (Raw: 0.0037, Risk-Adj: 0.0471, Vol: 0.0781)
#       TEVA (Raw: -0.0420, Risk-Adj: -1.2844, Vol: 0.0327)
#       HUM (Raw: -0.0327, Risk-Adj: -1.6837, Vol: 0.0194)
#       XBI (Raw: -0.0656, Risk-Adj: -4.9944, Vol: 0.0131)
#       IBB (Raw: -0.0485, Risk-Adj: -5.1080, Vol: 0.0095)
#       CNC (Raw: -0.1242, Risk-Adj: -6.7544, Vol: 0.0184)
#
# 📦 Cluster 3 (75 members):
#    🏆 Selected: BOXX (Raw Score: 0.42, Risk-Adj: 1846.14, Volatility: 0.00)
#    📊 Members:
#       BOXX (Raw: 0.4220, Risk-Adj: 1846.1395, Vol: 0.0002)
#       CAH (Raw: 0.3143, Risk-Adj: 28.2111, Vol: 0.0111)
#       SPOT (Raw: 1.0764, Risk-Adj: 26.6338, Vol: 0.0404)
#       PGX (Raw: 0.1244, Risk-Adj: 26.5568, Vol: 0.0047)
#       RYAN (Raw: 0.3315, Risk-Adj: 21.9105, Vol: 0.0151)
#       SONY (Raw: 0.4680, Risk-Adj: 21.7408, Vol: 0.0215)
#       MMM (Raw: 0.3671, Risk-Adj: 19.9058, Vol: 0.0184)
#       OKTA (Raw: 1.0978, Risk-Adj: 19.4493, Vol: 0.0564)
#       NTES (Raw: 0.3333, Risk-Adj: 18.2037, Vol: 0.0183)
#       EWY (Raw: 0.2994, Risk-Adj: 18.1653, Vol: 0.0165)
#       G (Raw: 0.2868, Risk-Adj: 17.9711, Vol: 0.0160)
#       FTI (Raw: 0.4086, Risk-Adj: 16.6892, Vol: 0.0245)
#       TS (Raw: 0.3595, Risk-Adj: 16.6623, Vol: 0.0216)
#       CDNS (Raw: 0.3691, Risk-Adj: 16.4235, Vol: 0.0225)
#       KLAC (Raw: 0.4222, Risk-Adj: 15.9681, Vol: 0.0264)
#       PWR (Raw: 0.4406, Risk-Adj: 15.1315, Vol: 0.0291)
#       MU (Raw: 0.6079, Risk-Adj: 14.4984, Vol: 0.0419)
#       GE (Raw: 0.2358, Risk-Adj: 13.9056, Vol: 0.0170)
#       TTWO (Raw: 0.2170, Risk-Adj: 11.2398, Vol: 0.0193)
#       EMXC (Raw: 0.1108, Risk-Adj: 9.9580, Vol: 0.0111)
#       GLW (Raw: 0.1435, Risk-Adj: 7.4202, Vol: 0.0193)
#       GGAL (Raw: 0.2446, Risk-Adj: 7.3304, Vol: 0.0334)
#       YPF (Raw: 0.2251, Risk-Adj: 7.0173, Vol: 0.0321)
#       NU (Raw: 0.2730, Risk-Adj: 5.9576, Vol: 0.0458)
#       TLN (Raw: 0.3310, Risk-Adj: 5.8331, Vol: 0.0567)
#       NVDL (Raw: 0.4407, Risk-Adj: 5.3278, Vol: 0.0827)
#       HWM (Raw: 0.1180, Risk-Adj: 4.5664, Vol: 0.0258)
#       SCHW (Raw: 0.1016, Risk-Adj: 4.3575, Vol: 0.0233)
#       NVDA (Raw: 0.1812, Risk-Adj: 4.3540, Vol: 0.0416)
#       DOCU (Raw: 0.2075, Risk-Adj: 4.2500, Vol: 0.0488)
#       PFF (Raw: 0.0170, Risk-Adj: 4.0253, Vol: 0.0042)
#       PRMB (Raw: 0.0709, Risk-Adj: 3.3641, Vol: 0.0211)
#       LRCX (Raw: 0.1012, Risk-Adj: 3.1148, Vol: 0.0325)
#       KVUE (Raw: 0.0454, Risk-Adj: 3.0325, Vol: 0.0150)
#       GWRE (Raw: 0.0943, Risk-Adj: 2.9855, Vol: 0.0316)
#       EQH (Raw: 0.0649, Risk-Adj: 2.4838, Vol: 0.0261)
#       AMAT (Raw: 0.0629, Risk-Adj: 2.3796, Vol: 0.0264)
#       STLD (Raw: 0.0460, Risk-Adj: 2.1504, Vol: 0.0214)
#       NTNX (Raw: 0.0691, Risk-Adj: 1.8551, Vol: 0.0373)
#       MFC (Raw: 0.0339, Risk-Adj: 1.4480, Vol: 0.0234)
#       PLTR (Raw: 0.0694, Risk-Adj: 1.1253, Vol: 0.0617)
#       SE (Raw: 0.0341, Risk-Adj: 0.9174, Vol: 0.0372)
#       NRG (Raw: 0.0362, Risk-Adj: 0.8896, Vol: 0.0407)
#       ASML (Raw: 0.0183, Risk-Adj: 0.6589, Vol: 0.0277)
#       AXON (Raw: 0.0304, Risk-Adj: 0.6133, Vol: 0.0495)
#       TT (Raw: 0.0066, Risk-Adj: 0.4006, Vol: 0.0164)
#       DOCS (Raw: -0.0080, Risk-Adj: -0.1682, Vol: 0.0478)
#       TRMB (Raw: -0.0134, Risk-Adj: -0.6348, Vol: 0.0212)
#       NUE (Raw: -0.0200, Risk-Adj: -0.9183, Vol: 0.0218)
#       CRBG (Raw: -0.0383, Risk-Adj: -1.3363, Vol: 0.0287)
#       NFLX (Raw: -0.0431, Risk-Adj: -1.5162, Vol: 0.0284)
#       MPWR (Raw: -0.0599, Risk-Adj: -1.5301, Vol: 0.0391)
#       BKR (Raw: -0.0323, Risk-Adj: -1.6501, Vol: 0.0196)
#       CRH (Raw: -0.0480, Risk-Adj: -1.6750, Vol: 0.0286)
#       ETN (Raw: -0.0485, Risk-Adj: -1.7821, Vol: 0.0272)
#       AS (Raw: -0.0609, Risk-Adj: -1.8763, Vol: 0.0325)
#       CIBR (Raw: -0.0410, Risk-Adj: -2.1550, Vol: 0.0190)
#       SMH (Raw: -0.0592, Risk-Adj: -2.2288, Vol: 0.0266)
#       VT (Raw: -0.0263, Risk-Adj: -2.2625, Vol: 0.0116)
#       EWT (Raw: -0.0391, Risk-Adj: -2.5191, Vol: 0.0155)
#       LSCC (Raw: -0.0824, Risk-Adj: -2.6641, Vol: 0.0309)
#       CWB (Raw: -0.0245, Risk-Adj: -2.7547, Vol: 0.0089)
#       PLNT (Raw: -0.0701, Risk-Adj: -3.0728, Vol: 0.0228)
#       JCI (Raw: -0.0655, Risk-Adj: -3.1606, Vol: 0.0207)
#       ACWI (Raw: -0.0368, Risk-Adj: -3.1693, Vol: 0.0116)
#       TCOM (Raw: -0.0977, Risk-Adj: -3.2850, Vol: 0.0297)
#       BSX (Raw: -0.0626, Risk-Adj: -3.2967, Vol: 0.0190)
#       AA (Raw: -0.1096, Risk-Adj: -3.4972, Vol: 0.0313)
#       PANW (Raw: -0.0968, Risk-Adj: -4.3994, Vol: 0.0220)
#       QCOM (Raw: -0.0994, Risk-Adj: -4.6616, Vol: 0.0213)
#       WFC (Raw: -0.1256, Risk-Adj: -5.3192, Vol: 0.0236)
#       CGGO (Raw: -0.0706, Risk-Adj: -5.5401, Vol: 0.0128)
#       SPMO (Raw: -0.1235, Risk-Adj: -8.5775, Vol: 0.0144)
#       BUFR (Raw: -0.0850, Risk-Adj: -10.0362, Vol: 0.0085)
#       TCAF (Raw: -0.1122, Risk-Adj: -10.1301, Vol: 0.0111)
#
# 📦 Cluster 4 (107 members):
#    🏆 Selected: FLOT (Raw Score: 0.28, Risk-Adj: 605.14, Volatility: 0.00)
#    📊 Members:
#       FLOT (Raw: 0.2797, Risk-Adj: 605.1409, Vol: 0.0005)
#       ABEV (Raw: 1.8117, Risk-Adj: 96.0226, Vol: 0.0189)
#       MUFG (Raw: 1.5650, Risk-Adj: 90.5573, Vol: 0.0173)
#       BUD (Raw: 1.3433, Risk-Adj: 88.7511, Vol: 0.0151)
#       EWU (Raw: 0.7255, Risk-Adj: 75.5141, Vol: 0.0096)
#       EFV (Raw: 0.7064, Risk-Adj: 74.0775, Vol: 0.0095)
#       AZN (Raw: 0.9013, Risk-Adj: 73.4439, Vol: 0.0123)
#       ING (Raw: 1.2881, Risk-Adj: 63.8966, Vol: 0.0202)
#       ERJ (Raw: 1.8412, Risk-Adj: 63.7686, Vol: 0.0289)
#       BBVA (Raw: 1.2943, Risk-Adj: 61.9436, Vol: 0.0209)
#       DFIV (Raw: 0.6363, Risk-Adj: 60.9062, Vol: 0.0104)
#       VRSN (Raw: 0.6174, Risk-Adj: 59.6147, Vol: 0.0104)
#       SMFG (Raw: 0.9212, Risk-Adj: 57.3883, Vol: 0.0161)
#       FNDF (Raw: 0.5434, Risk-Adj: 54.0874, Vol: 0.0100)
#       HMC (Raw: 0.8480, Risk-Adj: 50.9461, Vol: 0.0166)
#       MFG (Raw: 0.9148, Risk-Adj: 50.9419, Vol: 0.0180)
#       DFIC (Raw: 0.5056, Risk-Adj: 48.5437, Vol: 0.0104)
#       DFAX (Raw: 0.4756, Risk-Adj: 48.3004, Vol: 0.0098)
#       SAN (Raw: 1.1664, Risk-Adj: 46.5291, Vol: 0.0251)
#       NOK (Raw: 0.8947, Risk-Adj: 46.3306, Vol: 0.0193)
#       SCZ (Raw: 0.4730, Risk-Adj: 44.5209, Vol: 0.0106)
#       EZU (Raw: 0.6105, Risk-Adj: 43.7257, Vol: 0.0140)
#       IEUR (Raw: 0.5185, Risk-Adj: 43.4162, Vol: 0.0119)
#       PUK (Raw: 0.8561, Risk-Adj: 42.9855, Vol: 0.0199)
#       DFAI (Raw: 0.4374, Risk-Adj: 42.2903, Vol: 0.0103)
#       VGK (Raw: 0.5120, Risk-Adj: 42.1101, Vol: 0.0122)
#       IEFA (Raw: 0.4527, Risk-Adj: 41.4177, Vol: 0.0109)
#       EFA (Raw: 0.4497, Risk-Adj: 40.7967, Vol: 0.0110)
#       VEU (Raw: 0.4075, Risk-Adj: 38.3160, Vol: 0.0106)
#       FEZ (Raw: 0.5400, Risk-Adj: 38.0784, Vol: 0.0142)
#       ACWX (Raw: 0.4014, Risk-Adj: 37.6119, Vol: 0.0107)
#       VXUS (Raw: 0.3905, Risk-Adj: 37.1383, Vol: 0.0105)
#       DB (Raw: 1.2888, Risk-Adj: 36.6391, Vol: 0.0352)
#       SCHF (Raw: 0.3943, Risk-Adj: 36.5431, Vol: 0.0108)
#       VEA (Raw: 0.3959, Risk-Adj: 36.1909, Vol: 0.0109)
#       IXUS (Raw: 0.3901, Risk-Adj: 36.1599, Vol: 0.0108)
#       BBJP (Raw: 0.3993, Risk-Adj: 36.1331, Vol: 0.0111)
#       IDEV (Raw: 0.3937, Risk-Adj: 35.7532, Vol: 0.0110)
#       SPDW (Raw: 0.3870, Risk-Adj: 35.3644, Vol: 0.0109)
#       LIN (Raw: 0.3471, Risk-Adj: 35.1601, Vol: 0.0099)
#       IQLT (Raw: 0.3543, Risk-Adj: 34.8605, Vol: 0.0102)
#       EWJ (Raw: 0.3940, Risk-Adj: 34.7185, Vol: 0.0113)
#       YUMC (Raw: 0.7104, Risk-Adj: 34.4137, Vol: 0.0206)
#       JAAA (Raw: 0.0288, Risk-Adj: 34.3285, Vol: 0.0008)
#       LYG (Raw: 0.7980, Risk-Adj: 33.8088, Vol: 0.0236)
#       HSBC (Raw: 0.5405, Risk-Adj: 30.6519, Vol: 0.0176)
#       HEFA (Raw: 0.2906, Risk-Adj: 28.9123, Vol: 0.0100)
#       DBEF (Raw: 0.2582, Risk-Adj: 25.9653, Vol: 0.0099)
#       HYG (Raw: 0.0703, Risk-Adj: 24.5050, Vol: 0.0029)
#       UMC (Raw: 0.5281, Risk-Adj: 24.4499, Vol: 0.0216)
#       NLY (Raw: 0.3613, Risk-Adj: 24.3490, Vol: 0.0148)
#       TD (Raw: 0.2737, Risk-Adj: 23.6417, Vol: 0.0116)
#       HYLB (Raw: 0.0688, Risk-Adj: 23.5304, Vol: 0.0029)
#       GLPI (Raw: 0.2460, Risk-Adj: 22.8181, Vol: 0.0108)
#       CHKP (Raw: 0.4431, Risk-Adj: 22.3503, Vol: 0.0198)
#       HTHT (Raw: 0.4164, Risk-Adj: 21.7721, Vol: 0.0191)
#       SHYG (Raw: 0.0533, Risk-Adj: 20.5828, Vol: 0.0026)
#       FPE (Raw: 0.0489, Risk-Adj: 19.9954, Vol: 0.0024)
#       USHY (Raw: 0.0544, Risk-Adj: 19.6221, Vol: 0.0028)
#       AGNC (Raw: 0.2237, Risk-Adj: 18.4585, Vol: 0.0121)
#       NWG (Raw: 0.4784, Risk-Adj: 18.3494, Vol: 0.0261)
#       EFG (Raw: 0.2211, Risk-Adj: 17.0966, Vol: 0.0129)
#       SPHY (Raw: 0.0474, Risk-Adj: 16.6794, Vol: 0.0028)
#       SJNK (Raw: 0.0418, Risk-Adj: 15.9455, Vol: 0.0026)
#       UNM (Raw: 0.2936, Risk-Adj: 14.5546, Vol: 0.0202)
#       RKT (Raw: 0.8161, Risk-Adj: 14.4835, Vol: 0.0563)
#       BCS (Raw: 0.4219, Risk-Adj: 14.2119, Vol: 0.0297)
#       AEG (Raw: 0.3178, Risk-Adj: 12.5489, Vol: 0.0253)
#       CSGP (Raw: 0.2774, Risk-Adj: 12.1901, Vol: 0.0228)
#       JNK (Raw: 0.0337, Risk-Adj: 11.3000, Vol: 0.0030)
#       CGXU (Raw: 0.1603, Risk-Adj: 10.2142, Vol: 0.0157)
#       RYAAY (Raw: 0.1893, Risk-Adj: 7.9248, Vol: 0.0239)
#       CARR (Raw: 0.1154, Risk-Adj: 5.4916, Vol: 0.0210)
#       ERIC (Raw: 0.1112, Risk-Adj: 4.6490, Vol: 0.0239)
#       UBS (Raw: 0.0672, Risk-Adj: 2.6749, Vol: 0.0251)
#       XP (Raw: 0.0616, Risk-Adj: 2.1024, Vol: 0.0293)
#       INTU (Raw: 0.0596, Risk-Adj: 2.0497, Vol: 0.0291)
#       ALC (Raw: 0.0115, Risk-Adj: 0.6554, Vol: 0.0176)
#       APG (Raw: 0.0021, Risk-Adj: 0.0929, Vol: 0.0231)
#       BERY (Raw: -0.0075, Risk-Adj: -0.5255, Vol: 0.0142)
#       CP (Raw: -0.0170, Risk-Adj: -0.7880, Vol: 0.0216)
#       XLV (Raw: -0.0184, Risk-Adj: -2.4266, Vol: 0.0076)
#       STM (Raw: -0.0904, Risk-Adj: -2.7308, Vol: 0.0331)
#       GRMN (Raw: -0.0731, Risk-Adj: -3.0835, Vol: 0.0237)
#       MLI (Raw: -0.0570, Risk-Adj: -3.1129, Vol: 0.0183)
#       APTV (Raw: -0.0660, Risk-Adj: -3.6118, Vol: 0.0183)
#       SAP (Raw: -0.1061, Risk-Adj: -4.6044, Vol: 0.0231)
#       CGDV (Raw: -0.0454, Risk-Adj: -4.8159, Vol: 0.0094)
#       TMO (Raw: -0.0760, Risk-Adj: -5.2163, Vol: 0.0146)
#       WYNN (Raw: -0.1379, Risk-Adj: -5.5906, Vol: 0.0247)
#       TEL (Raw: -0.1023, Risk-Adj: -5.6529, Vol: 0.0181)
#       DRI (Raw: -0.1300, Risk-Adj: -6.1888, Vol: 0.0210)
#       VTV (Raw: -0.0576, Risk-Adj: -6.2006, Vol: 0.0093)
#       FOXA (Raw: -0.1121, Risk-Adj: -6.6741, Vol: 0.0168)
#       RBA (Raw: -0.1228, Risk-Adj: -6.8845, Vol: 0.0178)
#       WMG (Raw: -0.1289, Risk-Adj: -7.0583, Vol: 0.0183)
#       SCHV (Raw: -0.0809, Risk-Adj: -8.3860, Vol: 0.0097)
#       BKLN (Raw: -0.0115, Risk-Adj: -8.8314, Vol: 0.0013)
#       CSCO (Raw: -0.1139, Risk-Adj: -9.0463, Vol: 0.0126)
#       VFLO (Raw: -0.0950, Risk-Adj: -9.5638, Vol: 0.0099)
#       VYM (Raw: -0.0924, Risk-Adj: -9.7261, Vol: 0.0095)
#       IWD (Raw: -0.0959, Risk-Adj: -9.9110, Vol: 0.0097)
#       XLI (Raw: -0.1141, Risk-Adj: -10.0324, Vol: 0.0114)
#       VONV (Raw: -0.0986, Risk-Adj: -10.2099, Vol: 0.0097)
#       JEPI (Raw: -0.1025, Risk-Adj: -12.3351, Vol: 0.0083)
#       DGRO (Raw: -0.1141, Risk-Adj: -12.6345, Vol: 0.0090)
#       SRLN (Raw: -0.0674, Risk-Adj: -46.6571, Vol: 0.0014)
#
# 📦 Cluster 5 (18 members):
#    🏆 Selected: PHYS (Raw Score: 1.29, Risk-Adj: 173.92, Volatility: 0.01)
#    📊 Members:
#       PHYS (Raw: 1.2878, Risk-Adj: 173.9196, Vol: 0.0074)
#       GLDM (Raw: 1.3238, Risk-Adj: 158.6979, Vol: 0.0083)
#       SGOL (Raw: 1.3184, Risk-Adj: 157.3962, Vol: 0.0084)
#       IAU (Raw: 1.3085, Risk-Adj: 156.0932, Vol: 0.0084)
#       GLD (Raw: 1.3129, Risk-Adj: 155.4579, Vol: 0.0084)
#       WPM (Raw: 1.6351, Risk-Adj: 110.8873, Vol: 0.0147)
#       AEM (Raw: 1.4594, Risk-Adj: 81.1278, Vol: 0.0180)
#       GDX (Raw: 1.4352, Risk-Adj: 76.5050, Vol: 0.0188)
#       AGI (Raw: 1.6240, Risk-Adj: 75.6815, Vol: 0.0215)
#       GDXJ (Raw: 1.4503, Risk-Adj: 61.0779, Vol: 0.0237)
#       SLV (Raw: 0.7586, Risk-Adj: 57.8506, Vol: 0.0131)
#       NEM (Raw: 1.2503, Risk-Adj: 54.4419, Vol: 0.0230)
#       GOLD (Raw: 0.8019, Risk-Adj: 45.3571, Vol: 0.0177)
#       PAAS (Raw: 1.1864, Risk-Adj: 43.9911, Vol: 0.0270)
#       AU (Raw: 0.8823, Risk-Adj: 36.2876, Vol: 0.0243)
#       GFI (Raw: 0.7565, Risk-Adj: 30.2027, Vol: 0.0250)
#       HMY (Raw: 0.8943, Risk-Adj: 25.4803, Vol: 0.0351)
#       KGC (Raw: 0.7078, Risk-Adj: 25.3580, Vol: 0.0279)
#
# 📦 Cluster 6 (62 members):
#    🏆 Selected: TTE (Raw Score: 1.61, Risk-Adj: 201.66, Volatility: 0.01)
#    📊 Members:
#       TTE (Raw: 1.6092, Risk-Adj: 201.6558, Vol: 0.0080)
#       SHEL (Raw: 1.4477, Risk-Adj: 169.5739, Vol: 0.0085)
#       HALO (Raw: 1.4626, Risk-Adj: 130.8058, Vol: 0.0112)
#       FNDE (Raw: 1.1301, Risk-Adj: 99.8832, Vol: 0.0113)
#       EBR (Raw: 1.3470, Risk-Adj: 96.2266, Vol: 0.0140)
#       KT (Raw: 1.3285, Risk-Adj: 94.2023, Vol: 0.0141)
#       SBS (Raw: 1.2611, Risk-Adj: 83.4635, Vol: 0.0151)
#       GUNR (Raw: 0.6820, Risk-Adj: 78.8704, Vol: 0.0086)
#       EWZ (Raw: 1.1774, Risk-Adj: 67.3613, Vol: 0.0175)
#       ITUB (Raw: 1.2463, Risk-Adj: 66.8084, Vol: 0.0187)
#       FXI (Raw: 1.2487, Risk-Adj: 66.5644, Vol: 0.0188)
#       MCHI (Raw: 1.1666, Risk-Adj: 60.5410, Vol: 0.0193)
#       RIO (Raw: 0.7581, Risk-Adj: 53.9553, Vol: 0.0140)
#       SCCO (Raw: 1.1477, Risk-Adj: 49.9703, Vol: 0.0230)
#       VIV (Raw: 0.7827, Risk-Adj: 39.1050, Vol: 0.0200)
#       BABA (Raw: 1.3629, Risk-Adj: 36.9721, Vol: 0.0369)
#       EA (Raw: 0.6143, Risk-Adj: 35.8369, Vol: 0.0171)
#       BBD (Raw: 0.8428, Risk-Adj: 35.7370, Vol: 0.0236)
#       SCHE (Raw: 0.4098, Risk-Adj: 35.6050, Vol: 0.0115)
#       SPEM (Raw: 0.3835, Risk-Adj: 33.5073, Vol: 0.0114)
#       DFAE (Raw: 0.3724, Risk-Adj: 32.8284, Vol: 0.0113)
#       MOS (Raw: 0.7241, Risk-Adj: 32.7185, Vol: 0.0221)
#       EEM (Raw: 0.3988, Risk-Adj: 32.6204, Vol: 0.0122)
#       VWO (Raw: 0.3790, Risk-Adj: 32.4624, Vol: 0.0117)
#       HII (Raw: 1.0682, Risk-Adj: 31.6485, Vol: 0.0338)
#       EC (Raw: 0.7805, Risk-Adj: 31.6369, Vol: 0.0247)
#       DFEM (Raw: 0.3386, Risk-Adj: 30.8286, Vol: 0.0110)
#       IEMG (Raw: 0.3665, Risk-Adj: 30.7590, Vol: 0.0119)
#       YMM (Raw: 1.0926, Risk-Adj: 29.6791, Vol: 0.0368)
#       TECK (Raw: 0.9123, Risk-Adj: 29.2498, Vol: 0.0312)
#       PDD (Raw: 0.7976, Risk-Adj: 28.2822, Vol: 0.0282)
#       FCX (Raw: 0.9421, Risk-Adj: 27.9236, Vol: 0.0337)
#       MT (Raw: 1.0468, Risk-Adj: 27.5434, Vol: 0.0380)
#       KWEB (Raw: 0.6861, Risk-Adj: 26.0029, Vol: 0.0264)
#       JD (Raw: 0.8636, Risk-Adj: 25.6754, Vol: 0.0336)
#       PBR-A (Raw: 0.4902, Risk-Adj: 24.3741, Vol: 0.0201)
#       BEKE (Raw: 0.9634, Risk-Adj: 22.2896, Vol: 0.0432)
#       VALE (Raw: 0.5146, Risk-Adj: 21.1025, Vol: 0.0244)
#       ZTO (Raw: 0.4027, Risk-Adj: 20.3593, Vol: 0.0198)
#       PBR (Raw: 0.3921, Risk-Adj: 18.1490, Vol: 0.0216)
#       BHP (Raw: 0.2050, Risk-Adj: 14.4956, Vol: 0.0141)
#       FUTU (Raw: 0.7356, Risk-Adj: 13.6091, Vol: 0.0541)
#       BIDU (Raw: 0.3483, Risk-Adj: 13.5301, Vol: 0.0257)
#       EDU (Raw: 0.3878, Risk-Adj: 11.4251, Vol: 0.0339)
#       PPG (Raw: 0.1721, Risk-Adj: 10.6169, Vol: 0.0162)
#       LYB (Raw: 0.1382, Risk-Adj: 7.4385, Vol: 0.0186)
#       NTR (Raw: 0.1230, Risk-Adj: 6.7555, Vol: 0.0182)
#       INDA (Raw: 0.0552, Risk-Adj: 6.6683, Vol: 0.0083)
#       MSTR (Raw: 0.4895, Risk-Adj: 6.4627, Vol: 0.0757)
#       F (Raw: 0.1299, Risk-Adj: 6.1917, Vol: 0.0210)
#       TME (Raw: 0.2080, Risk-Adj: 5.9627, Vol: 0.0349)
#       DOW (Raw: 0.0677, Risk-Adj: 3.1294, Vol: 0.0216)
#       DHR (Raw: 0.0372, Risk-Adj: 2.1942, Vol: 0.0170)
#       GM (Raw: 0.0331, Risk-Adj: 1.3020, Vol: 0.0254)
#       REXR (Raw: -0.0240, Risk-Adj: -1.5870, Vol: 0.0151)
#       CX (Raw: -0.0549, Risk-Adj: -2.0874, Vol: 0.0263)
#       QGEN (Raw: -0.0578, Risk-Adj: -3.7969, Vol: 0.0152)
#       RDY (Raw: -0.0435, Risk-Adj: -4.1094, Vol: 0.0106)
#       XLB (Raw: -0.0532, Risk-Adj: -4.8383, Vol: 0.0110)
#       CTVA (Raw: -0.0746, Risk-Adj: -5.5149, Vol: 0.0135)
#       DD (Raw: -0.1157, Risk-Adj: -7.1493, Vol: 0.0162)
#       RCI (Raw: -0.0976, Risk-Adj: -9.1242, Vol: 0.0107)
#
# 📦 Cluster 7 (60 members):
#    🏆 Selected: PULS (Raw Score: 0.41, Risk-Adj: 1514.77, Volatility: 0.00)
#    📊 Members:
#       PULS (Raw: 0.4075, Risk-Adj: 1514.7744, Vol: 0.0003)
#       VUSB (Raw: 0.4953, Risk-Adj: 1111.2934, Vol: 0.0004)
#       JPST (Raw: 0.2700, Risk-Adj: 693.2143, Vol: 0.0004)
#       SHY (Raw: 0.3069, Risk-Adj: 356.6322, Vol: 0.0009)
#       VGSH (Raw: 0.3126, Risk-Adj: 352.6410, Vol: 0.0009)
#       BSCQ (Raw: 0.1741, Risk-Adj: 320.7723, Vol: 0.0005)
#       SPTS (Raw: 0.3170, Risk-Adj: 317.5776, Vol: 0.0010)
#       VTIP (Raw: 0.3192, Risk-Adj: 288.3732, Vol: 0.0011)
#       SCHO (Raw: 0.2811, Risk-Adj: 261.1291, Vol: 0.0011)
#       SPSB (Raw: 0.2034, Risk-Adj: 241.3182, Vol: 0.0008)
#       BSV (Raw: 0.2824, Risk-Adj: 212.4704, Vol: 0.0013)
#       IGSB (Raw: 0.2140, Risk-Adj: 184.0546, Vol: 0.0012)
#       VCSH (Raw: 0.1901, Risk-Adj: 178.9013, Vol: 0.0011)
#       BSCR (Raw: 0.1818, Risk-Adj: 176.9683, Vol: 0.0010)
#       UCON (Raw: 0.2305, Risk-Adj: 174.4046, Vol: 0.0013)
#       IEI (Raw: 0.2903, Risk-Adj: 122.2369, Vol: 0.0024)
#       PYLD (Raw: 0.1964, Risk-Adj: 107.7547, Vol: 0.0018)
#       SPTI (Raw: 0.2840, Risk-Adj: 107.2626, Vol: 0.0026)
#       VGIT (Raw: 0.2765, Risk-Adj: 102.9001, Vol: 0.0027)
#       MUB (Raw: 0.2139, Risk-Adj: 100.6253, Vol: 0.0021)
#       SCHR (Raw: 0.2624, Risk-Adj: 94.2292, Vol: 0.0028)
#       SPIB (Raw: 0.1657, Risk-Adj: 91.4187, Vol: 0.0018)
#       GOVT (Raw: 0.2321, Risk-Adj: 75.3418, Vol: 0.0031)
#       BIV (Raw: 0.2160, Risk-Adj: 72.1395, Vol: 0.0030)
#       IUSB (Raw: 0.1918, Risk-Adj: 71.5837, Vol: 0.0027)
#       SCHZ (Raw: 0.2074, Risk-Adj: 71.3405, Vol: 0.0029)
#       TIP (Raw: 0.2032, Risk-Adj: 71.0905, Vol: 0.0029)
#       SPAB (Raw: 0.2071, Risk-Adj: 70.5098, Vol: 0.0029)
#       BND (Raw: 0.2013, Risk-Adj: 68.5152, Vol: 0.0029)
#       SCHP (Raw: 0.1899, Risk-Adj: 67.5839, Vol: 0.0028)
#       SPMB (Raw: 0.2151, Risk-Adj: 67.3773, Vol: 0.0032)
#       AGG (Raw: 0.2010, Risk-Adj: 67.1033, Vol: 0.0030)
#       JCPB (Raw: 0.1734, Risk-Adj: 66.9411, Vol: 0.0026)
#       CGCP (Raw: 0.1416, Risk-Adj: 65.9294, Vol: 0.0021)
#       IEF (Raw: 0.2533, Risk-Adj: 65.0369, Vol: 0.0039)
#       FBND (Raw: 0.1883, Risk-Adj: 64.3701, Vol: 0.0029)
#       VMBS (Raw: 0.2010, Risk-Adj: 62.7337, Vol: 0.0032)
#       DFCF (Raw: 0.1677, Risk-Adj: 61.9969, Vol: 0.0027)
#       FIXD (Raw: 0.1972, Risk-Adj: 59.8786, Vol: 0.0033)
#       MBB (Raw: 0.1877, Risk-Adj: 59.5190, Vol: 0.0032)
#       EMB (Raw: 0.1683, Risk-Adj: 58.2024, Vol: 0.0029)
#       IGIB (Raw: 0.1580, Risk-Adj: 57.6453, Vol: 0.0027)
#       BINC (Raw: 0.0592, Risk-Adj: 54.2777, Vol: 0.0011)
#       VCIT (Raw: 0.1431, Risk-Adj: 52.1441, Vol: 0.0027)
#       SCHI (Raw: 0.1397, Risk-Adj: 50.1980, Vol: 0.0028)
#       USIG (Raw: 0.1384, Risk-Adj: 47.6297, Vol: 0.0029)
#       LQD (Raw: 0.1145, Risk-Adj: 32.1875, Vol: 0.0036)
#       TLH (Raw: 0.2031, Risk-Adj: 32.1206, Vol: 0.0063)
#       HYD (Raw: 0.0799, Risk-Adj: 27.8227, Vol: 0.0029)
#       SPTL (Raw: 0.1762, Risk-Adj: 24.5232, Vol: 0.0072)
#       VGLT (Raw: 0.1733, Risk-Adj: 23.9701, Vol: 0.0072)
#       BLV (Raw: 0.1390, Risk-Adj: 22.5526, Vol: 0.0062)
#       TLT (Raw: 0.1580, Risk-Adj: 20.1270, Vol: 0.0079)
#       VCLT (Raw: 0.0736, Risk-Adj: 13.9273, Vol: 0.0053)
#       EDV (Raw: 0.1142, Risk-Adj: 10.1035, Vol: 0.0113)
#       EXEL (Raw: 0.0995, Risk-Adj: 4.7403, Vol: 0.0210)
#       TMF (Raw: 0.0093, Risk-Adj: 0.3986, Vol: 0.0234)
#       BNDX (Raw: -0.0151, Risk-Adj: -5.3955, Vol: 0.0028)
#       VTEB (Raw: -0.0300, Risk-Adj: -14.2495, Vol: 0.0021)
#       TFI (Raw: -0.0554, Risk-Adj: -25.3243, Vol: 0.0022)
#
# 📦 Cluster 8 (78 members):
#    🏆 Selected: K (Raw Score: 0.27, Risk-Adj: 163.32, Volatility: 0.00)
#    📊 Members:
#       K (Raw: 0.2685, Risk-Adj: 163.3164, Vol: 0.0016)
#       BRO (Raw: 0.9258, Risk-Adj: 110.3890, Vol: 0.0084)
#       CNP (Raw: 1.2934, Risk-Adj: 106.3801, Vol: 0.0122)
#       EVRG (Raw: 0.9692, Risk-Adj: 100.4567, Vol: 0.0096)
#       PGR (Raw: 0.9711, Risk-Adj: 93.8526, Vol: 0.0103)
#       DTE (Raw: 0.8666, Risk-Adj: 83.8449, Vol: 0.0103)
#       ADC (Raw: 0.8240, Risk-Adj: 79.4656, Vol: 0.0104)
#       BRK-B (Raw: 0.9111, Risk-Adj: 72.6486, Vol: 0.0125)
#       ICE (Raw: 0.6565, Risk-Adj: 72.4486, Vol: 0.0091)
#       PNW (Raw: 0.6996, Risk-Adj: 61.1084, Vol: 0.0114)
#       PCG (Raw: 0.9225, Risk-Adj: 60.6558, Vol: 0.0152)
#       HIG (Raw: 0.6737, Risk-Adj: 58.2610, Vol: 0.0116)
#       ALL (Raw: 0.9075, Risk-Adj: 58.2585, Vol: 0.0156)
#       FNF (Raw: 0.9126, Risk-Adj: 57.9368, Vol: 0.0157)
#       OGE (Raw: 0.6002, Risk-Adj: 57.5221, Vol: 0.0104)
#       ETR (Raw: 1.0142, Risk-Adj: 56.4951, Vol: 0.0180)
#       AIG (Raw: 0.8379, Risk-Adj: 56.2367, Vol: 0.0149)
#       TRV (Raw: 0.7242, Risk-Adj: 55.9250, Vol: 0.0129)
#       CB (Raw: 0.7896, Risk-Adj: 55.6952, Vol: 0.0142)
#       AMT (Raw: 0.8125, Risk-Adj: 51.8750, Vol: 0.0157)
#       L (Raw: 0.5541, Risk-Adj: 51.8320, Vol: 0.0107)
#       MMC (Raw: 0.4304, Risk-Adj: 50.5994, Vol: 0.0085)
#       WRB (Raw: 0.5962, Risk-Adj: 47.9790, Vol: 0.0124)
#       RTX (Raw: 0.5885, Risk-Adj: 46.9785, Vol: 0.0125)
#       PPL (Raw: 0.5731, Risk-Adj: 46.0566, Vol: 0.0124)
#       AEE (Raw: 0.5622, Risk-Adj: 46.0293, Vol: 0.0122)
#       ORI (Raw: 0.5499, Risk-Adj: 45.0908, Vol: 0.0122)
#       CINF (Raw: 0.6466, Risk-Adj: 42.9374, Vol: 0.0151)
#       TW (Raw: 0.5818, Risk-Adj: 42.4589, Vol: 0.0137)
#       AON (Raw: 0.3419, Risk-Adj: 41.7973, Vol: 0.0082)
#       ACGL (Raw: 0.5108, Risk-Adj: 41.0666, Vol: 0.0124)
#       LNT (Raw: 0.4604, Risk-Adj: 39.7014, Vol: 0.0116)
#       RPRX (Raw: 0.4125, Risk-Adj: 39.2799, Vol: 0.0105)
#       PBA (Raw: 0.5646, Risk-Adj: 37.3231, Vol: 0.0151)
#       AFL (Raw: 0.4278, Risk-Adj: 33.1851, Vol: 0.0129)
#       WM (Raw: 0.3424, Risk-Adj: 32.5921, Vol: 0.0105)
#       RSG (Raw: 0.3211, Risk-Adj: 32.4186, Vol: 0.0099)
#       MNST (Raw: 0.4863, Risk-Adj: 32.2095, Vol: 0.0151)
#       ROL (Raw: 0.3770, Risk-Adj: 31.0347, Vol: 0.0121)
#       WCN (Raw: 0.2846, Risk-Adj: 28.9873, Vol: 0.0098)
#       AES (Raw: 0.8842, Risk-Adj: 28.2722, Vol: 0.0313)
#       OHI (Raw: 0.4869, Risk-Adj: 27.5932, Vol: 0.0176)
#       DGX (Raw: 0.3909, Risk-Adj: 26.9683, Vol: 0.0145)
#       NI (Raw: 0.3219, Risk-Adj: 24.4260, Vol: 0.0132)
#       ATO (Raw: 0.2852, Risk-Adj: 24.3717, Vol: 0.0117)
#       WPC (Raw: 0.2921, Risk-Adj: 21.9891, Vol: 0.0133)
#       VICI (Raw: 0.2683, Risk-Adj: 21.0345, Vol: 0.0128)
#       XEL (Raw: 0.2704, Risk-Adj: 20.9266, Vol: 0.0129)
#       EIX (Raw: 0.3920, Risk-Adj: 20.2912, Vol: 0.0193)
#       WELL (Raw: 0.2801, Risk-Adj: 19.8918, Vol: 0.0141)
#       VTR (Raw: 0.2958, Risk-Adj: 19.0089, Vol: 0.0156)
#       SBAC (Raw: 0.2316, Risk-Adj: 16.6807, Vol: 0.0139)
#       DOC (Raw: 0.1949, Risk-Adj: 15.7346, Vol: 0.0124)
#       WBA (Raw: 0.5558, Risk-Adj: 15.0060, Vol: 0.0370)
#       INVH (Raw: 0.1988, Risk-Adj: 13.1203, Vol: 0.0151)
#       MAA (Raw: 0.1476, Risk-Adj: 12.7883, Vol: 0.0115)
#       O (Raw: 0.1089, Risk-Adj: 8.5432, Vol: 0.0127)
#       GFL (Raw: 0.1262, Risk-Adj: 6.8703, Vol: 0.0184)
#       ARE (Raw: -0.0064, Risk-Adj: -0.3586, Vol: 0.0178)
#       ELS (Raw: -0.0054, Risk-Adj: -0.4354, Vol: 0.0123)
#       AMH (Raw: -0.0139, Risk-Adj: -0.8337, Vol: 0.0167)
#       PFG (Raw: -0.0230, Risk-Adj: -1.4300, Vol: 0.0161)
#       UDR (Raw: -0.0191, Risk-Adj: -1.5423, Vol: 0.0124)
#       SPGI (Raw: -0.0307, Risk-Adj: -2.2033, Vol: 0.0139)
#       MET (Raw: -0.0479, Risk-Adj: -2.4404, Vol: 0.0196)
#       SUI (Raw: -0.0688, Risk-Adj: -3.9602, Vol: 0.0174)
#       FI (Raw: -0.0726, Risk-Adj: -4.0625, Vol: 0.0179)
#       VRSK (Raw: -0.0522, Risk-Adj: -4.1391, Vol: 0.0126)
#       IYR (Raw: -0.0599, Risk-Adj: -5.0014, Vol: 0.0120)
#       PAYX (Raw: -0.0939, Risk-Adj: -5.6167, Vol: 0.0167)
#       XLRE (Raw: -0.0671, Risk-Adj: -5.6848, Vol: 0.0118)
#       SCHH (Raw: -0.0672, Risk-Adj: -5.9547, Vol: 0.0113)
#       VNQ (Raw: -0.0754, Risk-Adj: -6.3416, Vol: 0.0119)
#       WY (Raw: -0.1218, Risk-Adj: -7.6104, Vol: 0.0160)
#       XLF (Raw: -0.1002, Risk-Adj: -7.6404, Vol: 0.0131)
#       CPT (Raw: -0.0968, Risk-Adj: -8.1665, Vol: 0.0119)
#       CUBE (Raw: -0.1391, Risk-Adj: -9.1452, Vol: 0.0152)
#       V (Raw: -0.1195, Risk-Adj: -9.5293, Vol: 0.0125)
#
# 📦 Cluster 9 (63 members):
#    🏆 Selected: ICSH (Raw Score: 0.50, Risk-Adj: 1697.98, Volatility: 0.00)
#    📊 Members:
#       ICSH (Raw: 0.4995, Risk-Adj: 1697.9750, Vol: 0.0003)
#       FTSM (Raw: 0.2713, Risk-Adj: 1107.2824, Vol: 0.0002)
#       IBDR (Raw: 0.2232, Risk-Adj: 382.8616, Vol: 0.0006)
#       ITCI (Raw: 1.4467, Risk-Adj: 95.9599, Vol: 0.0151)
#       TAK (Raw: 0.8402, Risk-Adj: 81.3440, Vol: 0.0103)
#       MO (Raw: 0.9245, Risk-Adj: 74.5762, Vol: 0.0124)
#       DUK (Raw: 0.7881, Risk-Adj: 70.1878, Vol: 0.0112)
#       EXC (Raw: 0.8543, Risk-Adj: 69.9279, Vol: 0.0122)
#       VOD (Raw: 1.1775, Risk-Adj: 69.1180, Vol: 0.0170)
#       MCK (Raw: 0.8247, Risk-Adj: 64.8224, Vol: 0.0127)
#       ABBV (Raw: 0.6765, Risk-Adj: 60.9418, Vol: 0.0111)
#       GSK (Raw: 0.8664, Risk-Adj: 59.5668, Vol: 0.0145)
#       ED (Raw: 0.9532, Risk-Adj: 57.2647, Vol: 0.0166)
#       COR (Raw: 0.6570, Risk-Adj: 51.9066, Vol: 0.0127)
#       SNY (Raw: 0.6360, Risk-Adj: 48.6491, Vol: 0.0131)
#       CMS (Raw: 0.6032, Risk-Adj: 48.0562, Vol: 0.0126)
#       WEC (Raw: 0.6302, Risk-Adj: 42.9991, Vol: 0.0147)
#       AWK (Raw: 0.8256, Risk-Adj: 40.2585, Vol: 0.0205)
#       AMGN (Raw: 0.5614, Risk-Adj: 38.4244, Vol: 0.0146)
#       AEP (Raw: 0.5790, Risk-Adj: 38.1298, Vol: 0.0152)
#       SO (Raw: 0.5588, Risk-Adj: 37.7863, Vol: 0.0148)
#       WTRG (Raw: 0.6396, Risk-Adj: 37.7295, Vol: 0.0169)
#       MDT (Raw: 0.5362, Risk-Adj: 37.4418, Vol: 0.0143)
#       ZBH (Raw: 0.6023, Risk-Adj: 30.8055, Vol: 0.0196)
#       T (Raw: 0.5797, Risk-Adj: 29.3814, Vol: 0.0197)
#       GILD (Raw: 0.3904, Risk-Adj: 27.4122, Vol: 0.0142)
#       JNJ (Raw: 0.2565, Risk-Adj: 26.1632, Vol: 0.0098)
#       CI (Raw: 0.4372, Risk-Adj: 26.0237, Vol: 0.0168)
#       GD (Raw: 0.4095, Risk-Adj: 25.2039, Vol: 0.0162)
#       ES (Raw: 0.4359, Risk-Adj: 23.7943, Vol: 0.0183)
#       SNN (Raw: 0.3500, Risk-Adj: 18.0219, Vol: 0.0194)
#       FE (Raw: 0.3632, Risk-Adj: 15.5523, Vol: 0.0234)
#       MRK (Raw: 0.2110, Risk-Adj: 15.4595, Vol: 0.0136)
#       HRL (Raw: 0.2317, Risk-Adj: 15.3292, Vol: 0.0151)
#       KO (Raw: 0.1612, Risk-Adj: 13.8748, Vol: 0.0116)
#       NEE (Raw: 0.2671, Risk-Adj: 13.7143, Vol: 0.0195)
#       NNN (Raw: 0.1655, Risk-Adj: 13.5142, Vol: 0.0122)
#       LMT (Raw: 0.1932, Risk-Adj: 12.8936, Vol: 0.0150)
#       D (Raw: 0.1952, Risk-Adj: 10.9408, Vol: 0.0178)
#       KR (Raw: 0.1775, Risk-Adj: 9.8487, Vol: 0.0180)
#       NVS (Raw: 0.1392, Risk-Adj: 9.4102, Vol: 0.0148)
#       NOC (Raw: 0.1837, Risk-Adj: 9.2159, Vol: 0.0199)
#       KMB (Raw: 0.1253, Risk-Adj: 8.8021, Vol: 0.0142)
#       HCA (Raw: 0.1978, Risk-Adj: 8.7829, Vol: 0.0225)
#       VZ (Raw: 0.2017, Risk-Adj: 8.5858, Vol: 0.0235)
#       HLN (Raw: 0.1260, Risk-Adj: 8.0262, Vol: 0.0157)
#       LHX (Raw: 0.0982, Risk-Adj: 7.1258, Vol: 0.0138)
#       SCI (Raw: 0.1422, Risk-Adj: 6.8246, Vol: 0.0208)
#       BMRN (Raw: 0.1012, Risk-Adj: 6.6172, Vol: 0.0153)
#       CHD (Raw: 0.0773, Risk-Adj: 6.0901, Vol: 0.0127)
#       TMUS (Raw: 0.1020, Risk-Adj: 6.0091, Vol: 0.0170)
#       BF-B (Raw: 0.1437, Risk-Adj: 4.5353, Vol: 0.0317)
#       TSN (Raw: 0.0510, Risk-Adj: 4.3621, Vol: 0.0117)
#       PEP (Raw: 0.0519, Risk-Adj: 3.6016, Vol: 0.0144)
#       TAP (Raw: 0.0745, Risk-Adj: 3.5107, Vol: 0.0212)
#       BMY (Raw: 0.0601, Risk-Adj: 3.2994, Vol: 0.0182)
#       DG (Raw: 0.0832, Risk-Adj: 2.4052, Vol: 0.0346)
#       SJM (Raw: 0.0321, Risk-Adj: 1.6141, Vol: 0.0199)
#       MDLZ (Raw: 0.0239, Risk-Adj: 1.4101, Vol: 0.0170)
#       MKC (Raw: -0.0261, Risk-Adj: -1.7142, Vol: 0.0152)
#       STZ (Raw: -0.0577, Risk-Adj: -3.1072, Vol: 0.0186)
#       TU (Raw: -0.0817, Risk-Adj: -5.4203, Vol: 0.0151)
#       PG (Raw: -0.1277, Risk-Adj: -10.3571, Vol: 0.0123)
#
# 📦 Cluster 10 (49 members):
#    🏆 Selected: BIL (Raw Score: 0.51, Risk-Adj: 5019.44, Volatility: 0.00)
#    📊 Members:
#       BIL (Raw: 0.5060, Risk-Adj: 5019.4396, Vol: 0.0001)
#       SGOV (Raw: 0.5507, Risk-Adj: 4496.3430, Vol: 0.0001)
#       SHV (Raw: 0.3791, Risk-Adj: 2628.8572, Vol: 0.0001)
#       TBIL (Raw: 0.4793, Risk-Adj: 2598.9769, Vol: 0.0002)
#       USFR (Raw: 0.3229, Risk-Adj: 1707.9947, Vol: 0.0002)
#       TFLO (Raw: 0.2530, Risk-Adj: 1539.0907, Vol: 0.0002)
#       MINT (Raw: 0.2899, Risk-Adj: 1325.8714, Vol: 0.0002)
#       BSCP (Raw: 0.2565, Risk-Adj: 671.9586, Vol: 0.0004)
#       CCI (Raw: 1.0468, Risk-Adj: 33.5401, Vol: 0.0312)
#       PARA (Raw: 0.5128, Risk-Adj: 29.3655, Vol: 0.0175)
#       YUM (Raw: 0.4105, Risk-Adj: 26.3572, Vol: 0.0156)
#       BAX (Raw: 0.3903, Risk-Adj: 19.0014, Vol: 0.0205)
#       OTIS (Raw: 0.2007, Risk-Adj: 17.0326, Vol: 0.0118)
#       HON (Raw: 0.1890, Risk-Adj: 15.1293, Vol: 0.0125)
#       LKQ (Raw: 0.2179, Risk-Adj: 14.1078, Vol: 0.0154)
#       BG (Raw: 0.2121, Risk-Adj: 12.8117, Vol: 0.0166)
#       JNPR (Raw: 0.0761, Risk-Adj: 11.2036, Vol: 0.0068)
#       SPLV (Raw: 0.0933, Risk-Adj: 10.7161, Vol: 0.0087)
#       BJ (Raw: 0.3350, Risk-Adj: 10.5411, Vol: 0.0318)
#       VLTO (Raw: 0.1236, Risk-Adj: 8.4456, Vol: 0.0146)
#       CCK (Raw: 0.1286, Risk-Adj: 8.0229, Vol: 0.0160)
#       VEEV (Raw: 0.1448, Risk-Adj: 5.4950, Vol: 0.0263)
#       ALLE (Raw: 0.1028, Risk-Adj: 5.3454, Vol: 0.0192)
#       DE (Raw: 0.1035, Risk-Adj: 5.1784, Vol: 0.0200)
#       CHRW (Raw: 0.0981, Risk-Adj: 5.0232, Vol: 0.0195)
#       USMV (Raw: 0.0360, Risk-Adj: 4.7844, Vol: 0.0075)
#       CNH (Raw: 0.1326, Risk-Adj: 4.7202, Vol: 0.0281)
#       CRL (Raw: 0.0935, Risk-Adj: 3.9096, Vol: 0.0239)
#       QSR (Raw: 0.0541, Risk-Adj: 3.6903, Vol: 0.0147)
#       BDX (Raw: 0.0131, Risk-Adj: 1.1132, Vol: 0.0117)
#       NYT (Raw: 0.0074, Risk-Adj: 0.4179, Vol: 0.0178)
#       GPC (Raw: -0.0161, Risk-Adj: -0.9345, Vol: 0.0173)
#       LDOS (Raw: -0.0264, Risk-Adj: -1.4837, Vol: 0.0178)
#       IBM (Raw: -0.0296, Risk-Adj: -1.5219, Vol: 0.0195)
#       AMX (Raw: -0.0315, Risk-Adj: -2.2937, Vol: 0.0137)
#       LBRDK (Raw: -0.0499, Risk-Adj: -2.4685, Vol: 0.0202)
#       SPYD (Raw: -0.0259, Risk-Adj: -2.6361, Vol: 0.0098)
#       UPS (Raw: -0.0498, Risk-Adj: -2.9884, Vol: 0.0167)
#       FAST (Raw: -0.0603, Risk-Adj: -3.1421, Vol: 0.0192)
#       SCHD (Raw: -0.0368, Risk-Adj: -3.7464, Vol: 0.0098)
#       AOS (Raw: -0.0647, Risk-Adj: -4.0309, Vol: 0.0160)
#       BALL (Raw: -0.0789, Risk-Adj: -4.4101, Vol: 0.0179)
#       NOBL (Raw: -0.0594, Risk-Adj: -5.9790, Vol: 0.0099)
#       MCD (Raw: -0.1001, Risk-Adj: -6.2378, Vol: 0.0160)
#       TXT (Raw: -0.1118, Risk-Adj: -6.3389, Vol: 0.0176)
#       UNP (Raw: -0.0994, Risk-Adj: -6.8029, Vol: 0.0146)
#       PFE (Raw: -0.0811, Risk-Adj: -6.9272, Vol: 0.0117)
#       SYY (Raw: -0.1028, Risk-Adj: -7.3640, Vol: 0.0140)
#       GGG (Raw: -0.1195, Risk-Adj: -8.8361, Vol: 0.0135)
#
# ✅ Execution completed. Final portfolio:
# ['TRP', 'ALTR', 'BOXX', 'FLOT', 'PHYS', 'TTE', 'PULS', 'K', 'ICSH', 'BIL']

# %%
# (2 * 0.1) + (2 * 0.2) + (2 * 0.05) + (2 * 0.15) + (2 * 0.05)
#  + (2 * 0.1) + (2 * 0.1) + (2 * 0.05) + (2 * 0.15) + (2 * 0.05) 
# = 2 * (0.1 + 0.2 + 0.05 + 0.15 + 0.05 + 0.1 + 0.1 + 0.05 + 0.15 + 0.05) 
# = 2 * 1 = 2

import numpy as np

weights = np.array([0.1, 0.2, 0.05, 0.15, 0.05, 0.1, 0.1, 0.05, 0.15, 0.05])  #Example Weights

z_scores = np.array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2]) # Example Z-scores

weighted_z = z_scores @ weights
print(weighted_z)
# Out:
# 2.0

# %%
df_data.loc['TBIL']
# Out:
# Company                                 US Treasury 3 Month Bill ETF
# Info               Financial, Exchange Traded Fund, Bonds - Treas...
# MktCap AUM, M                                              5220.0000
# Beta                                                         -0.0000
# RSI                                                          51.1400
# Perf YTD %                                                    0.1200
# Perf 3D %                                                     0.0601
# Perf Week %                                                   0.0800
# Perf Month %                                                  0.0400
# Perf Quart %                                                  0.3800
# Perf Half %                                                   0.4200
# Perf Year %                                                   0.4000
# SMA20 %                                                      -0.0200
# SMA50 %                                                      -0.0200
# SMA200 %                                                      0.2500
# 50D High %                                                   -0.2400
# 50D Low %                                                     0.1600
# 52W High %                                                   -0.2400
# 52W Low %                                                     0.5900
# All-Time High %                                              -0.2400
# All-Time Low %                                                1.4700
# ATR                                                           0.0200
# Volatility W %                                                0.0200
# Volatility M %                                                0.0200
# Volume, M                                                     1.5127
# Avg Volume, M                                                 1.5700
# Rel Volume                                                    0.9700
# Price                                                        49.9200
# Change %                                                      0.0200
# Dividend %                                                    4.4600
# Sharpe 3d                                                 23287.5767
# Sortino 3d                                               100000.0000
# Omega 3d                                                 100000.0000
# Sharpe 5d                                                    -1.3355
# Sortino 5d                                                   -1.6861
# Omega 5d                                                      0.7876
# Sharpe 10d                                                   -0.2652
# Sortino 10d                                                  -0.3384
# Omega 10d                                                     0.9515
# Sharpe 15d                                                   -0.1291
# Sortino 15d                                                  -0.1599
# Omega 15d                                                     0.9764
# Sharpe 30d                                                    0.0370
# Sortino 30d                                                   0.0536
# Omega 30d                                                     1.0062
# Sharpe 60d                                                    1.0515
# Sortino 60d                                                   1.5891
# Omega 60d                                                     1.1776
# Sharpe 120d                                                   0.9057
# Sortino 120d                                                  1.4270
# Omega 120d                                                    1.1502
# Sharpe 250d                                                   2.4143
# Sortino 250d                                                  4.0612
# Omega 250d                                                    1.4685
# Name: TBIL, dtype: object
