# %%
# #### String Representation of a List of Dictionaries

# you are a highly skilled and experienced quantitative trader working for Goldman Sachs. you are also an expert python coder experience writing codes for quantitative trading. Your primary responsibility is to 
# write python codes to identify and construct portfolios that will outperform the market based on rigorous data analysis and sophisticated financial modeling. 

# Write python code to select 50 Tickers that is expected to outperform the market in the next 5, 10, 15, 30, 60 and 120 days. Use the correlation and or covariance matrices to reduce the 50 selected tickers to 10 tickers portfolio that is expected to outperform the market in the next 5, 10, 15, 30, 60 and 120 days.

# You are given three pandas dataframes: df_data, df_correlation_matrix, and df_covariance_matrix.
# df_data index:
# ---
# Ticker
# ---  
# df_data.info():
# ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, UBS to PCVX
# Data columns (total 49 columns):
#  #   Column           Non-Null Count  Dtype  
# ---  ------           --------------  -----  
#  0   Dividend %       1118 non-null   float64
#  1   Perf Week %      1379 non-null   float64
#  2   Perf Month %     1379 non-null   float64
#  3   Perf Quart %     1379 non-null   float64
#  4   Perf Half %      1379 non-null   float64
#  5   Perf Year %      1379 non-null   float64
#  6   Perf YTD %       1379 non-null   float64
#  7   Beta             1378 non-null   object 
#  8   ATR              1379 non-null   object 
#  9   Volatility W %   1379 non-null   float64
#  10  Volatility M %   1379 non-null   float64
#  11  SMA20 %          1379 non-null   float64
#  12  SMA50 %          1379 non-null   float64
#  13  SMA200 %         1379 non-null   float64
#  14  50D High %       1379 non-null   float64
#  15  50D Low %        1379 non-null   float64
#  16  52W High %       1379 non-null   float64
#  17  52W Low %        1379 non-null   float64
#  18  All-Time High %  1378 non-null   float64
#  19  All-Time Low %   1377 non-null   float64
#  20  RSI              1379 non-null   object 
#  21  Gap %            1379 non-null   float64
#  22  Rel Volume       1379 non-null   object 
#  23  Price            1379 non-null   object 
#  24  Change %         1379 non-null   float64
#  25  MktCap AUM, M    980 non-null    float64
#  26  Avg Volume, M    1379 non-null   float64
#  27  Volume, M        1379 non-null   float64
#  28  Sharpe 5d        1379 non-null   float64
#  29  Sortino 5d       1379 non-null   float64
#  30  Omega 5d         1329 non-null   float64
#  31  Sharpe 10d       1379 non-null   float64
#  32  Sortino 10d      1379 non-null   float64
#  33  Omega 10d        1379 non-null   float64
#  34  Sharpe 15d       1379 non-null   float64
#  35  Sortino 15d      1379 non-null   float64
#  36  Omega 15d        1379 non-null   float64
#  37  Sharpe 30d       1379 non-null   float64
#  38  Sortino 30d      1379 non-null   float64
#  39  Omega 30d        1379 non-null   float64
#  40  Sharpe 60d       1379 non-null   float64
#  41  Sortino 60d      1379 non-null   float64
#  42  Omega 60d        1379 non-null   float64
#  43  Sharpe 120d      1379 non-null   float64
#  44  Sortino 120d     1379 non-null   float64
#  45  Omega 120d       1379 non-null   float64
#  46  Sharpe 250d      1379 non-null   float64
#  47  Sortino 250d     1379 non-null   float64
#  48  Omega 250d       1379 non-null   float64
# dtypes: float64(44), object(5)
# memory usage: 538.7+ KB
# ---
# df_data column descripton:
# ---  
# Ticker: The stock symbol or identifier for the company.

# Dividend %: The annual dividend yield expressed as a percentage of the current stock price.

# Perf Week %: The percentage price change over the past week.

# Perf Month %: The percentage price change over the past month.

# Perf Quart %: The percentage price change over the past quarter (3 months).

# Perf Half %: The percentage price change over the past half-year (6 months).

# Perf Year %: The percentage price change over the past year (52 weeks).

# Perf YTD %: The percentage price change from the beginning of the current calendar year to date.

# Beta: A measure of a stock's volatility relative to the overall market (usually S&P 500). A beta of 1 indicates the stock moves with the market. Greater than 1 is more volatile, less than 1 is less volatile.

# ATR (Average True Range): A technical analysis indicator measuring the average price range of a stock over a specific period (often 14 days). It represents the stock's volatility.

# Volatility W %: The volatility (standard deviation of price changes) calculated over the past week.

# Volatility M %: The volatility calculated over the past month.

# SMA20 %: The percentage difference between the current price and the 20-day Simple Moving Average.

# SMA50 %: The percentage difference between the current price and the 50-day Simple Moving Average.

# SMA200 %: The percentage difference between the current price and the 200-day Simple Moving Average.

# 50D High %: The percentage difference between the current price and the 50-day high price.

# 50D Low %: The percentage difference between the current price and the 50-day low price.

# 52W High %: The percentage difference between the current price and the 52-week high price.

# 52W Low %: The percentage difference between the current price and the 52-week low price.

# All-Time High %: The percentage difference between the current price and the all-time high price.

# All-Time Low %: The percentage difference between the current price and the all-time low price.

# RSI (Relative Strength Index): A momentum oscillator that measures the speed and change of price movements. Ranges from 0-100, commonly used to identify overbought (above 70) and oversold (below 30) conditions.

# Gap %: The percentage difference between the previous day's closing price and the current day's opening price.

# Rel Volume (Relative Volume): The ratio of the current trading volume to the average trading volume over a specified period (often the past 30 days). Values above 1 indicate higher than average volume.

# Price: The current trading price of the stock.

# Change %: The percentage change in the stock price from the previous day's close.

# MktCap AUM, M (Market Capitalization or Assets Under Management, Millions): The total market value of a company's outstanding shares (market cap) or the total value of assets managed by a fund (AUM), expressed in millions of dollars.

# Avg Volume, M (Average Volume, Millions): The average number of shares traded per day, expressed in millions.

# Volume, M (Volume, Millions): The number of shares traded on the current day, expressed in millions.

# Sharpe (5d, 10d, 15d, 30d, 60d, 120d, 250d): The Sharpe ratio measures risk-adjusted return. It represents the excess return earned per unit of risk (volatility). Higher is better. Calculated over different timeframes (5 days, 10 days, etc.).

# Sortino (5d, 10d, 15d, 30d, 60d, 120d, 250d): Similar to the Sharpe ratio, but only penalizes downside risk (negative volatility). Higher is better. Calculated over different timeframes.

# Omega (5d, 10d, 15d, 30d, 60d, 120d, 250d): A risk-return performance measure that uses the entire return distribution. Values above 1 indicate more upside potential than downside risk. Calculated over different timeframes.
# ---
# df_correlation_matrix.info():
# ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, UBS to PCVX
# Columns: 1379 entries, UBS to PCVX
# dtypes: float64(1379)
# memory usage: 14.5+ MB
# ---
# df_covariance_matrix.info():
# ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, UBS to PCVX
# Columns: 1379 entries, UBS to PCVX
# dtypes: float64(1379)
# memory usage: 14.5+ MB
# ---

# %%
import pandas as pd
# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
# pd.set_option('display.width', None)        # Let the display adjust to the window
# pd.set_option('display.max_colwidth', None) # Show full content of each cell


# Configure display settings
pd.set_option('display.max_rows', 100)
# pd.set_option('display.width', 120)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
path_data = '..\data\df_finviz_n_ratios.pkl'
path_corr = '..\data\df_correlation_matrix.pkl'
path_covar = '..\data\df_covariance_matrix.pkl'

# %%
df_data = pd.read_pickle(path_data)
df_corr = pd.read_pickle(path_corr)
df_covar = pd.read_pickle(path_covar)
display(df_data.head(), df_corr.head(), df_covar.head())
# Out:
#                       Company  Dividend %  Perf Week %  Perf Month %  \
# Ticker
# UBS              UBS Group AG        2.99        -4.16         -0.91
# INTC               Intel Corp        0.47        16.52          6.98
# ADI        Analog Devices Inc        1.88        -7.58          1.76
# IBN       ICICI Bank Ltd. ADR        0.89         5.17          1.53
# TD      Toronto Dominion Bank        4.94        -1.04         -1.70
#
#         Perf Quart %  Perf Half %  Perf Year %  Perf YTD %  Beta   ATR  \
# Ticker
# UBS             3.28        12.86         4.78        7.95  1.14  0.92
# INTC           19.30        22.45       -46.84       19.95  1.08  1.47
# ADI            -3.18        -7.25         4.79       -1.75  1.05  7.31
# IBN            -5.70         0.34        12.09       -1.91  0.69  0.41
# TD             10.96        -4.52        -2.47       10.69  0.73  1.04
#
#         Volatility W %  Volatility M %  SMA20 %  SMA50 %  SMA200 %  \
# Ticker
# UBS               2.15            2.04    -1.90    -2.08      3.89
# INTC              4.56            6.45     4.64    12.58      0.34
# ADI               3.42            3.20    -7.15    -4.15     -6.36
# IBN               1.50            1.21     3.43     2.48      0.67
# TD                1.94            1.58    -0.63     2.18      2.77
#
#         50D High %  50D Low %  52W High %  52W Low %  All-Time High %  \
# Ticker
# UBS          -8.68       8.58       -8.68      25.86            -8.68
# INTC        -12.70      28.40      -47.04      29.93           -68.28
# ADI         -15.52       3.96      -15.52      14.34           -15.52
# IBN          -3.11       6.84       -8.87      16.58            -8.87
# TD           -3.16      11.97       -9.21      14.99           -31.49
#
#         All-Time Low %    RSI  Gap % Rel Volume   Price  Change %  \
# Ticker
# UBS             374.93  47.29   1.83       2.26   32.73      3.22
# INTC           6949.95  59.30  -0.13       1.23   24.05      1.48
# ADI           22673.03  41.26   1.82       0.69  208.75      2.43
# IBN            6355.55  62.04   0.45       1.12   29.29      1.17
# TD             1148.85  52.00   0.80       0.45   58.93      2.18
#
#         MktCap AUM, M  Avg Volume, M  Volume, M  Sharpe 5d  Sortino 5d  \
# Ticker
# UBS         104270.00           3.23       7.31       4.75       12.04
# INTC        104140.00          94.78     116.40      11.60      204.64
# ADI         103540.00           3.74       2.59      -5.79       -7.30
# IBN         103450.00           4.08       4.57      40.22         inf
# TD          103230.00           2.29       1.03       0.62        1.08
#
#         Omega 5d  Sharpe 10d  Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  \
# Ticker
# UBS         2.14       -2.31        -2.92       0.70       -0.77        -0.98
# INTC       26.78        2.01         4.77       1.50        0.12         0.23
# ADI         0.41       -6.44        -6.97       0.38       -5.98        -6.55
# IBN          NaN        8.50        19.72       3.39        4.49         9.89
# TD          1.10       -1.38        -1.96       0.81       -0.89        -1.23
#
#         Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  \
# Ticker
# UBS          0.88       -1.62        -1.93       0.75        0.41
# INTC         1.02        2.51         5.45       1.56        1.17
# ADI          0.40       -0.09        -0.16       0.98       -0.30
# IBN          2.06        0.86         1.23       1.15       -1.74
# TD           0.87        1.39         2.36       1.27        2.80
#
#         Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  \
# Ticker
# UBS            0.53       1.08         0.67          0.89        1.13
# INTC           2.27       1.24         0.56          0.99        1.11
# ADI           -0.44       0.95        -0.46         -0.66        0.92
# IBN           -2.17       0.75        -0.76         -1.09        0.87
# TD             5.32       1.64        -0.79         -0.97        0.85
#
#         Sharpe 250d  Sortino 250d  Omega 250d
# Ticker
# UBS            0.18          0.24        1.03
# INTC          -0.76         -1.02        0.86
# ADI            0.30          0.45        1.05
# IBN            0.54          0.78        1.11
# TD             0.06          0.08        1.01
# Symbol   UBS  INTC   ADI   IBN    TD   SAN  MELI  SMFG  LRCX   KKR   UPS  \
# Symbol
# UBS     1.00 -0.40  0.41  0.34  0.17  0.54  0.55  0.76 -0.28  0.70 -0.43
# INTC   -0.40  1.00 -0.35 -0.68 -0.18 -0.25 -0.75 -0.56  0.75 -0.70  0.75
# ADI     0.41 -0.35  1.00  0.44  0.10  0.22  0.50  0.42  0.08  0.27 -0.32
# IBN     0.34 -0.68  0.44  1.00  0.12  0.05  0.68  0.54 -0.56  0.75 -0.45
# TD      0.17 -0.18  0.10  0.12  1.00  0.42  0.51  0.07 -0.25  0.07 -0.25
#
# Symbol    MO   APP    SO   AMT   ICE   ELV  WELL  KLAC   ENB  EMXC   HYG  \
# Symbol
# UBS     0.63  0.72  0.50  0.08  0.61 -0.66  0.72  0.03  0.71  0.09  0.73
# INTC   -0.81 -0.56 -0.83 -0.45 -0.74  0.48 -0.79  0.12 -0.81 -0.20 -0.81
# ADI     0.37  0.09  0.56  0.47  0.41  0.00  0.38  0.56  0.22  0.62  0.38
# IBN     0.75  0.49  0.74  0.49  0.68 -0.48  0.68 -0.15  0.68  0.51  0.75
# TD      0.26  0.05  0.40  0.52  0.54  0.10  0.37  0.19  0.28  0.30  0.36
#
# Symbol  DYNF   VOT   SLV  DGRW  FNDF  VOOG   PFF   TIP   GDX   IWV  AVUV  \
# Symbol
# UBS     0.79  0.79  0.62  0.74  0.37  0.78  0.60  0.52  0.55  0.79  0.55
# INTC   -0.70 -0.55 -0.55 -0.72 -0.21 -0.67 -0.65 -0.77 -0.65 -0.68 -0.44
# ADI     0.42  0.16  0.60  0.51  0.52  0.43  0.41  0.52  0.51  0.39  0.21
# IBN     0.75  0.59  0.58  0.82  0.25  0.71  0.80  0.71  0.59  0.75  0.68
# TD      0.13  0.09  0.17  0.26  0.67  0.06  0.41  0.55  0.52  0.14  0.03
#
# Symbol  CGDV  VCLT   EMB  MOAT   EWJ  MTUM  VTIP   SCI   PSO   PNW  SWKS  \
# Symbol
# UBS     0.74  0.30  0.66  0.61  0.37  0.84  0.70  0.51  0.70  0.57 -0.51
# INTC   -0.77 -0.61 -0.80 -0.71 -0.00 -0.58 -0.82 -0.61 -0.64 -0.82  0.40
# ADI     0.45  0.48  0.44  0.30  0.30  0.37  0.40  0.21  0.10  0.39  0.03
# IBN     0.78  0.66  0.75  0.78  0.29  0.62  0.69  0.76  0.55  0.76 -0.17
# TD      0.36  0.53  0.48  0.30  0.54  0.16  0.39  0.16  0.20  0.41 -0.15
#
# Symbol   HLI  AVTR  FUTU  NBIX   ITT   RTO    PR  ALLE   UHS  VTRS  WTRG  \
# Symbol
# UBS     0.70 -0.56  0.70 -0.23  0.65 -0.40 -0.30  0.27  0.06  0.01  0.04
# INTC   -0.75  0.23 -0.48  0.30 -0.52  0.41  0.77 -0.43 -0.51 -0.22 -0.31
# ADI     0.27 -0.22  0.34 -0.24  0.25 -0.02 -0.47  0.08  0.43 -0.13  0.44
# IBN     0.76 -0.21  0.41 -0.39  0.70 -0.30 -0.57  0.60  0.51  0.52  0.48
# TD      0.17  0.09  0.27 -0.42  0.19 -0.14 -0.34  0.42  0.42 -0.12  0.15
#
# Symbol  BSAC   LKQ   KMX   SNX   AIZ   FCX  CHTR   LYG   HLT   ALL   MET  \
# Symbol
# UBS     0.55 -0.36  0.46  0.73  0.63 -0.49  0.56  0.55  0.78  0.56  0.75
# INTC   -0.37  0.84 -0.20 -0.37 -0.65  0.61 -0.69 -0.55 -0.58 -0.72 -0.63
# ADI     0.39 -0.46 -0.03  0.30  0.02  0.04  0.28  0.53  0.24  0.14  0.24
# IBN     0.27 -0.71  0.33  0.05  0.64 -0.33  0.72  0.35  0.63  0.71  0.68
# TD      0.62  0.07  0.22  0.13  0.19 -0.20  0.19  0.57  0.18  0.32  0.30
#
# Symbol  MPLX  ADSK  MNST   TFC    CM   NSC   JCI  PAYX   PSA  NXPI   NEM  \
# Symbol
# UBS     0.76  0.68 -0.12  0.68  0.63  0.39  0.76  0.75  0.31 -0.34  0.10
# INTC   -0.61 -0.55  0.54 -0.71 -0.74 -0.34 -0.64 -0.70 -0.66  0.54 -0.50
# ADI     0.17  0.14 -0.43  0.27  0.24 -0.17  0.34  0.24  0.43  0.38  0.54
# IBN     0.49  0.71 -0.23  0.71  0.79  0.41  0.64  0.60  0.78 -0.34  0.47
# TD      0.26  0.14 -0.09  0.26  0.22  0.38  0.17  0.30  0.48 -0.22  0.56
#
# Symbol   AEM  PCAR   PSX   WFC   IBM   ABT   LIN   NVS   MCD    GE  SHEL  \
# Symbol
# UBS     0.70  0.29 -0.51  0.75  0.71  0.67  0.22  0.15  0.52  0.69 -0.39
# INTC   -0.78  0.41  0.84 -0.43 -0.64 -0.52 -0.15 -0.49 -0.63 -0.68  0.35
# ADI     0.38 -0.42 -0.44  0.06  0.17  0.06  0.15  0.62  0.07  0.38  0.12
# IBN     0.63 -0.22 -0.70  0.38  0.56  0.31  0.25  0.43  0.56  0.50 -0.44
# TD      0.41 -0.23  0.03 -0.03  0.43  0.48  0.72  0.53  0.48  0.48  0.10
#
# Symbol   PEP  HSBC  PLTR   ACN   TMO     T   AXP    MS    VZ   DIS   NOW  \
# Symbol
# UBS    -0.62  0.73  0.72  0.61 -0.28  0.73  0.75  0.80  0.44  0.21  0.63
# INTC    0.31 -0.60 -0.58 -0.49  0.01 -0.72 -0.70 -0.61 -0.49  0.29 -0.67
# ADI    -0.01  0.31  0.09 -0.01  0.04  0.31  0.23  0.22  0.39 -0.51  0.11
# IBN    -0.23  0.40  0.47  0.54 -0.21  0.63  0.66  0.60  0.59 -0.20  0.70
# TD      0.07  0.22  0.18  0.38  0.40  0.34  0.16  0.06  0.55 -0.25  0.04
#
# Symbol   RTX  ANSS   AWK   DTE  DXCM   LYV  TSCO   WDS    IP   EQR  BEKE  \
# Symbol
# UBS     0.66  0.51  0.09  0.58 -0.39  0.77  0.64 -0.49  0.76  0.44  0.57
# INTC   -0.85  0.07 -0.53 -0.78  0.87 -0.49 -0.56  0.80 -0.73 -0.81 -0.46
# ADI     0.37 -0.23  0.56  0.43 -0.42  0.05  0.60 -0.16  0.40  0.52  0.33
# IBN     0.62  0.07  0.53  0.64 -0.79  0.48  0.55 -0.54  0.71  0.84  0.47
# TD      0.43 -0.16  0.43  0.50 -0.33  0.14  0.21 -0.06  0.10  0.38  0.16
#
# Symbol   CHD   HPQ   TTD   AEE    BR   TEF  KEYS  BIDU   DOW   CCL   TER  \
# Symbol
# UBS     0.37  0.40  0.33  0.69  0.76 -0.04  0.61 -0.28 -0.66  0.76 -0.03
# INTC   -0.15 -0.39 -0.48 -0.75 -0.67 -0.28 -0.31  0.60  0.65 -0.54  0.02
# ADI     0.03  0.76  0.21  0.19  0.17  0.46 -0.07 -0.29 -0.11  0.18  0.63
# IBN     0.08  0.65  0.68  0.61  0.57  0.44  0.37 -0.48 -0.51  0.63  0.05
# TD     -0.12 -0.01 -0.22  0.37  0.23  0.46  0.22  0.08 -0.05 -0.01 -0.22
#
# Symbol   BCH   KIM  ITCI   UNM  DLTR   PAA  INSM   EBR   IEX   MDB  UTHR  \
# Symbol
# UBS     0.50  0.50  0.71  0.75 -0.58  0.68  0.57 -0.51 -0.07 -0.33  0.57
# INTC   -0.51 -0.77 -0.47 -0.62  0.85 -0.38 -0.74  0.58  0.44  0.51 -0.79
# ADI     0.48  0.32  0.09  0.10 -0.40  0.14  0.65 -0.31 -0.53 -0.56  0.53
# IBN     0.26  0.87  0.21  0.54 -0.81  0.22  0.72 -0.54 -0.14 -0.33  0.86
# TD      0.58  0.23  0.30  0.13 -0.29  0.38  0.24  0.34 -0.19 -0.01  0.16
#
# Symbol   WLK   JHX   WPC  GLPI  HOLX    RL  CHWY  ILMN   DUK   CME   BTI  \
# Symbol
# UBS    -0.63 -0.25  0.36  0.54 -0.46  0.81  0.74  0.08  0.54  0.66  0.64
# INTC    0.63  0.34 -0.45 -0.76  0.04 -0.49 -0.76 -0.26 -0.84 -0.56 -0.82
# ADI    -0.07 -0.37  0.44  0.42  0.01  0.17  0.40 -0.07  0.46 -0.01  0.28
# IBN    -0.49 -0.08  0.35  0.79  0.18  0.40  0.68  0.50  0.72  0.39  0.67
# TD     -0.08  0.42  0.71  0.48  0.03  0.16  0.23 -0.05  0.45  0.28  0.42
#
# Symbol  RELX    WM    BP  CRWD   AON   SHW    CI  MDLZ    BN   AJG   CVS  \
# Symbol
# UBS     0.76  0.60 -0.46  0.58  0.66  0.47 -0.56 -0.51  0.75  0.69 -0.08
# INTC   -0.70 -0.20  0.75  0.02 -0.63 -0.60  0.48  0.19 -0.72 -0.73  0.60
# ADI     0.55  0.13 -0.34  0.13  0.10  0.14 -0.11  0.05  0.28  0.38 -0.31
# IBN     0.66  0.31 -0.83  0.06  0.58  0.69 -0.35 -0.11  0.74  0.59 -0.52
# TD      0.38  0.27  0.02 -0.23  0.39  0.48  0.29  0.39  0.20  0.43  0.42
#
# Symbol  BBVA   MMM  EQIX   MCK   GSK  BSCQ  DFSD  ISTB   IDV  FIXD  FELC  \
# Symbol
# UBS     0.42  0.68  0.69  0.43 -0.49  0.69  0.68  0.63  0.54  0.37  0.79
# INTC    0.01 -0.85 -0.65 -0.17  0.38 -0.84 -0.84 -0.85 -0.60 -0.72 -0.68
# ADI    -0.06  0.35  0.20  0.13 -0.03  0.36  0.40  0.42  0.56  0.47  0.40
# IBN    -0.20  0.65  0.71  0.07 -0.51  0.73  0.73  0.74  0.52  0.67  0.76
# TD      0.46  0.44  0.18 -0.24  0.23  0.36  0.37  0.43  0.59  0.56  0.12
#
# Symbol   DSI   PGX  URTH  SPXL  BBEU  NVDL  VSGX  EEMV  PYLD  BBUS  DFSV  \
# Symbol
# UBS     0.76  0.48  0.81  0.77  0.41  0.46  0.63  0.55  0.67  0.79  0.59
# INTC   -0.63 -0.60 -0.69 -0.62 -0.28 -0.34 -0.55 -0.72 -0.84 -0.69 -0.46
# ADI     0.44  0.39  0.46  0.43  0.55  0.63  0.62  0.51  0.42  0.41  0.22
# IBN     0.78  0.75  0.75  0.76  0.15  0.58  0.63  0.82  0.74  0.76  0.68
# TD      0.06  0.51  0.23  0.09  0.61 -0.27  0.57  0.44  0.41  0.14  0.07
#
# Symbol  SCHC   CWB   IXJ  BINC  FNDA  SPAB  FTCS  INDA   IJK  QYLD  SRLN  \
# Symbol
# UBS     0.49  0.78  0.03  0.70  0.64  0.43  0.67 -0.27  0.58  0.79  0.77
# INTC   -0.41 -0.64 -0.27 -0.83 -0.57 -0.76 -0.71 -0.21 -0.33 -0.64 -0.76
# ADI     0.64  0.23  0.51  0.40  0.27  0.48  0.37  0.48  0.19  0.28  0.32
# IBN     0.53  0.69  0.26  0.73  0.76  0.70  0.78  0.49  0.60  0.62  0.67
# TD      0.62  0.15  0.56  0.39  0.12  0.54  0.38  0.06 -0.01  0.18  0.16
#
# Symbol   JNK   XLG  DFIC  SCHI   FXI   IJJ  CIBR  PAVE  HEFA  DBEF  AVEM  \
# Symbol
# UBS     0.73  0.77  0.55  0.54  0.71  0.74  0.80  0.62  0.82  0.83  0.47
# INTC   -0.81 -0.69 -0.41 -0.82 -0.58 -0.64 -0.59 -0.40 -0.42 -0.42 -0.46
# ADI     0.39  0.46  0.56  0.46  0.34  0.25  0.19  0.09  0.46  0.45  0.74
# IBN     0.75  0.75  0.42  0.77  0.50  0.73  0.56  0.60  0.35  0.35  0.65
# TD      0.36  0.07  0.66  0.49  0.28  0.17  0.22  0.06  0.29  0.29  0.27
#
# Symbol  SPTI   ASX   GFS   TSN  EXPE   PHM    EC   SYF  TROW   WSM   WSO  \
# Symbol
# UBS     0.41  0.15 -0.41 -0.04  0.68 -0.02 -0.40  0.71  0.23  0.65  0.58
# INTC   -0.77  0.55  0.79 -0.44 -0.54 -0.29  0.61 -0.64  0.24 -0.34 -0.54
# ADI     0.46  0.26 -0.12  0.03  0.09  0.29 -0.06  0.18  0.01 -0.00  0.56
# IBN     0.68 -0.27 -0.53  0.43  0.56  0.50 -0.72  0.67  0.19  0.19  0.70
# TD      0.55 -0.27 -0.41  0.31  0.15  0.35 -0.05 -0.01 -0.52  0.04  0.06
#
# Symbol    KB   HPE  INVH   LII  BIIB   FMX   IFF  SSNC    LH  NTRA  AAPL  \
# Symbol
# UBS     0.38  0.63 -0.47  0.67 -0.63 -0.65 -0.17  0.71  0.69  0.73  0.61
# INTC   -0.52 -0.38  0.23 -0.75  0.64  0.81 -0.19 -0.73 -0.67 -0.70 -0.78
# ADI     0.53  0.45  0.22  0.46  0.04 -0.34  0.54  0.26  0.11  0.23  0.59
# IBN     0.68  0.54 -0.06  0.83 -0.48 -0.71  0.30  0.56  0.53  0.62  0.81
# TD      0.12 -0.18  0.17  0.17 -0.19 -0.06  0.17  0.46  0.35  0.06  0.09
#
# Symbol  NVDA  MSFT  AMZN  GOOG  GOOGL  META  BRK-B  BRK-A  AVGO   TSM  TSLA  \
# Symbol
# UBS     0.66  0.12  0.68  0.54   0.53  0.78   0.69   0.69  0.69  0.75  0.62
# INTC   -0.61  0.13 -0.43 -0.37  -0.37 -0.60  -0.70  -0.69 -0.63 -0.69 -0.60
# ADI     0.62  0.37  0.08  0.34   0.34  0.17   0.31   0.31  0.30  0.48  0.15
# IBN     0.73  0.27  0.45  0.35   0.35  0.49   0.64   0.63  0.53  0.70  0.64
# TD     -0.08 -0.38 -0.09 -0.34  -0.34  0.27   0.46   0.46  0.07  0.01 -0.07
#
# Symbol   LLY   WMT   JPM     V   XOM    MA   UNH  ORCL   HSY  VICI   HIG  \
# Symbol
# UBS     0.19  0.76  0.81  0.73 -0.21  0.73  0.15  0.67 -0.63  0.37  0.58
# INTC   -0.32 -0.75 -0.63 -0.46  0.11 -0.57 -0.55 -0.64  0.36 -0.68 -0.74
# ADI     0.68  0.30  0.21  0.02 -0.01  0.05  0.32  0.36  0.02  0.37  0.35
# IBN     0.31  0.67  0.53  0.31  0.07  0.48  0.65  0.80 -0.28  0.67  0.74
# TD      0.40  0.21  0.19  0.19  0.22  0.30  0.32  0.20  0.06  0.59  0.44
#
# Symbol   BRO  IDXX   WEC   WPM  DKNG   VRT  CSGP    IR  PBR-A   RMD   GIS  \
# Symbol
# UBS     0.68 -0.49  0.66  0.58  0.20  0.58 -0.40  0.10  -0.45  0.55 -0.55
# INTC   -0.77  0.65 -0.77 -0.69  0.40 -0.41  0.72  0.04   0.36 -0.83  0.04
# ADI     0.40 -0.12  0.22  0.50 -0.37  0.15 -0.63  0.14  -0.07  0.37 -0.03
# IBN     0.69 -0.60  0.62  0.64 -0.23  0.52 -0.63  0.44  -0.30  0.73  0.01
# TD      0.37  0.16  0.42  0.41  0.09 -0.21  0.04 -0.10   0.09  0.31  0.28
#
# Symbol   STZ   IQV  GOLD   WTW    DD   WIT  RACE   MCO   RIO   HCA    PH  \
# Symbol
# UBS    -0.71 -0.58  0.03  0.72  0.34 -0.37  0.39  0.66 -0.19 -0.03  0.68
# INTC    0.55  0.43 -0.33 -0.68 -0.40  0.24 -0.52 -0.81  0.28 -0.31 -0.63
# ADI    -0.14 -0.20  0.45  0.13  0.67  0.14  0.37  0.47  0.23  0.36  0.11
# IBN    -0.22 -0.36  0.41  0.60  0.64  0.15  0.50  0.77 -0.15  0.31  0.65
# TD     -0.26  0.23  0.61  0.30  0.33  0.02  0.58  0.35  0.07  0.52  0.26
#
# Symbol    TT  CTAS   TRI  ABNB  DASH   BAM  MSTR   APO  SCCO  INFY   APH  \
# Symbol
# UBS     0.57  0.57  0.53 -0.23  0.69  0.75  0.69  0.70 -0.37  0.44  0.63
# INTC   -0.70 -0.74 -0.47  0.86 -0.52 -0.60 -0.48 -0.53  0.47 -0.75 -0.55
# ADI     0.44  0.42  0.65 -0.34 -0.05  0.14  0.04  0.14  0.06  0.38  0.53
# IBN     0.84  0.81  0.39 -0.56  0.42  0.63  0.52  0.63 -0.22  0.82  0.65
# TD      0.09  0.32  0.28 -0.27  0.22  0.14 -0.12 -0.10 -0.13  0.29 -0.26
#
# Symbol  ORLY   TDG   ITW  FTNT   TPR    DT  APTV  BURL    BJ   VIV   UDR  \
# Symbol
# UBS     0.68  0.68  0.53  0.71  0.75  0.69 -0.41  0.55  0.74 -0.23  0.49
# INTC   -0.56 -0.65 -0.22 -0.63 -0.44 -0.64  0.61 -0.70 -0.51  0.18 -0.81
# ADI    -0.01  0.50 -0.11  0.06  0.07  0.18 -0.07  0.39  0.35 -0.19  0.53
# IBN     0.46  0.55  0.44  0.50  0.30  0.57 -0.68  0.76  0.41 -0.08  0.85
# TD      0.34  0.33  0.24  0.25  0.18  0.29  0.02  0.10  0.07  0.65  0.35
#
# Symbol  BLDR  ZBRA   KGC  ARCC   GGG   BAH   PNR  FSLR  AMCR   FMS   AVY  \
# Symbol
# UBS    -0.23  0.51  0.74  0.83  0.22 -0.28  0.61 -0.26  0.29  0.70 -0.55
# INTC    0.29 -0.65 -0.79 -0.62  0.21  0.15 -0.63  0.01 -0.64 -0.55  0.53
# ADI    -0.38  0.26  0.48  0.28 -0.44  0.22  0.12  0.54  0.60  0.17  0.12
# IBN    -0.05  0.76  0.69  0.45  0.04  0.17  0.72  0.06  0.60  0.41 -0.33
# TD      0.30 -0.04  0.31  0.15  0.23 -0.09  0.11 -0.18  0.47  0.06 -0.11
#
# Symbol   YPF   VNO  SPHY  DFAX  SDVY  AVDV  SPLV  AVUS  DUHP   VDE  VIGI  \
# Symbol
# UBS     0.62  0.65  0.74  0.57  0.63  0.64  0.68  0.79  0.79  0.11  0.42
# INTC   -0.57 -0.73 -0.81 -0.44 -0.52 -0.57 -0.77 -0.64 -0.69  0.38 -0.53
# ADI     0.02  0.20  0.38  0.64  0.23  0.56  0.36  0.35  0.44 -0.26  0.59
# IBN     0.48  0.76  0.74  0.53  0.71  0.58  0.74  0.73  0.76 -0.19  0.64
# TD     -0.11  0.26  0.35  0.56  0.13  0.57  0.39  0.13  0.26 -0.03  0.63
#
# Symbol  SOXL  SCHH   PRF  XLRE  BBCA   VDC   VPL  DFAU  IAGG  VLUE  ONEQ  \
# Symbol
# UBS    -0.31  0.49  0.79  0.53  0.72  0.63  0.32  0.79  0.63  0.78  0.77
# INTC    0.67 -0.73 -0.67 -0.73 -0.69 -0.78 -0.08 -0.68 -0.84 -0.44 -0.63
# ADI     0.24  0.44  0.34  0.42  0.29  0.42  0.45  0.39  0.30  0.30  0.44
# IBN    -0.40  0.81  0.73  0.79  0.76  0.74  0.37  0.76  0.76  0.64  0.72
# TD     -0.34  0.48  0.27  0.49  0.35  0.40  0.62  0.13  0.34  0.32 -0.00
#
# Symbol    AR  CHRW   THC  LBRDK  LBRDA   JEF  HTHT   SGI  COKE   DVA  TXRH  \
# Symbol
# UBS     0.51  0.58  0.28   0.68   0.68  0.65  0.01  0.68  0.64  0.63  0.61
# INTC   -0.12 -0.86 -0.65  -0.65  -0.64 -0.73  0.40 -0.31 -0.87 -0.69 -0.63
# ADI     0.08  0.49  0.63   0.23   0.22  0.23 -0.25 -0.06  0.48  0.26  0.44
# IBN    -0.08  0.83  0.67   0.70   0.69  0.78 -0.28  0.17  0.71  0.62  0.77
# TD     -0.12  0.21  0.28   0.20   0.19  0.06  0.00  0.36  0.38  0.33 -0.12
#
# Symbol   FTI   CPB  LAMR   BXP  UHAL  UHAL-B   BBD  GMED  MNDY   SYM   RGA  \
# Symbol
# UBS     0.60 -0.46  0.60  0.45  0.47    0.11 -0.46  0.76  0.65 -0.28  0.48
# INTC   -0.43 -0.10 -0.63 -0.68 -0.58   -0.28  0.26 -0.75 -0.52  0.87 -0.55
# ADI     0.05  0.26  0.42  0.33  0.23    0.10 -0.18  0.43  0.51 -0.38  0.47
# IBN     0.46  0.23  0.80  0.84  0.63    0.38 -0.25  0.68  0.66 -0.62  0.69
# TD     -0.02  0.23  0.34  0.30  0.49    0.51  0.39  0.03  0.38 -0.36  0.04
#
# Symbol   ACM   CPT   XPO   BSY   SWK   NLY   SNN    SN    OC  POOL  MORN  \
# Symbol
# UBS     0.50  0.47  0.46 -0.52 -0.07  0.72  0.03  0.68  0.36 -0.09  0.49
# INTC   -0.57 -0.84 -0.29  0.47 -0.18 -0.59 -0.41 -0.83 -0.14  0.30 -0.50
# ADI    -0.03  0.52 -0.20 -0.11  0.14  0.42  0.43  0.44  0.19 -0.44  0.14
# IBN     0.65  0.80  0.42 -0.31  0.21  0.45  0.31  0.72  0.44 -0.18  0.73
# TD      0.10  0.39 -0.15 -0.21  0.65  0.50  0.61  0.35 -0.25  0.17  0.00
#
# Symbol   CAG  ALGN   ACI  EWBC  RIVN  MBLY   MTZ  ALTR  CUBE  UWMC   PRI  \
# Symbol
# UBS    -0.65 -0.56  0.11  0.68  0.14 -0.44  0.75  0.79 -0.03 -0.27  0.75
# INTC    0.09  0.81  0.30 -0.61 -0.22  0.88 -0.70 -0.58 -0.38 -0.13 -0.63
# ADI     0.02 -0.53 -0.34  0.11  0.38 -0.40  0.35  0.35  0.38  0.34  0.20
# IBN    -0.03 -0.60 -0.56  0.67  0.34 -0.72  0.67  0.57  0.60  0.05  0.68
# TD      0.19 -0.12 -0.02  0.05 -0.04 -0.46  0.03 -0.02  0.44  0.42  0.27
#
# Symbol   CNM  SRPT   NIO  ARMK   TLN  SAIA   STN  SEIC  VNOM  AGNC   EGP  \
# Symbol
# UBS    -0.06 -0.44 -0.01  0.61  0.74  0.09 -0.06  0.71  0.55  0.66  0.25
# INTC    0.48  0.28  0.04 -0.78 -0.74  0.42  0.30 -0.49 -0.74 -0.66 -0.26
# ADI    -0.42  0.17  0.21  0.33  0.28 -0.42  0.15 -0.01  0.25  0.50  0.35
# IBN    -0.56  0.01  0.20  0.81  0.70 -0.03  0.09  0.50  0.77  0.54  0.35
# TD     -0.31 -0.28  0.29  0.21  0.22 -0.17 -0.13 -0.03  0.19  0.59  0.69
#
# Symbol   NVT  PAAS   SSB   ORI  BKNG   PFE  SONY   UNP   SNY   BLK  SCHW  \
# Symbol
# UBS    -0.15  0.62  0.61  0.72  0.72 -0.02  0.70  0.30  0.34  0.69  0.53
# INTC    0.51 -0.59 -0.69 -0.79 -0.57 -0.20 -0.55 -0.29 -0.62 -0.71 -0.07
# ADI     0.06  0.57  0.18  0.28  0.27  0.55  0.22 -0.01  0.49  0.21 -0.11
# IBN    -0.15  0.58  0.77  0.66  0.68  0.20  0.44  0.19  0.43  0.76  0.09
# TD     -0.53  0.16  0.28  0.35 -0.03  0.30  0.33  0.74  0.70  0.15 -0.28
#
# Symbol   BSX   SYK  GILD   HON  CMCSA   TTE  VRTX     C    DE   TJX   LOW  \
# Symbol
# UBS     0.80  0.77  0.71  0.62  -0.13 -0.57  0.35  0.79  0.68  0.70  0.50
# INTC   -0.71 -0.51 -0.63 -0.48   0.16  0.58 -0.35 -0.43 -0.39 -0.78 -0.49
# ADI     0.31  0.13  0.19  0.33  -0.04 -0.10  0.70  0.15 -0.03  0.48  0.07
# IBN     0.53  0.50  0.55  0.66   0.25 -0.60  0.42  0.35  0.29  0.78  0.64
# TD      0.27  0.28  0.35 -0.24   0.01  0.19  0.24  0.12  0.29  0.20  0.35
#
# Symbol  AMAT   COP   EDV   CMF  EAGG  DIVO  JHMM  HYLB  BSCP  SCHK  GSIE  \
# Symbol
# UBS    -0.35 -0.61 -0.11  0.46  0.43  0.78  0.73  0.73  0.72  0.79  0.63
# INTC    0.63  0.78 -0.28 -0.74 -0.76 -0.71 -0.60 -0.81 -0.82 -0.69 -0.51
# ADI     0.20 -0.48  0.35  0.30  0.48  0.34  0.23  0.38  0.34  0.40  0.55
# IBN    -0.42 -0.62  0.31  0.77  0.70  0.73  0.71  0.75  0.70  0.76  0.49
# TD     -0.23 -0.12  0.47  0.39  0.54  0.30  0.19  0.36  0.28  0.14  0.64
#
# Symbol  ARKB  REET  SLYV   TFI   KNG  BILS  FBCG  UCON  JMST   DON   IYR  \
# Symbol
# UBS     0.68  0.46  0.61  0.41  0.50  0.72  0.77  0.63  0.71  0.70  0.52
# INTC   -0.40 -0.71 -0.59 -0.65 -0.62 -0.81 -0.59 -0.84 -0.83 -0.63 -0.73
# ADI    -0.03  0.45  0.23  0.26  0.29  0.34  0.41  0.42  0.36  0.25  0.42
# IBN     0.36  0.79  0.76  0.67  0.73  0.68  0.67  0.74  0.70  0.75  0.79
# TD     -0.13  0.52  0.12  0.51  0.46  0.25 -0.06  0.44  0.29  0.19  0.49
#
# Symbol     Z    ZG   GPC  CYBR   GEN   WST   FDS  PSTG  ULTA  ESLT  BF-B  \
# Symbol
# UBS     0.73  0.73 -0.67  0.79  0.69 -0.41  0.52  0.42 -0.11  0.69 -0.66
# INTC   -0.65 -0.65  0.68 -0.56 -0.71  0.56 -0.34 -0.11  0.57 -0.48  0.51
# ADI     0.15  0.14 -0.33  0.15  0.49 -0.59 -0.05  0.30 -0.50 -0.03 -0.24
# IBN     0.66  0.65 -0.65  0.45  0.81 -0.40  0.57 -0.00 -0.32  0.25 -0.26
# TD      0.21  0.22  0.06  0.26  0.11 -0.40  0.07 -0.38 -0.17  0.18 -0.08
#
# Symbol  BF-A   SUI  PAGP   HRL   COO    AU   LNT   CNH   IGV  DFIV  SCHE  \
# Symbol
# UBS    -0.70  0.29  0.70 -0.59  0.07  0.47  0.62  0.52  0.71  0.63  0.63
# INTC    0.59 -0.53 -0.47  0.44 -0.18 -0.58 -0.81 -0.00 -0.54 -0.42 -0.65
# ADI    -0.30  0.24  0.17 -0.55  0.10  0.42  0.37 -0.32  0.13  0.46  0.59
# IBN    -0.35  0.50  0.28 -0.40  0.37  0.40  0.75 -0.03  0.64  0.34  0.74
# TD     -0.10  0.67  0.38 -0.16  0.36  0.54  0.39  0.22  0.02  0.63  0.33
#
# Symbol  SPTM   FVD  DFAS  ESGD   SUB  FLOT  DFAI  IQLT   SCZ  BKLN   EZU  \
# Symbol
# UBS     0.79  0.63  0.66  0.50  0.65  0.74  0.58  0.41  0.44  0.76  0.43
# INTC   -0.69 -0.75 -0.54 -0.35 -0.84 -0.79 -0.44 -0.24 -0.42 -0.77 -0.09
# ADI     0.42  0.34  0.25  0.61  0.32  0.34  0.56  0.60  0.57  0.33  0.34
# IBN     0.76  0.78  0.73  0.35  0.71  0.66  0.44  0.26  0.49  0.69 -0.07
# TD      0.14  0.41  0.09  0.64  0.42  0.22  0.66  0.62  0.67  0.17  0.57
#
# Symbol  VYMI   VSS   MGV  SCHZ  SPSB  KWEB   BHP   ARM  SHOP    BA  PANW  \
# Symbol
# UBS     0.66  0.41  0.76  0.50  0.68  0.61 -0.35  0.53  0.67 -0.10  0.68
# INTC   -0.58 -0.44 -0.72 -0.81 -0.85 -0.37  0.54 -0.11 -0.50  0.51 -0.73
# ADI     0.55  0.69  0.39  0.50  0.38  0.27  0.09  0.56 -0.04 -0.12  0.43
# IBN     0.57  0.65  0.74  0.76  0.73  0.32 -0.25  0.40  0.47 -0.56  0.79
# TD      0.58  0.47  0.37  0.49  0.37  0.23  0.02  0.01  0.11 -0.24  0.11
#
# Symbol    FI   BMY   MDT   ADP    CB  SPOT   ETN   MMC    MU  SBUX   LMT  \
# Symbol
# UBS     0.74  0.62  0.63  0.71  0.47  0.74  0.31  0.58 -0.23  0.67  0.01
# INTC   -0.65 -0.55 -0.56 -0.75 -0.72 -0.62 -0.13 -0.68  0.67 -0.54 -0.55
# ADI     0.16 -0.11  0.19  0.21  0.46  0.16  0.12  0.50  0.14  0.08  0.35
# IBN     0.59  0.48  0.37  0.65  0.74  0.46  0.44  0.63 -0.48  0.41  0.58
# TD      0.25  0.26  0.62  0.29  0.38  0.22 -0.34  0.52 -0.46  0.50  0.34
#
# Symbol   BUD   PLD   NKE  ANET   SPG   KMI   OKE   DEO    JD   BNS   AZO  \
# Symbol
# UBS    -0.39  0.24 -0.43  0.70  0.75  0.75  0.64 -0.54  0.69  0.51  0.58
# INTC    0.26 -0.10  0.60 -0.67 -0.71 -0.72 -0.70  0.56 -0.52 -0.53 -0.52
# ADI     0.23  0.16 -0.27  0.33  0.29  0.24  0.22 -0.27  0.24  0.11 -0.09
# IBN    -0.19  0.16 -0.63  0.69  0.70  0.65  0.74 -0.37  0.46  0.73  0.33
# TD      0.27  0.71 -0.12  0.03  0.27  0.08  0.12 -0.07  0.21  0.17  0.38
#
# Symbol  MRVL   TRV    BK   AFL   FDX  CARR  TEAM   RCL   CSX   BCS   AEP  \
# Symbol
# UBS     0.66  0.64  0.79  0.57 -0.05  0.36  0.65  0.78 -0.18  0.79  0.54
# INTC   -0.49 -0.56 -0.73 -0.83 -0.11 -0.64 -0.31 -0.65  0.47 -0.71 -0.79
# ADI     0.08  0.07  0.29  0.43  0.12  0.55 -0.11  0.23 -0.29  0.38  0.46
# IBN     0.46  0.61  0.65  0.78  0.46  0.81  0.31  0.64 -0.06  0.58  0.61
# TD     -0.14  0.25  0.28  0.42  0.02  0.30  0.00  0.07  0.08  0.27  0.56
#
# Symbol    NU   SLB   CVE  FCNCA  VLTO   TYL   UAL  LPLA   LYB   WRB    EL  \
# Symbol
# UBS     0.20 -0.44 -0.68   0.60  0.26  0.59  0.72  0.68 -0.67  0.64 -0.61
# INTC   -0.25  0.90  0.72  -0.74 -0.77 -0.86 -0.54 -0.22  0.62 -0.58  0.83
# ADI     0.37 -0.45 -0.20   0.27  0.58  0.48  0.07 -0.02 -0.13  0.06 -0.43
# IBN     0.48 -0.68 -0.58   0.70  0.68  0.82  0.49  0.15 -0.51  0.54 -0.77
# TD      0.38 -0.02 -0.19   0.11  0.27  0.27 -0.04 -0.17  0.09  0.33 -0.17
#
# Symbol   TKO   VOD   EXE  BNTX   ATO  CPAY   MKL  SBAC   GPN   GIB  GNRC  \
# Symbol
# UBS     0.73  0.16  0.64  0.66  0.66  0.67  0.76  0.16 -0.17  0.44  0.36
# INTC   -0.74 -0.52 -0.19 -0.57 -0.76 -0.51 -0.50 -0.41  0.34 -0.40 -0.48
# ADI     0.29  0.62 -0.08  0.22  0.26 -0.05  0.20  0.24 -0.71  0.02  0.36
# IBN     0.55  0.55  0.14  0.57  0.70  0.52  0.35  0.55 -0.21  0.50  0.71
# TD      0.21  0.43 -0.11  0.26  0.36  0.24  0.12  0.58  0.01  0.52 -0.11
#
# Symbol   LAD  MTCH   RRX   DBX  ENPH   HII  FRHC  MDGL  SIRI   VFS  HALO  \
# Symbol
# UBS     0.67  0.09 -0.11  0.66 -0.65 -0.64  0.77  0.62 -0.44  0.26  0.45
# INTC   -0.56 -0.24  0.11 -0.53  0.54  0.54 -0.69 -0.29  0.74  0.24 -0.66
# ADI     0.02  0.08 -0.30 -0.03 -0.00 -0.15  0.22  0.12 -0.30  0.21  0.59
# IBN     0.61  0.26  0.16  0.50 -0.49 -0.45  0.56  0.34 -0.45  0.05  0.51
# TD      0.08  0.56 -0.01  0.10 -0.02  0.12  0.19 -0.09 -0.07 -0.29  0.51
#
# Symbol  FBIN  ROIV   GAP   AXS   CMA   KNX   HMY  SNOW   HWM  CPRT   MFC  \
# Symbol
# UBS    -0.08  0.03  0.31  0.77  0.66  0.51  0.53  0.38  0.79  0.40  0.73
# INTC   -0.05 -0.46  0.23 -0.76 -0.62 -0.37 -0.49  0.07 -0.77  0.01 -0.70
# ADI    -0.05  0.22 -0.02  0.33  0.14 -0.05  0.33 -0.34  0.33 -0.22  0.42
# IBN     0.28  0.65 -0.14  0.67  0.71  0.53  0.35 -0.14  0.60  0.19  0.79
# TD      0.37  0.01 -0.39  0.17  0.20  0.12  0.47 -0.17  0.25 -0.27  0.13
#
# Symbol     O   COR   DLR   PBR   AIG   TRP   LNG   AMP    GM   WCN   TGT  \
# Symbol
# UBS     0.21  0.47  0.57  0.07  0.35  0.61  0.73  0.76  0.54  0.59 -0.49
# INTC   -0.64 -0.25 -0.61 -0.20  0.19 -0.79 -0.69 -0.57 -0.48 -0.61  0.62
# ADI     0.43 -0.23  0.28  0.12  0.14  0.29  0.19  0.18  0.29  0.35 -0.32
# IBN     0.59  0.02  0.79  0.04 -0.11  0.79  0.59  0.63  0.69  0.65 -0.40
# TD      0.58  0.25 -0.10  0.35  0.15  0.30  0.14  0.02 -0.16  0.42  0.03
#
# Symbol     E   TAK   NWG    KR   GWW  ASTS   ALB   SUN     G  CFLT   DAY  \
# Symbol
# UBS    -0.45  0.08  0.73  0.59  0.54  0.52 -0.38  0.42  0.75  0.26  0.41
# INTC    0.39 -0.27 -0.76 -0.41 -0.45 -0.84  0.71  0.15 -0.66  0.33 -0.27
# ADI    -0.11  0.14  0.39 -0.13 -0.00  0.47 -0.38 -0.15  0.18 -0.30 -0.22
# IBN    -0.40  0.21  0.63  0.35  0.63  0.72 -0.49 -0.06  0.50 -0.21  0.45
# TD      0.37  0.69  0.25  0.24  0.03  0.41 -0.37  0.37  0.34 -0.38 -0.09
#
# Symbol     X   TME  HSIC   AES   LNW   CHE   CRL   BLD    AA  BRBR   WBS  \
# Symbol
# UBS    -0.02 -0.04  0.46 -0.59 -0.09 -0.17 -0.65 -0.48  0.26  0.71  0.69
# INTC    0.43  0.34 -0.11  0.42  0.15  0.38  0.82  0.65  0.00 -0.51 -0.42
# ADI    -0.16  0.34 -0.26  0.15  0.28 -0.47 -0.44 -0.07  0.29  0.02 -0.04
# IBN    -0.31 -0.24  0.06 -0.31 -0.03 -0.37 -0.57 -0.36  0.31  0.50  0.51
# TD      0.11 -0.31  0.30 -0.08  0.38  0.44 -0.20 -0.03 -0.41 -0.04  0.04
#
# Symbol   AIT   WPP  QGEN   VNQ   IEF  IUSB  VGIT   XLE  DFAC  JPST  SPYG  \
# Symbol
# UBS     0.73  0.11 -0.06  0.52  0.26  0.48  0.41  0.05  0.78  0.71  0.78
# INTC   -0.58 -0.25 -0.33 -0.73 -0.66 -0.79 -0.77  0.42 -0.66 -0.83 -0.67
# ADI     0.15  0.20  0.09  0.41  0.46  0.48  0.47 -0.29  0.38  0.36  0.43
# IBN     0.66  0.59  0.20  0.80  0.60  0.72  0.68 -0.24  0.77  0.69  0.71
# TD      0.10 -0.24 -0.05  0.48  0.57  0.52  0.55  0.04  0.15  0.28  0.06
#
# Symbol  SCHB   LQD  DGRO   VBR  GOVT  SPYV  USMV  SPDW  VONG  COWZ   SHY  \
# Symbol
# UBS     0.79  0.44  0.74  0.67  0.37  0.69  0.70  0.56  0.77  0.61  0.64
# INTC   -0.68 -0.73 -0.75 -0.60 -0.74 -0.69 -0.78 -0.39 -0.65 -0.37 -0.86
# ADI     0.39  0.49  0.39  0.25  0.46  0.36  0.40  0.59  0.41  0.09  0.39
# IBN     0.75  0.73  0.77  0.75  0.67  0.79  0.76  0.42  0.71  0.58  0.73
# TD      0.14  0.53  0.35  0.18  0.54  0.33  0.40  0.65  0.02  0.24  0.41
#
# Symbol   MGK   AME  CPNG  VRSK  TCOM   NET   XEL   GLW   DHI  OTIS   LHX  \
# Symbol
# UBS     0.77  0.51  0.35  0.71  0.65  0.66  0.65  0.78 -0.21  0.48  0.12
# INTC   -0.65 -0.05 -0.67 -0.68 -0.51 -0.33 -0.78 -0.72 -0.19 -0.00 -0.30
# ADI     0.44 -0.19  0.41  0.58  0.12 -0.09  0.23  0.47  0.18  0.31  0.45
# IBN     0.72  0.23  0.64  0.69  0.53  0.19  0.72  0.75  0.35  0.28  0.59
# TD      0.02 -0.02  0.23  0.15 -0.08  0.23  0.28  0.21  0.38  0.23  0.05
#
# Symbol  LULU  CTSH   PWR  CVNA     F   PRU  CCEP  VEEV  RBLX  CBRE   CNP  \
# Symbol
# UBS     0.32  0.69  0.53  0.73 -0.43  0.47  0.65  0.51  0.71  0.71  0.69
# INTC    0.20 -0.61 -0.51 -0.71  0.82 -0.29 -0.72 -0.29 -0.62 -0.75 -0.35
# ADI    -0.47  0.16  0.20  0.28 -0.11  0.48  0.48 -0.26  0.07  0.21  0.24
# IBN    -0.20  0.57  0.63  0.74 -0.43  0.70  0.57  0.30  0.50  0.70  0.31
# TD     -0.22  0.44 -0.16  0.13 -0.24 -0.06  0.45  0.28  0.17  0.32 -0.03
#
# Symbol    IX   TDY    FE   FOX  FOXA  CINF    TU    ZM   ADM   PBA  VRSN  \
# Symbol
# UBS    -0.17  0.78  0.27  0.73  0.73  0.57 -0.31  0.67 -0.64  0.29  0.65
# INTC   -0.11 -0.59 -0.71 -0.74 -0.74 -0.71  0.13 -0.56  0.60 -0.58 -0.36
# ADI     0.37  0.08  0.44  0.27  0.28  0.18  0.17  0.02  0.00  0.48  0.01
# IBN     0.31  0.51  0.67  0.59  0.59  0.79 -0.06  0.58 -0.38  0.74  0.13
# TD      0.30  0.28  0.49  0.25  0.27  0.18  0.45  0.06 -0.07  0.32  0.33
#
# Symbol    ES   FTS   DVN   WAT  CBOE    LI   STE  TOST   EDR   ESS  ERIE  \
# Symbol
# UBS     0.03  0.52 -0.66  0.68  0.45  0.10  0.07  0.71  0.67  0.54  0.02
# INTC   -0.51 -0.80  0.79 -0.52 -0.76  0.30 -0.23 -0.54 -0.69 -0.80 -0.52
# ADI     0.34  0.36 -0.26 -0.08  0.17 -0.46  0.40  0.09  0.21  0.58  0.20
# IBN     0.46  0.73 -0.70  0.37  0.62 -0.23  0.16  0.57  0.61  0.81  0.48
# TD      0.61  0.51 -0.11  0.22  0.53  0.26  0.53  0.03  0.11  0.33  0.63
#
# Symbol   MAA  OKTA  FWONA    RF    UI  YUMC  NTRS  STLD  NTAP   AER   NRG  \
# Symbol
# UBS     0.55 -0.05   0.74  0.63  0.76  0.59  0.77  0.14  0.32  0.75  0.79
# INTC   -0.84  0.52  -0.71 -0.66 -0.71 -0.43 -0.59  0.54 -0.36 -0.64 -0.67
# ADI     0.43 -0.34   0.28  0.22  0.20 -0.06  0.14 -0.32  0.66  0.64  0.33
# IBN     0.76 -0.65   0.60  0.79  0.62  0.42  0.59 -0.20  0.51  0.68  0.54
# TD      0.41 -0.06   0.13  0.20  0.10  0.13  0.14 -0.05 -0.07  0.25  0.19
#
# Symbol  RPRX   DGX   NMR   LUV   PTC  TEVA   PFG   STX    NI  NTNX   CCJ  \
# Symbol
# UBS     0.49  0.67  0.42  0.58  0.14  0.44  0.55  0.42  0.71  0.46  0.30
# INTC   -0.09 -0.77  0.29 -0.48  0.08 -0.70 -0.03 -0.31 -0.78 -0.14  0.01
# ADI    -0.06  0.40 -0.15  0.08 -0.14  0.45  0.24  0.73  0.29 -0.16  0.16
# IBN    -0.20  0.64 -0.25  0.60  0.31  0.56  0.32  0.49  0.68  0.14  0.27
# TD      0.58  0.38  0.07 -0.05 -0.40 -0.11  0.46  0.32  0.31  0.10 -0.50
#
# Symbol     L  XPEV  RYAN  HUBB   BIP   GFL    ON  KSPI   CLX   GFI  DECK  \
# Symbol
# UBS     0.71  0.69  0.62  0.34  0.56  0.65 -0.52 -0.46  0.40  0.26  0.46
# INTC   -0.64 -0.46 -0.75 -0.24 -0.62 -0.73  0.39  0.48 -0.63  0.06 -0.39
# ADI     0.10  0.14  0.37 -0.01  0.38  0.33  0.13  0.20  0.02 -0.07  0.16
# IBN     0.58  0.34  0.76  0.49  0.78  0.71 -0.05 -0.30  0.68 -0.22  0.42
# TD      0.18  0.32  0.32 -0.07  0.32  0.16 -0.23 -0.16  0.30  0.36 -0.39
#
# Symbol  PODD   FNF  VUSB  PDBC  DFEM  IEUR  CGUS  BBAX   EWT  JGRO   IHI  \
# Symbol
# UBS     0.74  0.59  0.71  0.10  0.50  0.37  0.78  0.60  0.62  0.79  0.81
# INTC   -0.72 -0.74 -0.83  0.48 -0.52 -0.25 -0.73 -0.63 -0.53 -0.61 -0.55
# ADI     0.29  0.31  0.35 -0.12  0.71  0.55  0.40  0.54  0.74  0.39  0.16
# IBN     0.69  0.73  0.70 -0.55  0.71  0.14  0.75  0.78  0.74  0.69  0.42
# TD      0.17  0.47  0.29 -0.07  0.30  0.62  0.18  0.44  0.04  0.02  0.39
#
# Symbol  FDVV  ESGE  CGCP   DLN  OMFL   PPA   IXN  SGOL   FEZ   SSO   VOX  \
# Symbol
# UBS     0.74  0.65  0.51  0.77  0.71  0.73  0.70  0.71  0.44  0.78  0.80
# INTC   -0.78 -0.61 -0.80 -0.74 -0.23 -0.78 -0.52 -0.73 -0.06 -0.65 -0.64
# ADI     0.50  0.61  0.48  0.41  0.01  0.34  0.63  0.31  0.29  0.43  0.25
# IBN     0.80  0.70  0.74  0.76  0.26  0.75  0.69  0.60 -0.11  0.76  0.61
# TD      0.26  0.40  0.52  0.30  0.01  0.24 -0.03  0.38  0.57  0.11  0.11
#
# Symbol  TWLO  USFD   BAP  ONON   RCI    RS   CSL     J   RPM  ICLR   MAS  \
# Symbol
# UBS     0.73  0.76  0.65  0.72 -0.63 -0.00 -0.01  0.59  0.61 -0.65  0.42
# INTC   -0.53 -0.68 -0.57 -0.76  0.43  0.62 -0.04 -0.47 -0.55  0.60 -0.46
# ADI    -0.03  0.19  0.11  0.34 -0.04 -0.41  0.37  0.08  0.18 -0.02  0.10
# IBN     0.40  0.64  0.69  0.72 -0.22 -0.29  0.39  0.62  0.69 -0.49  0.55
# TD      0.07  0.19  0.22  0.13  0.01  0.02 -0.06  0.10  0.16 -0.06  0.53
#
# Symbol  JBHT   JBL  ENTG   TLK  CASY  SNAP  BALL   DOC   DPZ   BIL    VT  \
# Symbol
# UBS     0.14  0.69 -0.49 -0.46  0.69 -0.19 -0.61  0.37 -0.17  0.73  0.80
# INTC    0.14 -0.20  0.88  0.56 -0.73  0.50  0.46 -0.78  0.57 -0.81 -0.69
# ADI    -0.38 -0.13 -0.14 -0.15  0.43  0.17 -0.10  0.55 -0.13  0.34  0.48
# IBN     0.14  0.09 -0.61 -0.27  0.76 -0.25 -0.33  0.80 -0.57  0.68  0.77
# TD      0.02  0.07 -0.24  0.17  0.10 -0.54 -0.05  0.33 -0.39  0.23  0.25
#
# Symbol   IAU   VEU  IXUS   MUB  QQQM  JEPI    VV  SGOV   XLV   MBB   IWR  \
# Symbol
# UBS     0.71  0.62  0.62  0.51  0.78  0.76  0.79  0.73  0.20  0.43  0.74
# INTC   -0.73 -0.51 -0.50 -0.74 -0.61 -0.72 -0.69 -0.81 -0.37 -0.76 -0.62
# ADI     0.31  0.62  0.64  0.34  0.46  0.33  0.41  0.34  0.51  0.48  0.23
# IBN     0.60  0.56  0.56  0.75  0.70  0.74  0.75  0.68  0.35  0.69  0.71
# TD      0.38  0.59  0.58  0.44  0.02  0.31  0.14  0.23  0.65  0.54  0.18
#
# Symbol   DIA   IVE   IWB  VTEB  VCSH  SCHG   BSV   MFG  REGN    CL   EPD  \
# Symbol
# UBS     0.78  0.69  0.79  0.53  0.65  0.77  0.60  0.76 -0.56 -0.19  0.75
# INTC   -0.68 -0.69 -0.69 -0.75 -0.85 -0.66 -0.85 -0.48  0.25 -0.40 -0.57
# ADI     0.28  0.36  0.40  0.36  0.42  0.41  0.42  0.16  0.20  0.50  0.12
# IBN     0.72  0.79  0.75  0.76  0.75  0.72  0.74  0.40 -0.19  0.42  0.46
# TD      0.25  0.33  0.14  0.42  0.42  0.02  0.45  0.15  0.12  0.29  0.19
#
# Symbol   RSG   ZTS  IBKR   ECL    GD   BMO    CP   NOC   WMB   MSI  SNPS  \
# Symbol
# UBS     0.69  0.10  0.79  0.66 -0.42  0.65 -0.37  0.12  0.77  0.62 -0.19
# INTC   -0.63 -0.41 -0.58 -0.59  0.16 -0.25  0.57 -0.57 -0.70 -0.80  0.67
# ADI     0.25  0.52  0.16  0.60  0.20 -0.15 -0.25  0.07  0.27  0.35  0.03
# IBN     0.50  0.51  0.48  0.60  0.00  0.22 -0.38  0.49  0.65  0.83 -0.35
# TD      0.41  0.36  0.14  0.48  0.04  0.09  0.44  0.51  0.12  0.16 -0.40
#
# Symbol   EOG   PNC  PYPL  CDNS   IYF  TOTL    FV  QTEC  DIHP   KRE   DXJ  \
# Symbol
# UBS     0.22  0.66  0.58  0.07  0.79  0.45  0.79  0.60  0.37  0.68  0.56
# INTC    0.01 -0.71 -0.64  0.38 -0.68 -0.80 -0.36 -0.02 -0.12 -0.68  0.05
# ADI    -0.23  0.25  0.07 -0.17  0.25  0.47  0.30  0.43  0.50  0.23  0.27
# IBN    -0.00  0.78  0.66 -0.09  0.67  0.71  0.56  0.34  0.14  0.75  0.21
# TD      0.21  0.19  0.05 -0.51  0.21  0.53 -0.01 -0.11  0.65  0.19 -0.20
#
# Symbol  SUSA  SPHD   SHM  XMMO  CGXU  TCAF   GVI  ACWV  PTLC  KBWB   HYD  \
# Symbol
# UBS     0.76  0.61  0.56  0.72  0.32  0.78  0.53  0.67  0.79  0.77  0.63
# INTC   -0.72 -0.82 -0.79 -0.54 -0.11 -0.73 -0.83 -0.78 -0.69 -0.65 -0.78
# ADI     0.42  0.42  0.30  0.22  0.59  0.45  0.46  0.42  0.43  0.22  0.45
# IBN     0.79  0.80  0.72  0.67  0.36  0.78  0.73  0.76  0.76  0.65  0.77
# TD      0.17  0.40  0.53  0.01  0.39  0.18  0.50  0.47  0.14  0.14  0.40
#
# Symbol  TSLL   CMG   CEG    SE  DELL   MAR  EQNR   CRH   COF   USB  WDAY  \
# Symbol
# UBS     0.52 -0.14  0.75  0.78 -0.10  0.69 -0.41  0.74  0.76  0.60  0.22
# INTC   -0.51  0.20 -0.49 -0.70  0.38 -0.33  0.42 -0.58 -0.51 -0.59 -0.03
# ADI     0.09 -0.05  0.29  0.30  0.28  0.01  0.02  0.10  0.07  0.12 -0.45
# IBN     0.59 -0.03  0.41  0.60 -0.04  0.46 -0.52  0.58  0.48  0.73  0.14
# TD     -0.19 -0.61  0.18  0.20 -0.46 -0.02 -0.21  0.31  0.11  0.12  0.18
#
# Symbol   APD   BDX    ET  NTES   EMR   ING   NGG   CNQ   CNI   ROP   HAS  \
# Symbol
# UBS     0.77  0.07  0.73  0.24  0.63  0.19 -0.15 -0.58 -0.61  0.50  0.16
# INTC   -0.75  0.09 -0.60  0.29 -0.23 -0.31 -0.11  0.65  0.79 -0.04 -0.58
# ADI     0.41 -0.12  0.11 -0.29 -0.02  0.59 -0.13 -0.27 -0.25  0.37  0.50
# IBN     0.69 -0.26  0.49 -0.41  0.38  0.20  0.19 -0.48 -0.59  0.23  0.57
# TD      0.18  0.26  0.07  0.06 -0.16  0.47  0.61 -0.17 -0.08  0.41  0.53
#
# Symbol   FRT   EDU  PARA   ADC    WF  ALSN   MOS    KD   SKM  BIRK   DCI  \
# Symbol
# UBS     0.28 -0.65 -0.13  0.55  0.33  0.67 -0.34  0.75  0.19  0.33 -0.05
# INTC   -0.73  0.78  0.46 -0.87 -0.44 -0.66  0.79 -0.48 -0.47 -0.34  0.28
# ADI     0.31 -0.31 -0.25  0.42  0.43  0.10 -0.40  0.19  0.35  0.42  0.02
# IBN     0.81 -0.58 -0.41  0.80  0.55  0.68 -0.69  0.35  0.61  0.17  0.03
# TD      0.30 -0.27 -0.08  0.37  0.58  0.10 -0.12 -0.02  0.55 -0.26 -0.01
#
# Symbol    AM   AYI  MIDD  CBSH  CHDN  HLNE  BERY     D  COIN   KMB    DB  \
# Symbol
# UBS     0.79  0.73  0.48  0.63 -0.19  0.56  0.76  0.51  0.41  0.08  0.70
# INTC   -0.62 -0.43 -0.09 -0.71 -0.16 -0.68 -0.71 -0.82  0.06 -0.48 -0.43
# ADI     0.35  0.08 -0.34  0.23  0.45  0.39  0.27  0.43 -0.18  0.61  0.25
# IBN     0.49  0.51 -0.07  0.72  0.47  0.84  0.66  0.74  0.10  0.45  0.25
# TD      0.31  0.08  0.47  0.13 -0.24  0.23  0.27  0.39 -0.44  0.39  0.31
#
# Symbol   HLN   SRE   HES   KDP  ARES   HMC    SU   CCI   EXC   CMI   ALC  \
# Symbol
# UBS     0.41  0.44 -0.09 -0.05  0.76 -0.56  0.22 -0.16  0.58  0.69  0.30
# INTC   -0.80 -0.65  0.69 -0.50 -0.65  0.74 -0.21 -0.22 -0.56 -0.62 -0.48
# ADI     0.40  0.34 -0.32  0.56  0.21 -0.30  0.23  0.29  0.15  0.10  0.68
# IBN     0.72  0.80 -0.59  0.39  0.63 -0.67  0.12  0.37  0.33  0.61  0.43
# TD      0.57 -0.00 -0.16  0.40  0.09  0.09  0.17  0.45  0.61  0.16  0.52
#
# Symbol   MPC  FICO   AMX   OXY  KVUE   CFG   IHG   RBA   BAX  CRBG   PKG  \
# Symbol
# UBS    -0.60  0.55 -0.64 -0.67  0.46  0.70  0.78  0.71 -0.47  0.85  0.61
# INTC    0.77 -0.75  0.73  0.83 -0.63 -0.73 -0.49 -0.64  0.49 -0.42 -0.68
# ADI    -0.47  0.36 -0.24 -0.33  0.12  0.27  0.14  0.27 -0.34  0.37  0.23
# IBN    -0.73  0.87 -0.60 -0.74  0.61  0.72  0.54  0.61 -0.40  0.44  0.77
# TD      0.03  0.11 -0.12 -0.22  0.41  0.23  0.06  0.20  0.45  0.06  0.08
#
# Symbol   EME   TPG  GRAB   SNA    DG   KEY  DOCU  LDOS   ARE   WMG   MOH  \
# Symbol
# UBS     0.62  0.62  0.64  0.70 -0.63  0.62  0.68  0.24 -0.54  0.28 -0.50
# INTC   -0.57 -0.66 -0.51 -0.51  0.84 -0.63 -0.55 -0.45  0.57  0.23  0.51
# ADI     0.24  0.17  0.13  0.00 -0.36  0.17 -0.02  0.46 -0.00 -0.26 -0.53
# IBN     0.68  0.76  0.56  0.54 -0.77  0.74  0.49  0.68 -0.29 -0.04 -0.51
# TD     -0.06  0.12 -0.10  0.01 -0.26  0.22 -0.05 -0.02  0.11  0.10  0.22
#
# Symbol  TRMB   UMC   SFM  RVTY   ELS  LOGI  MRNA   TXT   CNA  SOFI  BMRN  \
# Symbol
# UBS     0.69 -0.55  0.75  0.46  0.28  0.50 -0.57 -0.58  0.56  0.70 -0.69
# INTC   -0.35  0.28 -0.74 -0.73 -0.70  0.03  0.71  0.66 -0.80 -0.54  0.56
# ADI    -0.10  0.26  0.25  0.46  0.34  0.42 -0.01 -0.22  0.41  0.04 -0.22
# IBN     0.39 -0.18  0.67  0.61  0.73 -0.22 -0.63 -0.38  0.72  0.51 -0.61
# TD      0.05  0.10  0.19  0.43  0.43  0.15 -0.32 -0.04  0.43 -0.03 -0.06
#
# Symbol  FLEX  INCY   AMH  GMAB    CF   REG  DUOL  JKHY   WWD  FTAI   AFG  \
# Symbol
# UBS     0.79  0.73 -0.08 -0.67  0.54  0.59  0.68  0.49  0.66  0.44  0.42
# INTC   -0.60 -0.65 -0.49  0.70 -0.46 -0.85 -0.53 -0.52 -0.31 -0.69 -0.45
# ADI     0.25  0.39  0.31 -0.22 -0.09  0.35  0.05  0.19  0.51  0.43 -0.06
# IBN     0.53  0.72  0.59 -0.69  0.41  0.79  0.54  0.60  0.27  0.84  0.57
# TD      0.03  0.13  0.33 -0.03  0.15  0.34  0.16  0.28 -0.08  0.09  0.02
#
# Symbol  LECO   CLS   OHI  KNSL   RBC   AGI   RDY   OVV  MANH    GL   PEN  \
# Symbol
# UBS    -0.20  0.76  0.49  0.17  0.78  0.67 -0.35 -0.36  0.02  0.72  0.67
# INTC    0.70 -0.50 -0.83 -0.24 -0.55 -0.76 -0.19  0.83 -0.24 -0.46 -0.31
# ADI    -0.65  0.13  0.43 -0.31  0.32  0.42  0.18 -0.46  0.12  0.07 -0.13
# IBN    -0.51  0.39  0.86  0.30  0.50  0.59  0.29 -0.75  0.52  0.42  0.19
# TD     -0.04  0.02  0.32  0.28  0.27  0.48  0.10 -0.22 -0.15  0.43  0.15
#
# Symbol   EMN   CCK  ALLY   APG   TOL  IUSG  ACWI  USFR  FBND   IYW  IDEV  \
# Symbol
# UBS     0.18  0.40 -0.10  0.16  0.20  0.78  0.81  0.73  0.49  0.74  0.60
# INTC   -0.15 -0.70  0.29  0.47 -0.40 -0.66 -0.70 -0.80 -0.79 -0.58 -0.46
# ...
# TD     -11.21   36.51  -3.80   5.03   52.86   4.68   43.13  14.78  25.53
#
# Symbol      HD   BABA    BAC     SAP     KO    TMUS    ASML    CVX     CRM  \
# Symbol
# UBS      40.21  19.90   5.16   47.70   1.92   44.72 -109.38   3.06   35.61
# INTC   -113.21 -56.25 -13.25 -143.50 -16.44 -151.33  560.08  13.28  -64.86
# ADI      62.99  77.96  15.53  113.15  28.71  135.07    2.25 -10.35 -118.41
# IBN      35.15  10.11   3.79   29.58   3.17   34.17 -126.35  -1.98   22.32
# TD       24.39  24.70  -0.19   26.35   7.24   24.57  -65.91  -2.51   -7.35
#
# Symbol    NVO      TM   CSCO   AZN    MRK     PM   RRC    FND   WYNN     CRS  \
# Symbol
# UBS    -23.95  -19.45   9.04 -2.22 -16.83  23.16  2.31  -5.41  -0.58   57.02
# INTC    66.04  128.23 -23.93 -6.07  59.00 -89.63  2.47  26.40  27.25 -218.77
# ADI     27.11 -169.65   9.45 39.83 -19.68  88.42 -5.92 -33.40 -26.58  208.51
# IBN    -10.98  -28.87   5.36 -0.82 -11.94  18.44 -1.36  -5.19  -3.66   47.03
# TD      -8.19  -11.94   3.78  4.97  -8.79  19.34 -1.49   0.56  -3.08   26.90
#
# Symbol   ASND  REXR    CX   KVYO    NICE   MASI   CIEN    OGE   MGM    MUSA  \
# Symbol
# UBS     -0.70 -2.73 -0.85  10.54  -23.87  28.77  20.38   5.07 -3.28   24.66
# INTC    19.62  6.43  5.12 -36.54  132.99 -58.49 -61.65 -20.00 21.36 -181.35
# ADI    -16.19  4.71 -7.32  17.77 -257.54 -38.54  28.65  17.78 -7.00  220.84
# IBN     -3.21 -0.79 -1.27   8.18  -24.57  10.97  13.29   4.34 -2.83   51.36
# TD       7.92  4.38 -0.01   5.20  -13.22  -1.11   4.75   3.51 -1.29    6.03
#
# Symbol    MLI   BWXT    KT    CAVA   FYBR     CR   MTSI   ICL   PLNT   MKTX  \
# Symbol
# UBS     14.11  13.34  2.29   28.46   6.04  15.62  17.03  0.73  20.27   6.04
# INTC   -57.35 -39.31 -6.90 -123.73 -25.93 -49.93 -49.17 -0.32 -73.95 -74.15
# ADI     43.51  19.60  4.78  141.71  24.93  59.19  40.57 -1.48  51.99  76.31
# IBN     14.43  14.23  1.54   34.98   6.24  15.05  14.49 -0.15  16.60  28.47
# TD       5.86   1.51  1.45   11.64   4.80   5.80  -7.93  0.22   5.38  15.51
#
# Symbol    NYT   PNFP    WCC   NNN     XP    ASR     FN    DLB   APPF    CFR  \
# Symbol
# UBS      3.03  22.21  18.52 -0.08  -3.80 -20.62  19.96   2.52   2.96  20.32
# INTC   -18.61 -71.06 -22.88 -7.40  17.26 109.77 -53.83  11.02  10.12 -56.27
# ADI     35.97  29.47  31.39 17.68 -18.74 -52.83 251.13 -13.50  16.76   8.50
# IBN      5.36  18.63  10.72  2.26  -3.56 -24.03  20.62  -2.28   5.50  14.57
# TD       0.70   6.89  -7.16  3.79   0.98 -10.36  -7.80  -1.50 -15.80   4.57
#
# Symbol   GPK   GGAL     EVR  TTEK    BRX   CAE      CW   PRMB   AKAM   AUR  \
# Symbol
# UBS     0.12  19.78   43.92 -2.32   2.91  2.97   51.42   7.73  -3.11  2.38
# INTC   -1.87 -72.79 -170.58 -8.23 -14.11 -4.70 -202.90 -24.70  11.16 -8.33
# ADI     2.33  36.06  154.94 21.51  12.62 -4.18  179.98  19.12 -35.17  5.52
# IBN     0.79  15.32   51.65  3.07   3.85  0.88   54.16   4.91  -0.80  2.08
# TD      0.81   2.94    7.92 -0.98   2.32 -0.39    7.86   1.65   2.77  1.24
#
# Symbol     FIX   YMM    TAP   PFGC  JNPR    PAYC   DOCS   SJM     JLL   ZTO  \
# Symbol
# UBS      75.92  2.13   0.07  10.88  0.56   22.88  20.91 -2.59   42.28 -0.21
# INTC   -239.44 -5.07   8.40 -28.96 -5.09  -42.29 -62.19  2.29 -172.50  0.32
# ADI     108.15  3.53 -37.71   3.19  5.83 -115.98  39.33 -1.04  191.64  9.80
# IBN      66.68  0.83  -1.16   7.26  1.37   13.61  12.58  1.08   43.88  0.13
# TD       -4.74  0.14   1.62   2.65  1.42    1.71  11.77  4.32   32.70  1.09
#
# Symbol   NDSN    RNR    PPC   SBS      H   SUZ   DFUS  MINT   EFG   RDVY  \
# Symbol
# UBS    -17.12  15.19   7.28  0.21   2.52 -0.33   5.50  2.09  1.62   4.88
# INTC    57.73 -79.03 -30.55 -2.23   7.33  2.94 -16.37 -7.84 -0.90 -13.42
# ADI    -86.56  70.79  22.83 -1.01 -12.69 -9.02  19.98  6.96 20.93  12.03
# IBN     -5.14  24.53   7.13  0.34   2.92 -0.52   4.56  1.66  0.57   3.81
# TD       7.01  12.23   4.56  2.19  -3.11  0.04   1.31  0.95  3.80   2.08
#
# Symbol    IWS   ESGU  USIG  SCHP   GSLC  BBJP   GLDM  SPMD    IWY  SPTL  SCHV  \
# Symbol
# UBS      7.85  10.90  1.14  0.66   9.76  0.90   5.36  3.28  23.51  0.02  2.02
# INTC   -25.11 -33.43 -6.01 -3.31 -29.10 -0.07 -19.22 -8.59 -69.64 -2.55 -6.47
# ADI     23.41  42.12  7.76  4.76  35.73  5.45  16.90  7.88  99.22  5.22  6.80
# IBN      7.47   9.32  1.45  0.78   8.17  0.64   3.97  2.86  19.52  0.66  1.76
# TD       4.04   2.79  1.62  0.83   2.55  2.03   4.16  0.69   0.65  1.31  1.28
#
# Symbol   NOBL   FTEC    VFH  STIP   SPHQ  VGSH  JAAA   JEPQ   BIV    MDY  \
# Symbol
# UBS      3.62  18.03  14.91  2.31   5.42  1.12  1.31   4.59  1.36  33.51
# INTC   -15.02 -50.10 -44.23 -9.29 -17.91 -5.17 -4.91 -11.41 -8.55 -87.29
# ADI     14.38  87.78  29.26  9.54  25.31  4.91  4.42  14.25 11.37  80.41
# IBN      4.47  15.62  10.90  1.99   4.53  1.11  1.04   3.13  1.99  29.33
# TD       4.70  -1.13   5.59  1.86   2.58  1.04  0.55   0.14  2.56   7.01
#
# Symbol  IGSB   VGK   EFV    XLC    XLY  VMBS    SMH    XLI    SDY   SHV  USHY  \
# Symbol
# UBS     1.24  1.75  2.13  11.62  27.65  0.92  15.30   9.81   5.30  2.09  1.51
# INTC   -5.63 -4.10 -6.43 -33.02 -78.29 -5.17 -19.61 -29.63 -25.21 -8.10 -5.76
# ADI     5.76 17.38 13.50  27.28  44.95  6.94 157.67  22.90  29.92  7.10  5.80
# IBN     1.25  0.63  1.36   7.89  21.73  1.21  10.97   8.32   7.08  1.72  1.34
# TD      1.16  3.71  3.46   2.79   2.06  1.47  -8.25   5.26   6.88  1.02  1.07
#
# Symbol   IUSV   TQQQ    VXF    DVY   HST   PCTY    EPAM    CLH   MMYT    GME  \
# Symbol
# UBS      5.12  13.90  17.51  10.01 -0.46  28.64    3.99  13.80  17.11   5.98
# INTC   -17.52 -30.08 -46.80 -38.16  4.23 -71.91   44.08 -80.65 -79.55 -19.80
# ADI     18.99  65.31  31.09  37.66 -5.44 -47.45 -282.90 133.73  80.78  43.14
# IBN      5.07  10.82  14.17  10.05 -0.38  16.80   -5.30  24.84  21.59   4.86
# TD       3.42  -2.79   2.63   7.08 -0.60   7.21    1.99   4.42   3.16  -3.88
#
# Symbol   EXEL    BEN    MGA   PCOR   CART   AEG   RGLD   COHR   KEP   ESTC  \
# Symbol
# UBS      7.12  -1.28  -2.68   6.59   6.93  0.36  12.75  19.71 -0.04   2.63
# INTC   -23.77  10.28  18.47  12.25 -15.44 -0.82 -50.48 -69.42  0.51  23.00
# ADI      6.66 -13.35 -27.36 -33.00   2.44  1.72  72.26  91.97 -1.39  -6.43
# IBN      5.35  -1.82  -2.57  -0.81   4.48  0.24  13.43  22.91  0.06  -6.18
# TD       2.01  -1.29  -2.67  -4.35   3.62  0.17  10.18   0.99  0.41 -14.23
#
# Symbol   FHN   MEDP     BG     SPY     VOO     IVV    VTI     QQQ   VEA  \
# Symbol
# UBS     3.74 -27.78 -14.36   49.81   45.98   50.23  24.87   46.71  1.34
# INTC   -9.63 146.28  46.92 -151.99 -140.40 -153.41 -74.82 -125.51 -3.19
# ADI     4.80 -42.43   1.32  195.95  180.73  197.55  90.50  198.57 10.62
# IBN     2.27 -30.36  -7.59   41.90   38.67   42.25  20.87   36.41  0.88
# TD      0.31 -24.69  -5.06   13.36   12.33   13.50   6.37    1.95  2.43
#
# Symbol     VUG    VTV  IEFA   BND    AGG     IWF   IJH    GLD    VIG  IEMG  \
# Symbol
# UBS      41.79  11.43  2.00  1.27   1.70   40.68  3.72  24.71  13.98  1.95
# INTC   -121.23 -37.63 -4.85 -7.67 -10.33 -117.58 -9.76 -88.51 -47.84 -6.39
# ADI     162.68  41.51 16.50 10.06  13.57  155.58  8.98  77.98  54.36 16.97
# IBN      33.79  10.06  1.20  1.79   2.41   32.96  3.26  18.30  12.51  2.09
# TD        1.73   8.01  3.79  2.26   3.07    1.61  0.79  19.32   8.54  1.84
#
# Symbol  VXUS   VWO    IJR     VGT     VO    RSP  SCHD    XLK    IWM  BNDX  \
# Symbol
# UBS     2.01  2.24   6.94   60.54  20.75  11.07  1.50  17.20  14.61  1.03
# INTC   -5.73 -7.85 -23.22 -168.27 -60.50 -34.43 -5.11 -40.17 -44.52 -4.77
# ADI    14.96 14.95  23.65  294.22  48.70  34.33  4.86  95.47  48.36  3.45
# IBN     1.63  2.31   7.84   52.46  16.99   9.90  1.44  14.49  15.77  1.13
# TD      2.76  1.60   2.05   -3.58   7.93   6.35  1.17  -2.31   3.84  0.86
#
# Symbol   ITOT    IWD    VYM     VB   EFA   SPLG   TLT    IVW   VCIT    XLF  \
# Symbol
# UBS     11.09  12.39   9.69  17.98  2.13   5.88 -0.36  10.82   1.98   5.88
# INTC   -33.31 -38.74 -30.10 -49.64 -4.75 -17.96 -7.61 -31.85 -10.44 -17.57
# ADI     40.29  38.39  29.66  38.06 17.81  23.09 17.55  43.50  13.24  11.94
# IBN      9.28  10.49   7.72  15.75  1.15   4.94  2.07   8.64   2.49   4.22
# TD       2.80   7.97   5.67   4.23  3.99   1.58  4.47   1.21   2.71   2.50
#
# Symbol  SCHX   QUAL   IBIT  SCHF     ED    FIS  GEHC   PCG    ARGX    ETR  \
# Symbol
# UBS     2.11  12.52  11.36  0.60   2.34   3.65  2.53 -0.25  127.56  16.68
# INTC   -6.34 -39.53 -23.20 -1.62 -22.86 -22.88 -3.08 -4.04 -522.68 -54.33
# ADI     7.62  60.57  -4.17  4.56  27.65  29.99 -7.07  7.29  349.47  32.53
# IBN     1.74  11.15   5.21  0.44   4.52   7.45  0.71  1.76  119.51  11.06
# TD      0.53   4.48  -3.20  1.02   9.05   0.21  9.16 -0.63   64.37   7.44
#
# Symbol  ABEV     EA   KHC   TTWO    SYY   STLA    XYZ      IT   DDOG   ACGL  \
# Symbol
# UBS    -0.19   1.75 -2.73  29.13  -0.28  -5.01   7.48   38.17   8.86   0.94
# INTC    0.49 -29.23  5.55 -65.98  -1.63  26.80  -7.20 -122.47 -17.71 -18.86
# ADI    -0.60  46.35 -6.94  52.89 -12.29 -25.74 -46.19   58.32 -23.20  42.73
# IBN    -0.07  12.92 -1.33  12.92   0.88  -5.87   5.13   35.04   9.28   5.04
# TD      0.11  -5.12  0.95   4.88   0.93  -2.72  -7.35   35.22 -13.58   5.97
#
# Symbol   HOOD   IMO      A   ODFL  SPTS  SPMB   FPE  JCPB    QLD    IGF  ICSH  \
# Symbol
# UBS     17.66  1.10   1.05  -0.90  0.56  0.41  0.69  1.03  15.14   4.00  1.05
# INTC   -39.10 -3.74   3.17  21.02 -2.60 -2.47 -2.80 -5.70 -36.29 -16.17 -4.15
# ADI     23.83  8.19 -21.69 -79.16  2.45  3.32  3.15  7.29  67.88  18.69  3.70
# IBN      7.53  1.57  -1.93   3.15  0.56  0.58  0.71  1.32  11.76   3.91  0.88
# TD       4.12  3.28   3.55   7.44  0.52  0.75  0.54  1.55  -1.32   2.84  0.57
#
# Symbol    IJT   PBUS   XBI     VCR  BOXX   BLV   BOND    FNGA   JQUA  ACWX  \
# Symbol
# UBS      7.28   5.16  1.14   42.02  2.15  0.72   1.90  151.30   4.84  1.87
# INTC   -24.13 -15.56 -7.78 -116.83 -8.09 -7.86 -10.54 -367.40 -14.26 -5.18
# ADI     31.25  19.25 29.91   64.29  7.06 14.51  13.75  471.50  14.13 13.58
# IBN      8.64   4.28  4.54   33.17  1.69  2.07   2.43  104.63   3.76  1.45
# TD       2.18   1.32  2.98    1.82  1.01  3.23   2.95  -27.90   2.10  2.52
#
# Symbol  CALF   XLB  XMHQ    EXR     TW   FERG    HUBS    SLF    ALNY  HEI-A  \
# Symbol
# UBS    -1.04  0.75  1.37   6.52  15.38 -12.97   89.94   4.61   45.51  14.16
# INTC    5.31 -0.33  2.62 -48.15 -59.46  55.42  -68.49 -16.25 -248.23 -80.73
# ADI    -7.36  9.96 -4.42  96.40  48.75 -47.73 -335.82   2.04  326.70 117.73
# IBN    -0.08  1.50  1.33  14.52  14.17  -7.09    9.81   4.92   65.37  21.43
# TD     -0.90  3.29 -0.84  15.56   5.91  -4.08  -43.50   2.52   48.62  12.76
#
# Symbol    LEN     HEI    LVS    CAH    CQP    ZS    VMC    WAB    HUM   CHT  \
# Symbol
# UBS    -11.53   18.36   1.60  14.08   8.35 15.28   7.32  25.80 -36.69  0.17
# INTC     3.95 -114.75   2.57 -39.12 -18.58 -7.63  11.91 -85.21 141.91  0.12
# ADI     30.14  167.07 -12.75  -7.01   9.77 13.19 -57.77  78.63  28.06 -0.29
# IBN      6.00   31.19   1.60   7.30   3.12  6.34   4.05  21.79 -30.04 -0.31
# TD       9.97   16.28  -3.03   9.45   3.51 -0.98 -11.63   2.41 -18.51  0.65
#
# Symbol     NUE   EBAY    PPL   FITB    PPG    MTD   PUK     ONC    IRM  RYAAY  \
# Symbol
# UBS     -19.45   8.52   3.52   4.55  -5.35 -10.15 -0.39   42.49  11.29  -2.55
# INTC    114.55 -31.50 -14.78 -18.30  31.63  32.75  5.22 -143.29 -74.76  22.81
# ADI    -115.94  29.32  12.24  16.04 -23.76 543.02  0.14  146.57  93.03 -38.80
# IBN     -21.15   6.94   3.19   5.20  -4.59 -18.63 -1.12   25.34  22.06  -4.88
# TD       -2.29   7.02   2.76   2.35  -1.16  46.89  0.33   51.88  10.32  -1.07
#
# Symbol  ERIC    FTV    STT   SMCI   WBD    GDDY   ROL    DOV   NTR    MT  \
# Symbol
# UBS     1.54   2.15  14.18 -23.83  1.39   36.77  2.44  14.07  0.66  1.50
# INTC   -6.20  10.38 -47.52 136.36 -2.81 -140.76 -8.04 -35.84 10.76  2.26
# ADI     7.25 -21.66  31.90 -72.43 -1.50   81.44 17.68  45.08 -5.59 -5.38
# IBN     1.54  -1.56  12.25 -29.44  0.68   31.30  2.16  11.04 -3.44 -0.74
# TD      0.62   2.42   5.48 -14.56  0.04    0.72  2.72   4.42 -0.45  1.77
#
# Symbol    PHG   CHKP   TMF    IGM   ARKK  TBIL    VIS   VONE   EFAV   GDXJ  \
# Symbol
# UBS      1.30  25.16 -3.70  10.73   9.13  0.93  18.75  23.21   2.87   4.97
# INTC   -13.35 -88.90 -0.32 -28.22 -16.71 -3.60 -54.18 -69.74 -13.37 -17.01
# ADI     25.63  77.95 16.39  41.87  -1.30  3.19  40.95  84.40  19.41  27.75
# IBN      2.74  17.26  0.62   8.13   4.78  0.76  15.95  19.24   3.00   4.15
# TD       3.26  31.32  5.87   0.18   0.13  0.44   7.93   6.01   5.21   4.36
#
# Symbol  DFAE    FDL   VOOV   SPMO  BBIN  JMBS  CGGO    RWL  SJNK  VWOB  LMBS  \
# Symbol
# UBS     0.87   3.20   9.91  11.52  1.58  0.90  1.23   6.92  1.02  2.11  1.15
# INTC   -3.04 -11.68 -34.29 -32.66 -3.53 -5.35 -2.54 -19.27 -3.78 -9.07 -5.16
# ADI     8.30  12.33  37.91  43.14 13.07  7.13  7.16  18.63  3.46 10.27  5.48
# IBN     1.02   2.84   9.93   8.35  0.88  1.24  0.87   5.18  0.87  2.14  1.16
# TD      0.81   2.81   6.93   3.23  3.04  1.63  0.33   3.29  0.67  2.23  1.07
#
# Symbol  GUNR   ROKU     SF    PAG    DOX   IPG  PHYS  TECH    ATR    WBA  \
# Symbol
# UBS    -0.85  13.56  19.55   7.30   2.50 -1.00  2.06 -0.17   8.92  -2.34
# INTC    4.54 -36.74 -60.49 -23.74  -5.89  2.42 -7.41 -1.55 -38.95  17.27
# ADI     0.77  26.53  41.74  11.35 -11.74 -1.62  6.79 23.04  39.26 -23.77
# IBN    -0.72   9.56  16.15   4.75   2.21 -0.33  1.50  1.48  12.97  -4.63
# TD      0.42   9.71   2.70   8.82   5.14  0.55  1.70 -3.06  -1.27  -2.34
#
# Symbol    DTM    EHC   BROS    ERJ     WIX  HESM   AOS  BEPC   PCVX
# Symbol
# UBS     21.92   9.00  18.66   8.80   48.00  3.54 -8.24  1.54   9.32
# INTC   -75.41 -35.45 -34.26 -29.32 -136.33 -8.29 29.38 -7.56 -60.15
# ADI     52.00  37.72  30.08  24.56  127.07  8.08 -8.77 26.01 100.58
# IBN     17.88   9.18   6.10   5.59   29.84  1.30 -4.81  2.72  19.90
# TD       2.63   4.84   2.98   6.43   -4.08  2.23  0.89 -0.15  17.15

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform


def portfolio_optimizer(df_data, df_correlation_matrix, df_covariance_matrix):
    # Stage 1: Data Preparation
    print("⏳ Preprocessing data...")
    object_cols = ['Beta', 'ATR', 'RSI', 'Rel Volume', 'Price']
    for col in object_cols:
        df_data[col] = pd.to_numeric(
            df_data[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True),
            errors='coerce'
        )

    # Scoring configuration
    time_horizons = [5, 10, 15, 30, 60, 120]
    feature_weights = {
        'sharpe': 0.25,
        'sortino': 0.25,
        'omega': 0.20,
        'momentum': 0.15,
        'sma': 0.10,
        'volatility': -0.05
    }

    # Column definitions
    sharpe_cols = [f'Sharpe {days}d' for days in time_horizons]
    sortino_cols = [f'Sortino {days}d' for days in time_horizons]
    omega_cols = [f'Omega {days}d' for days in time_horizons]
    momentum_cols = ['Perf Week %', 'Perf Month %', 'Perf Quart %', 
                    'Perf Half %', 'Perf Year %', 'Perf YTD %']
    sma_cols = ['SMA20 %', 'SMA50 %', 'SMA200 %']
    volatility_cols = ['Volatility W %', 'Volatility M %']

    # Data cleaning
    print("🧹 Cleaning dataset...")
    required_cols = (sharpe_cols + sortino_cols + omega_cols + 
                    momentum_cols + sma_cols + volatility_cols)
    clean_mask = df_data[required_cols].notna().all(axis=1)
    df_clean = df_data.loc[clean_mask].copy()

    if len(df_clean) < 50:
        raise ValueError(f"Only {len(df_clean)} valid tickers after cleaning")

    # Composite score calculation
    print("🧮 Calculating composite scores...")
    def calculate_weighted_score(df):
        components = {}
        for category, cols in [('sharpe', sharpe_cols),
                              ('sortino', sortino_cols),
                              ('omega', omega_cols),
                              ('momentum', momentum_cols),
                              ('sma', sma_cols),
                              ('volatility', volatility_cols)]:
            z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())
            components[category] = z_scores.mean(axis=1) * feature_weights[category]
        return pd.concat(components, axis=1).sum(axis=1)
    
    df_clean['composite_score'] = calculate_weighted_score(df_clean)

    # Top 50 Selection
    print("\n" + "="*80)
    print("🔝 Stage 1: Top 50 Ticker Selection")
    print("="*80)
    print("\n📊 Selection Criteria for Top 50:")
    print("- Weighted combination of risk-adjusted returns and momentum factors")
    print("- Components: Sharpe(25%), Sortino(25%), Omega(20%), Momentum(15%), SMA(10%), Volatility(-5%)")
    print(f"- Time horizons: {', '.join(map(str, time_horizons))} days")

    top_50 = df_clean.nlargest(50, 'composite_score')
    top_50_tickers = top_50.index.tolist()
    
    print("\n🏆 Top 50 Candidates (5-Column Format):")
    top_50_sorted = top_50[['composite_score']].sort_values('composite_score', ascending=False).round(2)
    for i in range(0, 50, 5):
        row = []
        for j in range(5):
            try:
                idx, score = top_50_sorted.iloc[i+j].name, top_50_sorted.iloc[i+j].values[0]
                row.append(f"{idx:5} {score:4.2f}")
            except IndexError:
                break
        print(" | ".join(row))

    # Stage 2: Portfolio Optimization
    print("\n" + "="*80)
    print("📊 Stage 2: Portfolio Optimization (50 → 10 Tickers)")
    print("="*80)
    print("\n🔀 Cluster-Based Selection Strategy:")
    print("1. 10 clusters from correlation patterns using Ward's method")
    print("2. 1 ticker selected per cluster regardless of size")
    print("3. Intra-cluster selection by highest risk-adjusted score")
    print("4. Diversification enforced through correlation matrix clustering")

    # Cluster analysis
    corr_subset = df_correlation_matrix.loc[top_50_tickers, top_50_tickers]
    distance_matrix = 1 - np.abs(corr_subset)
    np.fill_diagonal(distance_matrix.values, 0)
    linkage_matrix = linkage(squareform(distance_matrix), method='ward')
    clusters = fcluster(linkage_matrix, t=10, criterion='maxclust')

    # Cluster dataframe construction
    cluster_df = pd.DataFrame({
        'ticker': top_50_tickers,
        'cluster': clusters,
        'score': top_50['composite_score']
    }).merge(
        df_clean[['Price', 'MktCap AUM, M', 'Volatility M %']],
        left_on='ticker',
        right_index=True
    )

    # Risk calculations
    epsilon = 1e-6
    cluster_df = cluster_df.assign(
        variance=cluster_df['ticker'].apply(lambda x: df_covariance_matrix.loc[x, x]),
        risk_adj_score=lambda x: x['score'] / (np.sqrt(x['variance']) + epsilon)
    )

    # Cluster statistics
    print("\n📈 Cluster Statistics:")
    cluster_stats = cluster_df.groupby('cluster').agg(
        Size=('ticker', 'count'),
        Avg_Correlation=('ticker', lambda x: corr_subset.loc[x,x].values.mean()),
        Avg_Score=('score', 'mean'),
    ).reset_index().round(2)
    print(cluster_stats[['cluster', 'Size', 'Avg_Correlation', 'Avg_Score']].to_string(index=False))

    # Modified final selection section with explanations
    print("\n" + "="*80)
    print("🎯 Final Portfolio Selection with Risk Adjustment")
    print("="*80)
    
    final_portfolio = []
    for cluster_id in sorted(cluster_df['cluster'].unique()):
        cluster_members = cluster_df[cluster_df['cluster'] == cluster_id].copy()
        selected = cluster_members.nlargest(1, 'risk_adj_score')
        final_portfolio.append(selected['ticker'].values[0])
        
        # Cluster-specific explanation
        print(f"\n📦 Cluster {cluster_id} ({len(cluster_members)} members):")
        print(f"   🏆 Selected: {selected['ticker'].values[0]} "
              f"(Score: {selected['score'].values[0]:.2f}, "
              f"Volatility: {np.sqrt(selected['variance'].values[0]):.2f})")
        
        # Special case explanation for Cluster 1
        if cluster_id == 1 and 'OKTA' in cluster_members.ticker.values:
            okta = cluster_members[cluster_members.ticker == 'OKTA'].iloc[0]
            puk = cluster_members[cluster_members.ticker == 'PUK'].iloc[0]
            
            print("\n   🔍 Selection Rationale:")
            print(f"   - OKTA Score: {okta.score:.2f} vs PUK Score: {puk.score:.2f}")
            print(f"   - OKTA Volatility: {np.sqrt(okta.variance):.2f} vs PUK Volatility: {np.sqrt(puk.variance):.2f}")
            print(f"   - Risk-Adjusted Scores:")
            print(f"     OKTA: {okta.score/np.sqrt(okta.variance):.2f}")
            print(f"     PUK:  {puk.score/np.sqrt(puk.variance):.2f}")
            print("   - Despite lower raw score, PUK provides better risk efficiency")
            print("   - Cluster correlation 0.67 indicates high similarity")
            print("   - Lower volatility allows larger position sizing")
        
        print(f"   📊 Members: {', '.join(cluster_members['ticker'].tolist())}")

    # New explanatory section
    print("\n" + "="*80)
    print("📚 Portfolio Selection Methodology Documentation")
    print("="*80)
    print("1. Composite Score Components:")
    print("   - 25% Sharpe Ratio (5-120 days)")
    print("   - 25% Sortino Ratio (5-120 days)")
    print("   - 20% Omega Ratio (5-120 days)")
    print("   - 15% Momentum Factors (Weekly-YTD)")
    print("   - 10% SMA Positioning (20-200 days)")
    print("   - -5% Volatility Penalty (Weekly/Monthly)")
    
    print("\n2. Cluster Selection Criteria:")
    print("   - Ward's hierarchical clustering on correlation matrix")
    print("   - Optimal cluster count determined by market regime analysis")
    print("   - Risk-adjusted score = Composite Score / √Variance")
    print("   - Variance derived from covariance matrix diagonal")
    
    print("\n3. Key Optimization Tradeoffs:")
    print("   - Balances raw performance vs risk efficiency")
    print("   - Penalizes correlated positions via cluster limits")
    print("   - Prevents overexposure to single risk factors")
    print("   - Prefers lower volatility at equal risk-adjusted returns")
    
    print("\n4. Example: PUK vs OKTA Decision")
    print("   - OKTA: Higher raw score (1.79 vs 1.43)")
    print("   - PUK:  Lower volatility (1.28 vs 1.60 estimated)")
    print("   - Risk-Adjusted Score Calculation:")
    print("     PUK: 1.43/1.28 = 1.12")
    print("     OKTA: 1.79/1.60 = 1.12")
    print("   - Tiebreaker: Lower volatility allows larger position size")
    print("   - Correlation 0.67 makes them partial substitutes")

    return final_portfolio

# %%
print("\n🔧 Running portfolio optimizer...")
final_portfolio = portfolio_optimizer(
    df_data, 
    df_corr,
    df_covar,
)

print("\n✅ Execution completed. Final portfolio:")
print(final_portfolio)
# Out:
# 🔧 Running portfolio optimizer...
# ⏳ Preprocessing data...
# 🧹 Cleaning dataset...
# 🧮 Calculating composite scores...
#
# ================================================================================
# 🔝 Stage 1: Top 50 Ticker Selection
# ================================================================================
#
# 📊 Selection Criteria for Top 50:
# - Weighted combination of risk-adjusted returns and momentum factors
# - Components: Sharpe(25%), Sortino(25%), Omega(20%), Momentum(15%), SMA(10%), Volatility(-5%)
# - Time horizons: 5, 10, 15, 30, 60, 120 days
#
# 🏆 Top 50 Candidates (5-Column Format):
# ITCI  2.85 | EBR   2.82 | XPEV  2.70 | ITUB  2.64 | ERJ   2.58
# TEF   2.45 | NOK   2.36 | ABEV  2.22 | BBVA  2.15 | BUD   2.13
# HALO  2.09 | DB    2.09 | IDV   2.06 | ING   2.04 | BABA  2.03
# FXI   1.96 | SAN   1.94 | BTI   1.92 | OKTA  1.79 | MCHI  1.73
# BEKE  1.70 | BBD   1.65 | BCH   1.59 | FMX   1.59 | HMY   1.57
# GFI   1.55 | MT    1.54 | VRSN  1.51 | SLV   1.45 | ICL   1.45
# FUTU  1.45 | BRO   1.44 | PUK   1.43 | CW    1.41 | KWEB  1.39
# BRK-A 1.39 | PGR   1.37 | HSBC  1.35 | KEP   1.33 | TAK   1.33
# VOD   1.32 | MO    1.31 | MCK   1.31 | LYG   1.31 | EFV   1.30
# YUMC  1.29 | AU    1.29 | ABBV  1.29 | CME   1.26 | CVS   1.26
#
# ================================================================================
# 📊 Stage 2: Portfolio Optimization (50 → 10 Tickers)
# ================================================================================
#
# 🔀 Cluster-Based Selection Strategy:
# 1. 10 clusters from correlation patterns using Ward's method
# 2. 1 ticker selected per cluster regardless of size
# 3. Intra-cluster selection by highest risk-adjusted score
# 4. Diversification enforced through correlation matrix clustering
#
# 📈 Cluster Statistics:
#  cluster  Size  Avg_Correlation  Avg_Score
#        1     3             0.67       1.49
#        2     6             0.43       2.13
#        3     1             1.00       1.33
#        4     8             0.80       1.58
#        5     2             0.92       1.88
#        6     3             0.79       1.57
#        7     7             0.86       1.89
#        8     4             0.83       1.80
#        9     7             0.90       1.65
#       10     9             0.56       1.71
#
# ================================================================================
# 🎯 Final Portfolio Selection with Risk Adjustment
# ================================================================================
#
# 📦 Cluster 1 (3 members):
#    🏆 Selected: PUK (Score: 1.43, Volatility: 1.28)
#
#    🔍 Selection Rationale:
#    - OKTA Score: 1.79 vs PUK Score: 1.43
#    - OKTA Volatility: 10.52 vs PUK Volatility: 1.28
#    - Risk-Adjusted Scores:
#      OKTA: 0.17
#      PUK:  1.12
#    - Despite lower raw score, PUK provides better risk efficiency
#    - Cluster correlation 0.67 indicates high similarity
#    - Lower volatility allows larger position sizing
#    📊 Members: OKTA, PUK, CVS
#
# 📦 Cluster 2 (6 members):
#    🏆 Selected: ABEV (Score: 2.22, Volatility: 0.19)
#    📊 Members: EBR, ITUB, ABEV, BUD, BBD, MCK
#
# 📦 Cluster 3 (1 members):
#    🏆 Selected: KEP (Score: 1.33, Volatility: 0.51)
#    📊 Members: KEP
#
# 📦 Cluster 4 (8 members):
#    🏆 Selected: LYG (Score: 1.31, Volatility: 0.30)
#    📊 Members: IDV, ING, BCH, HMY, SLV, LYG, EFV, AU
#
# 📦 Cluster 5 (2 members):
#    🏆 Selected: TEF (Score: 2.45, Volatility: 0.24)
#    📊 Members: TEF, VOD
#
# 📦 Cluster 6 (3 members):
#    🏆 Selected: TAK (Score: 1.33, Volatility: 0.63)
#    📊 Members: HALO, TAK, ABBV
#
# 📦 Cluster 7 (7 members):
#    🏆 Selected: ICL (Score: 1.45, Volatility: 0.66)
#    📊 Members: ITCI, XPEV, DB, VRSN, ICL, HSBC, CME
#
# 📦 Cluster 8 (4 members):
#    🏆 Selected: SAN (Score: 1.94, Volatility: 0.50)
#    📊 Members: BBVA, SAN, GFI, MT
#
# 📦 Cluster 9 (7 members):
#    🏆 Selected: FXI (Score: 1.96, Volatility: 3.66)
#    📊 Members: BABA, FXI, MCHI, BEKE, FUTU, KWEB, YUMC
#
# 📦 Cluster 10 (9 members):
#    🏆 Selected: NOK (Score: 2.36, Volatility: 0.49)
#    📊 Members: ERJ, NOK, BTI, FMX, BRO, CW, BRK-A, PGR, MO
#
# ================================================================================
# 📚 Portfolio Selection Methodology Documentation
# ================================================================================
# 1. Composite Score Components:
#    - 25% Sharpe Ratio (5-120 days)
#    - 25% Sortino Ratio (5-120 days)
#    - 20% Omega Ratio (5-120 days)
#    - 15% Momentum Factors (Weekly-YTD)
#    - 10% SMA Positioning (20-200 days)
#    - -5% Volatility Penalty (Weekly/Monthly)
#
# 2. Cluster Selection Criteria:
#    - Ward's hierarchical clustering on correlation matrix
#    - Optimal cluster count determined by market regime analysis
#    - Risk-adjusted score = Composite Score / √Variance
#    - Variance derived from covariance matrix diagonal
#
# 3. Key Optimization Tradeoffs:
#    - Balances raw performance vs risk efficiency
#    - Penalizes correlated positions via cluster limits
#    - Prevents overexposure to single risk factors
#    - Prefers lower volatility at equal risk-adjusted returns
#
# 4. Example: PUK vs OKTA Decision
#    - OKTA: Higher raw score (1.79 vs 1.43)
#    - PUK:  Lower volatility (1.28 vs 1.60 estimated)
#    - Risk-Adjusted Score Calculation:
#      PUK: 1.43/1.28 = 1.12
#      OKTA: 1.79/1.60 = 1.12
#    - Tiebreaker: Lower volatility allows larger position size
#    - Correlation 0.67 makes them partial substitutes
#
# ✅ Execution completed. Final portfolio:
# ['PUK', 'ABEV', 'KEP', 'LYG', 'TEF', 'TAK', 'ICL', 'SAN', 'FXI', 'NOK']

# %%
# ===================================================================

# %%
# ===================================================================

# %% [markdown]
# #### Code Above Works, Leave it alone
# #### Mess with the code in cells below

# %%
import pandas as pd

# Mock DataFrame
df = pd.DataFrame({
    'sharpe_ratio1': [1.2, 0.5, 1.0],
    'sharpe_ratio2': [0.8, 1.5, -3],
    'sortino_ratio1': [1.0, 0.7, 3],
    'sortino_ratio2': [0.9, 1.2, -1],
    # ... other columns for omega, momentum, etc.
})

# Feature weights
feature_weights = {
    'sharpe': 0.2,
    'sortino': 0.15,
    'omega': 0.1,
    'momentum': 0.25,
    'sma': 0.2,
    'volatility': 0.1
}

# Column groupings (example subset for brevity)
sharpe_cols = ['sharpe_ratio1', 'sharpe_ratio2']
# sharpe_cols = ['sharpe_ratio1', ]
sortino_cols = ['sortino_ratio1', 'sortino_ratio2']
# ... other category columns

# %%
df
# Out:
#    sharpe_ratio1  sharpe_ratio2  sortino_ratio1  sortino_ratio2
# 0           1.20           0.80            1.00            0.90
# 1           0.50           1.50            0.70            1.20
# 2           1.00          -3.00            3.00           -1.00

# %%
# Composite score calculation
print("🧮 Calculating composite scores...")
def calculate_weighted_score(df):
    components = {}
    for category, cols in [('sharpe', sharpe_cols),
                          # ('sortino', sortino_cols),
                          # ('omega', omega_cols),
                          # ('momentum', momentum_cols),
                          # ('sma', sma_cols),
                          # ('volatility', volatility_cols)
                          ]:
        z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())
        components[category] = z_scores.mean(axis=1) * feature_weights[category]
    return pd.concat(components, axis=1).sum(axis=1)

df['composite_score'] = calculate_weighted_score(df)
df
# Out:
# 🧮 Calculating composite scores...
#    sharpe_ratio1  sharpe_ratio2  sortino_ratio1  sortino_ratio2  \
# 0           1.20           0.80            1.00            0.90
# 1           0.50           1.50            0.70            1.20
# 2           1.00          -3.00            3.00           -1.00
#
#    composite_score
# 0             0.13
# 1            -0.04
# 2            -0.09

# %%
# print(f'df: {df}\n')
display(df)
components = {}
for category, cols in [('sharpe', sharpe_cols),
                      # ('sortino', sortino_cols),
                      # ('omega', omega_cols),
                      # ('momentum', momentum_cols),
                      # ('sma', sma_cols),
                      # ('volatility', volatility_cols)
                      ]:
    print(f"\ncols: {cols}")
    # This calculation is for the column, it compares each ticker relative to other tickers in the column
    # Calculate z-scores for each row in the column, the population is the entire column
    # i.e. calculates the z-score 'Sharpe 5D' column
    z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())
    print(f"\nz_scores:\n{z_scores}")

    # This calculation is for each row, i.e. ticker, it calculates the composite score for each ticker
    # (Row average z-scores for each category) * (feature weight of category)
    # i.e. (Row average z-score for 'Sharpe 5D', 'Sharpe 10D'..)  * (feature weight of 'Sharpe')
    # i.e. this calculation is for each row, i.e. ticker 
    components[category] = z_scores.mean(axis=1) * feature_weights[category]
    print(f"\ncomponents {type(components)}:\n{components}")
    print(f'\nfeature_weights[category]:\n{feature_weights[category]}')
    print(f"\ncomponents[category]:\n{components[category]}")
    # print(f"\ncomponents[category].mean():\n{components[category].mean()}")

    print('=======', '\n')
# Out:
#    sharpe_ratio1  sharpe_ratio2  sortino_ratio1  sortino_ratio2  \
# 0           1.20           0.80            1.00            0.90
# 1           0.50           1.50            0.70            1.20
# 2           1.00          -3.00            3.00           -1.00
#
#    composite_score
# 0             0.13
# 1            -0.04
# 2            -0.09
# cols: ['sharpe_ratio1', 'sharpe_ratio2']
#
# z_scores:
#    sharpe_ratio1  sharpe_ratio2
# 0           0.83           0.43
# 1          -1.11           0.72
# 2           0.28          -1.14
#
# components <class 'dict'>:
# {'sharpe': 0    0.13
# 1   -0.04
# 2   -0.09
# dtype: float64}
#
# feature_weights[category]:
# 0.2
#
# components[category]:
# 0    0.13
# 1   -0.04
# 2   -0.09
# dtype: float64
# =======

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import squareform


def portfolio_optimizer(df_data, df_correlation_matrix, df_covariance_matrix):
    # Stage 1: Data Preparation
    print("⏳ Preprocessing data...")
    object_cols = ['Beta', 'ATR', 'RSI', 'Rel Volume', 'Price']
    for col in object_cols:
        df_data[col] = pd.to_numeric(
            df_data[col].astype(str).str.replace(r'[^0-9.-]', '', regex=True),
            errors='coerce'
        )

    # Scoring configuration
    time_horizons = [5, 10, 15, 30, 60, 120]
    feature_weights = {
        'sharpe': 0.25,
        'sortino': 0.25,
        'omega': 0.20,
        'momentum': 0.15,
        'sma': 0.10,
        'volatility': -0.05
    }

    # Column definitions
    sharpe_cols = [f'Sharpe {days}d' for days in time_horizons]
    sortino_cols = [f'Sortino {days}d' for days in time_horizons]
    omega_cols = [f'Omega {days}d' for days in time_horizons]
    momentum_cols = ['Perf Week %', 'Perf Month %', 'Perf Quart %', 
                    'Perf Half %', 'Perf Year %', 'Perf YTD %']
    sma_cols = ['SMA20 %', 'SMA50 %', 'SMA200 %']
    volatility_cols = ['Volatility W %', 'Volatility M %']

    # Data cleaning
    print("🧹 Cleaning dataset...")
    required_cols = (sharpe_cols + sortino_cols + omega_cols + 
                    momentum_cols + sma_cols + volatility_cols)
    clean_mask = df_data[required_cols].notna().all(axis=1)
    df_clean = df_data.loc[clean_mask].copy()


# # ========================
#     print(f'df_clean.head():\n{df_clean.head()}')
# # ========================    



    if len(df_clean) < 50:
        raise ValueError(f"Only {len(df_clean)} valid tickers after cleaning")

    # Composite score calculation
    print("🧮 Calculating composite scores...")
    def calculate_weighted_score(df):
        components = {}
        for category, cols in [('sharpe', sharpe_cols),
                              ('sortino', sortino_cols),
                              ('omega', omega_cols),
                              ('momentum', momentum_cols),
                              ('sma', sma_cols),
                              ('volatility', volatility_cols)]:
            z_scores = df[cols].apply(lambda x: (x - x.mean()) / x.std())
            components[category] = z_scores.mean(axis=1) * feature_weights[category]
        return pd.concat(components, axis=1).sum(axis=1)
    
    df_clean['composite_score'] = calculate_weighted_score(df_clean)


# ========================
    # print(f'df_clean.head():\n{df_clean.head()}')
    display(df_clean.head())
# ========================   



    # Top 50 Selection
    print("\n" + "="*80)
    print("🔝 Stage 1: Top 50 Ticker Selection")
    print("="*80)
    print("\n📊 Selection Criteria for Top 50:")
    print("- Weighted combination of risk-adjusted returns and momentum factors")
    print("- Components: Sharpe(25%), Sortino(25%), Omega(20%), Momentum(15%), SMA(10%), Volatility(-5%)")
    print(f"- Time horizons: {', '.join(map(str, time_horizons))} days")

    top_50 = df_clean.nlargest(50, 'composite_score')
    top_50_tickers = top_50.index.tolist()
    
    print("\n🏆 Top 50 Candidates (5-Column Format):")
    top_50_sorted = top_50[['composite_score']].sort_values('composite_score', ascending=False).round(2)
    for i in range(0, 50, 5):
        row = []
        for j in range(5):
            try:
                idx, score = top_50_sorted.iloc[i+j].name, top_50_sorted.iloc[i+j].values[0]
                row.append(f"{idx:5} {score:4.2f}")
            except IndexError:
                break
        print(" | ".join(row))

    # Stage 2: Portfolio Optimization
    print("\n" + "="*80)
    print("📊 Stage 2: Portfolio Optimization (50 → 10 Tickers)")
    print("="*80)
    print("\n🔀 Cluster-Based Selection Strategy:")
    print("1. 10 clusters from correlation patterns using Ward's method")
    print("2. 1 ticker selected per cluster regardless of size")
    print("3. Intra-cluster selection by highest risk-adjusted score")
    print("4. Diversification enforced through correlation matrix clustering")

    # Cluster analysis
    corr_subset = df_correlation_matrix.loc[top_50_tickers, top_50_tickers]
    distance_matrix = 1 - np.abs(corr_subset)
    np.fill_diagonal(distance_matrix.values, 0)
    linkage_matrix = linkage(squareform(distance_matrix), method='ward')
    clusters = fcluster(linkage_matrix, t=10, criterion='maxclust')

    # Cluster dataframe construction
    cluster_df = pd.DataFrame({
        'ticker': top_50_tickers,
        'cluster': clusters,
        'score': top_50['composite_score']
    }).merge(
        df_clean[['Price', 'MktCap AUM, M', 'Volatility M %']],
        left_on='ticker',
        right_index=True
    )

    # Risk calculations
    epsilon = 1e-6
    cluster_df = cluster_df.assign(
        variance=cluster_df['ticker'].apply(lambda x: df_covariance_matrix.loc[x, x]),
        risk_adj_score=lambda x: x['score'] / (np.sqrt(x['variance']) + epsilon)
    )

    # Cluster statistics
    print("\n📈 Cluster Statistics:")
    cluster_stats = cluster_df.groupby('cluster').agg(
        Size=('ticker', 'count'),
        Avg_Correlation=('ticker', lambda x: corr_subset.loc[x,x].values.mean()),
        Avg_Score=('score', 'mean'),
    ).reset_index().round(2)
    print(cluster_stats[['cluster', 'Size', 'Avg_Correlation', 'Avg_Score']].to_string(index=False))

    # Modified final selection section with explanations
    print("\n" + "="*80)
    print("🎯 Final Portfolio Selection with Risk Adjustment")
    print("="*80)
    
    final_portfolio = []
    for cluster_id in sorted(cluster_df['cluster'].unique()):
        cluster_members = cluster_df[cluster_df['cluster'] == cluster_id].copy()
        selected = cluster_members.nlargest(1, 'risk_adj_score')
        final_portfolio.append(selected['ticker'].values[0])
        
        # Cluster-specific explanation
        print(f"\n📦 Cluster {cluster_id} ({len(cluster_members)} members):")
        print(f"   🏆 Selected: {selected['ticker'].values[0]} "
              f"(Score: {selected['score'].values[0]:.2f}, "
              f"Volatility: {np.sqrt(selected['variance'].values[0]):.2f})")
        
        # Special case explanation for Cluster 1
        if cluster_id == 1 and 'OKTA' in cluster_members.ticker.values:
            okta = cluster_members[cluster_members.ticker == 'OKTA'].iloc[0]
            puk = cluster_members[cluster_members.ticker == 'PUK'].iloc[0]
            
            print("\n   🔍 Selection Rationale:")
            print(f"   - OKTA Score: {okta.score:.2f} vs PUK Score: {puk.score:.2f}")
            print(f"   - OKTA Volatility: {np.sqrt(okta.variance):.2f} vs PUK Volatility: {np.sqrt(puk.variance):.2f}")
            print(f"   - Risk-Adjusted Scores:")
            print(f"     OKTA: {okta.score/np.sqrt(okta.variance):.2f}")
            print(f"     PUK:  {puk.score/np.sqrt(puk.variance):.2f}")
            print("   - Despite lower raw score, PUK provides better risk efficiency")
            print("   - Cluster correlation 0.67 indicates high similarity")
            print("   - Lower volatility allows larger position sizing")
        
        print(f"   📊 Members: {', '.join(cluster_members['ticker'].tolist())}")

    # New explanatory section
    print("\n" + "="*80)
    print("📚 Portfolio Selection Methodology Documentation")
    print("="*80)
    print("1. Composite Score Components:")
    print("   - 25% Sharpe Ratio (5-120 days)")
    print("   - 25% Sortino Ratio (5-120 days)")
    print("   - 20% Omega Ratio (5-120 days)")
    print("   - 15% Momentum Factors (Weekly-YTD)")
    print("   - 10% SMA Positioning (20-200 days)")
    print("   - -5% Volatility Penalty (Weekly/Monthly)")
    
    print("\n2. Cluster Selection Criteria:")
    print("   - Ward's hierarchical clustering on correlation matrix")
    print("   - Optimal cluster count determined by market regime analysis")
    print("   - Risk-adjusted score = Composite Score / √Variance")
    print("   - Variance derived from covariance matrix diagonal")
    
    print("\n3. Key Optimization Tradeoffs:")
    print("   - Balances raw performance vs risk efficiency")
    print("   - Penalizes correlated positions via cluster limits")
    print("   - Prevents overexposure to single risk factors")
    print("   - Prefers lower volatility at equal risk-adjusted returns")
    
    print("\n4. Example: PUK vs OKTA Decision")
    print("   - OKTA: Higher raw score (1.79 vs 1.43)")
    print("   - PUK:  Lower volatility (1.28 vs 1.60 estimated)")
    print("   - Risk-Adjusted Score Calculation:")
    print("     PUK: 1.43/1.28 = 1.12")
    print("     OKTA: 1.79/1.60 = 1.12")
    print("   - Tiebreaker: Lower volatility allows larger position size")
    print("   - Correlation 0.67 makes them partial substitutes")

    return final_portfolio
