# %%
import sys
from pathlib import Path

# Notebook cell
# %load_ext autoreload
# %autoreload 2

# Get root directory (assuming notebook is in root/notebooks/)
NOTEBOOK_DIR = Path.cwd()
ROOT_DIR = NOTEBOOK_DIR.parent if NOTEBOOK_DIR.name == 'notebooks' else NOTEBOOK_DIR

# Add src directory to Python path
sys.path.append(str(ROOT_DIR / 'src'))

# Verify path
print(f"Python will look in these locations:\n{sys.path}")


# --- Execute the processor ---
import utils

SOURCE_PATH, DEST_PATH = utils.main_processor(
    data_dir='..\data',  # search project ..\data
    downloads_dir='',  # None searchs Downloads dir, '' omits search
    downloads_limit=0,  # search the first 10 files
    clean_name_override='df_finviz_etfs_n_ratios.pkl',  # override filename
    start_file_pattern='df_finviz_etfs_2025', # search for files starting with 'df_'
)
# Out:
# Python will look in these locations:
# ['C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5\\python310.zip', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5\\DLLs', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5\\lib', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv', '', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages\\win32', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages\\win32\\lib', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages\\Pythonwin', 'c:\\Users\\ping\\Files_win10\\python\\py310\\stocks\\src']
# **Available 'df_finviz_etfs_2025' files:**
# - (1) `[DATA]` `df_finviz_etfs_2025-03-06.pkl` <span style='color:#00ffff'>(0.07 MB, 2025-03-09 12:58)</span>
# Input a number to select file (1-1)
#     **Selected paths:**
#     - Source: `..\data\df_finviz_etfs_2025-03-06.pkl`
#     - Destination: `..\data\df_finviz_etfs_n_ratios.pkl`

# %%
import pandas as pd

# Load the pickle file into a DataFrame
df_finviz = pd.read_pickle(SOURCE_PATH)

# Display basic information about the DataFrame
print(f"df_finviz.shape: {df_finviz.shape}")
print("\nFirst few rows:")
df_finviz.head()
# Out:
# df_finviz.shape: (420, 19)
#
# First few rows:
#         Dividend  Perf Quart  Perf Half  Beta    ATR  Volatility W  \
# Ticker
# SPY         7.06     -0.0512     0.0374  1.01   9.00        0.0225
# VOO         6.70     -0.0511     0.0377  1.01   8.29        0.0225
# IVV         7.65     -0.0514     0.0365  1.01   9.04        0.0224
# VTI         3.67     -0.0613     0.0353  1.03   4.55        0.0231
# QQQ         2.85     -0.0526     0.0571  1.17  10.72        0.0293
#
#         Volatility M    RSI  Avg Volume  Rel Volume  Expense     AUM  \
# Ticker
# SPY           0.0131  34.03       51.73        1.53   0.0009  619.80
# VOO           0.0130  34.17        6.26        1.15   0.0003  610.93
# IVV           0.0130  34.10        6.64        0.75   0.0003  582.94
# VTI           0.0134  33.00        3.38        1.43   0.0003  459.80
# QQQ           0.0180  32.68       33.23        1.71   0.0020  317.74
#
#         Flows% 1M  Flows% 3M  Flows% YTD  Return% 1Y  Return% 3Y  Return% 5Y  \
# Ticker
# SPY        0.0255     0.0209     -0.0021      0.1476      0.1162      0.1617
# VOO        0.0153     0.0716      0.0544      0.1491      0.1172      0.1629
# IVV        0.0017     0.0417     -0.0003      0.1527      0.1181      0.1645
# VTI        0.0067     0.0252      0.0157      0.1388      0.1066      0.1549
# QQQ        0.0134     0.0197      0.0155      0.1314      0.1382      0.2022
#
#                                   Tags
# Ticker
# SPY                U.S., equity, SP500
# VOO     U.S., equity, SP500, large-cap
# IVV     U.S., equity, SP500, large-cap
# VTI                       U.S., equity
# QQQ            U.S., equity, Nasdaq100

# %%
# Remove duplicates from df_finviz, keeping the first occurrence
df_finviz = df_finviz[~df_finviz.index.duplicated(keep='first')]

# Verify no duplicates remain
print(f"Duplicates removed. New shape: {df_finviz.shape}")
print(f"Any duplicates remaining? {df_finviz.index.has_duplicates}")
# Out:
# Duplicates removed. New shape: (420, 19)
# Any duplicates remaining? False

# %%
# Load the pickle file into a DataFrame
df_perf_ratios= pd.read_pickle('..\data\df_perf_ratios.pkl')

# Display basic information about the DataFrame
print(f"df_perf_ratios.shape: {df_perf_ratios.shape}")
print("\nFirst few rows:")
df_perf_ratios.head()
# Out:
# df_perf_ratios.shape: (2480, 15)
#
# First few rows:
#       Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  \
# A      -5.505585    -5.855561   0.335729   -6.734780    -7.002462   0.300426
# AA     -5.666268    -6.069974   0.374360   -2.033830    -2.547147   0.701730
# AAL    -9.758861    -9.581713   0.204881   -7.367966    -7.556580   0.281696
# AAON   -5.291580    -5.546311   0.302506   -3.217010    -3.543728   0.480896
# AAP    -3.486874    -3.946222   0.472947   -3.332664    -3.740184   0.507988
#
#       Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  \
# A      -2.586946    -3.246425   0.631665    -1.011509     -1.416187
# AA     -2.670805    -3.190910   0.632979    -0.331531     -0.463910
# AAL    -3.579376    -4.116275   0.534457     0.800832      1.360534
# AAON   -2.643905    -2.898112   0.551803    -0.399326     -0.517818
# AAP    -1.644883    -1.942857   0.731557    -0.215078     -0.277779
#
#       Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# A       0.839895    -0.725754     -0.971669    0.881852
# AA      0.944742     0.203909      0.293562    1.034045
# AAL     1.164174    -0.249204     -0.365144    0.954561
# AAON    0.914083     0.189950      0.245595    1.040837
# AAP     0.962819    -1.244576     -1.530156    0.799701

# %%
# Remove duplicates from df_perf_ratios, keeping the first occurrence
df_perf_ratios = df_perf_ratios[~df_perf_ratios.index.duplicated(keep='first')]

# Verify no duplicates remain
print(f"Duplicates removed. New shape: {df_perf_ratios.shape}")
print(f"Any duplicates remaining? {df_perf_ratios.index.has_duplicates}")
# Out:
# Duplicates removed. New shape: (2480, 15)
# Any duplicates remaining? False

# %%
# combine columns from df_perf_ratios into df_finviz using their indexes as the key
# If columns overlap, use suffixes (e.g., lsuffix='_finviz', rsuffix='_perf').
_df = df_finviz.join(df_perf_ratios, lsuffix='_finviz', rsuffix='_perf')

# Print info about the merged dataframe
print(f"Original df_finviz shape: {df_finviz.shape}")
print(f"Original df_perf_ratios shape: {df_perf_ratios.shape}")
print(f"Merged dataframe shape: {_df.shape}")
# Out:
# Original df_finviz shape: (420, 19)
# Original df_perf_ratios shape: (2480, 15)
# Merged dataframe shape: (420, 34)

# %%
_df.to_pickle(DEST_PATH)

print(f"Merged dataframe saved to {DEST_PATH}")
# Out:
# Merged dataframe saved to ..\data\df_finviz_etfs_n_ratios.pkl

# %%
_df
# Out:
#         Dividend  Perf Quart  Perf Half  Beta    ATR  Volatility W  \
# Ticker
# SPY         7.06     -0.0512     0.0374  1.01   9.00        0.0225
# VOO         6.70     -0.0511     0.0377  1.01   8.29        0.0225
# IVV         7.65     -0.0514     0.0365  1.01   9.04        0.0224
# VTI         3.67     -0.0613     0.0353  1.03   4.55        0.0231
# QQQ         2.85     -0.0526     0.0571  1.17  10.72        0.0293
# ...          ...         ...        ...   ...    ...           ...
# USRT        1.63     -0.0491    -0.0321  1.00   0.89        0.0168
# EPI         0.12     -0.1242    -0.1647  0.66   0.51        0.0110
# IBDS        1.05      0.0025    -0.0017  0.23   0.05        0.0022
# HYMB        1.10     -0.0176    -0.0081  0.31   0.13        0.0058
# TDIV        1.25     -0.0507     0.0152  1.01   1.52        0.0245
#
#         Volatility M    RSI  Avg Volume  Rel Volume  ...  Omega 30d  \
# Ticker                                               ...
# SPY           0.0131  34.03    51.73000        1.53  ...   0.539006
# VOO           0.0130  34.17     6.26000        1.15  ...   0.540467
# IVV           0.0130  34.10     6.64000        0.75  ...   0.537020
# VTI           0.0134  33.00     3.38000        1.43  ...   0.506365
# QQQ           0.0180  32.68    33.23000        1.71  ...   0.564338
# ...              ...    ...         ...         ...  ...        ...
# USRT          0.0131  46.78     0.35978        0.59  ...   0.882991
# EPI           0.0071  41.87     1.06000        0.72  ...   0.654672
# IBDS          0.0017  58.36     0.72376        0.84  ...   1.555746
# HYMB          0.0040  45.17     0.99261        1.54  ...   1.029545
# TDIV          0.0164  35.89     0.11153        2.01  ...   0.802779
#
#         Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  \
# Ticker
# SPY      -2.025652    -2.435628   0.717054    -0.188698     -0.246125
# VOO      -2.038103    -2.451023   0.716033    -0.183651     -0.239834
# IVV      -2.039605    -2.455558   0.716209    -0.182210     -0.238156
# VTI      -2.264636    -2.694847   0.687853    -0.239430     -0.313804
# QQQ      -1.894574    -2.283806   0.732560    -0.093715     -0.121238
# ...            ...          ...        ...          ...           ...
# USRT     -0.795713    -0.993756   0.874619    -0.945256     -1.194620
# EPI      -4.464476    -5.178221   0.482159    -3.124888     -3.791600
# IBDS      0.926753     1.383588   1.159779    -0.776586     -1.045121
# HYMB     -1.049591    -1.331120   0.843526    -0.624092     -0.786939
# TDIV     -0.729262    -0.920164   0.888578    -0.252459     -0.330681
#
#         Omega 120d  Sharpe 250d Sortino 250d  Omega 250d
# Ticker
# SPY       0.968096     0.560391     0.755054    1.099893
# VOO       0.968988     0.565143     0.762127    1.100588
# IVV       0.969342     0.564714     0.762309    1.100140
# VTI       0.960000     0.478327     0.644574    1.084382
# QQQ       0.984136     0.329354     0.437935    1.057367
# ...            ...          ...          ...         ...
# USRT      0.858105     0.469099     0.637548    1.080038
# EPI       0.596226    -0.621304    -0.774438    0.892405
# IBDS      0.883754     0.852532     1.235905    1.150075
# HYMB      0.895951     0.172913     0.231208    1.029736
# TDIV      0.959428     0.470197     0.640310    1.079074
#
# [420 rows x 34 columns]

# %%
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 420 entries, SPY to TDIV
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Dividend      400 non-null    float64
#  1   Perf Quart    420 non-null    float64
#  2   Perf Half     420 non-null    float64
#  3   Beta          419 non-null    float64
#  4   ATR           420 non-null    float64
#  5   Volatility W  420 non-null    float64
#  6   Volatility M  420 non-null    float64
#  7   RSI           420 non-null    float64
#  8   Avg Volume    420 non-null    float64
#  9   Rel Volume    420 non-null    float64
#  10  Expense       420 non-null    float64
#  11  AUM           420 non-null    float64
#  12  Flows% 1M     420 non-null    float64
#  13  Flows% 3M     420 non-null    float64
#  14  Flows% YTD    420 non-null    float64
#  15  Return% 1Y    419 non-null    float64
#  16  Return% 3Y    393 non-null    float64
#  17  Return% 5Y    362 non-null    float64
#  18  Tags          420 non-null    string
#  19  Sharpe 15d    414 non-null    float64
#  20  Sortino 15d   414 non-null    float64
#  21  Omega 15d     414 non-null    float64
#  22  Sharpe 30d    414 non-null    float64
#  23  Sortino 30d   414 non-null    float64
#  24  Omega 30d     414 non-null    float64
#  25  Sharpe 60d    414 non-null    float64
#  26  Sortino 60d   414 non-null    float64
#  27  Omega 60d     414 non-null    float64
#  28  Sharpe 120d   414 non-null    float64
#  29  Sortino 120d  414 non-null    float64
#  30  Omega 120d    414 non-null    float64
#  31  Sharpe 250d   414 non-null    float64
#  32  Sortino 250d  414 non-null    float64
#  33  Omega 250d    414 non-null    float64
# dtypes: float64(33), string(1)
# memory usage: 131.0+ KB
