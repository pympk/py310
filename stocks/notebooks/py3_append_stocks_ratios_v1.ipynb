# %%
import sys
from pathlib import Path

# Notebook cell
# %load_ext autoreload
# %autoreload 2

# Get root directory (assuming notebook is in root/notebooks/)
NOTEBOOK_DIR = Path.cwd()
ROOT_DIR = NOTEBOOK_DIR.parent if NOTEBOOK_DIR.name == 'notebooks' else NOTEBOOK_DIR

# Add src directory to Python path
sys.path.append(str(ROOT_DIR / 'src'))

# Verify path
print(f"Python will look in these locations:\n{sys.path}")


# --- Execute the processor ---
import utils

SOURCE_PATH, DEST_PATH = utils.main_processor(
    data_dir='..\data',  # search project ..\data
    downloads_dir='',  # None searchs Downloads dir, '' omits search
    downloads_limit=0,  # search the first 10 files
    clean_name_override='df_finviz_stocks_n_ratios.pkl',  # override filename
    start_file_pattern='df_finviz_stocks_2025', # search for files starting with 'df_'
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Python will look in these locations:
# ['C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5\\python310.zip', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5\\DLLs', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5\\lib', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.10.5', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv', '', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages\\win32', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages\\win32\\lib', 'c:\\Users\\ping\\Files_win10\\python\\py310\\.venv\\lib\\site-packages\\Pythonwin', 'c:\\Users\\ping\\Files_win10\\python\\py310\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py310\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py310\\stocks\\src']
# **Available 'df_finviz_stocks_2025' files:**
# - (1) `[DATA]` `df_finviz_stocks_2025-03-06.pkl` <span style='color:#00ffff'>(0.22 MB, 2025-03-09 12:58)</span>
# Input a number to select file (1-1)
#     **Selected paths:**
#     - Source: `..\data\df_finviz_stocks_2025-03-06.pkl`
#     - Destination: `..\data\df_finviz_stocks_n_ratios.pkl`

# %%
import pandas as pd

# Load the pickle file into a DataFrame
df_finviz = pd.read_pickle(SOURCE_PATH)

# Display basic information about the DataFrame
print(f"df_finviz.shape: {df_finviz.shape}")
print("\nFirst few rows:")
df_finviz.head()
# Out:
# df_finviz.shape: (1020, 28)
#
# First few rows:
#                               Industry  Market Cap    P/E  Fwd P/E   PEG  \
# Ticker
# AAPL              Consumer Electronics     3535.14  37.41    28.72  3.80
# MSFT         Software - Infrastructure     2950.47  31.97    26.55  2.23
# NVDA                    Semiconductors     2697.91  37.62    19.19  1.28
# AMZN                   Internet Retail     2126.96  36.35    26.28  1.82
# GOOGL   Internet Content & Information     2111.73  21.42    16.87  1.58
#
#         P/FCF  Dividend  Payout Ratio  EPS this Y  EPS next Y  ...  Quick R  \
# Ticker                                                         ...
# AAPL    35.96    0.0044        0.1611      0.0845      0.1192  ...     0.88
# MSFT    42.13    0.0083        0.2542      0.1146      0.1365  ...     1.34
# NVDA    44.33    0.0004        0.0116      0.5194      0.2686  ...     3.88
# AMZN    64.69       NaN        0.0000      0.1483      0.2027  ...     0.87
# GOOGL   29.02    0.0029        0.0746      0.1090      0.1458  ...     1.84
#
#         Gross M  Oper M  Profit M  Beta   ATR  Volatility W  Volatility M  \
# Ticker
# AAPL     0.4652  0.3176    0.2430  1.25  5.98        0.0320        0.0229
# MSFT     0.6941  0.4496    0.3543  0.99  9.37        0.0298        0.0197
# NVDA     0.7499  0.6242    0.5585  1.94  7.21        0.0679        0.0493
# AMZN     0.4885  0.1087    0.0929  1.38  6.82        0.0404        0.0274
# GOOGL    0.5826  0.3246    0.2862  1.01  4.99        0.0333        0.0248
#
#         Recom  Target Price
# Ticker
# AAPL     2.14        254.02
# MSFT     1.29        508.26
# NVDA     1.28        175.11
# AMZN     1.27        267.01
# GOOGL    1.55        219.78
#
# [5 rows x 28 columns]

# %%
# Remove duplicates from df_finviz, keeping the first occurrence
df_finviz = df_finviz[~df_finviz.index.duplicated(keep='first')]

# Verify no duplicates remain
print(f"Duplicates removed. New shape: {df_finviz.shape}")
print(f"Any duplicates remaining? {df_finviz.index.has_duplicates}")
# Out:
# Duplicates removed. New shape: (1000, 28)
# Any duplicates remaining? False

# %%
# Load the pickle file into a DataFrame
df_perf_ratios= pd.read_pickle('..\data\df_perf_ratios.pkl')

# Display basic information about the DataFrame
print(f"df_perf_ratios.shape: {df_perf_ratios.shape}")
print("\nFirst few rows:")
df_perf_ratios.head()
# Out:
# df_perf_ratios.shape: (2480, 15)
#
# First few rows:
#       Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  \
# A      -5.505585    -5.855561   0.335729   -6.734780    -7.002462   0.300426
# AA     -5.666268    -6.069974   0.374360   -2.033830    -2.547147   0.701730
# AAL    -9.758861    -9.581713   0.204881   -7.367966    -7.556580   0.281696
# AAON   -5.291580    -5.546311   0.302506   -3.217010    -3.543728   0.480896
# AAP    -3.486874    -3.946222   0.472947   -3.332664    -3.740184   0.507988
#
#       Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  \
# A      -2.586946    -3.246425   0.631665    -1.011509     -1.416187
# AA     -2.670805    -3.190910   0.632979    -0.331531     -0.463910
# AAL    -3.579376    -4.116275   0.534457     0.800832      1.360534
# AAON   -2.643905    -2.898112   0.551803    -0.399326     -0.517818
# AAP    -1.644883    -1.942857   0.731557    -0.215078     -0.277779
#
#       Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# A       0.839895    -0.725754     -0.971669    0.881852
# AA      0.944742     0.203909      0.293562    1.034045
# AAL     1.164174    -0.249204     -0.365144    0.954561
# AAON    0.914083     0.189950      0.245595    1.040837
# AAP     0.962819    -1.244576     -1.530156    0.799701

# %%
# Remove duplicates from df_perf_ratios, keeping the first occurrence
df_perf_ratios = df_perf_ratios[~df_perf_ratios.index.duplicated(keep='first')]

# Verify no duplicates remain
print(f"Duplicates removed. New shape: {df_perf_ratios.shape}")
print(f"Any duplicates remaining? {df_perf_ratios.index.has_duplicates}")
# Out:
# Duplicates removed. New shape: (2480, 15)
# Any duplicates remaining? False

# %%
# combine columns from df_perf_ratios into df_finviz using their indexes as the key
# If columns overlap, use suffixes (e.g., lsuffix='_finviz', rsuffix='_perf').
_df = df_finviz.join(df_perf_ratios, lsuffix='_finviz', rsuffix='_perf')

# Print info about the merged dataframe
print(f"Original df_finviz shape: {df_finviz.shape}")
print(f"Original df_perf_ratios shape: {df_perf_ratios.shape}")
print(f"Merged dataframe shape: {_df.shape}")
# Out:
# Original df_finviz shape: (1000, 28)
# Original df_perf_ratios shape: (2480, 15)
# Merged dataframe shape: (1000, 43)

# %%
_df.to_pickle(DEST_PATH)

print(f"Merged dataframe saved to {DEST_PATH}")
# Out:
# Merged dataframe saved to ..\data\df_finviz_stocks_n_ratios.pkl

# %%
_df
# Out:
#                                   Industry  Market Cap    P/E  Fwd P/E   PEG  \
# Ticker
# AAPL                  Consumer Electronics     3535.14  37.41    28.72  3.80
# MSFT             Software - Infrastructure     2950.47  31.97    26.55  2.23
# NVDA                        Semiconductors     2697.91  37.62    19.19  1.28
# AMZN                       Internet Retail     2126.96  36.35    26.28  1.82
# GOOGL       Internet Content & Information     2111.73  21.42    16.87  1.58
# ...                                    ...         ...    ...      ...   ...
# HALO                         Biotechnology        7.41  17.52     8.94  0.67
# BBWI                      Specialty Retail        7.41   8.34     8.59  0.82
# MHK     Furnishings, Fixtures & Appliances        7.40  14.53    10.17  1.43
# LW                          Packaged Foods        7.37  20.43    14.12   NaN
# BXSL                      Asset Management        7.36   9.00    10.33   NaN
#
#         P/FCF  Dividend  Payout Ratio  EPS this Y  EPS next Y  ...  Omega 30d  \
# Ticker                                                         ...
# AAPL    35.96    0.0044        0.1611      0.0845      0.1192  ...   0.951980
# MSFT    42.13    0.0083        0.2542      0.1146      0.1365  ...   0.472073
# NVDA    44.33    0.0004        0.0116      0.5194      0.2686  ...   0.836825
# AMZN    64.69       NaN        0.0000      0.1483      0.2027  ...   0.395566
# GOOGL   29.02    0.0029        0.0746      0.1090      0.1458  ...   0.544594
# ...       ...       ...           ...         ...         ...  ...        ...
# HALO    15.82       NaN        0.0000      0.1962      0.3299  ...   2.154786
# BBWI    11.52    0.0249        0.2087      0.0944      0.1056  ...   0.658383
# MHK     10.88       NaN        0.0000     -0.0085      0.2085  ...   0.636878
# LW        NaN    0.0278        0.2569     -0.3912      0.1835  ...   0.461256
# BXSL      NaN    0.0953        0.9107     -0.0791     -0.0326  ...   0.984938
#
#         Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  \
# Ticker
# AAPL     -1.357429    -1.711443   0.792638     0.422498      0.572634
# MSFT     -2.554413    -3.143758   0.629964    -1.172973     -1.461555
# NVDA     -1.273979    -1.546680   0.803057    -0.158190     -0.201804
# AMZN     -2.252683    -2.770751   0.698528     0.380775      0.541276
# GOOGL    -1.351244    -1.744750   0.794154     0.365282      0.506776
# ...            ...          ...        ...          ...           ...
# HALO      3.887966     7.180750   2.025724     0.044845      0.059132
# BBWI     -2.001914    -2.442873   0.668190     0.433599      0.689282
# MHK      -1.784425    -2.328923   0.749573    -1.761950     -2.092541
# LW       -2.562607    -2.858454   0.575461    -0.788667     -0.958026
# BXSL      1.099531     1.602904   1.203452     1.586707      2.329603
#
#         Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# Ticker
# AAPL      1.075420     1.119216      1.654793    1.216122
# MSFT      0.807796    -0.331737     -0.427837    0.944538
# NVDA      0.973349     0.610690      0.852376    1.107441
# AMZN      1.063373     0.443764      0.615729    1.076911
# GOOGL     1.064406     0.669860      0.970339    1.124188
# ...            ...          ...           ...         ...
# HALO      1.009613     1.118916      1.636128    1.253111
# BBWI      1.089235    -0.670455     -0.944528    0.885029
# MHK       0.714142    -0.005955     -0.009142    0.998849
# LW        0.840114    -1.082411     -1.216032    0.766775
# BXSL      1.294912     1.025621      1.449795    1.186905
#
# [1000 rows x 43 columns]

# %%
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, AAPL to BXSL
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Industry       1000 non-null   string
#  1   Market Cap     1000 non-null   float64
#  2   P/E            890 non-null    float64
#  3   Fwd P/E        965 non-null    float64
#  4   PEG            807 non-null    float64
#  5   P/FCF          855 non-null    float64
#  6   Dividend       748 non-null    float64
#  7   Payout Ratio   915 non-null    float64
#  8   EPS this Y     991 non-null    float64
#  9   EPS next Y     989 non-null    float64
#  10  EPS next 5Y    929 non-null    float64
#  11  Sales past 5Y  994 non-null    float64
#  12  Sales Q/Q      988 non-null    float64
#  13  EPS Q/Q        987 non-null    float64
#  14  Inst Own       997 non-null    float64
#  15  ROA            989 non-null    float64
#  16  ROE            949 non-null    float64
#  17  Curr R         890 non-null    float64
#  18  Quick R        791 non-null    float64
#  19  Gross M        879 non-null    float64
#  20  Oper M         989 non-null    float64
#  21  Profit M       989 non-null    float64
#  22  Beta           987 non-null    float64
#  23  ATR            1000 non-null   float64
#  24  Volatility W   1000 non-null   float64
#  25  Volatility M   999 non-null    float64
#  26  Recom          992 non-null    float64
#  27  Target Price   996 non-null    float64
#  28  Sharpe 15d     977 non-null    float64
#  29  Sortino 15d    977 non-null    float64
#  30  Omega 15d      977 non-null    float64
#  31  Sharpe 30d     977 non-null    float64
#  32  Sortino 30d    977 non-null    float64
#  33  Omega 30d      977 non-null    float64
#  34  Sharpe 60d     977 non-null    float64
#  35  Sortino 60d    977 non-null    float64
#  36  Omega 60d      977 non-null    float64
#  37  Sharpe 120d    977 non-null    float64
#  38  Sortino 120d   977 non-null    float64
#  39  Omega 120d     977 non-null    float64
#  40  Sharpe 250d    977 non-null    float64
#  41  Sortino 250d   977 non-null    float64
#  42  Omega 250d     977 non-null    float64
# dtypes: float64(42), string(1)
# memory usage: 376.0+ KB
