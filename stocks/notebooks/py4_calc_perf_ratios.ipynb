# %%
# Retrieve pickled dataframe with symbols' OHLCV
source_filename = "df_OHLCV_2025-03-03_clean.pkl"
destination_filename = "df_perf_ratios.pkl"

# days used in calculating ratios
days_ratio = [30, 63, 125, 250]

# risk free rate
risk_free_rate = 0.04

# %%
import os

# Create temp directory if it doesn't exist
temp_dir = os.path.join(os.getcwd(), 'temp')
os.makedirs(temp_dir, exist_ok=True)

# Get source and destination paths
source_path = os.path.join(temp_dir, source_filename)
dest_path = os.path.join(temp_dir, destination_filename)

print(f'temp_dir: {temp_dir}')
print(f'source_path: {source_path}')
print(f'dest_path: {dest_path}')
# Out:
# temp_dir: c:\Users\ping\Files_win10\python\py310\stocks\temp
# source_path: c:\Users\ping\Files_win10\python\py310\stocks\temp\df_OHLCV_2025-03-03_clean.pkl
# dest_path: c:\Users\ping\Files_win10\python\py310\stocks\temp\df_perf_ratios.pkl

# %%
import pandas as pd

# Load the DataFrame from the pickle file
df = pd.read_pickle(source_path)

# Display the first few rows of the DataFrame to verify
df = df[['Adj Close']].copy()
df
# Out:
#                    Adj Close
# Symbol Date
# AAPL   2025-03-03     238.03
#        2025-02-28     241.84
#        2025-02-27     237.30
#        2025-02-26     240.36
#        2025-02-25     247.04
# ...                      ...
# FCOM   2024-03-08      47.87
#        2024-03-07      47.85
#        2024-03-06      47.13
#        2024-03-05      47.21
#        2024-03-04      47.47
#
# [619500 rows x 1 columns]

# %%
import utils

list_dfs = utils.get_latest_dfs(df, days_ratio)

# %%
all_results = {}

for _df in list_dfs:
    tickers_in_df = _df.index.get_level_values(0).unique()
    for ticker in tickers_in_df:
        result_df = utils.analyze_stock(_df, ticker, risk_free_rate=risk_free_rate)
        if result_df is not None:
            # Extract the ticker name from the result_df index
            ticker_name = result_df.index[0]
            # Convert the single-row DataFrame to a dictionary
            metrics = result_df.iloc[0].to_dict()
            
            # Update the existing ticker entry or create a new one
            if ticker_name in all_results:
                all_results[ticker_name].update(metrics)
            else:
                all_results[ticker_name] = metrics

if all_results:
    combined_df = pd.DataFrame.from_dict(all_results, orient='index')
    print("\nCombined performance metrics DataFrame:")
    print(combined_df)
else:
    print("No performance metrics were calculated.")
# Out:
# Combined performance metrics DataFrame:
#       Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 63d  Sortino 63d  Omega 63d  \
# A      -5.141319    -5.874034   0.387854   -1.557570    -2.072968   0.764167
# AA     -4.138950    -4.757844   0.486068   -3.534636    -4.033184   0.538406
# AAL    -6.545431    -6.369321   0.275131   -0.309140    -0.519767   0.936498
# AAON   -5.192318    -5.220528   0.288863   -3.497344    -3.650716   0.442304
# AAP    -2.981175    -3.289828   0.528001   -1.346271    -1.597772   0.775338
# ...          ...          ...        ...         ...          ...        ...
# ZM     -0.949757    -1.295046   0.814267   -1.609598    -2.139231   0.735023
# ZS      0.217949     0.340288   1.037328   -0.797255    -1.081709   0.878738
# ZTO     1.049341     1.471367   1.172388    0.437474     0.613256   1.071279
# ZTS     0.904212     1.190219   1.167916   -0.577078    -0.736313   0.909223
# ZWS    -3.867918    -4.316013   0.522642   -2.628016    -3.051696   0.651794
#
#       Sharpe 125d  Sortino 125d  Omega 125d  Sharpe 250d  Sortino 250d  \
# A       -1.005100     -1.413684    0.840729    -0.481007     -0.651968
# AA       0.062464      0.089683    1.010611     0.448254      0.656808
# AAL      1.359764      2.433435    1.300548    -0.043775     -0.065025
# AAON    -0.655890     -0.829606    0.862521    -0.053361     -0.067795
# AAP     -0.698480     -0.888870    0.884525    -1.143217     -1.407391
# ...           ...           ...         ...          ...           ...
# ZM       0.491707      0.702016    1.091808     0.235457      0.354255
# ZS      -0.119164     -0.148472    0.978349    -0.228743     -0.297141
# ZTO     -0.293324     -0.425053    0.953742     0.112484      0.170525
# ZTS     -0.665969     -0.845534    0.895115    -0.392578     -0.530085
# ZWS      0.622600      0.960935    1.112177     0.359073      0.533973
#
#       Omega 250d
# A       0.920348
# AA      1.076155
# AAL     0.991775
# AAON    0.988760
# AAP     0.814298
# ...          ...
# ZM      1.044013
# ZS      0.960021
# ZTO     1.018740
# ZTS     0.933928
# ZWS     1.060325
#
# [2478 rows x 12 columns]

# %%
# Save the combined DataFrame to pickle file
combined_df.to_pickle(dest_path)
print(f"DataFrame successfully saved to {dest_path}")
# Out:
# DataFrame successfully saved to c:\Users\ping\Files_win10\python\py310\stocks\temp\df_perf_ratios.pkl

# %%
_symbols = ['AAPL', 'NVDA','MSFT', 'GLD', 'VOO', 'VGK', 'VCSH']

for symbol in _symbols:
    print(symbol)
    print(combined_df.loc[symbol])
    print('\n')
# Out:
# AAPL
# Sharpe 30d      1.101196
# Sortino 30d     1.630158
# Omega 30d       1.207613
# Sharpe 63d      0.193790
# Sortino 63d     0.261539
# Omega 63d       1.033302
# Sharpe 125d     0.303724
# Sortino 125d    0.416518
# Omega 125d      1.053039
# Sharpe 250d     1.266030
# Sortino 250d    1.902143
# Omega 250d      1.245869
# Name: AAPL, dtype: float64
#
#
# NVDA
# Sharpe 30d     -1.682736
# Sortino 30d    -2.001462
# Omega 30d       0.741572
# Sharpe 63d     -0.867978
# Sortino 63d    -1.072248
# Omega 63d       0.859233
# Sharpe 125d     0.032991
# Sortino 125d    0.042736
# Omega 125d      1.005706
# Sharpe 250d     0.737774
# Sortino 250d    1.037035
# Omega 250d      1.131086
# Name: NVDA, dtype: float64
#
#
# MSFT
# Sharpe 30d     -2.966416
# Sortino 30d    -3.590833
# Omega 30d       0.568237
# Sharpe 63d     -1.462950
# Sortino 63d    -1.838948
# Omega 63d       0.766052
# Sharpe 125d    -0.671672
# Sortino 125d   -0.846994
# Omega 125d      0.886161
# Sharpe 250d    -0.355745
# Sortino 250d   -0.456417
# Omega 250d      0.940744
# Name: MSFT, dtype: float64
#
#
# GLD
# Sharpe 30d      3.891600
# Sortino 30d     6.561320
# Omega 30d       1.869287
# Sharpe 63d      2.472175
# Sortino 63d     3.759748
# Omega 63d       1.462135
# Sharpe 125d     1.750960
# Sortino 125d    2.478873
# Omega 125d      1.325114
# Sharpe 250d     1.839133
# Sortino 250d    2.647006
# Omega 250d      1.343670
# Name: GLD, dtype: float64
#
#
# VOO
# Sharpe 30d     -1.715117
# Sortino 30d    -2.144654
# Omega 30d       0.763272
# Sharpe 63d     -0.859424
# Sortino 63d    -1.092456
# Omega 63d       0.866581
# Sharpe 125d     0.413193
# Sortino 125d    0.556976
# Omega 125d      1.072795
# Sharpe 250d     0.882308
# Sortino 250d    1.219355
# Omega 250d      1.160624
# Name: VOO, dtype: float64
#
#
# VGK
# Sharpe 30d      5.233611
# Sortino 30d     9.034353
# Omega 30d       2.215417
# Sharpe 63d      2.771075
# Sortino 63d     4.294223
# Omega 63d       1.556326
# Sharpe 125d     0.021095
# Sortino 125d    0.028962
# Omega 125d      1.003359
# Sharpe 250d     0.632050
# Sortino 250d    0.890218
# Omega 250d      1.103834
# Name: VGK, dtype: float64
#
#
# VCSH
# Sharpe 30d      2.991675
# Sortino 30d     4.724764
# Omega 30d       1.572522
# Sharpe 63d      0.651190
# Sortino 63d     0.928432
# Omega 63d       1.113557
# Sharpe 125d    -0.143992
# Sortino 125d   -0.198081
# Omega 125d      0.977142
# Sharpe 250d     0.950283
# Sortino 250d    1.378681
# Omega 250d      1.167214
# Name: VCSH, dtype: float64

# %%
from tabulate import tabulate

# Create a DataFrame with only the selected symbols
selected_df = combined_df.loc[_symbols]

# Display the formatted table
print(tabulate(selected_df, headers='keys', tablefmt='grid', floatfmt='.4f'))
# Out:
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# |      |   Sharpe 30d |   Sortino 30d |   Omega 30d |   Sharpe 63d |   Sortino 63d |   Omega 63d |   Sharpe 125d |   Sortino 125d |   Omega 125d |   Sharpe 250d |   Sortino 250d |   Omega 250d |
# +======+==============+===============+=============+==============+===============+=============+===============+================+==============+===============+================+==============+
# | AAPL |       1.1012 |        1.6302 |      1.2076 |       0.1938 |        0.2615 |      1.0333 |        0.3037 |         0.4165 |       1.0530 |        1.2660 |         1.9021 |       1.2459 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# | NVDA |      -1.6827 |       -2.0015 |      0.7416 |      -0.8680 |       -1.0722 |      0.8592 |        0.0330 |         0.0427 |       1.0057 |        0.7378 |         1.0370 |       1.1311 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# | MSFT |      -2.9664 |       -3.5908 |      0.5682 |      -1.4630 |       -1.8389 |      0.7661 |       -0.6717 |        -0.8470 |       0.8862 |       -0.3557 |        -0.4564 |       0.9407 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# | GLD  |       3.8916 |        6.5613 |      1.8693 |       2.4722 |        3.7597 |      1.4621 |        1.7510 |         2.4789 |       1.3251 |        1.8391 |         2.6470 |       1.3437 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# | VOO  |      -1.7151 |       -2.1447 |      0.7633 |      -0.8594 |       -1.0925 |      0.8666 |        0.4132 |         0.5570 |       1.0728 |        0.8823 |         1.2194 |       1.1606 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# | VGK  |       5.2336 |        9.0344 |      2.2154 |       2.7711 |        4.2942 |      1.5563 |        0.0211 |         0.0290 |       1.0034 |        0.6320 |         0.8902 |       1.1038 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
# | VCSH |       2.9917 |        4.7248 |      1.5725 |       0.6512 |        0.9284 |      1.1136 |       -0.1440 |        -0.1981 |       0.9771 |        0.9503 |         1.3787 |       1.1672 |
# +------+--------------+---------------+-------------+--------------+---------------+-------------+---------------+----------------+--------------+---------------+----------------+--------------+
