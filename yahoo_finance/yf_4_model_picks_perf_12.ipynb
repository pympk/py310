# %% [markdown]
# #### This notebook calculate performance of stock picks from the model

# %%
def get_trading_date_n(date, idx_close, n, verbose=False):
  """
  Retrieves the trading date n days away from the input date, if it exists in the closing price index.

  Args:
      date (datetime): The starting date.
      idx_close (dict or Series): Date index of close prices.
      n (int): Number of days to move (positive for future, negative for past).
      verbose (bool, optional): Print debug information. Defaults to False.

  Returns:
      datetime or None: The trading date n days away from the input date, or None if not found.
  """

  # Check if the input date is present in the closing price index.
  if date in idx_close:
    # Calculate the index of the date n days away from the input date.
    idx_date_n = idx_close.get_loc(date) + n

    # Check if the calculated index is within the bounds of the closing price index.
    if 0 <= idx_date_n <= len(idx_close) - 1:
      # Retrieve the date n days away.
      date_n = idx_close[idx_date_n]

      if verbose:
        print(f"Retrieving date {n} days away: {date_n}")
    else:
      date_n = None
      if verbose:
        print(f"Date {n} days away is out of bounds.")
  else:
    date_n = None
    if verbose:
      print(f"Input date {date} not found in idx_close.")

  return date_n

# %%
def any_not_in_list(list1, list2):
  """
  Determines if any items in list1 are not present in list2.

  Args:
    list1: The first list of items.
    list2: The second list of items.

  Returns:
    True if any item in list1 is not found in list2, False otherwise.
  """

  # Create sets from the lists for efficient difference calculation.
  set1 = set(list1)
  set2 = set(list2)

  # Check for items in list1 that are not in list2 by using set difference.
  # If the difference is not empty, there are items in list1 not in list2.
  return bool(set1 - set2)

# %%
def is_date_in_close(date, df_close):
  """
  Determines if a given date is present in a DataFrame's index, considering only the date portion (YYYY-MM-DD).

  Args:
    date (str): The date to check in the format YYYY-MM-DD.
    df_close (pandas.DataFrame): A DataFrame containing a date index.

  Returns:
    str or None: The input date if found in the index, otherwise None.
  """

  # Format the index to YYYY-MM-DD for comparison, ensuring consistent string format.
  formatted_idx_close = df_close.index.strftime('%Y-%m-%d')

  # Check if the input date is present in the formatted index.
  if date in formatted_idx_close:
    # If found, return the date to confirm its presence.
    return date
  else:
    # If not found, return None to indicate its absence.
    return None

# %%
import numpy as np  # Import necessary libraries at the beginning
from ast import literal_eval

def calc_portf_shares(df_close, date, str_symbols, portf_target):
  """
  Calculates the number of shares to buy for each symbol in a portfolio to meet a target investment value.

  Args:
    df_close (pandas.DataFrame): DataFrame with closing prices, indexed by date and symbols.
    date (str): The date for which to calculate shares.
    str_symbols (str): String representation of a list of symbols to include in the portfolio.
    portf_target (float): The total target investment value for the portfolio.

  Returns:
    numpy.ndarray: An array containing the number of shares to buy for each symbol.
  """

  # 1. Convert string representation of symbols to a list
  l_syms = literal_eval(str_symbols)

  # 2. Retrieve closing prices for the specified symbols on the given date
  ar_price = df_close.loc[date][l_syms].values

  # 3. Calculate the target investment amount per symbol
  amt_per_sym = portf_target / len(l_syms)  # Calculate directly using len(l_syms)

  # 4. Calculate the number of shares to buy for each symbol, rounding down to whole shares
  ar_shares = np.floor(amt_per_sym / ar_price)

  return ar_shares

# %%
import numpy as np  # Import at the beginning for better organization
from ast import literal_eval

def calc_portf_value(df_close, date, str_symbols, ar_shares, verbose=False):
  """
  Calculates the total value of a portfolio of stocks for a given date.

  Args:
    df_close (pandas.DataFrame): DataFrame containing closing prices, indexed by date and symbols.
    date (str): The date for which to calculate the portfolio value.
    str_symbols (str): String representation of a list of symbols in the portfolio.
    ar_shares (numpy.ndarray): Array containing the number of shares held for each symbol.
    verbose (bool, optional): If True, prints details of the calculation. Defaults to False.

  Returns:
    tuple: A tuple containing the date, symbols, closing prices, shares, individual symbol values, and total portfolio value.
  """

  # 1. Convert string representation of symbols to a list
  l_syms = literal_eval(str_symbols)

  # 2. Retrieve closing prices for the specified symbols on the given date
  ar_price = df_close.loc[date][l_syms].values

  # 3. Calculate the dollar value invested in each symbol
  ar_value = ar_price * ar_shares

  # 4. Calculate the total portfolio value
  portf_value = sum(ar_value)  # Directly calculate the total value

  # 5. Print details if verbose is True
  if verbose:
    print(f"Portfolio value details:\n"
          f"- Date: {date}\n"
          f"- Symbols: {l_syms}\n"
          f"- Closing prices: {ar_price}\n"
          f"- Shares: {ar_shares}\n"
          f"- Individual symbol values: {ar_value}\n"
          f"- Total portfolio value: {portf_value}")

  # 6. Return the calculated values
  return date, l_syms, ar_price, ar_shares, ar_value, portf_value

# %%
def calc_portf_value_date_buy(idx_date, str_symbols, df_close, portf_target, n, verbose=False):
  """
  Calculates portfolio values for multiple dates and symbol combinations, handling potential data gaps.

  Args:
    idx_date (list): List of dates (str) to evaluate portfolios.
    str_symbols (list): List of symbol lists (str) to evaluate for each date.
    df_close (pandas.DataFrame): DataFrame with closing prices, indexed by date and symbols.
    portf_target (float): Target portfolio value for allocation.
    n (int): Number of trading days to offset execution from the lookback date.
    verbose (bool, optional): If True, prints details. Defaults to False.

  Returns:
    tuple: Tuple containing lists of buy dates, shares, and portfolio values for both the selected symbols and SPY.
  """

  from ast import literal_eval

  # Extract trading dates and symbols from the DataFrame
  idx_close = df_close.index.strftime('%Y-%m-%d')  # Trading dates in format YYYY-MM-DD
  symbols_df_close = df_close.columns  # Symbols in df_close

  # Initialize lists to store results
  date_exec = []  # Buy date of portfolio
  shares_syms = []  # Lists of shares of each symbol bought on each date
  value_portf = []  # List of portfolio values on each date
  shares_SPY = []  # List of shares of SPY bought on each date
  value_SPY = []  # List of values of SPY shares on each date

  # Iterate through pairs of dates and symbol lists
  for date, syms in zip(idx_date, str_symbols):

    # Determine the execution date based on the lookback date and the offset n
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    # Print information for debugging
    print(f'++++++++++++++')
    print(f'date: {date}')
    print(f'n (days increment): {n}')         
    print(f'next_date_n: {next_date_n}')
    print(f'close_date_n: {close_date_n}')
    print(f'syms: {syms}')
    print(f'++++++++++++++')    

    #TODO ??? l_syms overwrite l_syms ???     
    # Convert string representation of symbols back to a list
    l_syms = literal_eval(syms)
    # print(f'syms: {syms}, l_syms: {l_syms}')
    #TODO ??? l_syms overwrite l_syms ???         

    # Check if any symbols are not present in the DataFrame
    sym_not_in_df_close = any_not_in_list(l_syms, symbols_df_close)

    if close_date_n is None or sym_not_in_df_close:
      # Handle missing data:
      print(f'l_syms: {l_syms}')  
      ## print(f'sym_not_in_df_close: {sym_not_in_df_close}')  
      print(f'l_syms are in df_close: {not sym_not_in_df_close}')        

      p_date = None
      p_ar_shares = None
      p_portf_value = None  # Set to None when data are not available
      SPY_shares = None
      SPY_value = None  # Set to None when data are not available

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")
        print(f'No data for close_date_n {close_date_n}, SPY portf value =    None')

    else:
      # Calculate portfolio values when data is available:
      p_ar_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      p_date, _l_syms, _ar_price, _ar_shares, _ar_value, p_portf_value = calc_portf_value(df_close, close_date_n, syms, p_ar_shares, verbose)

      syms = str(['SPY'])
      SPY_shares = calc_portf_shares(df_close, close_date_n, syms, portf_target)
      _date, l_syms, _ar_price, _ar_shares, _ar_value, SPY_value = calc_portf_value(df_close, close_date_n, syms, SPY_shares, verbose)

      if verbose:
        print(f"close_date_n pick's portf value = {p_portf_value}")
        print(f'close_date_n SPY portf value =    {SPY_value}')

    date_exec.append(p_date)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_portf_value)
    shares_SPY.append(SPY_shares)
    value_SPY.append(SPY_value)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
def calc_portf_value_date_n(idx_date, str_symbols, df_close, my_portf_shares, my_SPY_shares, n, verbose=False):
  """
  Calculates portfolio values for multiple dates and symbol combinations, taking pre-determined shares as input.

  Args:
    idx_date (list): List of dates (str) to evaluate portfolios.
    str_symbols (list): List of symbol lists (str) to evaluate for each date.
    df_close (pandas.DataFrame): DataFrame with closing prices, indexed by date and symbols.
    my_portf_shares (list): List of lists of shares for each symbol combination.
    my_SPY_shares (list): List of shares of SPY to evaluate for each date.
    n (int): Number of trading days to offset execution from the lookback date.
    verbose (bool, optional): If True, prints details. Defaults to False.

  Returns:
    tuple: Tuple containing lists of buy dates, shares, and portfolio values for both the selected symbols and SPY.
  """

  # Extract trading dates from the DataFrame
  idx_close = df_close.index.strftime('%Y-%m-%d')  # Trading dates in format YYYY-MM-DD

  # Initialize lists to store results
  date_exec = []  # Buy date of portfolio
  shares_syms = []  # Lists of shares of each symbol bought on each date
  value_portf = []  # List of portfolio values on each date
  shares_SPY = []  # List of shares of SPY bought on each date
  value_SPY = []  # List of values of SPY shares on each date

  # Iterate through pairs of dates, symbol lists, and shares
  for date, symbols, portf_shares, SPY_shares in zip(idx_date, str_symbols, my_portf_shares, my_SPY_shares):

    # Determine the execution date based on the lookback date and the offset n
    next_date_n = get_trading_date_n(date, idx_close, n, verbose=False)
    close_date_n = is_date_in_close(next_date_n, df_close)

    # Print information for debugging
    print(f'++++++++++++++')
    print(f'date: {date}')
    print(f'n (days increment): {n}')        
    print(f'next_date_n: {next_date_n}')
    print(f'close_date_n: {close_date_n}')
    print(f'symbols: {symbols}')
    print(f'++++++++++++++')   


    if close_date_n is None or portf_shares is None:
      # Handle missing data or missing shares:
      p_date_exec = None
      p_ar_shares = None
      p_value_portf = None  # Set to None when data or shares are unavailable
      SPY_ar_shares = None
      SPY_value_portf = None  # Set to None when data or shares are unavailable

      if verbose:
        print(f"No data for close_date_n {close_date_n}, pick's portf value = None")

    else:
      # Calculate portfolio values when data and shares are available:
      p_date_exec, _p_ar_syms, _p_ar_price, p_ar_shares, _p_ar_value, p_value_portf = calc_portf_value(df_close, close_date_n, symbols, portf_shares, verbose)

      SPY = str(['SPY'])  # Calculate SPY portfolio value separately
      _SPY_date_exec, _SPY_ar_syms, _SPY_ar_price, SPY_ar_shares, _SPY_ar_value, SPY_value_portf = calc_portf_value(df_close, close_date_n, SPY, SPY_shares, verbose)

      if verbose:
        print(f"next_date_n pick's portf value = {p_value_portf}")
        print(f'next_date_n SPY portf value =    {SPY_value_portf}')

    # Append results to lists
    date_exec.append(p_date_exec)
    shares_syms.append(p_ar_shares)
    value_portf.append(p_value_portf)
    shares_SPY.append(SPY_ar_shares)
    value_SPY.append(SPY_value_portf)

    print('='*20, '\n')

  return date_exec, shares_syms, value_portf, shares_SPY, value_SPY

# %%
import datetime

def calculate_date_n_days_back(input_date, n_days_back):
  """
  Calculates the date n days back from a given input date.

  Args:
    input_date (datetime.date): The input date.
    n_days_back (int): The number of days back from the input date.

  Returns:
    str: The date n days back from the input date, formatted as 'yyyy-mm-dd'.
  """

  previous_date = input_date - datetime.timedelta(days=n_days_back)
  previous_date_str = previous_date.strftime("%Y-%m-%d")

  return previous_date_str


# if __name__ == "__main__":
#   # Example usage
#   input_date = date.today()  # Replace with your desired date
#   n_days_back = 365*2
#   previous_date_str = calculate_date_n_days_back(input_date, n_days_back)
#   print(f"{input_date} - {n_days_back} days ago: {previous_date_str}")

# %%
import pandas as pd  # Explicitly import pandas for clarity

def sort_df_columns(df: pd.DataFrame) -> pd.DataFrame:
  """Sorts a DataFrame in descending order (most recent date first) by specified columns and reset index.

  Args:
      df: The DataFrame to be sorted.

  Returns:
      The sorted DataFrame.
  """

  # Define the sorting columns and order explicitly
  sorting_columns = ['date', 'days_lookback', 'syms_freq', 'symbols']
  ascending = False  # Descending order for all columns

  # Perform the sorting in a single step with clear variable names
  sorted_df = df.sort_values(by=sorting_columns, ascending=ascending).reset_index(drop=True)

  return sorted_df

# %%
def find_first_non_nan_in_column(df, column_name):
  """
  Finds the index of the first non-NaN value in a specific column of a DataFrame.

  Args:
      df (pd.DataFrame): The DataFrame to search.
      column_name (str): The name of the column to check for non-NaN values.

  Returns:
      int: The index of the first non-NaN value in the specified column,
       or -1 if no non-NaN values are found.
  """

  for idx, row in df.iterrows():
    # Check if all values in the current row are non-NaN (using vectorized operation)
    if not pd.isna(row[column_name]):
      return idx
  return -1

# %%
# Import libraries
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations and array manipulation
import matplotlib.pyplot as plt  # For plotting
import matplotlib.dates as mdates  # For handling dates in plots
from datetime import date, timedelta  # For working with dates
from myUtils import pickle_load, pickle_dump  # For loading and saving data

# Set pandas display options
pd.set_option('display.max_rows', 100)  # Display up to 100 rows
pd.set_option('display.max_columns', 30)  # Display up to 30 columns
pd.set_option('display.max_colwidth', 30)  # Limit column width to 30 characters
pd.set_option('display.width', 900)  # Set overall display width to 900 characters

# Define file paths
# path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"  # Base directory for stock data
path_dir = "G:/My Drive/stocks/yfinance/"# Base directory for stock data
path_data_dump = path_dir + "VSCode_dump/"  # Subdirectory for pickled data

# Define file names
fp_df_model_top_picks = 'df_model_top_picks'  # Model's top stock picks
fp_df_close_clean = 'df_close_clean'  # Historic closing prices
fp_df_model_perf = 'df_model_perf'  # Model picks' performance

# Set verbose mode
verbose = True  # Print information during execution if True

# Number of rows to check for missing data
check_n_rows = 200

# %%
"""
Loads pre-processed datasets from pickled files.
"""

# Load the DataFrame containing historical closing prices:
df_close = pickle_load(path_data_dump, fp_df_close_clean)  # Load from the specified pickle file

# Load the DataFrame containing top stock picks from the model:
df_model_picks = pickle_load(path_data_dump, fp_df_model_top_picks)  # Load from the specified pickle file

# %%
"""
Extracts and prints information about the date range and length of the df_model_picks DataFrame.
"""

# Extract dates from the DataFrame and sort them chronologically:
dates_sorted = sorted(df_model_picks.date.tolist())  # Create a list of dates and sort them

# Extract the first and last dates to determine the date range:
date_start_model_picks = dates_sorted[0]  # Get the earliest date
date_end_model_picks = dates_sorted[-1]  # Get the latest date

# Print the date range and the number of rows in the DataFrame:
print(f'date_start_model_picks: {date_start_model_picks}')
print(f'date_end_model_picks: {date_end_model_picks}')
print(f'len(df_model_picks): {len(df_model_picks)}')  # Print the length (number of rows)
# Out:
# date_start_model_picks: 2018-07-06
# date_end_model_picks: 2024-08-30
# len(df_model_picks): 1705

# %%
"""
Filters the df_close DataFrame to match the date range of df_model_picks and extracts information.
"""

# Create a boolean mask to filter rows within the desired date range:
mask = (df_close.index >= date_start_model_picks) & (df_close.index <= date_end_model_picks)  # Select rows between the start and end dates

# Apply the mask to filter the DataFrame:
df_close = df_close.loc[mask]  # Keep only rows that meet the date criteria

# Extract trading dates as formatted strings:
idx_close = df_close.index.strftime('%Y-%m-%d')  # Get trading dates in YYYY-MM-DD format

# Extract symbols present in the filtered DataFrame:
symbols_df_close = df_close.columns  # Get a list of symbols in the DataFrame

# Display the filtered DataFrame to verify its contents:
print(f'df_close:\n{df_close}')  # Print the DataFrame to view the filtered data
# Out:
# df_close:
#                      A         AA        AAL         AAP        AAPL         AB        ABBV        ABR         ABT        ACGL       ACHC       ACIW        ACLS   ACRS        ADBE  ...         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION          ZS        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                                 ...
# 2018-09-14   65.897255  41.495049  38.999985  150.746124   53.321922  18.642292   72.885605   6.573483   61.721043   30.400000  35.950001  28.930000   19.200001  15.29  274.690002  ...   75.270180  46.049999   79.042488  31.228489  63.166550  120.594536  178.699997  71.132263  46.119999  42.715153   42.639999  16.296482   85.280243  28.299999  29.576534
# 2018-09-17   66.117401  41.533844  39.569187  148.969452   51.902172  18.341127   72.649467   6.573483   61.044456   30.180000  35.529999  27.870001   19.500000  15.05  268.250000  ...   75.837532  46.279999   78.638908  31.350840  60.833782  120.112404  175.649994  69.866310  43.849998  42.306091   40.259998  15.727572   84.600014  28.100000  29.902613
# 2018-09-18   65.973824  41.815063  40.030437  152.750595   51.987930  18.130310   70.547005   6.557075   61.712017   30.240000  35.450001  28.250000   20.400000  14.98  270.790009  ...   76.144432  49.970001   79.176987  31.689655  60.929173  120.946846  176.259995  70.456520  44.220001  42.142460   39.750000  15.764277   85.443108  27.850000  29.816298
# 2018-09-19   66.576820  41.339897  40.825344  154.527313   52.018887  18.401358   69.335785   6.403948   61.793186   30.150000  35.110001  28.010000   19.900000  15.45  264.880005  ...   75.651505  48.770000   79.410141  32.762608  62.429432  120.381294  172.699997  69.318886  43.810001  42.608810   37.830002  16.507528   85.347328  27.650000  30.228683
# 2018-09-20   68.079491  41.630817  41.109951  154.536453   52.414326  18.461596   70.600319   6.327387   62.054802   30.219999  36.000000  28.510000   20.150000  15.43  266.339996  ...   75.697998  52.070000   79.777824  33.054379  64.345932  121.197189  174.779999  70.636147  44.570000  42.952427   38.820000  16.489178   86.286240  28.600000  30.545160
# ...                ...        ...        ...         ...         ...        ...         ...        ...         ...         ...        ...        ...         ...    ...         ...  ...         ...        ...         ...        ...        ...         ...         ...        ...        ...        ...         ...        ...         ...        ...        ...
# 2024-08-26  140.490005  34.560001  10.210000   49.110001  227.179993  34.930000  197.440002  13.510000  112.699997  109.489998  78.349998  49.220001  109.800003   1.22  559.440002  ...  135.888855  34.759998  134.279999  33.410000  33.689999  114.629997  347.690002  47.099998  55.779999  49.070000  197.820007  20.440001  181.559998  28.490000  32.090000
# 2024-08-27  141.100006  34.299999  10.170000   47.849998  228.029999  34.770000  195.919998  13.610000  113.099998  110.680000  78.139999  49.139999  110.879997   1.19  567.820007  ...  135.061066  34.720001  134.500000  33.490002  33.570000  114.669998  346.040009  47.070000  55.459999  48.750000  197.220001  20.900000  182.100006  28.299999  32.029999
# 2024-08-28  141.059998  32.090000  10.150000   46.639999  226.490005  34.340000  195.399994  13.550000  112.900002  111.010002  79.059998  48.889999  109.019997   1.20  560.539978  ...  135.460007  34.389999  135.649994  33.169998  34.610001  114.190002  343.829987  46.849998  54.520000  49.279999  193.970001  20.790001  182.910004  28.040001  31.889999
# 2024-08-29  142.529999  32.470001  10.390000   46.150002  229.789993  34.240002  195.179993  13.680000  112.760002  112.809998  80.849998  49.669998  109.480003   1.17  569.630005  ...  135.770004  34.910000  135.250000  33.470001  34.580002  114.669998  342.269989  48.250000  53.980000  49.230000  197.250000  21.299999  182.889999  27.879999  32.230000
# 2024-08-30  142.919998  32.099998  10.620000   45.310001  229.000000  34.439999  196.309998  13.600000  113.269997  113.089996  81.930000  50.360001  109.330002   1.18  574.409973  ...  137.529999  34.930000  134.919998  33.810001  34.389999  115.459999  345.380005  48.869999  53.430000  49.560001  199.979996  21.440001  183.490005  27.740000  32.430000
#
# [1500 rows x 1258 columns]

# %%
"""
Displays the first few rows of the df_model_picks DataFrame for a quick overview.
"""

# Sort df by columns to ensure consistency before merging columns from other dfs
sorted_df_model_picks = sort_df_columns(df_model_picks)
len_before_drop = len(sorted_df_model_picks)

# Drop duplicate rows
sorted_df_model_picks = sorted_df_model_picks.drop_duplicates().copy()
len_after_drop = len(sorted_df_model_picks)

print(f'duplicate rows dropped: {len_after_drop - len_before_drop}\n')
print(f'sorted_df_model_picks:\n{sorted_df_model_picks}')
# Out:
# duplicate rows dropped: 0
#
# sorted_df_model_picks:
#             date  days_lookback   syms_freq   symbols
# 0     2024-08-30  [30, 60, 120]  sym_freq_9   ['SHV']
# 1     2024-08-29  [30, 60, 120]  sym_freq_8   ['SHV']
# 2     2024-08-28  [30, 60, 120]  sym_freq_9   ['SHV']
# 3     2024-08-27  [30, 60, 120]  sym_freq_9   ['SHV']
# 4     2024-08-26  [30, 60, 120]  sym_freq_8   ['SHV']
# ...          ...            ...         ...       ...
# 1700  2018-07-12  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1701  2018-07-11  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1702  2018-07-10  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1703  2018-07-09  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1704  2018-07-06  [30, 60, 120]  sym_freq_8  ['TNDM']
#
# [1705 rows x 4 columns]

# %%
print(f'sorted_df_model_picks.head(20):\n{sorted_df_model_picks.head(20)}')
# Out:
# sorted_df_model_picks.head(20):
#           date  days_lookback   syms_freq                        symbols
# 0   2024-08-30  [30, 60, 120]  sym_freq_9                        ['SHV']
# 1   2024-08-29  [30, 60, 120]  sym_freq_8                        ['SHV']
# 2   2024-08-28  [30, 60, 120]  sym_freq_9                        ['SHV']
# 3   2024-08-27  [30, 60, 120]  sym_freq_9                        ['SHV']
# 4   2024-08-26  [30, 60, 120]  sym_freq_8                        ['SHV']
# 5   2024-08-23  [30, 60, 120]  sym_freq_8                        ['SHV']
# 6   2024-08-22  [30, 60, 120]  sym_freq_8                        ['SHV']
# 7   2024-08-21  [30, 60, 120]  sym_freq_9                        ['SHV']
# 8   2024-08-20  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 9   2024-08-19  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 10  2024-08-16  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 11  2024-08-15  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 12  2024-08-14  [30, 60, 120]  sym_freq_8         ['LMT', 'LUMN', 'SHV']
# 13  2024-08-13  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 14  2024-08-12  [30, 60, 120]  sym_freq_9                        ['SHV']
# 15  2024-08-12  [30, 60, 120]  sym_freq_8                        ['LMT']
# 16  2024-08-09  [30, 60, 120]  sym_freq_9                        ['SHV']
# 17  2024-08-09  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...
# 18  2024-08-08  [30, 60, 120]  sym_freq_9                        ['SHV']
# 19  2024-08-08  [30, 60, 120]  sym_freq_8        ['FTSM', 'LUMN', 'VTR']

# %%
# Load the model picks performance data from the pickle file
df_model_perf = pickle_load(path_data_dump, fp_df_model_perf)

# Sort df by columns to ensure consistency before merging columns from other dfs
sorted_df_model_perf = sort_df_columns(df_model_perf)

# Print the first 20 rows of the DataFrame for initial inspection
print(f'sorted_df_model_perf.head(20):\n{sorted_df_model_perf.head(20)}\n')
# Out:
# sorted_df_model_perf.head(20):
#           date  days_lookback   syms_freq                  symbols    date_buy      sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell     sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2024-06-10  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-06-11             [9.0]   991.620003      [1.0]  536.950012  2024-06-14             [9.0]    992.519989     0.090759       [1.0]  542.780029   1.085765  -0.995006    0
# 1   2024-06-10  [30, 60, 120]  sym_freq_8         ['FTSM', 'NVAX']  2024-06-11       [8.0, 29.0]   962.609989      [1.0]  536.950012  2024-06-14       [8.0, 29.0]    895.439985    -6.977904       [1.0]  542.780029   1.085765  -8.063670    0
# 2   2024-06-07  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-06-10             [9.0]   991.529984      [1.0]  535.659973  2024-06-13             [9.0]    992.070030     0.054466       [1.0]  542.450012   1.267602  -1.213136    0
# 3   2024-06-07  [30, 60, 120]  sym_freq_8         ['FTSM', 'NVAX']  2024-06-10       [8.0, 31.0]   973.669992      [1.0]  535.659973  2024-06-13       [8.0, 31.0]    944.390002    -3.007178       [1.0]  542.450012   1.267602  -4.274781    0
# 4   2024-06-06  [30, 60, 120]  sym_freq_8  ['FTSM', 'NVAX', 'SHV']  2024-06-07  [5.0, 18.0, 3.0]   955.810005      [1.0]  534.010010  2024-06-12  [5.0, 18.0, 3.0]    914.640001    -4.307342       [1.0]  541.359985   1.376374  -5.683716    0
# 5   2024-06-05  [30, 60, 120]  sym_freq_8  ['FTSM', 'NVAX', 'SHV']  2024-06-06  [5.0, 17.0, 3.0]   961.280001      [1.0]  534.659973  2024-06-11  [5.0, 17.0, 3.0]    913.349995    -4.986061       [1.0]  536.950012   0.428317  -5.414378    0
# 6   2024-06-04  [30, 60, 120]  sym_freq_8          ['FTSM', 'SHV']  2024-06-05        [8.0, 4.0]   917.719971      [1.0]  534.669983  2024-06-10        [8.0, 4.0]    918.039978     0.034870       [1.0]  535.659973   0.185159  -0.150289    0
# 7   2024-06-03  [30, 60, 120]  sym_freq_8                  ['SHV']  2024-06-04             [9.0]   990.720016      [1.0]  528.390015  2024-06-07             [9.0]    991.350014     0.063590       [1.0]  534.010010   1.063607  -1.000018    0
# 8   2024-05-31  [30, 60, 120]  sym_freq_8                  ['SHV']  2024-06-03             [9.0]   990.539978      [1.0]  527.799988  2024-06-06             [9.0]    991.080025     0.054520       [1.0]  534.659973   1.299732  -1.245212    0
# 9   2024-05-30  [30, 60, 120]  sym_freq_8                  ['SHV']  2024-05-31             [9.0]   990.342018      [1.0]  527.369995  2024-06-05             [9.0]    990.809967     0.047251       [1.0]  534.669983   1.384225  -1.336974    0
# 10  2024-05-29  [30, 60, 120]  sym_freq_8                  ['SHV']  2024-05-30             [9.0]   989.983589      [1.0]  522.609985  2024-06-04             [9.0]    990.720016     0.074388       [1.0]  528.390015   1.105993  -1.031605    0
# 11  2024-05-28  [30, 60, 120]  sym_freq_8          ['FTSM', 'SHV']  2024-05-29        [8.0, 4.0]   916.273193      [1.0]  526.099976  2024-06-03        [8.0, 4.0]    917.279999     0.109880       [1.0]  527.799988   0.323135  -0.213254    0
# 12  2024-05-24  [30, 60, 120]  sym_freq_8                  ['SHV']  2024-05-28             [9.0]   989.625092      [1.0]  529.809998  2024-05-31             [9.0]    990.342018     0.072444       [1.0]  527.369995  -0.460543   0.532987    1
# 13  2024-05-23  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-05-24             [9.0]   989.714699      [1.0]  529.440002  2024-05-30             [9.0]    989.983589     0.027168       [1.0]  522.609985  -1.290046   1.317214    1
# 14  2024-05-22  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-05-23             [9.0]   993.870003      [1.0]  525.960022  2024-05-29             [9.0]    993.960022     0.009057       [1.0]  526.099976   0.026609  -0.017552    0
# 15  2024-05-22  [30, 60, 120]  sym_freq_8                 ['FTSM']  2024-05-23            [16.0]   956.320007      [1.0]  525.960022  2024-05-29            [16.0]    956.799988     0.050190       [1.0]  526.099976   0.026609   0.023581    1
# 16  2024-05-21  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-05-22             [9.0]   993.330025      [1.0]  529.830017  2024-05-28             [9.0]    993.870003     0.054360       [1.0]  529.809998  -0.003778   0.058139    1
# 17  2024-05-21  [30, 60, 120]  sym_freq_8                 ['FTSM']  2024-05-22            [16.0]   956.159973      [1.0]  529.830017  2024-05-28            [16.0]    956.799988     0.066936       [1.0]  529.809998  -0.003778   0.070714    1
# 18  2024-05-20  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-05-21             [9.0]   993.149986      [1.0]  531.359985  2024-05-24             [9.0]    993.960022     0.081562       [1.0]  529.440002  -0.361334   0.442896    1
# 19  2024-05-17  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-05-20             [9.0]   993.059967      [1.0]  530.059998  2024-05-23             [9.0]    993.825027     0.077041       [1.0]  525.960022  -0.773493   0.850533    1

# %%
# Merge on the date column, keeping only common dates (inner join)
merged_df = sorted_df_model_picks.merge(sorted_df_model_perf, on='date', how='inner')

# Check if there's a match
if merged_df.shape[0] > 0:
    # If there's a match, extract the first common date and its index
    first_common_date = merged_df['date'].iloc[0]
    row_index_in_sorted_df_model_picks = sorted_df_model_picks.index[sorted_df_model_picks['date'] == first_common_date].tolist()[0]
    print("The row index of the first common date in sorted_df_model_picks is:", row_index_in_sorted_df_model_picks)
else:
    print("There's no date in both DataFrames")
# Out:
# The row index of the first common date in sorted_df_model_picks is: 83

# %%
"""
Calculated model performance on sorted_df_model_picks_calc_perf.
"""

sorted_df_model_picks_calc_perf = sorted_df_model_picks[:row_index_in_sorted_df_model_picks].copy()
print(f'sorted_df_model_picks_calc_perf:\n{sorted_df_model_picks_calc_perf}')
# Out:
# sorted_df_model_picks_calc_perf:
#           date      days_lookback    syms_freq                        symbols
# 0   2024-08-30      [30, 60, 120]   sym_freq_9                        ['SHV']
# 1   2024-08-29      [30, 60, 120]   sym_freq_8                        ['SHV']
# 2   2024-08-28      [30, 60, 120]   sym_freq_9                        ['SHV']
# 3   2024-08-27      [30, 60, 120]   sym_freq_9                        ['SHV']
# 4   2024-08-26      [30, 60, 120]   sym_freq_8                        ['SHV']
# 5   2024-08-23      [30, 60, 120]   sym_freq_8                        ['SHV']
# 6   2024-08-22      [30, 60, 120]   sym_freq_8                        ['SHV']
# 7   2024-08-21      [30, 60, 120]   sym_freq_9                        ['SHV']
# 8   2024-08-20      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']
# 9   2024-08-19      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']
# 10  2024-08-16      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']
# 11  2024-08-15      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']
# 12  2024-08-14      [30, 60, 120]   sym_freq_8         ['LMT', 'LUMN', 'SHV']
# 13  2024-08-13      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']
# 14  2024-08-12      [30, 60, 120]   sym_freq_9                        ['SHV']
# 15  2024-08-12      [30, 60, 120]   sym_freq_8                        ['LMT']
# 16  2024-08-09      [30, 60, 120]   sym_freq_9                        ['SHV']
# 17  2024-08-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...
# 18  2024-08-08      [30, 60, 120]   sym_freq_9                        ['SHV']
# 19  2024-08-08      [30, 60, 120]   sym_freq_8        ['FTSM', 'LUMN', 'VTR']
# 20  2024-08-07      [30, 60, 120]   sym_freq_9                        ['SHV']
# 21  2024-08-07      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...
# 22  2024-08-06      [30, 60, 120]   sym_freq_9                        ['SHV']
# 23  2024-08-06      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 24  2024-08-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 25  2024-08-02      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 26  2024-08-01      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 27  2024-07-31      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 28  2024-07-30      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 29  2024-07-29      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 30  2024-07-26      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 31  2024-07-25      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 32  2024-07-24      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 33  2024-07-23      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']
# 34  2024-07-22      [30, 60, 120]   sym_freq_9                        ['SHV']
# 35  2024-07-22      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']
# 36  2024-07-19      [30, 60, 120]   sym_freq_9                        ['SHV']
# 37  2024-07-19      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']
# 38  2024-07-18      [30, 60, 120]   sym_freq_9                        ['SHV']
# 39  2024-07-18      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']
# 40  2024-07-17      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']
# 41  2024-07-17      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 42  2024-07-16      [30, 60, 120]   sym_freq_9                        ['SHV']
# 43  2024-07-16      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 44  2024-07-15      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']
# 45  2024-07-15      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 46  2024-07-15  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']
# 47  2024-07-12      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']
# 48  2024-07-12      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 49  2024-07-12  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']
# 50  2024-07-11      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']
# 51  2024-07-11      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 52  2024-07-11  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']
# 53  2024-07-10      [30, 60, 120]   sym_freq_9                        ['SHV']
# 54  2024-07-10      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 55  2024-07-09      [30, 60, 120]   sym_freq_9                        ['SHV']
# 56  2024-07-09      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 57  2024-07-08      [30, 60, 120]   sym_freq_9                        ['SHV']
# 58  2024-07-08      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 59  2024-07-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 60  2024-07-03      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 61  2024-07-02      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 62  2024-07-01      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 63  2024-06-28      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 64  2024-06-27      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 65  2024-06-26      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 66  2024-06-26  [15, 30, 60, 120]  sym_freq_12                        ['SHV']
# 67  2024-06-25      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 68  2024-06-24      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 69  2024-06-21      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']
# 70  2024-06-20      [30, 60, 120]   sym_freq_9                        ['SHV']
# 71  2024-06-20      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 72  2024-06-18      [30, 60, 120]   sym_freq_9                        ['SHV']
# 73  2024-06-18      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 74  2024-06-17      [30, 60, 120]   sym_freq_9                        ['SHV']
# 75  2024-06-17      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 76  2024-06-14      [30, 60, 120]   sym_freq_9                        ['SHV']
# 77  2024-06-14      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 78  2024-06-13      [30, 60, 120]   sym_freq_9                        ['SHV']
# 79  2024-06-13      [30, 60, 120]   sym_freq_8                       ['FTSM']
# 80  2024-06-12      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']
# 81  2024-06-11      [30, 60, 120]   sym_freq_9                        ['SHV']
# 82  2024-06-11      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']

# %%
"""
Sets a target investment amount and calls a function to calculate portfolio values.
"""

# Set the total target investment amount for each day's picks:
portf_target = 1000  # Invest $1000 in total for each day's picks

# Call the function to calculate portfolio values, handling potential missing data:
date_buy, shares_syms, value_portf, shares_SPY, value_SPY = \
  calc_portf_value_date_buy(
    sorted_df_model_picks_calc_perf.date,
    sorted_df_model_picks_calc_perf.symbols,
    df_close,
    portf_target,
    n=1,
    verbose=verbose
  )

# Breakdown of the function call:
# - calc_portf_value_date_buy: Function name (assumed to be defined elsewhere)
# - df_model_picks.date: List of dates from the df_model_picks DataFrame
# - df_model_picks.symbols: List of stock symbols from the df_model_picks DataFrame
# - df_close: DataFrame containing historical closing prices
# - portf_target: Total target investment amount ($1000 in this case)
# - n=1: Offset the execution date by 1 trading day from the lookback date
# - verbose=verbose: Print details if verbose mode is enabled
# Out:
# ++++++++++++++
# date: 2024-08-30
# n (days increment): 1
# next_date_n: None
# close_date_n: None
# syms: ['SHV']
# ++++++++++++++
# l_syms: ['SHV']
# l_syms are in df_close: True
# No data for close_date_n None, pick's portf value = None
# No data for close_date_n None, SPY portf value =    None
# ====================
#
# ++++++++++++++
# date: 2024-08-29
# n (days increment): 1
# next_date_n: 2024-08-30
# close_date_n: 2024-08-30
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-30
# - Symbols: ['SHV']
# - Closing prices: [110.59999847]
# - Shares: [9.]
# - Individual symbol values: [995.39998627]
# - Total portfolio value: 995.3999862670898
# Portfolio value details:
# - Date: 2024-08-30
# - Symbols: ['SPY']
# - Closing prices: [563.67999268]
# - Shares: [1.]
# - Individual symbol values: [563.67999268]
# - Total portfolio value: 563.6799926757812
# close_date_n pick's portf value = 995.3999862670898
# close_date_n SPY portf value =    563.6799926757812
# ====================
#
# ++++++++++++++
# date: 2024-08-28
# n (days increment): 1
# next_date_n: 2024-08-29
# close_date_n: 2024-08-29
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-29
# - Symbols: ['SHV']
# - Closing prices: [110.55999756]
# - Shares: [9.]
# - Individual symbol values: [995.03997803]
# - Total portfolio value: 995.0399780273438
# Portfolio value details:
# - Date: 2024-08-29
# - Symbols: ['SPY']
# - Closing prices: [558.34997559]
# - Shares: [1.]
# - Individual symbol values: [558.34997559]
# - Total portfolio value: 558.3499755859375
# close_date_n pick's portf value = 995.0399780273438
# close_date_n SPY portf value =    558.3499755859375
# ====================
#
# ++++++++++++++
# date: 2024-08-27
# n (days increment): 1
# next_date_n: 2024-08-28
# close_date_n: 2024-08-28
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-28
# - Symbols: ['SHV']
# - Closing prices: [110.55000305]
# - Shares: [9.]
# - Individual symbol values: [994.95002747]
# - Total portfolio value: 994.9500274658203
# Portfolio value details:
# - Date: 2024-08-28
# - Symbols: ['SPY']
# - Closing prices: [558.29998779]
# - Shares: [1.]
# - Individual symbol values: [558.29998779]
# - Total portfolio value: 558.2999877929688
# close_date_n pick's portf value = 994.9500274658203
# close_date_n SPY portf value =    558.2999877929688
# ====================
#
# ++++++++++++++
# date: 2024-08-26
# n (days increment): 1
# next_date_n: 2024-08-27
# close_date_n: 2024-08-27
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-27
# - Symbols: ['SHV']
# - Closing prices: [110.52999878]
# - Shares: [9.]
# - Individual symbol values: [994.76998901]
# - Total portfolio value: 994.7699890136719
# Portfolio value details:
# - Date: 2024-08-27
# - Symbols: ['SPY']
# - Closing prices: [561.55999756]
# - Shares: [1.]
# - Individual symbol values: [561.55999756]
# - Total portfolio value: 561.5599975585938
# close_date_n pick's portf value = 994.7699890136719
# close_date_n SPY portf value =    561.5599975585938
# ====================
#
# ++++++++++++++
# date: 2024-08-23
# n (days increment): 1
# next_date_n: 2024-08-26
# close_date_n: 2024-08-26
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-26
# - Symbols: ['SHV']
# - Closing prices: [110.51000214]
# - Shares: [9.]
# - Individual symbol values: [994.59001923]
# - Total portfolio value: 994.5900192260742
# Portfolio value details:
# - Date: 2024-08-26
# - Symbols: ['SPY']
# - Closing prices: [560.78997803]
# - Shares: [1.]
# - Individual symbol values: [560.78997803]
# - Total portfolio value: 560.7899780273438
# close_date_n pick's portf value = 994.5900192260742
# close_date_n SPY portf value =    560.7899780273438
# ====================
#
# ++++++++++++++
# date: 2024-08-22
# n (days increment): 1
# next_date_n: 2024-08-23
# close_date_n: 2024-08-23
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-23
# - Symbols: ['SHV']
# - Closing prices: [110.5]
# - Shares: [9.]
# - Individual symbol values: [994.5]
# - Total portfolio value: 994.5
# Portfolio value details:
# - Date: 2024-08-23
# - Symbols: ['SPY']
# - Closing prices: [562.13000488]
# - Shares: [1.]
# - Individual symbol values: [562.13000488]
# - Total portfolio value: 562.1300048828125
# close_date_n pick's portf value = 994.5
# close_date_n SPY portf value =    562.1300048828125
# ====================
#
# ++++++++++++++
# date: 2024-08-21
# n (days increment): 1
# next_date_n: 2024-08-22
# close_date_n: 2024-08-22
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-22
# - Symbols: ['SHV']
# - Closing prices: [110.44999695]
# - Shares: [9.]
# - Individual symbol values: [994.04997253]
# - Total portfolio value: 994.0499725341797
# Portfolio value details:
# - Date: 2024-08-22
# - Symbols: ['SPY']
# - Closing prices: [556.2199707]
# - Shares: [1.]
# - Individual symbol values: [556.2199707]
# - Total portfolio value: 556.219970703125
# close_date_n pick's portf value = 994.0499725341797
# close_date_n SPY portf value =    556.219970703125
# ====================
#
# ++++++++++++++
# date: 2024-08-20
# n (days increment): 1
# next_date_n: 2024-08-21
# close_date_n: 2024-08-21
# syms: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-21
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.13000011 110.43000031]
# - Shares: [81.  4.]
# - Individual symbol values: [496.53000927 441.72000122]
# - Total portfolio value: 938.2500104904175
# Portfolio value details:
# - Date: 2024-08-21
# - Symbols: ['SPY']
# - Closing prices: [560.61999512]
# - Shares: [1.]
# - Individual symbol values: [560.61999512]
# - Total portfolio value: 560.6199951171875
# close_date_n pick's portf value = 938.2500104904175
# close_date_n SPY portf value =    560.6199951171875
# ====================
#
# ++++++++++++++
# date: 2024-08-19
# n (days increment): 1
# next_date_n: 2024-08-20
# close_date_n: 2024-08-20
# syms: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-20
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.1500001  110.41000366]
# - Shares: [81.  4.]
# - Individual symbol values: [498.15000772 441.64001465]
# - Total portfolio value: 939.7900223731995
# Portfolio value details:
# - Date: 2024-08-20
# - Symbols: ['SPY']
# - Closing prices: [558.70001221]
# - Shares: [1.]
# - Individual symbol values: [558.70001221]
# - Total portfolio value: 558.7000122070312
# close_date_n pick's portf value = 939.7900223731995
# close_date_n SPY portf value =    558.7000122070312
# ====================
#
# ++++++++++++++
# date: 2024-08-16
# n (days increment): 1
# next_date_n: 2024-08-19
# close_date_n: 2024-08-19
# syms: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-19
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  5.76000023 110.37999725]
# - Shares: [86.  4.]
# - Individual symbol values: [495.36001968 441.51998901]
# - Total portfolio value: 936.8800086975098
# Portfolio value details:
# - Date: 2024-08-19
# - Symbols: ['SPY']
# - Closing prices: [559.60998535]
# - Shares: [1.]
# - Individual symbol values: [559.60998535]
# - Total portfolio value: 559.6099853515625
# close_date_n pick's portf value = 936.8800086975098
# close_date_n SPY portf value =    559.6099853515625
# ====================
#
# ++++++++++++++
# date: 2024-08-15
# n (days increment): 1
# next_date_n: 2024-08-16
# close_date_n: 2024-08-16
# syms: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-16
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.01999998 110.37000275]
# - Shares: [83.  4.]
# - Individual symbol values: [499.65999842 441.48001099]
# - Total portfolio value: 941.1400094032288
# Portfolio value details:
# - Date: 2024-08-16
# - Symbols: ['SPY']
# - Closing prices: [554.30999756]
# - Shares: [1.]
# - Individual symbol values: [554.30999756]
# - Total portfolio value: 554.3099975585938
# close_date_n pick's portf value = 941.1400094032288
# close_date_n SPY portf value =    554.3099975585938
# ====================
#
# ++++++++++++++
# date: 2024-08-14
# n (days increment): 1
# next_date_n: 2024-08-15
# close_date_n: 2024-08-15
# syms: ['LMT', 'LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-15
# - Symbols: ['LMT', 'LUMN', 'SHV']
# - Closing prices: [560.28997803   5.71000004 110.31999969]
# - Shares: [ 0. 58.  3.]
# - Individual symbol values: [  0.         331.18000221 330.95999908]
# - Total portfolio value: 662.1400012969971
# Portfolio value details:
# - Date: 2024-08-15
# - Symbols: ['SPY']
# - Closing prices: [553.07000732]
# - Shares: [1.]
# - Individual symbol values: [553.07000732]
# - Total portfolio value: 553.0700073242188
# close_date_n pick's portf value = 662.1400012969971
# close_date_n SPY portf value =    553.0700073242188
# ====================
#
# ++++++++++++++
# date: 2024-08-13
# n (days increment): 1
# next_date_n: 2024-08-14
# close_date_n: 2024-08-14
# syms: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-14
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  5.65999985 110.30999756]
# - Shares: [88.  4.]
# - Individual symbol values: [498.07998657 441.23999023]
# - Total portfolio value: 939.3199768066406
# Portfolio value details:
# - Date: 2024-08-14
# - Symbols: ['SPY']
# - Closing prices: [543.75]
# - Shares: [1.]
# - Individual symbol values: [543.75]
# - Total portfolio value: 543.75
# close_date_n pick's portf value = 939.3199768066406
# close_date_n SPY portf value =    543.75
# ====================
#
# ++++++++++++++
# date: 2024-08-12
# n (days increment): 1
# next_date_n: 2024-08-13
# close_date_n: 2024-08-13
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['SHV']
# - Closing prices: [110.30999756]
# - Shares: [9.]
# - Individual symbol values: [992.78997803]
# - Total portfolio value: 992.7899780273438
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['SPY']
# - Closing prices: [542.03997803]
# - Shares: [1.]
# - Individual symbol values: [542.03997803]
# - Total portfolio value: 542.0399780273438
# close_date_n pick's portf value = 992.7899780273438
# close_date_n SPY portf value =    542.0399780273438
# ====================
#
# ++++++++++++++
# date: 2024-08-12
# n (days increment): 1
# next_date_n: 2024-08-13
# close_date_n: 2024-08-13
# syms: ['LMT']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['LMT']
# - Closing prices: [559.41998291]
# - Shares: [1.]
# - Individual symbol values: [559.41998291]
# - Total portfolio value: 559.4199829101562
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['SPY']
# - Closing prices: [542.03997803]
# - Shares: [1.]
# - Individual symbol values: [542.03997803]
# - Total portfolio value: 542.0399780273438
# close_date_n pick's portf value = 559.4199829101562
# close_date_n SPY portf value =    542.0399780273438
# ====================
#
# ++++++++++++++
# date: 2024-08-09
# n (days increment): 1
# next_date_n: 2024-08-12
# close_date_n: 2024-08-12
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['SHV']
# - Closing prices: [110.27999878]
# - Shares: [9.]
# - Individual symbol values: [992.51998901]
# - Total portfolio value: 992.5199890136719
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['SPY']
# - Closing prices: [533.27001953]
# - Shares: [1.]
# - Individual symbol values: [533.27001953]
# - Total portfolio value: 533.27001953125
# close_date_n pick's portf value = 992.5199890136719
# close_date_n SPY portf value =    533.27001953125
# ====================
#
# ++++++++++++++
# date: 2024-08-09
# n (days increment): 1
# next_date_n: 2024-08-12
# close_date_n: 2024-08-12
# syms: ['FTSM', 'LMT', 'LUMN', 'VTR']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['FTSM', 'LMT', 'LUMN', 'VTR']
# - Closing prices: [ 59.62365723 556.90997314   4.63999987  58.97999954]
# - Shares: [ 4.  0. 53.  4.]
# - Individual symbol values: [238.49462891   0.         245.91999292 235.91999817]
# - Total portfolio value: 720.3346199989319
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['SPY']
# - Closing prices: [533.27001953]
# - Shares: [1.]
# - Individual symbol values: [533.27001953]
# - Total portfolio value: 533.27001953125
# close_date_n pick's portf value = 720.3346199989319
# close_date_n SPY portf value =    533.27001953125
# ====================
#
# ++++++++++++++
# date: 2024-08-08
# n (days increment): 1
# next_date_n: 2024-08-09
# close_date_n: 2024-08-09
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-09
# - Symbols: ['SHV']
# - Closing prices: [110.25]
# - Shares: [9.]
# - Individual symbol values: [992.25]
# - Total portfolio value: 992.25
# Portfolio value details:
# - Date: 2024-08-09
# - Symbols: ['SPY']
# - Closing prices: [532.98999023]
# - Shares: [1.]
# - Individual symbol values: [532.98999023]
# - Total portfolio value: 532.989990234375
# close_date_n pick's portf value = 992.25
# close_date_n SPY portf value =    532.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-08-08
# n (days increment): 1
# next_date_n: 2024-08-09
# close_date_n: 2024-08-09
# syms: ['FTSM', 'LUMN', 'VTR']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-09
# - Symbols: ['FTSM', 'LUMN', 'VTR']
# - Closing prices: [59.60373688  5.57000017 59.36999893]
# - Shares: [ 5. 59.  5.]
# - Individual symbol values: [298.01868439 328.63001013 296.84999466]
# - Total portfolio value: 923.4986891746521
# Portfolio value details:
# - Date: 2024-08-09
# - Symbols: ['SPY']
# - Closing prices: [532.98999023]
# - Shares: [1.]
# - Individual symbol values: [532.98999023]
# - Total portfolio value: 532.989990234375
# close_date_n pick's portf value = 923.4986891746521
# close_date_n SPY portf value =    532.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-08-07
# n (days increment): 1
# next_date_n: 2024-08-08
# close_date_n: 2024-08-08
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-08
# - Symbols: ['SHV']
# - Closing prices: [110.20999908]
# - Shares: [9.]
# - Individual symbol values: [991.88999176]
# - Total portfolio value: 991.8899917602539
# Portfolio value details:
# - Date: 2024-08-08
# - Symbols: ['SPY']
# - Closing prices: [530.65002441]
# - Shares: [1.]
# - Individual symbol values: [530.65002441]
# - Total portfolio value: 530.6500244140625
# close_date_n pick's portf value = 991.8899917602539
# close_date_n SPY portf value =    530.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-08-07
# n (days increment): 1
# next_date_n: 2024-08-08
# close_date_n: 2024-08-08
# syms: ['FTSM', 'LMT', 'LUMN', 'VTR']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-08
# - Symbols: ['FTSM', 'LMT', 'LUMN', 'VTR']
# - Closing prices: [ 59.58382416 551.61999512   5.38000011  58.99000168]
# - Shares: [ 4.  0. 46.  4.]
# - Individual symbol values: [238.33529663   0.         247.48000526 235.96000671]
# - Total portfolio value: 721.7753086090088
# Portfolio value details:
# - Date: 2024-08-08
# - Symbols: ['SPY']
# - Closing prices: [530.65002441]
# - Shares: [1.]
# - Individual symbol values: [530.65002441]
# - Total portfolio value: 530.6500244140625
# close_date_n pick's portf value = 721.7753086090088
# close_date_n SPY portf value =    530.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-08-06
# n (days increment): 1
# next_date_n: 2024-08-07
# close_date_n: 2024-08-07
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-07
# - Symbols: ['SHV']
# - Closing prices: [110.19999695]
# - Shares: [9.]
# - Individual symbol values: [991.79997253]
# - Total portfolio value: 991.7999725341797
# Portfolio value details:
# - Date: 2024-08-07
# - Symbols: ['SPY']
# - Closing prices: [518.65997314]
# - Shares: [1.]
# - Individual symbol values: [518.65997314]
# - Total portfolio value: 518.6599731445312
# close_date_n pick's portf value = 991.7999725341797
# close_date_n SPY portf value =    518.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-08-06
# n (days increment): 1
# next_date_n: 2024-08-07
# close_date_n: 2024-08-07
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-07
# - Symbols: ['FTSM']
# - Closing prices: [59.59378052]
# - Shares: [16.]
# - Individual symbol values: [953.50048828]
# - Total portfolio value: 953.50048828125
# Portfolio value details:
# - Date: 2024-08-07
# - Symbols: ['SPY']
# - Closing prices: [518.65997314]
# - Shares: [1.]
# - Individual symbol values: [518.65997314]
# - Total portfolio value: 518.6599731445312
# close_date_n pick's portf value = 953.50048828125
# close_date_n SPY portf value =    518.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-08-05
# n (days increment): 1
# next_date_n: 2024-08-06
# close_date_n: 2024-08-06
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-06
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.58382416 110.18000031]
# - Shares: [8. 4.]
# - Individual symbol values: [476.67059326 440.72000122]
# - Total portfolio value: 917.3905944824219
# Portfolio value details:
# - Date: 2024-08-06
# - Symbols: ['SPY']
# - Closing prices: [522.15002441]
# - Shares: [1.]
# - Individual symbol values: [522.15002441]
# - Total portfolio value: 522.1500244140625
# close_date_n pick's portf value = 917.3905944824219
# close_date_n SPY portf value =    522.1500244140625
# ====================
#
# ++++++++++++++
# date: 2024-08-02
# n (days increment): 1
# next_date_n: 2024-08-05
# close_date_n: 2024-08-05
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-05
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.62365723 110.18000031]
# - Shares: [8. 4.]
# - Individual symbol values: [476.98925781 440.72000122]
# - Total portfolio value: 917.7092590332031
# Portfolio value details:
# - Date: 2024-08-05
# - Symbols: ['SPY']
# - Closing prices: [517.38000488]
# - Shares: [1.]
# - Individual symbol values: [517.38000488]
# - Total portfolio value: 517.3800048828125
# close_date_n pick's portf value = 917.7092590332031
# close_date_n SPY portf value =    517.3800048828125
# ====================
#
# ++++++++++++++
# date: 2024-08-01
# n (days increment): 1
# next_date_n: 2024-08-02
# close_date_n: 2024-08-02
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-02
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.59378052 110.18000031]
# - Shares: [8. 4.]
# - Individual symbol values: [476.75024414 440.72000122]
# - Total portfolio value: 917.4702453613281
# Portfolio value details:
# - Date: 2024-08-02
# - Symbols: ['SPY']
# - Closing prices: [532.90002441]
# - Shares: [1.]
# - Individual symbol values: [532.90002441]
# - Total portfolio value: 532.9000244140625
# close_date_n pick's portf value = 917.4702453613281
# close_date_n SPY portf value =    532.9000244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-31
# n (days increment): 1
# next_date_n: 2024-08-01
# close_date_n: 2024-08-01
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-01
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.49419403 110.08000183]
# - Shares: [8. 4.]
# - Individual symbol values: [475.95355225 440.32000732]
# - Total portfolio value: 916.2735595703125
# Portfolio value details:
# - Date: 2024-08-01
# - Symbols: ['SPY']
# - Closing prices: [543.01000977]
# - Shares: [1.]
# - Individual symbol values: [543.01000977]
# - Total portfolio value: 543.010009765625
# close_date_n pick's portf value = 916.2735595703125
# close_date_n SPY portf value =    543.010009765625
# ====================
#
# ++++++++++++++
# date: 2024-07-30
# n (days increment): 1
# next_date_n: 2024-07-31
# close_date_n: 2024-07-31
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-31
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.4742775  110.05200195]
# - Shares: [8. 4.]
# - Individual symbol values: [475.79421997 440.20800781]
# - Total portfolio value: 916.0022277832031
# Portfolio value details:
# - Date: 2024-07-31
# - Symbols: ['SPY']
# - Closing prices: [550.80999756]
# - Shares: [1.]
# - Individual symbol values: [550.80999756]
# - Total portfolio value: 550.8099975585938
# close_date_n pick's portf value = 916.0022277832031
# close_date_n SPY portf value =    550.8099975585938
# ====================
#
# ++++++++++++++
# date: 2024-07-29
# n (days increment): 1
# next_date_n: 2024-07-30
# close_date_n: 2024-07-30
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-30
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.43742371 110.04204559]
# - Shares: [8. 4.]
# - Individual symbol values: [475.49938965 440.16818237]
# - Total portfolio value: 915.6675720214844
# Portfolio value details:
# - Date: 2024-07-30
# - Symbols: ['SPY']
# - Closing prices: [542.]
# - Shares: [1.]
# - Individual symbol values: [542.]
# - Total portfolio value: 542.0
# close_date_n pick's portf value = 915.6675720214844
# close_date_n SPY portf value =    542.0
# ====================
#
# ++++++++++++++
# date: 2024-07-26
# n (days increment): 1
# next_date_n: 2024-07-29
# close_date_n: 2024-07-29
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-29
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.43742371 110.03208923]
# - Shares: [8. 4.]
# - Individual symbol values: [475.49938965 440.12835693]
# - Total portfolio value: 915.6277465820312
# Portfolio value details:
# - Date: 2024-07-29
# - Symbols: ['SPY']
# - Closing prices: [544.76000977]
# - Shares: [1.]
# - Individual symbol values: [544.76000977]
# - Total portfolio value: 544.760009765625
# close_date_n pick's portf value = 915.6277465820312
# close_date_n SPY portf value =    544.760009765625
# ====================
#
# ++++++++++++++
# date: 2024-07-25
# n (days increment): 1
# next_date_n: 2024-07-26
# close_date_n: 2024-07-26
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-26
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.42750549 110.01217651]
# - Shares: [8. 4.]
# - Individual symbol values: [475.42004395 440.04870605]
# - Total portfolio value: 915.46875
# Portfolio value details:
# - Date: 2024-07-26
# - Symbols: ['SPY']
# - Closing prices: [544.44000244]
# - Shares: [1.]
# - Individual symbol values: [544.44000244]
# - Total portfolio value: 544.4400024414062
# close_date_n pick's portf value = 915.46875
# close_date_n SPY portf value =    544.4400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-24
# n (days increment): 1
# next_date_n: 2024-07-25
# close_date_n: 2024-07-25
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-25
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.37791824 109.95244598]
# - Shares: [8. 4.]
# - Individual symbol values: [475.02334595 439.80978394]
# - Total portfolio value: 914.8331298828125
# Portfolio value details:
# - Date: 2024-07-25
# - Symbols: ['SPY']
# - Closing prices: [538.40997314]
# - Shares: [1.]
# - Individual symbol values: [538.40997314]
# - Total portfolio value: 538.4099731445312
# close_date_n pick's portf value = 914.8331298828125
# close_date_n SPY portf value =    538.4099731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-23
# n (days increment): 1
# next_date_n: 2024-07-24
# close_date_n: 2024-07-24
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-24
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.37791824 109.94248962]
# - Shares: [8. 4.]
# - Individual symbol values: [475.02334595 439.7699585 ]
# - Total portfolio value: 914.7933044433594
# Portfolio value details:
# - Date: 2024-07-24
# - Symbols: ['SPY']
# - Closing prices: [541.22998047]
# - Shares: [1.]
# - Individual symbol values: [541.22998047]
# - Total portfolio value: 541.22998046875
# close_date_n pick's portf value = 914.7933044433594
# close_date_n SPY portf value =    541.22998046875
# ====================
#
# ++++++++++++++
# date: 2024-07-22
# n (days increment): 1
# next_date_n: 2024-07-23
# close_date_n: 2024-07-23
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['SHV']
# - Closing prices: [109.93253326]
# - Shares: [9.]
# - Individual symbol values: [989.39279938]
# - Total portfolio value: 989.3927993774414
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['SPY']
# - Closing prices: [553.7800293]
# - Shares: [1.]
# - Individual symbol values: [553.7800293]
# - Total portfolio value: 553.780029296875
# close_date_n pick's portf value = 989.3927993774414
# close_date_n SPY portf value =    553.780029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-22
# n (days increment): 1
# next_date_n: 2024-07-23
# close_date_n: 2024-07-23
# syms: ['FTSM', 'LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['FTSM', 'LNTH']
# - Closing prices: [ 59.34816742 115.51999664]
# - Shares: [8. 4.]
# - Individual symbol values: [474.78533936 462.07998657]
# - Total portfolio value: 936.8653259277344
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['SPY']
# - Closing prices: [553.7800293]
# - Shares: [1.]
# - Individual symbol values: [553.7800293]
# - Total portfolio value: 553.780029296875
# close_date_n pick's portf value = 936.8653259277344
# close_date_n SPY portf value =    553.780029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-19
# n (days increment): 1
# next_date_n: 2024-07-22
# close_date_n: 2024-07-22
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['SHV']
# - Closing prices: [109.91262054]
# - Shares: [9.]
# - Individual symbol values: [989.2135849]
# - Total portfolio value: 989.2135848999023
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['SPY']
# - Closing prices: [554.65002441]
# - Shares: [1.]
# - Individual symbol values: [554.65002441]
# - Total portfolio value: 554.6500244140625
# close_date_n pick's portf value = 989.2135848999023
# close_date_n SPY portf value =    554.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-19
# n (days increment): 1
# next_date_n: 2024-07-22
# close_date_n: 2024-07-22
# syms: ['FTSM', 'LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['FTSM', 'LNTH']
# - Closing prices: [ 59.34816742 114.68000031]
# - Shares: [8. 4.]
# - Individual symbol values: [474.78533936 458.72000122]
# - Total portfolio value: 933.5053405761719
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['SPY']
# - Closing prices: [554.65002441]
# - Shares: [1.]
# - Individual symbol values: [554.65002441]
# - Total portfolio value: 554.6500244140625
# close_date_n pick's portf value = 933.5053405761719
# close_date_n SPY portf value =    554.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-18
# n (days increment): 1
# next_date_n: 2024-07-19
# close_date_n: 2024-07-19
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['SHV']
# - Closing prices: [109.90266418]
# - Shares: [9.]
# - Individual symbol values: [989.12397766]
# - Total portfolio value: 989.1239776611328
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['SPY']
# - Closing prices: [548.98999023]
# - Shares: [1.]
# - Individual symbol values: [548.98999023]
# - Total portfolio value: 548.989990234375
# close_date_n pick's portf value = 989.1239776611328
# close_date_n SPY portf value =    548.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-18
# n (days increment): 1
# next_date_n: 2024-07-19
# close_date_n: 2024-07-19
# syms: ['FTSM', 'LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['FTSM', 'LNTH']
# - Closing prices: [ 59.32833099 116.79000092]
# - Shares: [8. 4.]
# - Individual symbol values: [474.62664795 467.16000366]
# - Total portfolio value: 941.7866516113281
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['SPY']
# - Closing prices: [548.98999023]
# - Shares: [1.]
# - Individual symbol values: [548.98999023]
# - Total portfolio value: 548.989990234375
# close_date_n pick's portf value = 941.7866516113281
# close_date_n SPY portf value =    548.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-17
# n (days increment): 1
# next_date_n: 2024-07-18
# close_date_n: 2024-07-18
# syms: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [115.73999786 109.84293365]
# - Shares: [4. 4.]
# - Individual symbol values: [462.95999146 439.37173462]
# - Total portfolio value: 902.3317260742188
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['SPY']
# - Closing prices: [552.65997314]
# - Shares: [1.]
# - Individual symbol values: [552.65997314]
# - Total portfolio value: 552.6599731445312
# close_date_n pick's portf value = 902.3317260742188
# close_date_n SPY portf value =    552.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-17
# n (days increment): 1
# next_date_n: 2024-07-18
# close_date_n: 2024-07-18
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['FTSM']
# - Closing prices: [59.32833099]
# - Shares: [16.]
# - Individual symbol values: [949.2532959]
# - Total portfolio value: 949.2532958984375
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['SPY']
# - Closing prices: [552.65997314]
# - Shares: [1.]
# - Individual symbol values: [552.65997314]
# - Total portfolio value: 552.6599731445312
# close_date_n pick's portf value = 949.2532958984375
# close_date_n SPY portf value =    552.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-16
# n (days increment): 1
# next_date_n: 2024-07-17
# close_date_n: 2024-07-17
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['SHV']
# - Closing prices: [109.82301331]
# - Shares: [9.]
# - Individual symbol values: [988.40711975]
# - Total portfolio value: 988.4071197509766
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['SPY']
# - Closing prices: [556.94000244]
# - Shares: [1.]
# - Individual symbol values: [556.94000244]
# - Total portfolio value: 556.9400024414062
# close_date_n pick's portf value = 988.4071197509766
# close_date_n SPY portf value =    556.9400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-16
# n (days increment): 1
# next_date_n: 2024-07-17
# close_date_n: 2024-07-17
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['FTSM']
# - Closing prices: [59.31841278]
# - Shares: [16.]
# - Individual symbol values: [949.09460449]
# - Total portfolio value: 949.0946044921875
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['SPY']
# - Closing prices: [556.94000244]
# - Shares: [1.]
# - Individual symbol values: [556.94000244]
# - Total portfolio value: 556.9400024414062
# close_date_n pick's portf value = 949.0946044921875
# close_date_n SPY portf value =    556.9400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-15
# n (days increment): 1
# next_date_n: 2024-07-16
# close_date_n: 2024-07-16
# syms: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [118.30000305 109.81306458]
# - Shares: [4. 4.]
# - Individual symbol values: [473.20001221 439.2522583 ]
# - Total portfolio value: 912.4522705078125
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['SPY']
# - Closing prices: [564.85998535]
# - Shares: [1.]
# - Individual symbol values: [564.85998535]
# - Total portfolio value: 564.8599853515625
# close_date_n pick's portf value = 912.4522705078125
# close_date_n SPY portf value =    564.8599853515625
# ====================
#
# ++++++++++++++
# date: 2024-07-15
# n (days increment): 1
# next_date_n: 2024-07-16
# close_date_n: 2024-07-16
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['FTSM']
# - Closing prices: [59.30849457]
# - Shares: [16.]
# - Individual symbol values: [948.93591309]
# - Total portfolio value: 948.9359130859375
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['SPY']
# - Closing prices: [564.85998535]
# - Shares: [1.]
# - Individual symbol values: [564.85998535]
# - Total portfolio value: 564.8599853515625
# close_date_n pick's portf value = 948.9359130859375
# close_date_n SPY portf value =    564.8599853515625
# ====================
#
# ++++++++++++++
# date: 2024-07-15
# n (days increment): 1
# next_date_n: 2024-07-16
# close_date_n: 2024-07-16
# syms: ['LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['LNTH']
# - Closing prices: [118.30000305]
# - Shares: [8.]
# - Individual symbol values: [946.40002441]
# - Total portfolio value: 946.4000244140625
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['SPY']
# - Closing prices: [564.85998535]
# - Shares: [1.]
# - Individual symbol values: [564.85998535]
# - Total portfolio value: 564.8599853515625
# close_date_n pick's portf value = 946.4000244140625
# close_date_n SPY portf value =    564.8599853515625
# ====================
#
# ++++++++++++++
# date: 2024-07-12
# n (days increment): 1
# next_date_n: 2024-07-15
# close_date_n: 2024-07-15
# syms: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [123.19000244 109.80310822]
# - Shares: [4. 4.]
# - Individual symbol values: [492.76000977 439.21243286]
# - Total portfolio value: 931.9724426269531
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['SPY']
# - Closing prices: [561.5300293]
# - Shares: [1.]
# - Individual symbol values: [561.5300293]
# - Total portfolio value: 561.530029296875
# close_date_n pick's portf value = 931.9724426269531
# close_date_n SPY portf value =    561.530029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-12
# n (days increment): 1
# next_date_n: 2024-07-15
# close_date_n: 2024-07-15
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['FTSM']
# - Closing prices: [59.30849457]
# - Shares: [16.]
# - Individual symbol values: [948.93591309]
# - Total portfolio value: 948.9359130859375
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['SPY']
# - Closing prices: [561.5300293]
# - Shares: [1.]
# - Individual symbol values: [561.5300293]
# - Total portfolio value: 561.530029296875
# close_date_n pick's portf value = 948.9359130859375
# close_date_n SPY portf value =    561.530029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-12
# n (days increment): 1
# next_date_n: 2024-07-15
# close_date_n: 2024-07-15
# syms: ['LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['LNTH']
# - Closing prices: [123.19000244]
# - Shares: [8.]
# - Individual symbol values: [985.52001953]
# - Total portfolio value: 985.52001953125
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['SPY']
# - Closing prices: [561.5300293]
# - Shares: [1.]
# - Individual symbol values: [561.5300293]
# - Total portfolio value: 561.530029296875
# close_date_n pick's portf value = 985.52001953125
# close_date_n SPY portf value =    561.530029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-11
# n (days increment): 1
# next_date_n: 2024-07-12
# close_date_n: 2024-07-12
# syms: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [123.41999817 109.78318787]
# - Shares: [4. 4.]
# - Individual symbol values: [493.67999268 439.13275146]
# - Total portfolio value: 932.812744140625
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['SPY']
# - Closing prices: [559.98999023]
# - Shares: [1.]
# - Individual symbol values: [559.98999023]
# - Total portfolio value: 559.989990234375
# close_date_n pick's portf value = 932.812744140625
# close_date_n SPY portf value =    559.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-11
# n (days increment): 1
# next_date_n: 2024-07-12
# close_date_n: 2024-07-12
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['FTSM']
# - Closing prices: [59.29858017]
# - Shares: [16.]
# - Individual symbol values: [948.77728271]
# - Total portfolio value: 948.7772827148438
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['SPY']
# - Closing prices: [559.98999023]
# - Shares: [1.]
# - Individual symbol values: [559.98999023]
# - Total portfolio value: 559.989990234375
# close_date_n pick's portf value = 948.7772827148438
# close_date_n SPY portf value =    559.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-11
# n (days increment): 1
# next_date_n: 2024-07-12
# close_date_n: 2024-07-12
# syms: ['LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['LNTH']
# - Closing prices: [123.41999817]
# - Shares: [8.]
# - Individual symbol values: [987.35998535]
# - Total portfolio value: 987.3599853515625
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['SPY']
# - Closing prices: [559.98999023]
# - Shares: [1.]
# - Individual symbol values: [559.98999023]
# - Total portfolio value: 559.989990234375
# close_date_n pick's portf value = 987.3599853515625
# close_date_n SPY portf value =    559.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-10
# n (days increment): 1
# next_date_n: 2024-07-11
# close_date_n: 2024-07-11
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-11
# - Symbols: ['SHV']
# - Closing prices: [109.72345734]
# - Shares: [9.]
# - Individual symbol values: [987.51111603]
# - Total portfolio value: 987.511116027832
# Portfolio value details:
# - Date: 2024-07-11
# - Symbols: ['SPY']
# - Closing prices: [556.47998047]
# - Shares: [1.]
# - Individual symbol values: [556.47998047]
# - Total portfolio value: 556.47998046875
# close_date_n pick's portf value = 987.511116027832
# close_date_n SPY portf value =    556.47998046875
# ====================
#
# ++++++++++++++
# date: 2024-07-10
# n (days increment): 1
# next_date_n: 2024-07-11
# close_date_n: 2024-07-11
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-11
# - Symbols: ['FTSM']
# - Closing prices: [59.24899292]
# - Shares: [16.]
# - Individual symbol values: [947.98388672]
# - Total portfolio value: 947.98388671875
# Portfolio value details:
# - Date: 2024-07-11
# - Symbols: ['SPY']
# - Closing prices: [556.47998047]
# - Shares: [1.]
# - Individual symbol values: [556.47998047]
# - Total portfolio value: 556.47998046875
# close_date_n pick's portf value = 947.98388671875
# close_date_n SPY portf value =    556.47998046875
# ====================
#
# ++++++++++++++
# date: 2024-07-09
# n (days increment): 1
# next_date_n: 2024-07-10
# close_date_n: 2024-07-10
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-10
# - Symbols: ['SHV']
# - Closing prices: [109.69358826]
# - Shares: [9.]
# - Individual symbol values: [987.24229431]
# - Total portfolio value: 987.2422943115234
# Portfolio value details:
# - Date: 2024-07-10
# - Symbols: ['SPY']
# - Closing prices: [561.32000732]
# - Shares: [1.]
# - Individual symbol values: [561.32000732]
# - Total portfolio value: 561.3200073242188
# close_date_n pick's portf value = 987.2422943115234
# close_date_n SPY portf value =    561.3200073242188
# ====================
#
# ++++++++++++++
# date: 2024-07-09
# n (days increment): 1
# next_date_n: 2024-07-10
# close_date_n: 2024-07-10
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-10
# - Symbols: ['FTSM']
# - Closing prices: [59.22915268]
# - Shares: [16.]
# - Individual symbol values: [947.66644287]
# - Total portfolio value: 947.6664428710938
# Portfolio value details:
# - Date: 2024-07-10
# - Symbols: ['SPY']
# - Closing prices: [561.32000732]
# - Shares: [1.]
# - Individual symbol values: [561.32000732]
# - Total portfolio value: 561.3200073242188
# close_date_n pick's portf value = 947.6664428710938
# close_date_n SPY portf value =    561.3200073242188
# ====================
#
# ++++++++++++++
# date: 2024-07-08
# n (days increment): 1
# next_date_n: 2024-07-09
# close_date_n: 2024-07-09
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-09
# - Symbols: ['SHV']
# - Closing prices: [109.6836319]
# - Shares: [9.]
# - Individual symbol values: [987.15268707]
# - Total portfolio value: 987.1526870727539
# Portfolio value details:
# - Date: 2024-07-09
# - Symbols: ['SPY']
# - Closing prices: [555.82000732]
# - Shares: [1.]
# - Individual symbol values: [555.82000732]
# - Total portfolio value: 555.8200073242188
# close_date_n pick's portf value = 987.1526870727539
# close_date_n SPY portf value =    555.8200073242188
# ====================
#
# ++++++++++++++
# date: 2024-07-08
# n (days increment): 1
# next_date_n: 2024-07-09
# close_date_n: 2024-07-09
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-09
# - Symbols: ['FTSM']
# - Closing prices: [59.21923447]
# - Shares: [16.]
# - Individual symbol values: [947.50775146]
# - Total portfolio value: 947.5077514648438
# Portfolio value details:
# - Date: 2024-07-09
# - Symbols: ['SPY']
# - Closing prices: [555.82000732]
# - Shares: [1.]
# - Individual symbol values: [555.82000732]
# - Total portfolio value: 555.8200073242188
# close_date_n pick's portf value = 947.5077514648438
# close_date_n SPY portf value =    555.8200073242188
# ====================
#
# ++++++++++++++
# date: 2024-07-05
# n (days increment): 1
# next_date_n: 2024-07-08
# close_date_n: 2024-07-08
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-08
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.19939804 109.6836319 ]
# - Shares: [8. 4.]
# - Individual symbol values: [473.59518433 438.73452759]
# - Total portfolio value: 912.3297119140625
# Portfolio value details:
# - Date: 2024-07-08
# - Symbols: ['SPY']
# - Closing prices: [555.2800293]
# - Shares: [1.]
# - Individual symbol values: [555.2800293]
# - Total portfolio value: 555.280029296875
# close_date_n pick's portf value = 912.3297119140625
# close_date_n SPY portf value =    555.280029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-03
# n (days increment): 1
# next_date_n: 2024-07-05
# close_date_n: 2024-07-05
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-05
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.20931625 109.65377045]
# - Shares: [8. 4.]
# - Individual symbol values: [473.67453003 438.61508179]
# - Total portfolio value: 912.2896118164062
# Portfolio value details:
# - Date: 2024-07-05
# - Symbols: ['SPY']
# - Closing prices: [554.64001465]
# - Shares: [1.]
# - Individual symbol values: [554.64001465]
# - Total portfolio value: 554.6400146484375
# close_date_n pick's portf value = 912.2896118164062
# close_date_n SPY portf value =    554.6400146484375
# ====================
#
# ++++++++++++++
# date: 2024-07-02
# n (days increment): 1
# next_date_n: 2024-07-03
# close_date_n: 2024-07-03
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-03
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.14981079 109.61394501]
# - Shares: [8. 4.]
# - Individual symbol values: [473.19848633 438.45578003]
# - Total portfolio value: 911.6542663574219
# Portfolio value details:
# - Date: 2024-07-03
# - Symbols: ['SPY']
# - Closing prices: [551.46002197]
# - Shares: [1.]
# - Individual symbol values: [551.46002197]
# - Total portfolio value: 551.4600219726562
# close_date_n pick's portf value = 911.6542663574219
# close_date_n SPY portf value =    551.4600219726562
# ====================
#
# ++++++++++++++
# date: 2024-07-01
# n (days increment): 1
# next_date_n: 2024-07-02
# close_date_n: 2024-07-02
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-02
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.12997055 109.58407593]
# - Shares: [8. 4.]
# - Individual symbol values: [473.0397644  438.33630371]
# - Total portfolio value: 911.3760681152344
# Portfolio value details:
# - Date: 2024-07-02
# - Symbols: ['SPY']
# - Closing prices: [549.01000977]
# - Shares: [1.]
# - Individual symbol values: [549.01000977]
# - Total portfolio value: 549.010009765625
# close_date_n pick's portf value = 911.3760681152344
# close_date_n SPY portf value =    549.010009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-28
# n (days increment): 1
# next_date_n: 2024-07-01
# close_date_n: 2024-07-01
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-01
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.12005615 109.56417084]
# - Shares: [8. 4.]
# - Individual symbol values: [472.96044922 438.25668335]
# - Total portfolio value: 911.2171325683594
# Portfolio value details:
# - Date: 2024-07-01
# - Symbols: ['SPY']
# - Closing prices: [545.34002686]
# - Shares: [1.]
# - Individual symbol values: [545.34002686]
# - Total portfolio value: 545.3400268554688
# close_date_n pick's portf value = 911.2171325683594
# close_date_n SPY portf value =    545.3400268554688
# ====================
#
# ++++++++++++++
# date: 2024-06-27
# n (days increment): 1
# next_date_n: 2024-06-28
# close_date_n: 2024-06-28
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-28
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.11013794 109.54823303]
# - Shares: [8. 4.]
# - Individual symbol values: [472.88110352 438.19293213]
# - Total portfolio value: 911.0740356445312
# Portfolio value details:
# - Date: 2024-06-28
# - Symbols: ['SPY']
# - Closing prices: [544.2199707]
# - Shares: [1.]
# - Individual symbol values: [544.2199707]
# - Total portfolio value: 544.219970703125
# close_date_n pick's portf value = 911.0740356445312
# close_date_n SPY portf value =    544.219970703125
# ====================
#
# ++++++++++++++
# date: 2024-06-26
# n (days increment): 1
# next_date_n: 2024-06-27
# close_date_n: 2024-06-27
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-27
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.07542801 109.49866486]
# - Shares: [8. 4.]
# - Individual symbol values: [472.60342407 437.99465942]
# - Total portfolio value: 910.5980834960938
# Portfolio value details:
# - Date: 2024-06-27
# - Symbols: ['SPY']
# - Closing prices: [546.36999512]
# - Shares: [1.]
# - Individual symbol values: [546.36999512]
# - Total portfolio value: 546.3699951171875
# close_date_n pick's portf value = 910.5980834960938
# close_date_n SPY portf value =    546.3699951171875
# ====================
#
# ++++++++++++++
# date: 2024-06-26
# n (days increment): 1
# next_date_n: 2024-06-27
# close_date_n: 2024-06-27
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-27
# - Symbols: ['SHV']
# - Closing prices: [109.49866486]
# - Shares: [9.]
# - Individual symbol values: [985.4879837]
# - Total portfolio value: 985.4879837036133
# Portfolio value details:
# - Date: 2024-06-27
# - Symbols: ['SPY']
# - Closing prices: [546.36999512]
# - Shares: [1.]
# - Individual symbol values: [546.36999512]
# - Total portfolio value: 546.3699951171875
# close_date_n pick's portf value = 985.4879837036133
# close_date_n SPY portf value =    546.3699951171875
# ====================
#
# ++++++++++++++
# date: 2024-06-25
# n (days increment): 1
# next_date_n: 2024-06-26
# close_date_n: 2024-06-26
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-26
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.06554413 109.46891785]
# - Shares: [8. 4.]
# - Individual symbol values: [472.52435303 437.87567139]
# - Total portfolio value: 910.4000244140625
# Portfolio value details:
# - Date: 2024-06-26
# - Symbols: ['SPY']
# - Closing prices: [545.51000977]
# - Shares: [1.]
# - Individual symbol values: [545.51000977]
# - Total portfolio value: 545.510009765625
# close_date_n pick's portf value = 910.4000244140625
# close_date_n SPY portf value =    545.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-24
# n (days increment): 1
# next_date_n: 2024-06-25
# close_date_n: 2024-06-25
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-25
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.07542801 109.46891785]
# - Shares: [8. 4.]
# - Individual symbol values: [472.60342407 437.87567139]
# - Total portfolio value: 910.4790954589844
# Portfolio value details:
# - Date: 2024-06-25
# - Symbols: ['SPY']
# - Closing prices: [544.83001709]
# - Shares: [1.]
# - Individual symbol values: [544.83001709]
# - Total portfolio value: 544.8300170898438
# close_date_n pick's portf value = 910.4790954589844
# close_date_n SPY portf value =    544.8300170898438
# ====================
#
# ++++++++++++++
# date: 2024-06-21
# n (days increment): 1
# next_date_n: 2024-06-24
# close_date_n: 2024-06-24
# syms: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-24
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.07542801 109.44909668]
# - Shares: [8. 4.]
# - Individual symbol values: [472.60342407 437.79638672]
# - Total portfolio value: 910.3998107910156
# Portfolio value details:
# - Date: 2024-06-24
# - Symbols: ['SPY']
# - Closing prices: [542.73999023]
# - Shares: [1.]
# - Individual symbol values: [542.73999023]
# - Total portfolio value: 542.739990234375
# close_date_n pick's portf value = 910.3998107910156
# close_date_n SPY portf value =    542.739990234375
# ====================
#
# ++++++++++++++
# date: 2024-06-20
# n (days increment): 1
# next_date_n: 2024-06-21
# close_date_n: 2024-06-21
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['SHV']
# - Closing prices: [109.43917847]
# - Shares: [9.]
# - Individual symbol values: [984.9526062]
# - Total portfolio value: 984.9526062011719
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['SPY']
# - Closing prices: [544.51000977]
# - Shares: [1.]
# - Individual symbol values: [544.51000977]
# - Total portfolio value: 544.510009765625
# close_date_n pick's portf value = 984.9526062011719
# close_date_n SPY portf value =    544.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-20
# n (days increment): 1
# next_date_n: 2024-06-21
# close_date_n: 2024-06-21
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['FTSM']
# - Closing prices: [59.06554413]
# - Shares: [16.]
# - Individual symbol values: [945.04870605]
# - Total portfolio value: 945.0487060546875
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['SPY']
# - Closing prices: [544.51000977]
# - Shares: [1.]
# - Individual symbol values: [544.51000977]
# - Total portfolio value: 544.510009765625
# close_date_n pick's portf value = 945.0487060546875
# close_date_n SPY portf value =    544.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-18
# n (days increment): 1
# next_date_n: 2024-06-20
# close_date_n: 2024-06-20
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['SHV']
# - Closing prices: [109.38961029]
# - Shares: [9.]
# - Individual symbol values: [984.50649261]
# - Total portfolio value: 984.5064926147461
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['SPY']
# - Closing prices: [545.2409668]
# - Shares: [1.]
# - Individual symbol values: [545.2409668]
# - Total portfolio value: 545.240966796875
# close_date_n pick's portf value = 984.5064926147461
# close_date_n SPY portf value =    545.240966796875
# ====================
#
# ++++++++++++++
# date: 2024-06-18
# n (days increment): 1
# next_date_n: 2024-06-20
# close_date_n: 2024-06-20
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['FTSM']
# - Closing prices: [59.02603531]
# - Shares: [16.]
# - Individual symbol values: [944.41656494]
# - Total portfolio value: 944.4165649414062
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['SPY']
# - Closing prices: [545.2409668]
# - Shares: [1.]
# - Individual symbol values: [545.2409668]
# - Total portfolio value: 545.240966796875
# close_date_n pick's portf value = 944.4165649414062
# close_date_n SPY portf value =    545.240966796875
# ====================
#
# ++++++++++++++
# date: 2024-06-17
# n (days increment): 1
# next_date_n: 2024-06-18
# close_date_n: 2024-06-18
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-18
# - Symbols: ['SHV']
# - Closing prices: [109.36978912]
# - Shares: [9.]
# - Individual symbol values: [984.32810211]
# - Total portfolio value: 984.3281021118164
# Portfolio value details:
# - Date: 2024-06-18
# - Symbols: ['SPY']
# - Closing prices: [546.72619629]
# - Shares: [1.]
# - Individual symbol values: [546.72619629]
# - Total portfolio value: 546.7261962890625
# close_date_n pick's portf value = 984.3281021118164
# close_date_n SPY portf value =    546.7261962890625
# ====================
#
# ++++++++++++++
# date: 2024-06-17
# n (days increment): 1
# next_date_n: 2024-06-18
# close_date_n: 2024-06-18
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-18
# - Symbols: ['FTSM']
# - Closing prices: [59.03591537]
# - Shares: [16.]
# - Individual symbol values: [944.574646]
# - Total portfolio value: 944.5746459960938
# Portfolio value details:
# - Date: 2024-06-18
# - Symbols: ['SPY']
# - Closing prices: [546.72619629]
# - Shares: [1.]
# - Individual symbol values: [546.72619629]
# - Total portfolio value: 546.7261962890625
# close_date_n pick's portf value = 944.5746459960938
# close_date_n SPY portf value =    546.7261962890625
# ====================
#
# ++++++++++++++
# date: 2024-06-14
# n (days increment): 1
# next_date_n: 2024-06-17
# close_date_n: 2024-06-17
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['SHV']
# - Closing prices: [109.34004211]
# - Shares: [9.]
# - Individual symbol values: [984.06037903]
# - Total portfolio value: 984.0603790283203
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['SPY']
# - Closing prices: [545.34063721]
# - Shares: [1.]
# - Individual symbol values: [545.34063721]
# - Total portfolio value: 545.3406372070312
# close_date_n pick's portf value = 984.0603790283203
# close_date_n SPY portf value =    545.3406372070312
# ====================
#
# ++++++++++++++
# date: 2024-06-14
# n (days increment): 1
# next_date_n: 2024-06-17
# close_date_n: 2024-06-17
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['FTSM']
# - Closing prices: [59.00628662]
# - Shares: [16.]
# - Individual symbol values: [944.10058594]
# - Total portfolio value: 944.1005859375
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['SPY']
# - Closing prices: [545.34063721]
# - Shares: [1.]
# - Individual symbol values: [545.34063721]
# - Total portfolio value: 545.3406372070312
# close_date_n pick's portf value = 944.1005859375
# close_date_n SPY portf value =    545.3406372070312
# ====================
#
# ++++++++++++++
# date: 2024-06-13
# n (days increment): 1
# next_date_n: 2024-06-14
# close_date_n: 2024-06-14
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-14
# - Symbols: ['SHV']
# - Closing prices: [109.33013153]
# - Shares: [9.]
# - Individual symbol values: [983.97118378]
# - Total portfolio value: 983.9711837768555
# Portfolio value details:
# - Date: 2024-06-14
# - Symbols: ['SPY']
# - Closing prices: [541.03460693]
# - Shares: [1.]
# - Individual symbol values: [541.03460693]
# - Total portfolio value: 541.0346069335938
# close_date_n pick's portf value = 983.9711837768555
# close_date_n SPY portf value =    541.0346069335938
# ====================
#
# ++++++++++++++
# date: 2024-06-13
# n (days increment): 1
# next_date_n: 2024-06-14
# close_date_n: 2024-06-14
# syms: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-14
# - Symbols: ['FTSM']
# - Closing prices: [58.99640656]
# - Shares: [16.]
# - Individual symbol values: [943.94250488]
# - Total portfolio value: 943.9425048828125
# Portfolio value details:
# - Date: 2024-06-14
# - Symbols: ['SPY']
# - Closing prices: [541.03460693]
# - Shares: [1.]
# - Individual symbol values: [541.03460693]
# - Total portfolio value: 541.0346069335938
# close_date_n pick's portf value = 943.9425048828125
# close_date_n SPY portf value =    541.0346069335938
# ====================
#
# ++++++++++++++
# date: 2024-06-12
# n (days increment): 1
# next_date_n: 2024-06-13
# close_date_n: 2024-06-13
# syms: ['FTSM', 'NVAX', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-13
# - Symbols: ['FTSM', 'NVAX', 'SHV']
# - Closing prices: [ 58.99640656  15.05000019 109.28056335]
# - Shares: [ 5. 22.  3.]
# - Individual symbol values: [294.98203278 331.1000042  327.84169006]
# - Total portfolio value: 953.9237270355225
# Portfolio value details:
# - Date: 2024-06-13
# - Symbols: ['SPY']
# - Closing prices: [540.70562744]
# - Shares: [1.]
# - Individual symbol values: [540.70562744]
# - Total portfolio value: 540.7056274414062
# close_date_n pick's portf value = 953.9237270355225
# close_date_n SPY portf value =    540.7056274414062
# ====================
#
# ++++++++++++++
# date: 2024-06-11
# n (days increment): 1
# next_date_n: 2024-06-12
# close_date_n: 2024-06-12
# syms: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-12
# - Symbols: ['SHV']
# - Closing prices: [109.27064514]
# - Shares: [9.]
# - Individual symbol values: [983.43580627]
# - Total portfolio value: 983.4358062744141
# Portfolio value details:
# - Date: 2024-06-12
# - Symbols: ['SPY']
# - Closing prices: [539.61914062]
# - Shares: [1.]
# - Individual symbol values: [539.61914062]
# - Total portfolio value: 539.619140625
# close_date_n pick's portf value = 983.4358062744141
# close_date_n SPY portf value =    539.619140625
# ====================
#
# ++++++++++++++
# date: 2024-06-11
# n (days increment): 1
# next_date_n: 2024-06-12
# close_date_n: 2024-06-12
# syms: ['FTSM', 'NVAX']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-12
# - Symbols: ['FTSM', 'NVAX']
# - Closing prices: [58.96677399 15.85999966]
# - Shares: [ 8. 31.]
# - Individual symbol values: [471.73419189 491.65998936]
# - Total portfolio value: 963.3941812515259
# Portfolio value details:
# - Date: 2024-06-12
# - Symbols: ['SPY']
# - Closing prices: [539.61914062]
# - Shares: [1.]
# - Individual symbol values: [539.61914062]
# - Total portfolio value: 539.619140625
# close_date_n pick's portf value = 963.3941812515259
# close_date_n SPY portf value =    539.619140625
# ====================

# %%
"""
Adds buy information, including dates, shares, and values, for both the portfolio and SPY to the df_model_picks_calc_perf DataFrame.
"""

# Add columns for portfolio buy information:
sorted_df_model_picks_calc_perf['date_buy'] = date_buy  # Date of portfolio purchase
sorted_df_model_picks_calc_perf['sh_portf_buy'] = shares_syms  # Number of shares bought for each symbol
sorted_df_model_picks_calc_perf['$_portf_buy'] = value_portf  # Total value of the portfolio at purchase

# Add columns for SPY buy information:
sorted_df_model_picks_calc_perf['sh_SPY_buy'] = shares_SPY  # Number of SPY shares bought
sorted_df_model_picks_calc_perf['$_SPY_buy'] = value_SPY  # Total value of SPY at purchase

# Display the updated DataFrame with all buy and sell information:
print(f'sorted_df_model_picks_calc_perf:\n{sorted_df_model_picks_calc_perf}')
# Out:
# sorted_df_model_picks_calc_perf:
#           date      days_lookback    syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy
# 0   2024-08-30      [30, 60, 120]   sym_freq_9                        ['SHV']        None                   None          NaN       None         NaN
# 1   2024-08-29      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-30                  [9.0]   995.399986      [1.0]  563.679993
# 2   2024-08-28      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-29                  [9.0]   995.039978      [1.0]  558.349976
# 3   2024-08-27      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-28                  [9.0]   994.950027      [1.0]  558.299988
# 4   2024-08-26      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998
# 5   2024-08-23      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978
# 6   2024-08-22      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005
# 7   2024-08-21      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971
# 8   2024-08-20      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995
# 9   2024-08-19      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012
# 10  2024-08-16      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985
# 11  2024-08-15      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998
# 12  2024-08-14      [30, 60, 120]   sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007
# 13  2024-08-13      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000
# 14  2024-08-12      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978
# 15  2024-08-12      [30, 60, 120]   sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978
# 16  2024-08-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020
# 17  2024-08-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020
# 18  2024-08-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990
# 19  2024-08-08      [30, 60, 120]   sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990
# 20  2024-08-07      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024
# 21  2024-08-07      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024
# 22  2024-08-06      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973
# 23  2024-08-06      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973
# 24  2024-08-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-08-06             [8.0, 4.0]   917.390594      [1.0]  522.150024
# 25  2024-08-02      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-05             [8.0, 4.0]   917.709259      [1.0]  517.380005
# 26  2024-08-01      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-02             [8.0, 4.0]   917.470245      [1.0]  532.900024
# 27  2024-07-31      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-01             [8.0, 4.0]   916.273560      [1.0]  543.010010
# 28  2024-07-30      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-31             [8.0, 4.0]   916.002228      [1.0]  550.809998
# 29  2024-07-29      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-30             [8.0, 4.0]   915.667572      [1.0]  542.000000
# 30  2024-07-26      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-29             [8.0, 4.0]   915.627747      [1.0]  544.760010
# 31  2024-07-25      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-26             [8.0, 4.0]   915.468750      [1.0]  544.440002
# 32  2024-07-24      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-25             [8.0, 4.0]   914.833130      [1.0]  538.409973
# 33  2024-07-23      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-24             [8.0, 4.0]   914.793304      [1.0]  541.229980
# 34  2024-07-22      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-23                  [9.0]   989.392799      [1.0]  553.780029
# 35  2024-07-22      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-23             [8.0, 4.0]   936.865326      [1.0]  553.780029
# 36  2024-07-19      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-22                  [9.0]   989.213585      [1.0]  554.650024
# 37  2024-07-19      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-22             [8.0, 4.0]   933.505341      [1.0]  554.650024
# 38  2024-07-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-19                  [9.0]   989.123978      [1.0]  548.989990
# 39  2024-07-18      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-19             [8.0, 4.0]   941.786652      [1.0]  548.989990
# 40  2024-07-17      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-18             [4.0, 4.0]   902.331726      [1.0]  552.659973
# 41  2024-07-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-18                 [16.0]   949.253296      [1.0]  552.659973
# 42  2024-07-16      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-17                  [9.0]   988.407120      [1.0]  556.940002
# 43  2024-07-16      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-17                 [16.0]   949.094604      [1.0]  556.940002
# 44  2024-07-15      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-16             [4.0, 4.0]   912.452271      [1.0]  564.859985
# 45  2024-07-15      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-16                 [16.0]   948.935913      [1.0]  564.859985
# 46  2024-07-15  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-16                  [8.0]   946.400024      [1.0]  564.859985
# 47  2024-07-12      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-15             [4.0, 4.0]   931.972443      [1.0]  561.530029
# 48  2024-07-12      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-15                 [16.0]   948.935913      [1.0]  561.530029
# 49  2024-07-12  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-15                  [8.0]   985.520020      [1.0]  561.530029
# 50  2024-07-11      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-12             [4.0, 4.0]   932.812744      [1.0]  559.989990
# 51  2024-07-11      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-12                 [16.0]   948.777283      [1.0]  559.989990
# 52  2024-07-11  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-12                  [8.0]   987.359985      [1.0]  559.989990
# 53  2024-07-10      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-11                  [9.0]   987.511116      [1.0]  556.479980
# 54  2024-07-10      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-11                 [16.0]   947.983887      [1.0]  556.479980
# 55  2024-07-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-10                  [9.0]   987.242294      [1.0]  561.320007
# 56  2024-07-09      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-10                 [16.0]   947.666443      [1.0]  561.320007
# 57  2024-07-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-09                  [9.0]   987.152687      [1.0]  555.820007
# 58  2024-07-08      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-09                 [16.0]   947.507751      [1.0]  555.820007
# 59  2024-07-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-08             [8.0, 4.0]   912.329712      [1.0]  555.280029
# 60  2024-07-03      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-05             [8.0, 4.0]   912.289612      [1.0]  554.640015
# 61  2024-07-02      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-03             [8.0, 4.0]   911.654266      [1.0]  551.460022
# 62  2024-07-01      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-02             [8.0, 4.0]   911.376068      [1.0]  549.010010
# 63  2024-06-28      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-01             [8.0, 4.0]   911.217133      [1.0]  545.340027
# 64  2024-06-27      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-28             [8.0, 4.0]   911.074036      [1.0]  544.219971
# 65  2024-06-26      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-27             [8.0, 4.0]   910.598083      [1.0]  546.369995
# 66  2024-06-26  [15, 30, 60, 120]  sym_freq_12                        ['SHV']  2024-06-27                  [9.0]   985.487984      [1.0]  546.369995
# 67  2024-06-25      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-26             [8.0, 4.0]   910.400024      [1.0]  545.510010
# 68  2024-06-24      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-25             [8.0, 4.0]   910.479095      [1.0]  544.830017
# 69  2024-06-21      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-24             [8.0, 4.0]   910.399811      [1.0]  542.739990
# 70  2024-06-20      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-21                  [9.0]   984.952606      [1.0]  544.510010
# 71  2024-06-20      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-21                 [16.0]   945.048706      [1.0]  544.510010
# 72  2024-06-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-20                  [9.0]   984.506493      [1.0]  545.240967
# 73  2024-06-18      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-20                 [16.0]   944.416565      [1.0]  545.240967
# 74  2024-06-17      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-18                  [9.0]   984.328102      [1.0]  546.726196
# 75  2024-06-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-18                 [16.0]   944.574646      [1.0]  546.726196
# 76  2024-06-14      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-17                  [9.0]   984.060379      [1.0]  545.340637
# 77  2024-06-14      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-17                 [16.0]   944.100586      [1.0]  545.340637
# 78  2024-06-13      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-14                  [9.0]   983.971184      [1.0]  541.034607
# 79  2024-06-13      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-14                 [16.0]   943.942505      [1.0]  541.034607
# 80  2024-06-12      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']  2024-06-13       [5.0, 22.0, 3.0]   953.923727      [1.0]  540.705627
# 81  2024-06-11      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-12                  [9.0]   983.435806      [1.0]  539.619141
# 82  2024-06-11      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']  2024-06-12            [8.0, 31.0]   963.394181      [1.0]  539.619141

# %%
"""
Calculates portfolio values for multiple dates and symbol combinations, using pre-determined shares and handling potential missing data.
"""

# Break the long line into multiple lines with clear intermediate variables:
date_for_calculation =  sorted_df_model_picks_calc_perf.date
symbols_for_calculation = sorted_df_model_picks_calc_perf.symbols
shares_to_buy = sorted_df_model_picks_calc_perf.sh_portf_buy
SPY_shares_to_buy = sorted_df_model_picks_calc_perf.sh_SPY_buy

# Call the function to calculate portfolio values:
date_exec, shares_syms, value_portf, shares_SPY, value_SPY = \
    calc_portf_value_date_n(
        date_for_calculation,
        symbols_for_calculation,
        df_close,
        shares_to_buy,
        SPY_shares_to_buy,
        n=4,
        verbose=verbose
    )

# Breakdown of the function call:
# - calc_portf_value_date_n: Function name (defined in a previous code block)
# - df_model_picks_calc_perf.date: List of dates from the df_model_picks_calc_perf DataFrame
# - df_model_picks_calc_perf.symbols: List of stock symbols from the df_model_picks_calc_perf DataFrame
# - df_close: DataFrame containing historical closing prices
# - df_model_picks_calc_perf.sh_portf_buy: List of shares bought for each symbol (from a previous calculation)
# - df_model_picks_calc_perf.sh_SPY_buy: List of SPY shares bought (from a previous calculation)
# - n=4: Offset the execution date by 4 trading days from the lookback date
# - verbose=verbose: Print details if verbose mode is enabled

# Note: The function handles potential missing data gracefully.
# Out:
# ++++++++++++++
# date: 2024-08-30
# n (days increment): 4
# next_date_n: None
# close_date_n: None
# symbols: ['SHV']
# ++++++++++++++
# No data for close_date_n None, pick's portf value = None
# ====================
#
# ++++++++++++++
# date: 2024-08-29
# n (days increment): 4
# next_date_n: None
# close_date_n: None
# symbols: ['SHV']
# ++++++++++++++
# No data for close_date_n None, pick's portf value = None
# ====================
#
# ++++++++++++++
# date: 2024-08-28
# n (days increment): 4
# next_date_n: None
# close_date_n: None
# symbols: ['SHV']
# ++++++++++++++
# No data for close_date_n None, pick's portf value = None
# ====================
#
# ++++++++++++++
# date: 2024-08-27
# n (days increment): 4
# next_date_n: None
# close_date_n: None
# symbols: ['SHV']
# ++++++++++++++
# No data for close_date_n None, pick's portf value = None
# ====================
#
# ++++++++++++++
# date: 2024-08-26
# n (days increment): 4
# next_date_n: 2024-08-30
# close_date_n: 2024-08-30
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-30
# - Symbols: ['SHV']
# - Closing prices: [110.59999847]
# - Shares: [9.]
# - Individual symbol values: [995.39998627]
# - Total portfolio value: 995.3999862670898
# Portfolio value details:
# - Date: 2024-08-30
# - Symbols: ['SPY']
# - Closing prices: [563.67999268]
# - Shares: [1.]
# - Individual symbol values: [563.67999268]
# - Total portfolio value: 563.6799926757812
# next_date_n pick's portf value = 995.3999862670898
# next_date_n SPY portf value =    563.6799926757812
# ====================
#
# ++++++++++++++
# date: 2024-08-23
# n (days increment): 4
# next_date_n: 2024-08-29
# close_date_n: 2024-08-29
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-29
# - Symbols: ['SHV']
# - Closing prices: [110.55999756]
# - Shares: [9.]
# - Individual symbol values: [995.03997803]
# - Total portfolio value: 995.0399780273438
# Portfolio value details:
# - Date: 2024-08-29
# - Symbols: ['SPY']
# - Closing prices: [558.34997559]
# - Shares: [1.]
# - Individual symbol values: [558.34997559]
# - Total portfolio value: 558.3499755859375
# next_date_n pick's portf value = 995.0399780273438
# next_date_n SPY portf value =    558.3499755859375
# ====================
#
# ++++++++++++++
# date: 2024-08-22
# n (days increment): 4
# next_date_n: 2024-08-28
# close_date_n: 2024-08-28
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-28
# - Symbols: ['SHV']
# - Closing prices: [110.55000305]
# - Shares: [9.]
# - Individual symbol values: [994.95002747]
# - Total portfolio value: 994.9500274658203
# Portfolio value details:
# - Date: 2024-08-28
# - Symbols: ['SPY']
# - Closing prices: [558.29998779]
# - Shares: [1.]
# - Individual symbol values: [558.29998779]
# - Total portfolio value: 558.2999877929688
# next_date_n pick's portf value = 994.9500274658203
# next_date_n SPY portf value =    558.2999877929688
# ====================
#
# ++++++++++++++
# date: 2024-08-21
# n (days increment): 4
# next_date_n: 2024-08-27
# close_date_n: 2024-08-27
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-27
# - Symbols: ['SHV']
# - Closing prices: [110.52999878]
# - Shares: [9.]
# - Individual symbol values: [994.76998901]
# - Total portfolio value: 994.7699890136719
# Portfolio value details:
# - Date: 2024-08-27
# - Symbols: ['SPY']
# - Closing prices: [561.55999756]
# - Shares: [1.]
# - Individual symbol values: [561.55999756]
# - Total portfolio value: 561.5599975585938
# next_date_n pick's portf value = 994.7699890136719
# next_date_n SPY portf value =    561.5599975585938
# ====================
#
# ++++++++++++++
# date: 2024-08-20
# n (days increment): 4
# next_date_n: 2024-08-26
# close_date_n: 2024-08-26
# symbols: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-26
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.11999989 110.51000214]
# - Shares: [81.  4.]
# - Individual symbol values: [495.71999073 442.04000854]
# - Total portfolio value: 937.7599992752075
# Portfolio value details:
# - Date: 2024-08-26
# - Symbols: ['SPY']
# - Closing prices: [560.78997803]
# - Shares: [1.]
# - Individual symbol values: [560.78997803]
# - Total portfolio value: 560.7899780273438
# next_date_n pick's portf value = 937.7599992752075
# next_date_n SPY portf value =    560.7899780273438
# ====================
#
# ++++++++++++++
# date: 2024-08-19
# n (days increment): 4
# next_date_n: 2024-08-23
# close_date_n: 2024-08-23
# symbols: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-23
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.23000002 110.5       ]
# - Shares: [81.  4.]
# - Individual symbol values: [504.63000154 442.        ]
# - Total portfolio value: 946.6300015449524
# Portfolio value details:
# - Date: 2024-08-23
# - Symbols: ['SPY']
# - Closing prices: [562.13000488]
# - Shares: [1.]
# - Individual symbol values: [562.13000488]
# - Total portfolio value: 562.1300048828125
# next_date_n pick's portf value = 946.6300015449524
# next_date_n SPY portf value =    562.1300048828125
# ====================
#
# ++++++++++++++
# date: 2024-08-16
# n (days increment): 4
# next_date_n: 2024-08-22
# close_date_n: 2024-08-22
# symbols: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-22
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.03999996 110.44999695]
# - Shares: [86.  4.]
# - Individual symbol values: [519.43999672 441.79998779]
# - Total portfolio value: 961.2399845123291
# Portfolio value details:
# - Date: 2024-08-22
# - Symbols: ['SPY']
# - Closing prices: [556.2199707]
# - Shares: [1.]
# - Individual symbol values: [556.2199707]
# - Total portfolio value: 556.219970703125
# next_date_n pick's portf value = 961.2399845123291
# next_date_n SPY portf value =    556.219970703125
# ====================
#
# ++++++++++++++
# date: 2024-08-15
# n (days increment): 4
# next_date_n: 2024-08-21
# close_date_n: 2024-08-21
# symbols: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-21
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  6.13000011 110.43000031]
# - Shares: [83.  4.]
# - Individual symbol values: [508.7900095  441.72000122]
# - Total portfolio value: 950.5100107192993
# Portfolio value details:
# - Date: 2024-08-21
# - Symbols: ['SPY']
# - Closing prices: [560.61999512]
# - Shares: [1.]
# - Individual symbol values: [560.61999512]
# - Total portfolio value: 560.6199951171875
# next_date_n pick's portf value = 950.5100107192993
# next_date_n SPY portf value =    560.6199951171875
# ====================
#
# ++++++++++++++
# date: 2024-08-14
# n (days increment): 4
# next_date_n: 2024-08-20
# close_date_n: 2024-08-20
# symbols: ['LMT', 'LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-20
# - Symbols: ['LMT', 'LUMN', 'SHV']
# - Closing prices: [557.01000977   6.1500001  110.41000366]
# - Shares: [ 0. 58.  3.]
# - Individual symbol values: [  0.         356.70000553 331.23001099]
# - Total portfolio value: 687.9300165176392
# Portfolio value details:
# - Date: 2024-08-20
# - Symbols: ['SPY']
# - Closing prices: [558.70001221]
# - Shares: [1.]
# - Individual symbol values: [558.70001221]
# - Total portfolio value: 558.7000122070312
# next_date_n pick's portf value = 687.9300165176392
# next_date_n SPY portf value =    558.7000122070312
# ====================
#
# ++++++++++++++
# date: 2024-08-13
# n (days increment): 4
# next_date_n: 2024-08-19
# close_date_n: 2024-08-19
# symbols: ['LUMN', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-19
# - Symbols: ['LUMN', 'SHV']
# - Closing prices: [  5.76000023 110.37999725]
# - Shares: [88.  4.]
# - Individual symbol values: [506.88002014 441.51998901]
# - Total portfolio value: 948.4000091552734
# Portfolio value details:
# - Date: 2024-08-19
# - Symbols: ['SPY']
# - Closing prices: [559.60998535]
# - Shares: [1.]
# - Individual symbol values: [559.60998535]
# - Total portfolio value: 559.6099853515625
# next_date_n pick's portf value = 948.4000091552734
# next_date_n SPY portf value =    559.6099853515625
# ====================
#
# ++++++++++++++
# date: 2024-08-12
# n (days increment): 4
# next_date_n: 2024-08-16
# close_date_n: 2024-08-16
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-16
# - Symbols: ['SHV']
# - Closing prices: [110.37000275]
# - Shares: [9.]
# - Individual symbol values: [993.33002472]
# - Total portfolio value: 993.3300247192383
# Portfolio value details:
# - Date: 2024-08-16
# - Symbols: ['SPY']
# - Closing prices: [554.30999756]
# - Shares: [1.]
# - Individual symbol values: [554.30999756]
# - Total portfolio value: 554.3099975585938
# next_date_n pick's portf value = 993.3300247192383
# next_date_n SPY portf value =    554.3099975585938
# ====================
#
# ++++++++++++++
# date: 2024-08-12
# n (days increment): 4
# next_date_n: 2024-08-16
# close_date_n: 2024-08-16
# symbols: ['LMT']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-16
# - Symbols: ['LMT']
# - Closing prices: [560.13000488]
# - Shares: [1.]
# - Individual symbol values: [560.13000488]
# - Total portfolio value: 560.1300048828125
# Portfolio value details:
# - Date: 2024-08-16
# - Symbols: ['SPY']
# - Closing prices: [554.30999756]
# - Shares: [1.]
# - Individual symbol values: [554.30999756]
# - Total portfolio value: 554.3099975585938
# next_date_n pick's portf value = 560.1300048828125
# next_date_n SPY portf value =    554.3099975585938
# ====================
#
# ++++++++++++++
# date: 2024-08-09
# n (days increment): 4
# next_date_n: 2024-08-15
# close_date_n: 2024-08-15
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-15
# - Symbols: ['SHV']
# - Closing prices: [110.31999969]
# - Shares: [9.]
# - Individual symbol values: [992.87999725]
# - Total portfolio value: 992.879997253418
# Portfolio value details:
# - Date: 2024-08-15
# - Symbols: ['SPY']
# - Closing prices: [553.07000732]
# - Shares: [1.]
# - Individual symbol values: [553.07000732]
# - Total portfolio value: 553.0700073242188
# next_date_n pick's portf value = 992.879997253418
# next_date_n SPY portf value =    553.0700073242188
# ====================
#
# ++++++++++++++
# date: 2024-08-09
# n (days increment): 4
# next_date_n: 2024-08-15
# close_date_n: 2024-08-15
# symbols: ['FTSM', 'LMT', 'LUMN', 'VTR']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-15
# - Symbols: ['FTSM', 'LMT', 'LUMN', 'VTR']
# - Closing prices: [ 59.62365723 560.28997803   5.71000004  58.04000092]
# - Shares: [ 4.  0. 53.  4.]
# - Individual symbol values: [238.49462891   0.         302.63000202 232.16000366]
# - Total portfolio value: 773.2846345901489
# Portfolio value details:
# - Date: 2024-08-15
# - Symbols: ['SPY']
# - Closing prices: [553.07000732]
# - Shares: [1.]
# - Individual symbol values: [553.07000732]
# - Total portfolio value: 553.0700073242188
# next_date_n pick's portf value = 773.2846345901489
# next_date_n SPY portf value =    553.0700073242188
# ====================
#
# ++++++++++++++
# date: 2024-08-08
# n (days increment): 4
# next_date_n: 2024-08-14
# close_date_n: 2024-08-14
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-14
# - Symbols: ['SHV']
# - Closing prices: [110.30999756]
# - Shares: [9.]
# - Individual symbol values: [992.78997803]
# - Total portfolio value: 992.7899780273438
# Portfolio value details:
# - Date: 2024-08-14
# - Symbols: ['SPY']
# - Closing prices: [543.75]
# - Shares: [1.]
# - Individual symbol values: [543.75]
# - Total portfolio value: 543.75
# next_date_n pick's portf value = 992.7899780273438
# next_date_n SPY portf value =    543.75
# ====================
#
# ++++++++++++++
# date: 2024-08-08
# n (days increment): 4
# next_date_n: 2024-08-14
# close_date_n: 2024-08-14
# symbols: ['FTSM', 'LUMN', 'VTR']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-14
# - Symbols: ['FTSM', 'LUMN', 'VTR']
# - Closing prices: [59.65353394  5.65999985 58.52000046]
# - Shares: [ 5. 59.  5.]
# - Individual symbol values: [298.26766968 333.939991   292.60000229]
# - Total portfolio value: 924.8076629638672
# Portfolio value details:
# - Date: 2024-08-14
# - Symbols: ['SPY']
# - Closing prices: [543.75]
# - Shares: [1.]
# - Individual symbol values: [543.75]
# - Total portfolio value: 543.75
# next_date_n pick's portf value = 924.8076629638672
# next_date_n SPY portf value =    543.75
# ====================
#
# ++++++++++++++
# date: 2024-08-07
# n (days increment): 4
# next_date_n: 2024-08-13
# close_date_n: 2024-08-13
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['SHV']
# - Closing prices: [110.30999756]
# - Shares: [9.]
# - Individual symbol values: [992.78997803]
# - Total portfolio value: 992.7899780273438
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['SPY']
# - Closing prices: [542.03997803]
# - Shares: [1.]
# - Individual symbol values: [542.03997803]
# - Total portfolio value: 542.0399780273438
# next_date_n pick's portf value = 992.7899780273438
# next_date_n SPY portf value =    542.0399780273438
# ====================
#
# ++++++++++++++
# date: 2024-08-07
# n (days increment): 4
# next_date_n: 2024-08-13
# close_date_n: 2024-08-13
# symbols: ['FTSM', 'LMT', 'LUMN', 'VTR']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['FTSM', 'LMT', 'LUMN', 'VTR']
# - Closing prices: [ 59.65353394 559.41998291   5.01000023  59.27999878]
# - Shares: [ 4.  0. 46.  4.]
# - Individual symbol values: [238.61413574   0.         230.46001053 237.11999512]
# - Total portfolio value: 706.1941413879395
# Portfolio value details:
# - Date: 2024-08-13
# - Symbols: ['SPY']
# - Closing prices: [542.03997803]
# - Shares: [1.]
# - Individual symbol values: [542.03997803]
# - Total portfolio value: 542.0399780273438
# next_date_n pick's portf value = 706.1941413879395
# next_date_n SPY portf value =    542.0399780273438
# ====================
#
# ++++++++++++++
# date: 2024-08-06
# n (days increment): 4
# next_date_n: 2024-08-12
# close_date_n: 2024-08-12
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['SHV']
# - Closing prices: [110.27999878]
# - Shares: [9.]
# - Individual symbol values: [992.51998901]
# - Total portfolio value: 992.5199890136719
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['SPY']
# - Closing prices: [533.27001953]
# - Shares: [1.]
# - Individual symbol values: [533.27001953]
# - Total portfolio value: 533.27001953125
# next_date_n pick's portf value = 992.5199890136719
# next_date_n SPY portf value =    533.27001953125
# ====================
#
# ++++++++++++++
# date: 2024-08-06
# n (days increment): 4
# next_date_n: 2024-08-12
# close_date_n: 2024-08-12
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['FTSM']
# - Closing prices: [59.62365723]
# - Shares: [16.]
# - Individual symbol values: [953.97851562]
# - Total portfolio value: 953.978515625
# Portfolio value details:
# - Date: 2024-08-12
# - Symbols: ['SPY']
# - Closing prices: [533.27001953]
# - Shares: [1.]
# - Individual symbol values: [533.27001953]
# - Total portfolio value: 533.27001953125
# next_date_n pick's portf value = 953.978515625
# next_date_n SPY portf value =    533.27001953125
# ====================
#
# ++++++++++++++
# date: 2024-08-05
# n (days increment): 4
# next_date_n: 2024-08-09
# close_date_n: 2024-08-09
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-09
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.60373688 110.25      ]
# - Shares: [8. 4.]
# - Individual symbol values: [476.82989502 441.        ]
# - Total portfolio value: 917.8298950195312
# Portfolio value details:
# - Date: 2024-08-09
# - Symbols: ['SPY']
# - Closing prices: [532.98999023]
# - Shares: [1.]
# - Individual symbol values: [532.98999023]
# - Total portfolio value: 532.989990234375
# next_date_n pick's portf value = 917.8298950195312
# next_date_n SPY portf value =    532.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-08-02
# n (days increment): 4
# next_date_n: 2024-08-08
# close_date_n: 2024-08-08
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-08
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.58382416 110.20999908]
# - Shares: [8. 4.]
# - Individual symbol values: [476.67059326 440.83999634]
# - Total portfolio value: 917.5105895996094
# Portfolio value details:
# - Date: 2024-08-08
# - Symbols: ['SPY']
# - Closing prices: [530.65002441]
# - Shares: [1.]
# - Individual symbol values: [530.65002441]
# - Total portfolio value: 530.6500244140625
# next_date_n pick's portf value = 917.5105895996094
# next_date_n SPY portf value =    530.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-08-01
# n (days increment): 4
# next_date_n: 2024-08-07
# close_date_n: 2024-08-07
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-07
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.59378052 110.19999695]
# - Shares: [8. 4.]
# - Individual symbol values: [476.75024414 440.79998779]
# - Total portfolio value: 917.5502319335938
# Portfolio value details:
# - Date: 2024-08-07
# - Symbols: ['SPY']
# - Closing prices: [518.65997314]
# - Shares: [1.]
# - Individual symbol values: [518.65997314]
# - Total portfolio value: 518.6599731445312
# next_date_n pick's portf value = 917.5502319335938
# next_date_n SPY portf value =    518.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-31
# n (days increment): 4
# next_date_n: 2024-08-06
# close_date_n: 2024-08-06
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-06
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.58382416 110.18000031]
# - Shares: [8. 4.]
# - Individual symbol values: [476.67059326 440.72000122]
# - Total portfolio value: 917.3905944824219
# Portfolio value details:
# - Date: 2024-08-06
# - Symbols: ['SPY']
# - Closing prices: [522.15002441]
# - Shares: [1.]
# - Individual symbol values: [522.15002441]
# - Total portfolio value: 522.1500244140625
# next_date_n pick's portf value = 917.3905944824219
# next_date_n SPY portf value =    522.1500244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-30
# n (days increment): 4
# next_date_n: 2024-08-05
# close_date_n: 2024-08-05
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-05
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.62365723 110.18000031]
# - Shares: [8. 4.]
# - Individual symbol values: [476.98925781 440.72000122]
# - Total portfolio value: 917.7092590332031
# Portfolio value details:
# - Date: 2024-08-05
# - Symbols: ['SPY']
# - Closing prices: [517.38000488]
# - Shares: [1.]
# - Individual symbol values: [517.38000488]
# - Total portfolio value: 517.3800048828125
# next_date_n pick's portf value = 917.7092590332031
# next_date_n SPY portf value =    517.3800048828125
# ====================
#
# ++++++++++++++
# date: 2024-07-29
# n (days increment): 4
# next_date_n: 2024-08-02
# close_date_n: 2024-08-02
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-02
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.59378052 110.18000031]
# - Shares: [8. 4.]
# - Individual symbol values: [476.75024414 440.72000122]
# - Total portfolio value: 917.4702453613281
# Portfolio value details:
# - Date: 2024-08-02
# - Symbols: ['SPY']
# - Closing prices: [532.90002441]
# - Shares: [1.]
# - Individual symbol values: [532.90002441]
# - Total portfolio value: 532.9000244140625
# next_date_n pick's portf value = 917.4702453613281
# next_date_n SPY portf value =    532.9000244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-26
# n (days increment): 4
# next_date_n: 2024-08-01
# close_date_n: 2024-08-01
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-08-01
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.49419403 110.08000183]
# - Shares: [8. 4.]
# - Individual symbol values: [475.95355225 440.32000732]
# - Total portfolio value: 916.2735595703125
# Portfolio value details:
# - Date: 2024-08-01
# - Symbols: ['SPY']
# - Closing prices: [543.01000977]
# - Shares: [1.]
# - Individual symbol values: [543.01000977]
# - Total portfolio value: 543.010009765625
# next_date_n pick's portf value = 916.2735595703125
# next_date_n SPY portf value =    543.010009765625
# ====================
#
# ++++++++++++++
# date: 2024-07-25
# n (days increment): 4
# next_date_n: 2024-07-31
# close_date_n: 2024-07-31
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-31
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.4742775  110.05200195]
# - Shares: [8. 4.]
# - Individual symbol values: [475.79421997 440.20800781]
# - Total portfolio value: 916.0022277832031
# Portfolio value details:
# - Date: 2024-07-31
# - Symbols: ['SPY']
# - Closing prices: [550.80999756]
# - Shares: [1.]
# - Individual symbol values: [550.80999756]
# - Total portfolio value: 550.8099975585938
# next_date_n pick's portf value = 916.0022277832031
# next_date_n SPY portf value =    550.8099975585938
# ====================
#
# ++++++++++++++
# date: 2024-07-24
# n (days increment): 4
# next_date_n: 2024-07-30
# close_date_n: 2024-07-30
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-30
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.43742371 110.04204559]
# - Shares: [8. 4.]
# - Individual symbol values: [475.49938965 440.16818237]
# - Total portfolio value: 915.6675720214844
# Portfolio value details:
# - Date: 2024-07-30
# - Symbols: ['SPY']
# - Closing prices: [542.]
# - Shares: [1.]
# - Individual symbol values: [542.]
# - Total portfolio value: 542.0
# next_date_n pick's portf value = 915.6675720214844
# next_date_n SPY portf value =    542.0
# ====================
#
# ++++++++++++++
# date: 2024-07-23
# n (days increment): 4
# next_date_n: 2024-07-29
# close_date_n: 2024-07-29
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-29
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.43742371 110.03208923]
# - Shares: [8. 4.]
# - Individual symbol values: [475.49938965 440.12835693]
# - Total portfolio value: 915.6277465820312
# Portfolio value details:
# - Date: 2024-07-29
# - Symbols: ['SPY']
# - Closing prices: [544.76000977]
# - Shares: [1.]
# - Individual symbol values: [544.76000977]
# - Total portfolio value: 544.760009765625
# next_date_n pick's portf value = 915.6277465820312
# next_date_n SPY portf value =    544.760009765625
# ====================
#
# ++++++++++++++
# date: 2024-07-22
# n (days increment): 4
# next_date_n: 2024-07-26
# close_date_n: 2024-07-26
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-26
# - Symbols: ['SHV']
# - Closing prices: [110.01217651]
# - Shares: [9.]
# - Individual symbol values: [990.10958862]
# - Total portfolio value: 990.1095886230469
# Portfolio value details:
# - Date: 2024-07-26
# - Symbols: ['SPY']
# - Closing prices: [544.44000244]
# - Shares: [1.]
# - Individual symbol values: [544.44000244]
# - Total portfolio value: 544.4400024414062
# next_date_n pick's portf value = 990.1095886230469
# next_date_n SPY portf value =    544.4400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-22
# n (days increment): 4
# next_date_n: 2024-07-26
# close_date_n: 2024-07-26
# symbols: ['FTSM', 'LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-26
# - Symbols: ['FTSM', 'LNTH']
# - Closing prices: [ 59.42750549 112.70999908]
# - Shares: [8. 4.]
# - Individual symbol values: [475.42004395 450.83999634]
# - Total portfolio value: 926.2600402832031
# Portfolio value details:
# - Date: 2024-07-26
# - Symbols: ['SPY']
# - Closing prices: [544.44000244]
# - Shares: [1.]
# - Individual symbol values: [544.44000244]
# - Total portfolio value: 544.4400024414062
# next_date_n pick's portf value = 926.2600402832031
# next_date_n SPY portf value =    544.4400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-19
# n (days increment): 4
# next_date_n: 2024-07-25
# close_date_n: 2024-07-25
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-25
# - Symbols: ['SHV']
# - Closing prices: [109.95244598]
# - Shares: [9.]
# - Individual symbol values: [989.57201385]
# - Total portfolio value: 989.5720138549805
# Portfolio value details:
# - Date: 2024-07-25
# - Symbols: ['SPY']
# - Closing prices: [538.40997314]
# - Shares: [1.]
# - Individual symbol values: [538.40997314]
# - Total portfolio value: 538.4099731445312
# next_date_n pick's portf value = 989.5720138549805
# next_date_n SPY portf value =    538.4099731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-19
# n (days increment): 4
# next_date_n: 2024-07-25
# close_date_n: 2024-07-25
# symbols: ['FTSM', 'LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-25
# - Symbols: ['FTSM', 'LNTH']
# - Closing prices: [ 59.37791824 112.94999695]
# - Shares: [8. 4.]
# - Individual symbol values: [475.02334595 451.79998779]
# - Total portfolio value: 926.8233337402344
# Portfolio value details:
# - Date: 2024-07-25
# - Symbols: ['SPY']
# - Closing prices: [538.40997314]
# - Shares: [1.]
# - Individual symbol values: [538.40997314]
# - Total portfolio value: 538.4099731445312
# next_date_n pick's portf value = 926.8233337402344
# next_date_n SPY portf value =    538.4099731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-18
# n (days increment): 4
# next_date_n: 2024-07-24
# close_date_n: 2024-07-24
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-24
# - Symbols: ['SHV']
# - Closing prices: [109.94248962]
# - Shares: [9.]
# - Individual symbol values: [989.48240662]
# - Total portfolio value: 989.4824066162109
# Portfolio value details:
# - Date: 2024-07-24
# - Symbols: ['SPY']
# - Closing prices: [541.22998047]
# - Shares: [1.]
# - Individual symbol values: [541.22998047]
# - Total portfolio value: 541.22998046875
# next_date_n pick's portf value = 989.4824066162109
# next_date_n SPY portf value =    541.22998046875
# ====================
#
# ++++++++++++++
# date: 2024-07-18
# n (days increment): 4
# next_date_n: 2024-07-24
# close_date_n: 2024-07-24
# symbols: ['FTSM', 'LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-24
# - Symbols: ['FTSM', 'LNTH']
# - Closing prices: [ 59.37791824 113.66000366]
# - Shares: [8. 4.]
# - Individual symbol values: [475.02334595 454.64001465]
# - Total portfolio value: 929.6633605957031
# Portfolio value details:
# - Date: 2024-07-24
# - Symbols: ['SPY']
# - Closing prices: [541.22998047]
# - Shares: [1.]
# - Individual symbol values: [541.22998047]
# - Total portfolio value: 541.22998046875
# next_date_n pick's portf value = 929.6633605957031
# next_date_n SPY portf value =    541.22998046875
# ====================
#
# ++++++++++++++
# date: 2024-07-17
# n (days increment): 4
# next_date_n: 2024-07-23
# close_date_n: 2024-07-23
# symbols: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [115.51999664 109.93253326]
# - Shares: [4. 4.]
# - Individual symbol values: [462.07998657 439.73013306]
# - Total portfolio value: 901.8101196289062
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['SPY']
# - Closing prices: [553.7800293]
# - Shares: [1.]
# - Individual symbol values: [553.7800293]
# - Total portfolio value: 553.780029296875
# next_date_n pick's portf value = 901.8101196289062
# next_date_n SPY portf value =    553.780029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-17
# n (days increment): 4
# next_date_n: 2024-07-23
# close_date_n: 2024-07-23
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['FTSM']
# - Closing prices: [59.34816742]
# - Shares: [16.]
# - Individual symbol values: [949.57067871]
# - Total portfolio value: 949.5706787109375
# Portfolio value details:
# - Date: 2024-07-23
# - Symbols: ['SPY']
# - Closing prices: [553.7800293]
# - Shares: [1.]
# - Individual symbol values: [553.7800293]
# - Total portfolio value: 553.780029296875
# next_date_n pick's portf value = 949.5706787109375
# next_date_n SPY portf value =    553.780029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-16
# n (days increment): 4
# next_date_n: 2024-07-22
# close_date_n: 2024-07-22
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['SHV']
# - Closing prices: [109.91262054]
# - Shares: [9.]
# - Individual symbol values: [989.2135849]
# - Total portfolio value: 989.2135848999023
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['SPY']
# - Closing prices: [554.65002441]
# - Shares: [1.]
# - Individual symbol values: [554.65002441]
# - Total portfolio value: 554.6500244140625
# next_date_n pick's portf value = 989.2135848999023
# next_date_n SPY portf value =    554.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-16
# n (days increment): 4
# next_date_n: 2024-07-22
# close_date_n: 2024-07-22
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['FTSM']
# - Closing prices: [59.34816742]
# - Shares: [16.]
# - Individual symbol values: [949.57067871]
# - Total portfolio value: 949.5706787109375
# Portfolio value details:
# - Date: 2024-07-22
# - Symbols: ['SPY']
# - Closing prices: [554.65002441]
# - Shares: [1.]
# - Individual symbol values: [554.65002441]
# - Total portfolio value: 554.6500244140625
# next_date_n pick's portf value = 949.5706787109375
# next_date_n SPY portf value =    554.6500244140625
# ====================
#
# ++++++++++++++
# date: 2024-07-15
# n (days increment): 4
# next_date_n: 2024-07-19
# close_date_n: 2024-07-19
# symbols: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [116.79000092 109.90266418]
# - Shares: [4. 4.]
# - Individual symbol values: [467.16000366 439.61065674]
# - Total portfolio value: 906.7706604003906
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['SPY']
# - Closing prices: [548.98999023]
# - Shares: [1.]
# - Individual symbol values: [548.98999023]
# - Total portfolio value: 548.989990234375
# next_date_n pick's portf value = 906.7706604003906
# next_date_n SPY portf value =    548.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-15
# n (days increment): 4
# next_date_n: 2024-07-19
# close_date_n: 2024-07-19
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['FTSM']
# - Closing prices: [59.32833099]
# - Shares: [16.]
# - Individual symbol values: [949.2532959]
# - Total portfolio value: 949.2532958984375
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['SPY']
# - Closing prices: [548.98999023]
# - Shares: [1.]
# - Individual symbol values: [548.98999023]
# - Total portfolio value: 548.989990234375
# next_date_n pick's portf value = 949.2532958984375
# next_date_n SPY portf value =    548.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-15
# n (days increment): 4
# next_date_n: 2024-07-19
# close_date_n: 2024-07-19
# symbols: ['LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['LNTH']
# - Closing prices: [116.79000092]
# - Shares: [8.]
# - Individual symbol values: [934.32000732]
# - Total portfolio value: 934.3200073242188
# Portfolio value details:
# - Date: 2024-07-19
# - Symbols: ['SPY']
# - Closing prices: [548.98999023]
# - Shares: [1.]
# - Individual symbol values: [548.98999023]
# - Total portfolio value: 548.989990234375
# next_date_n pick's portf value = 934.3200073242188
# next_date_n SPY portf value =    548.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-12
# n (days increment): 4
# next_date_n: 2024-07-18
# close_date_n: 2024-07-18
# symbols: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [115.73999786 109.84293365]
# - Shares: [4. 4.]
# - Individual symbol values: [462.95999146 439.37173462]
# - Total portfolio value: 902.3317260742188
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['SPY']
# - Closing prices: [552.65997314]
# - Shares: [1.]
# - Individual symbol values: [552.65997314]
# - Total portfolio value: 552.6599731445312
# next_date_n pick's portf value = 902.3317260742188
# next_date_n SPY portf value =    552.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-12
# n (days increment): 4
# next_date_n: 2024-07-18
# close_date_n: 2024-07-18
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['FTSM']
# - Closing prices: [59.32833099]
# - Shares: [16.]
# - Individual symbol values: [949.2532959]
# - Total portfolio value: 949.2532958984375
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['SPY']
# - Closing prices: [552.65997314]
# - Shares: [1.]
# - Individual symbol values: [552.65997314]
# - Total portfolio value: 552.6599731445312
# next_date_n pick's portf value = 949.2532958984375
# next_date_n SPY portf value =    552.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-12
# n (days increment): 4
# next_date_n: 2024-07-18
# close_date_n: 2024-07-18
# symbols: ['LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['LNTH']
# - Closing prices: [115.73999786]
# - Shares: [8.]
# - Individual symbol values: [925.91998291]
# - Total portfolio value: 925.9199829101562
# Portfolio value details:
# - Date: 2024-07-18
# - Symbols: ['SPY']
# - Closing prices: [552.65997314]
# - Shares: [1.]
# - Individual symbol values: [552.65997314]
# - Total portfolio value: 552.6599731445312
# next_date_n pick's portf value = 925.9199829101562
# next_date_n SPY portf value =    552.6599731445312
# ====================
#
# ++++++++++++++
# date: 2024-07-11
# n (days increment): 4
# next_date_n: 2024-07-17
# close_date_n: 2024-07-17
# symbols: ['LNTH', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['LNTH', 'SHV']
# - Closing prices: [121.61000061 109.82301331]
# - Shares: [4. 4.]
# - Individual symbol values: [486.44000244 439.29205322]
# - Total portfolio value: 925.7320556640625
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['SPY']
# - Closing prices: [556.94000244]
# - Shares: [1.]
# - Individual symbol values: [556.94000244]
# - Total portfolio value: 556.9400024414062
# next_date_n pick's portf value = 925.7320556640625
# next_date_n SPY portf value =    556.9400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-11
# n (days increment): 4
# next_date_n: 2024-07-17
# close_date_n: 2024-07-17
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['FTSM']
# - Closing prices: [59.31841278]
# - Shares: [16.]
# - Individual symbol values: [949.09460449]
# - Total portfolio value: 949.0946044921875
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['SPY']
# - Closing prices: [556.94000244]
# - Shares: [1.]
# - Individual symbol values: [556.94000244]
# - Total portfolio value: 556.9400024414062
# next_date_n pick's portf value = 949.0946044921875
# next_date_n SPY portf value =    556.9400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-11
# n (days increment): 4
# next_date_n: 2024-07-17
# close_date_n: 2024-07-17
# symbols: ['LNTH']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['LNTH']
# - Closing prices: [121.61000061]
# - Shares: [8.]
# - Individual symbol values: [972.88000488]
# - Total portfolio value: 972.8800048828125
# Portfolio value details:
# - Date: 2024-07-17
# - Symbols: ['SPY']
# - Closing prices: [556.94000244]
# - Shares: [1.]
# - Individual symbol values: [556.94000244]
# - Total portfolio value: 556.9400024414062
# next_date_n pick's portf value = 972.8800048828125
# next_date_n SPY portf value =    556.9400024414062
# ====================
#
# ++++++++++++++
# date: 2024-07-10
# n (days increment): 4
# next_date_n: 2024-07-16
# close_date_n: 2024-07-16
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['SHV']
# - Closing prices: [109.81306458]
# - Shares: [9.]
# - Individual symbol values: [988.31758118]
# - Total portfolio value: 988.3175811767578
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['SPY']
# - Closing prices: [564.85998535]
# - Shares: [1.]
# - Individual symbol values: [564.85998535]
# - Total portfolio value: 564.8599853515625
# next_date_n pick's portf value = 988.3175811767578
# next_date_n SPY portf value =    564.8599853515625
# ====================
#
# ++++++++++++++
# date: 2024-07-10
# n (days increment): 4
# next_date_n: 2024-07-16
# close_date_n: 2024-07-16
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['FTSM']
# - Closing prices: [59.30849457]
# - Shares: [16.]
# - Individual symbol values: [948.93591309]
# - Total portfolio value: 948.9359130859375
# Portfolio value details:
# - Date: 2024-07-16
# - Symbols: ['SPY']
# - Closing prices: [564.85998535]
# - Shares: [1.]
# - Individual symbol values: [564.85998535]
# - Total portfolio value: 564.8599853515625
# next_date_n pick's portf value = 948.9359130859375
# next_date_n SPY portf value =    564.8599853515625
# ====================
#
# ++++++++++++++
# date: 2024-07-09
# n (days increment): 4
# next_date_n: 2024-07-15
# close_date_n: 2024-07-15
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['SHV']
# - Closing prices: [109.80310822]
# - Shares: [9.]
# - Individual symbol values: [988.22797394]
# - Total portfolio value: 988.2279739379883
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['SPY']
# - Closing prices: [561.5300293]
# - Shares: [1.]
# - Individual symbol values: [561.5300293]
# - Total portfolio value: 561.530029296875
# next_date_n pick's portf value = 988.2279739379883
# next_date_n SPY portf value =    561.530029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-09
# n (days increment): 4
# next_date_n: 2024-07-15
# close_date_n: 2024-07-15
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['FTSM']
# - Closing prices: [59.30849457]
# - Shares: [16.]
# - Individual symbol values: [948.93591309]
# - Total portfolio value: 948.9359130859375
# Portfolio value details:
# - Date: 2024-07-15
# - Symbols: ['SPY']
# - Closing prices: [561.5300293]
# - Shares: [1.]
# - Individual symbol values: [561.5300293]
# - Total portfolio value: 561.530029296875
# next_date_n pick's portf value = 948.9359130859375
# next_date_n SPY portf value =    561.530029296875
# ====================
#
# ++++++++++++++
# date: 2024-07-08
# n (days increment): 4
# next_date_n: 2024-07-12
# close_date_n: 2024-07-12
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['SHV']
# - Closing prices: [109.78318787]
# - Shares: [9.]
# - Individual symbol values: [988.0486908]
# - Total portfolio value: 988.0486907958984
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['SPY']
# - Closing prices: [559.98999023]
# - Shares: [1.]
# - Individual symbol values: [559.98999023]
# - Total portfolio value: 559.989990234375
# next_date_n pick's portf value = 988.0486907958984
# next_date_n SPY portf value =    559.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-08
# n (days increment): 4
# next_date_n: 2024-07-12
# close_date_n: 2024-07-12
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['FTSM']
# - Closing prices: [59.29858017]
# - Shares: [16.]
# - Individual symbol values: [948.77728271]
# - Total portfolio value: 948.7772827148438
# Portfolio value details:
# - Date: 2024-07-12
# - Symbols: ['SPY']
# - Closing prices: [559.98999023]
# - Shares: [1.]
# - Individual symbol values: [559.98999023]
# - Total portfolio value: 559.989990234375
# next_date_n pick's portf value = 948.7772827148438
# next_date_n SPY portf value =    559.989990234375
# ====================
#
# ++++++++++++++
# date: 2024-07-05
# n (days increment): 4
# next_date_n: 2024-07-11
# close_date_n: 2024-07-11
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-11
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.24899292 109.72345734]
# - Shares: [8. 4.]
# - Individual symbol values: [473.99194336 438.89382935]
# - Total portfolio value: 912.8857727050781
# Portfolio value details:
# - Date: 2024-07-11
# - Symbols: ['SPY']
# - Closing prices: [556.47998047]
# - Shares: [1.]
# - Individual symbol values: [556.47998047]
# - Total portfolio value: 556.47998046875
# next_date_n pick's portf value = 912.8857727050781
# next_date_n SPY portf value =    556.47998046875
# ====================
#
# ++++++++++++++
# date: 2024-07-03
# n (days increment): 4
# next_date_n: 2024-07-10
# close_date_n: 2024-07-10
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-10
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.22915268 109.69358826]
# - Shares: [8. 4.]
# - Individual symbol values: [473.83322144 438.77435303]
# - Total portfolio value: 912.6075744628906
# Portfolio value details:
# - Date: 2024-07-10
# - Symbols: ['SPY']
# - Closing prices: [561.32000732]
# - Shares: [1.]
# - Individual symbol values: [561.32000732]
# - Total portfolio value: 561.3200073242188
# next_date_n pick's portf value = 912.6075744628906
# next_date_n SPY portf value =    561.3200073242188
# ====================
#
# ++++++++++++++
# date: 2024-07-02
# n (days increment): 4
# next_date_n: 2024-07-09
# close_date_n: 2024-07-09
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-09
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.21923447 109.6836319 ]
# - Shares: [8. 4.]
# - Individual symbol values: [473.75387573 438.73452759]
# - Total portfolio value: 912.4884033203125
# Portfolio value details:
# - Date: 2024-07-09
# - Symbols: ['SPY']
# - Closing prices: [555.82000732]
# - Shares: [1.]
# - Individual symbol values: [555.82000732]
# - Total portfolio value: 555.8200073242188
# next_date_n pick's portf value = 912.4884033203125
# next_date_n SPY portf value =    555.8200073242188
# ====================
#
# ++++++++++++++
# date: 2024-07-01
# n (days increment): 4
# next_date_n: 2024-07-08
# close_date_n: 2024-07-08
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-08
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.19939804 109.6836319 ]
# - Shares: [8. 4.]
# - Individual symbol values: [473.59518433 438.73452759]
# - Total portfolio value: 912.3297119140625
# Portfolio value details:
# - Date: 2024-07-08
# - Symbols: ['SPY']
# - Closing prices: [555.2800293]
# - Shares: [1.]
# - Individual symbol values: [555.2800293]
# - Total portfolio value: 555.280029296875
# next_date_n pick's portf value = 912.3297119140625
# next_date_n SPY portf value =    555.280029296875
# ====================
#
# ++++++++++++++
# date: 2024-06-28
# n (days increment): 4
# next_date_n: 2024-07-05
# close_date_n: 2024-07-05
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-05
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.20931625 109.65377045]
# - Shares: [8. 4.]
# - Individual symbol values: [473.67453003 438.61508179]
# - Total portfolio value: 912.2896118164062
# Portfolio value details:
# - Date: 2024-07-05
# - Symbols: ['SPY']
# - Closing prices: [554.64001465]
# - Shares: [1.]
# - Individual symbol values: [554.64001465]
# - Total portfolio value: 554.6400146484375
# next_date_n pick's portf value = 912.2896118164062
# next_date_n SPY portf value =    554.6400146484375
# ====================
#
# ++++++++++++++
# date: 2024-06-27
# n (days increment): 4
# next_date_n: 2024-07-03
# close_date_n: 2024-07-03
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-03
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.14981079 109.61394501]
# - Shares: [8. 4.]
# - Individual symbol values: [473.19848633 438.45578003]
# - Total portfolio value: 911.6542663574219
# Portfolio value details:
# - Date: 2024-07-03
# - Symbols: ['SPY']
# - Closing prices: [551.46002197]
# - Shares: [1.]
# - Individual symbol values: [551.46002197]
# - Total portfolio value: 551.4600219726562
# next_date_n pick's portf value = 911.6542663574219
# next_date_n SPY portf value =    551.4600219726562
# ====================
#
# ++++++++++++++
# date: 2024-06-26
# n (days increment): 4
# next_date_n: 2024-07-02
# close_date_n: 2024-07-02
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-02
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.12997055 109.58407593]
# - Shares: [8. 4.]
# - Individual symbol values: [473.0397644  438.33630371]
# - Total portfolio value: 911.3760681152344
# Portfolio value details:
# - Date: 2024-07-02
# - Symbols: ['SPY']
# - Closing prices: [549.01000977]
# - Shares: [1.]
# - Individual symbol values: [549.01000977]
# - Total portfolio value: 549.010009765625
# next_date_n pick's portf value = 911.3760681152344
# next_date_n SPY portf value =    549.010009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-26
# n (days increment): 4
# next_date_n: 2024-07-02
# close_date_n: 2024-07-02
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-02
# - Symbols: ['SHV']
# - Closing prices: [109.58407593]
# - Shares: [9.]
# - Individual symbol values: [986.25668335]
# - Total portfolio value: 986.2566833496094
# Portfolio value details:
# - Date: 2024-07-02
# - Symbols: ['SPY']
# - Closing prices: [549.01000977]
# - Shares: [1.]
# - Individual symbol values: [549.01000977]
# - Total portfolio value: 549.010009765625
# next_date_n pick's portf value = 986.2566833496094
# next_date_n SPY portf value =    549.010009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-25
# n (days increment): 4
# next_date_n: 2024-07-01
# close_date_n: 2024-07-01
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-07-01
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.12005615 109.56417084]
# - Shares: [8. 4.]
# - Individual symbol values: [472.96044922 438.25668335]
# - Total portfolio value: 911.2171325683594
# Portfolio value details:
# - Date: 2024-07-01
# - Symbols: ['SPY']
# - Closing prices: [545.34002686]
# - Shares: [1.]
# - Individual symbol values: [545.34002686]
# - Total portfolio value: 545.3400268554688
# next_date_n pick's portf value = 911.2171325683594
# next_date_n SPY portf value =    545.3400268554688
# ====================
#
# ++++++++++++++
# date: 2024-06-24
# n (days increment): 4
# next_date_n: 2024-06-28
# close_date_n: 2024-06-28
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-28
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.11013794 109.54823303]
# - Shares: [8. 4.]
# - Individual symbol values: [472.88110352 438.19293213]
# - Total portfolio value: 911.0740356445312
# Portfolio value details:
# - Date: 2024-06-28
# - Symbols: ['SPY']
# - Closing prices: [544.2199707]
# - Shares: [1.]
# - Individual symbol values: [544.2199707]
# - Total portfolio value: 544.219970703125
# next_date_n pick's portf value = 911.0740356445312
# next_date_n SPY portf value =    544.219970703125
# ====================
#
# ++++++++++++++
# date: 2024-06-21
# n (days increment): 4
# next_date_n: 2024-06-27
# close_date_n: 2024-06-27
# symbols: ['FTSM', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-27
# - Symbols: ['FTSM', 'SHV']
# - Closing prices: [ 59.07542801 109.49866486]
# - Shares: [8. 4.]
# - Individual symbol values: [472.60342407 437.99465942]
# - Total portfolio value: 910.5980834960938
# Portfolio value details:
# - Date: 2024-06-27
# - Symbols: ['SPY']
# - Closing prices: [546.36999512]
# - Shares: [1.]
# - Individual symbol values: [546.36999512]
# - Total portfolio value: 546.3699951171875
# next_date_n pick's portf value = 910.5980834960938
# next_date_n SPY portf value =    546.3699951171875
# ====================
#
# ++++++++++++++
# date: 2024-06-20
# n (days increment): 4
# next_date_n: 2024-06-26
# close_date_n: 2024-06-26
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-26
# - Symbols: ['SHV']
# - Closing prices: [109.46891785]
# - Shares: [9.]
# - Individual symbol values: [985.22026062]
# - Total portfolio value: 985.2202606201172
# Portfolio value details:
# - Date: 2024-06-26
# - Symbols: ['SPY']
# - Closing prices: [545.51000977]
# - Shares: [1.]
# - Individual symbol values: [545.51000977]
# - Total portfolio value: 545.510009765625
# next_date_n pick's portf value = 985.2202606201172
# next_date_n SPY portf value =    545.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-20
# n (days increment): 4
# next_date_n: 2024-06-26
# close_date_n: 2024-06-26
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-26
# - Symbols: ['FTSM']
# - Closing prices: [59.06554413]
# - Shares: [16.]
# - Individual symbol values: [945.04870605]
# - Total portfolio value: 945.0487060546875
# Portfolio value details:
# - Date: 2024-06-26
# - Symbols: ['SPY']
# - Closing prices: [545.51000977]
# - Shares: [1.]
# - Individual symbol values: [545.51000977]
# - Total portfolio value: 545.510009765625
# next_date_n pick's portf value = 945.0487060546875
# next_date_n SPY portf value =    545.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-18
# n (days increment): 4
# next_date_n: 2024-06-25
# close_date_n: 2024-06-25
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-25
# - Symbols: ['SHV']
# - Closing prices: [109.46891785]
# - Shares: [9.]
# - Individual symbol values: [985.22026062]
# - Total portfolio value: 985.2202606201172
# Portfolio value details:
# - Date: 2024-06-25
# - Symbols: ['SPY']
# - Closing prices: [544.83001709]
# - Shares: [1.]
# - Individual symbol values: [544.83001709]
# - Total portfolio value: 544.8300170898438
# next_date_n pick's portf value = 985.2202606201172
# next_date_n SPY portf value =    544.8300170898438
# ====================
#
# ++++++++++++++
# date: 2024-06-18
# n (days increment): 4
# next_date_n: 2024-06-25
# close_date_n: 2024-06-25
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-25
# - Symbols: ['FTSM']
# - Closing prices: [59.07542801]
# - Shares: [16.]
# - Individual symbol values: [945.20684814]
# - Total portfolio value: 945.2068481445312
# Portfolio value details:
# - Date: 2024-06-25
# - Symbols: ['SPY']
# - Closing prices: [544.83001709]
# - Shares: [1.]
# - Individual symbol values: [544.83001709]
# - Total portfolio value: 544.8300170898438
# next_date_n pick's portf value = 945.2068481445312
# next_date_n SPY portf value =    544.8300170898438
# ====================
#
# ++++++++++++++
# date: 2024-06-17
# n (days increment): 4
# next_date_n: 2024-06-24
# close_date_n: 2024-06-24
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-24
# - Symbols: ['SHV']
# - Closing prices: [109.44909668]
# - Shares: [9.]
# - Individual symbol values: [985.04187012]
# - Total portfolio value: 985.0418701171875
# Portfolio value details:
# - Date: 2024-06-24
# - Symbols: ['SPY']
# - Closing prices: [542.73999023]
# - Shares: [1.]
# - Individual symbol values: [542.73999023]
# - Total portfolio value: 542.739990234375
# next_date_n pick's portf value = 985.0418701171875
# next_date_n SPY portf value =    542.739990234375
# ====================
#
# ++++++++++++++
# date: 2024-06-17
# n (days increment): 4
# next_date_n: 2024-06-24
# close_date_n: 2024-06-24
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-24
# - Symbols: ['FTSM']
# - Closing prices: [59.07542801]
# - Shares: [16.]
# - Individual symbol values: [945.20684814]
# - Total portfolio value: 945.2068481445312
# Portfolio value details:
# - Date: 2024-06-24
# - Symbols: ['SPY']
# - Closing prices: [542.73999023]
# - Shares: [1.]
# - Individual symbol values: [542.73999023]
# - Total portfolio value: 542.739990234375
# next_date_n pick's portf value = 945.2068481445312
# next_date_n SPY portf value =    542.739990234375
# ====================
#
# ++++++++++++++
# date: 2024-06-14
# n (days increment): 4
# next_date_n: 2024-06-21
# close_date_n: 2024-06-21
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['SHV']
# - Closing prices: [109.43917847]
# - Shares: [9.]
# - Individual symbol values: [984.9526062]
# - Total portfolio value: 984.9526062011719
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['SPY']
# - Closing prices: [544.51000977]
# - Shares: [1.]
# - Individual symbol values: [544.51000977]
# - Total portfolio value: 544.510009765625
# next_date_n pick's portf value = 984.9526062011719
# next_date_n SPY portf value =    544.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-14
# n (days increment): 4
# next_date_n: 2024-06-21
# close_date_n: 2024-06-21
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['FTSM']
# - Closing prices: [59.06554413]
# - Shares: [16.]
# - Individual symbol values: [945.04870605]
# - Total portfolio value: 945.0487060546875
# Portfolio value details:
# - Date: 2024-06-21
# - Symbols: ['SPY']
# - Closing prices: [544.51000977]
# - Shares: [1.]
# - Individual symbol values: [544.51000977]
# - Total portfolio value: 544.510009765625
# next_date_n pick's portf value = 945.0487060546875
# next_date_n SPY portf value =    544.510009765625
# ====================
#
# ++++++++++++++
# date: 2024-06-13
# n (days increment): 4
# next_date_n: 2024-06-20
# close_date_n: 2024-06-20
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['SHV']
# - Closing prices: [109.38961029]
# - Shares: [9.]
# - Individual symbol values: [984.50649261]
# - Total portfolio value: 984.5064926147461
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['SPY']
# - Closing prices: [545.2409668]
# - Shares: [1.]
# - Individual symbol values: [545.2409668]
# - Total portfolio value: 545.240966796875
# next_date_n pick's portf value = 984.5064926147461
# next_date_n SPY portf value =    545.240966796875
# ====================
#
# ++++++++++++++
# date: 2024-06-13
# n (days increment): 4
# next_date_n: 2024-06-20
# close_date_n: 2024-06-20
# symbols: ['FTSM']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['FTSM']
# - Closing prices: [59.02603531]
# - Shares: [16.]
# - Individual symbol values: [944.41656494]
# - Total portfolio value: 944.4165649414062
# Portfolio value details:
# - Date: 2024-06-20
# - Symbols: ['SPY']
# - Closing prices: [545.2409668]
# - Shares: [1.]
# - Individual symbol values: [545.2409668]
# - Total portfolio value: 545.240966796875
# next_date_n pick's portf value = 944.4165649414062
# next_date_n SPY portf value =    545.240966796875
# ====================
#
# ++++++++++++++
# date: 2024-06-12
# n (days increment): 4
# next_date_n: 2024-06-18
# close_date_n: 2024-06-18
# symbols: ['FTSM', 'NVAX', 'SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-18
# - Symbols: ['FTSM', 'NVAX', 'SHV']
# - Closing prices: [ 59.03591537  13.78999996 109.36978912]
# - Shares: [ 5. 22.  3.]
# - Individual symbol values: [295.17957687 303.37999916 328.10936737]
# - Total portfolio value: 926.6689434051514
# Portfolio value details:
# - Date: 2024-06-18
# - Symbols: ['SPY']
# - Closing prices: [546.72619629]
# - Shares: [1.]
# - Individual symbol values: [546.72619629]
# - Total portfolio value: 546.7261962890625
# next_date_n pick's portf value = 926.6689434051514
# next_date_n SPY portf value =    546.7261962890625
# ====================
#
# ++++++++++++++
# date: 2024-06-11
# n (days increment): 4
# next_date_n: 2024-06-17
# close_date_n: 2024-06-17
# symbols: ['SHV']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['SHV']
# - Closing prices: [109.34004211]
# - Shares: [9.]
# - Individual symbol values: [984.06037903]
# - Total portfolio value: 984.0603790283203
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['SPY']
# - Closing prices: [545.34063721]
# - Shares: [1.]
# - Individual symbol values: [545.34063721]
# - Total portfolio value: 545.3406372070312
# next_date_n pick's portf value = 984.0603790283203
# next_date_n SPY portf value =    545.3406372070312
# ====================
#
# ++++++++++++++
# date: 2024-06-11
# n (days increment): 4
# next_date_n: 2024-06-17
# close_date_n: 2024-06-17
# symbols: ['FTSM', 'NVAX']
# ++++++++++++++
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['FTSM', 'NVAX']
# - Closing prices: [59.00628662 14.05000019]
# - Shares: [ 8. 31.]
# - Individual symbol values: [472.05029297 435.55000591]
# - Total portfolio value: 907.6002988815308
# Portfolio value details:
# - Date: 2024-06-17
# - Symbols: ['SPY']
# - Closing prices: [545.34063721]
# - Shares: [1.]
# - Individual symbol values: [545.34063721]
# - Total portfolio value: 545.3406372070312
# next_date_n pick's portf value = 907.6002988815308
# next_date_n SPY portf value =    545.3406372070312
# ====================

# %%
"""
Adds calculated portfolio values, performance metrics, and a comparison to SPY to the sorted_df_model_picks_calc_perf DataFrame.
"""

# Add columns for portfolio sell information:
sorted_df_model_picks_calc_perf['date_sell'] = date_exec  # Date of portfolio sale
sorted_df_model_picks_calc_perf['sh_portf_sell'] = shares_syms  # Number of shares sold for each symbol
sorted_df_model_picks_calc_perf['$_portf_sell'] = value_portf  # Total value of the portfolio at sale

# Calculate percentage change for the portfolio:
sorted_df_model_picks_calc_perf['%_portf_chg'] = (sorted_df_model_picks_calc_perf['$_portf_sell'] / sorted_df_model_picks_calc_perf['$_portf_buy'] - 1) * 100

# Add columns for SPY sell information:
sorted_df_model_picks_calc_perf['sh_SPY_sell'] = shares_SPY  # Number of SPY shares sold
sorted_df_model_picks_calc_perf['$_SPY_sell'] = value_SPY  # Total value of SPY at sale

# Calculate percentage change for SPY:
sorted_df_model_picks_calc_perf['%_SPY_chg'] = (sorted_df_model_picks_calc_perf['$_SPY_sell'] / sorted_df_model_picks_calc_perf['$_SPY_buy'] - 1) * 100

# Calculate the difference in percentage change between the portfolio and SPY:
sorted_df_model_picks_calc_perf['dif_%_chg'] = sorted_df_model_picks_calc_perf['%_portf_chg'] - sorted_df_model_picks_calc_perf['%_SPY_chg']

# %%
"""
Adds a "win" column to indicate out performance of SPY and displays the first 20 rows of the DataFrame.
"""

# Add a "win" column to indicate whether the portfolio outperformed SPY:
sorted_df_model_picks_calc_perf['win'] = np.where(sorted_df_model_picks_calc_perf['dif_%_chg'] > 0, 1, 0)  # 1 for outperformance, 0 otherwise

# Display the first 20 rows of the DataFrame for review:
print(f'sorted_df_model_picks_calc_perf:\n{sorted_df_model_picks_calc_perf}')
# Out:
# sorted_df_model_picks_calc_perf:
#           date      days_lookback    syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell          sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2024-08-30      [30, 60, 120]   sym_freq_9                        ['SHV']        None                   None          NaN       None         NaN        None                   None           NaN          NaN        None         NaN        NaN        NaN    0
# 1   2024-08-29      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-30                  [9.0]   995.399986      [1.0]  563.679993        None                   None           NaN          NaN        None         NaN        NaN        NaN    0
# 2   2024-08-28      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-29                  [9.0]   995.039978      [1.0]  558.349976        None                   None           NaN          NaN        None         NaN        NaN        NaN    0
# 3   2024-08-27      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-28                  [9.0]   994.950027      [1.0]  558.299988        None                   None           NaN          NaN        None         NaN        NaN        NaN    0
# 4   2024-08-26      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998  2024-08-30                  [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 5   2024-08-23      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978  2024-08-29                  [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 6   2024-08-22      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005  2024-08-28                  [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 7   2024-08-21      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971  2024-08-27                  [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 8   2024-08-20      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26            [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# 9   2024-08-19      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012  2024-08-23            [81.0, 4.0]    946.630002     0.727820       [1.0]  562.130005   0.613924   0.113896    1
# 10  2024-08-16      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985  2024-08-22            [86.0, 4.0]    961.239985     2.600117       [1.0]  556.219971  -0.605782   3.205899    1
# 11  2024-08-15      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998  2024-08-21            [83.0, 4.0]    950.510011     0.995601       [1.0]  560.619995   1.138352  -0.142751    0
# 12  2024-08-14      [30, 60, 120]   sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007  2024-08-20       [0.0, 58.0, 3.0]    687.930017     3.894949       [1.0]  558.700012   1.017955   2.876994    1
# 13  2024-08-13      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000  2024-08-19            [88.0, 4.0]    948.400009     0.966660       [1.0]  559.609985   2.916779  -1.950119    0
# 14  2024-08-12      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978  2024-08-16                  [9.0]    993.330025     0.054397       [1.0]  554.309998   2.263674  -2.209277    0
# 15  2024-08-12      [30, 60, 120]   sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978  2024-08-16                  [1.0]    560.130005     0.126921       [1.0]  554.309998   2.263674  -2.136753    0
# 16  2024-08-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020  2024-08-15                  [9.0]    992.879997     0.036272       [1.0]  553.070007   3.712938  -3.676666    0
# 17  2024-08-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020  2024-08-15  [4.0, 0.0, 53.0, 4.0]    773.284635     7.350752       [1.0]  553.070007   3.712938   3.637814    1
# 18  2024-08-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990  2024-08-14                  [9.0]    992.789978     0.054420       [1.0]  543.750000   2.018801  -1.964382    0
# 19  2024-08-08      [30, 60, 120]   sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990  2024-08-14       [5.0, 59.0, 5.0]    924.807663     0.141741       [1.0]  543.750000   2.018801  -1.877061    0
# 20  2024-08-07      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024  2024-08-13                  [9.0]    992.789978     0.090734       [1.0]  542.039978   2.146415  -2.055681    0
# 21  2024-08-07      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024  2024-08-13  [4.0, 0.0, 46.0, 4.0]    706.194141    -2.158728       [1.0]  542.039978   2.146415  -4.305144    0
# 22  2024-08-06      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973  2024-08-12                  [9.0]    992.519989     0.072597       [1.0]  533.270020   2.816883  -2.744286    0
# 23  2024-08-06      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973  2024-08-12                 [16.0]    953.978516     0.050134       [1.0]  533.270020   2.816883  -2.766749    0
# 24  2024-08-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-08-06             [8.0, 4.0]   917.390594      [1.0]  522.150024  2024-08-09             [8.0, 4.0]    917.829895     0.047886       [1.0]  532.989990   2.076025  -2.028139    0
# 25  2024-08-02      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-05             [8.0, 4.0]   917.709259      [1.0]  517.380005  2024-08-08             [8.0, 4.0]    917.510590    -0.021648       [1.0]  530.650024   2.564850  -2.586498    0
# 26  2024-08-01      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-02             [8.0, 4.0]   917.470245      [1.0]  532.900024  2024-08-07             [8.0, 4.0]    917.550232     0.008718       [1.0]  518.659973  -2.672181   2.680899    1
# 27  2024-07-31      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-01             [8.0, 4.0]   916.273560      [1.0]  543.010010  2024-08-06             [8.0, 4.0]    917.390594     0.121911       [1.0]  522.150024  -3.841547   3.963458    1
# 28  2024-07-30      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-31             [8.0, 4.0]   916.002228      [1.0]  550.809998  2024-08-05             [8.0, 4.0]    917.709259     0.186357       [1.0]  517.380005  -6.069242   6.255599    1
# 29  2024-07-29      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-30             [8.0, 4.0]   915.667572      [1.0]  542.000000  2024-08-02             [8.0, 4.0]    917.470245     0.196870       [1.0]  532.900024  -1.678962   1.875832    1
# 30  2024-07-26      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-29             [8.0, 4.0]   915.627747      [1.0]  544.760010  2024-08-01             [8.0, 4.0]    916.273560     0.070532       [1.0]  543.010010  -0.321242   0.391775    1
# 31  2024-07-25      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-26             [8.0, 4.0]   915.468750      [1.0]  544.440002  2024-07-31             [8.0, 4.0]    916.002228     0.058274       [1.0]  550.809998   1.170009  -1.111735    0
# 32  2024-07-24      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-25             [8.0, 4.0]   914.833130      [1.0]  538.409973  2024-07-30             [8.0, 4.0]    915.667572     0.091212       [1.0]  542.000000   0.666783  -0.575571    0
# 33  2024-07-23      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-24             [8.0, 4.0]   914.793304      [1.0]  541.229980  2024-07-29             [8.0, 4.0]    915.627747     0.091216       [1.0]  544.760010   0.652224  -0.561007    0
# 34  2024-07-22      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-23                  [9.0]   989.392799      [1.0]  553.780029  2024-07-26                  [9.0]    990.109589     0.072447       [1.0]  544.440002  -1.686595   1.759042    1
# 35  2024-07-22      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-23             [8.0, 4.0]   936.865326      [1.0]  553.780029  2024-07-26             [8.0, 4.0]    926.260040    -1.131997       [1.0]  544.440002  -1.686595   0.554598    1
# 36  2024-07-19      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-22                  [9.0]   989.213585      [1.0]  554.650024  2024-07-25                  [9.0]    989.572014     0.036234       [1.0]  538.409973  -2.927982   2.964215    1
# 37  2024-07-19      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-22             [8.0, 4.0]   933.505341      [1.0]  554.650024  2024-07-25             [8.0, 4.0]    926.823334    -0.715797       [1.0]  538.409973  -2.927982   2.212184    1
# 38  2024-07-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-19                  [9.0]   989.123978      [1.0]  548.989990  2024-07-24                  [9.0]    989.482407     0.036237       [1.0]  541.229980  -1.413507   1.449744    1
# 39  2024-07-18      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-19             [8.0, 4.0]   941.786652      [1.0]  548.989990  2024-07-24             [8.0, 4.0]    929.663361    -1.287265       [1.0]  541.229980  -1.413507   0.126241    1
# 40  2024-07-17      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-18             [4.0, 4.0]   902.331726      [1.0]  552.659973  2024-07-23             [4.0, 4.0]    901.810120    -0.057807       [1.0]  553.780029   0.202666  -0.260473    0
# 41  2024-07-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-18                 [16.0]   949.253296      [1.0]  552.659973  2024-07-23                 [16.0]    949.570679     0.033435       [1.0]  553.780029   0.202666  -0.169231    0
# 42  2024-07-16      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-17                  [9.0]   988.407120      [1.0]  556.940002  2024-07-22                  [9.0]    989.213585     0.081592       [1.0]  554.650024  -0.411171   0.492764    1
# 43  2024-07-16      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-17                 [16.0]   949.094604      [1.0]  556.940002  2024-07-22                 [16.0]    949.570679     0.050161       [1.0]  554.650024  -0.411171   0.461332    1
# 44  2024-07-15      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-16             [4.0, 4.0]   912.452271      [1.0]  564.859985  2024-07-19             [4.0, 4.0]    906.770660    -0.622675       [1.0]  548.989990  -2.809545   2.186870    1
# 45  2024-07-15      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-16                 [16.0]   948.935913      [1.0]  564.859985  2024-07-19                 [16.0]    949.253296     0.033446       [1.0]  548.989990  -2.809545   2.842991    1
# 46  2024-07-15  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-16                  [8.0]   946.400024      [1.0]  564.859985  2024-07-19                  [8.0]    934.320007    -1.276418       [1.0]  548.989990  -2.809545   1.533127    1
# 47  2024-07-12      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-15             [4.0, 4.0]   931.972443      [1.0]  561.530029  2024-07-18             [4.0, 4.0]    902.331726    -3.180428       [1.0]  552.659973  -1.579623  -1.600806    0
# 48  2024-07-12      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-15                 [16.0]   948.935913      [1.0]  561.530029  2024-07-18                 [16.0]    949.253296     0.033446       [1.0]  552.659973  -1.579623   1.613069    1
# 49  2024-07-12  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-15                  [8.0]   985.520020      [1.0]  561.530029  2024-07-18                  [8.0]    925.919983    -6.047572       [1.0]  552.659973  -1.579623  -4.467950    0
# 50  2024-07-11      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-12             [4.0, 4.0]   932.812744      [1.0]  559.989990  2024-07-17             [4.0, 4.0]    925.732056    -0.759069       [1.0]  556.940002  -0.544650  -0.214418    0
# 51  2024-07-11      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-12                 [16.0]   948.777283      [1.0]  559.989990  2024-07-17                 [16.0]    949.094604     0.033445       [1.0]  556.940002  -0.544650   0.578096    1
# 52  2024-07-11  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-12                  [8.0]   987.359985      [1.0]  559.989990  2024-07-17                  [8.0]    972.880005    -1.466535       [1.0]  556.940002  -0.544650  -0.921885    0
# 53  2024-07-10      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-11                  [9.0]   987.511116      [1.0]  556.479980  2024-07-16                  [9.0]    988.317581     0.081666       [1.0]  564.859985   1.505895  -1.424229    0
# 54  2024-07-10      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-11                 [16.0]   947.983887      [1.0]  556.479980  2024-07-16                 [16.0]    948.935913     0.100426       [1.0]  564.859985   1.505895  -1.405469    0
# 55  2024-07-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-10                  [9.0]   987.242294      [1.0]  561.320007  2024-07-15                  [9.0]    988.227974     0.099842       [1.0]  561.530029   0.037416   0.062426    1
# 56  2024-07-09      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-10                 [16.0]   947.666443      [1.0]  561.320007  2024-07-15                 [16.0]    948.935913     0.133957       [1.0]  561.530029   0.037416   0.096542    1
# 57  2024-07-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-09                  [9.0]   987.152687      [1.0]  555.820007  2024-07-12                  [9.0]    988.048691     0.090766       [1.0]  559.989990   0.750240  -0.659473    0
# 58  2024-07-08      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-09                 [16.0]   947.507751      [1.0]  555.820007  2024-07-12                 [16.0]    948.777283     0.133986       [1.0]  559.989990   0.750240  -0.616253    0
# 59  2024-07-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-08             [8.0, 4.0]   912.329712      [1.0]  555.280029  2024-07-11             [8.0, 4.0]    912.885773     0.060950       [1.0]  556.479980   0.216098  -0.155149    0
# 60  2024-07-03      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-05             [8.0, 4.0]   912.289612      [1.0]  554.640015  2024-07-10             [8.0, 4.0]    912.607574     0.034853       [1.0]  561.320007   1.204383  -1.169530    0
# 61  2024-07-02      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-03             [8.0, 4.0]   911.654266      [1.0]  551.460022  2024-07-09             [8.0, 4.0]    912.488403     0.091497       [1.0]  555.820007   0.790626  -0.699129    0
# 62  2024-07-01      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-02             [8.0, 4.0]   911.376068      [1.0]  549.010010  2024-07-08             [8.0, 4.0]    912.329712     0.104638       [1.0]  555.280029   1.142059  -1.037421    0
# 63  2024-06-28      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-01             [8.0, 4.0]   911.217133      [1.0]  545.340027  2024-07-05             [8.0, 4.0]    912.289612     0.117697       [1.0]  554.640015   1.705356  -1.587658    0
# 64  2024-06-27      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-28             [8.0, 4.0]   911.074036      [1.0]  544.219971  2024-07-03             [8.0, 4.0]    911.654266     0.063686       [1.0]  551.460022   1.330354  -1.266667    0
# 65  2024-06-26      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-27             [8.0, 4.0]   910.598083      [1.0]  546.369995  2024-07-02             [8.0, 4.0]    911.376068     0.085437       [1.0]  549.010010   0.483192  -0.397755    0
# 66  2024-06-26  [15, 30, 60, 120]  sym_freq_12                        ['SHV']  2024-06-27                  [9.0]   985.487984      [1.0]  546.369995  2024-07-02                  [9.0]    986.256683     0.078002       [1.0]  549.010010   0.483192  -0.405190    0
# 67  2024-06-25      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-26             [8.0, 4.0]   910.400024      [1.0]  545.510010  2024-07-01             [8.0, 4.0]    911.217133     0.089753       [1.0]  545.340027  -0.031160   0.120913    1
# 68  2024-06-24      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-25             [8.0, 4.0]   910.479095      [1.0]  544.830017  2024-06-28             [8.0, 4.0]    911.074036     0.065344       [1.0]  544.219971  -0.111970   0.177314    1
# 69  2024-06-21      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-24             [8.0, 4.0]   910.399811      [1.0]  542.739990  2024-06-27             [8.0, 4.0]    910.598083     0.021779       [1.0]  546.369995   0.668829  -0.647051    0
# 70  2024-06-20      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-21                  [9.0]   984.952606      [1.0]  544.510010  2024-06-26                  [9.0]    985.220261     0.027174       [1.0]  545.510010   0.183651  -0.156477    0
# 71  2024-06-20      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-21                 [16.0]   945.048706      [1.0]  544.510010  2024-06-26                 [16.0]    945.048706     0.000000       [1.0]  545.510010   0.183651  -0.183651    0
# 72  2024-06-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-20                  [9.0]   984.506493      [1.0]  545.240967  2024-06-25                  [9.0]    985.220261     0.072500       [1.0]  544.830017  -0.075370   0.147870    1
# 73  2024-06-18      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-20                 [16.0]   944.416565      [1.0]  545.240967  2024-06-25                 [16.0]    945.206848     0.083680       [1.0]  544.830017  -0.075370   0.159050    1
# 74  2024-06-17      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-18                  [9.0]   984.328102      [1.0]  546.726196  2024-06-24                  [9.0]    985.041870     0.072513       [1.0]  542.739990  -0.729105   0.801618    1
# 75  2024-06-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-18                 [16.0]   944.574646      [1.0]  546.726196  2024-06-24                 [16.0]    945.206848     0.066930       [1.0]  542.739990  -0.729105   0.796034    1
# 76  2024-06-14      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-17                  [9.0]   984.060379      [1.0]  545.340637  2024-06-21                  [9.0]    984.952606     0.090668       [1.0]  544.510010  -0.152314   0.242981    1
# 77  2024-06-14      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-17                 [16.0]   944.100586      [1.0]  545.340637  2024-06-21                 [16.0]    945.048706     0.100426       [1.0]  544.510010  -0.152314   0.252739    1
# 78  2024-06-13      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-14                  [9.0]   983.971184      [1.0]  541.034607  2024-06-20                  [9.0]    984.506493     0.054403       [1.0]  545.240967   0.777466  -0.723063    0
# 79  2024-06-13      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-14                 [16.0]   943.942505      [1.0]  541.034607  2024-06-20                 [16.0]    944.416565     0.050221       [1.0]  545.240967   0.777466  -0.727245    0
# 80  2024-06-12      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']  2024-06-13       [5.0, 22.0, 3.0]   953.923727      [1.0]  540.705627  2024-06-18       [5.0, 22.0, 3.0]    926.668943    -2.857124       [1.0]  546.726196   1.113465  -3.970589    0
# 81  2024-06-11      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-12                  [9.0]   983.435806      [1.0]  539.619141  2024-06-17                  [9.0]    984.060379     0.063509       [1.0]  545.340637   1.060284  -0.996775    0
# 82  2024-06-11      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']  2024-06-12            [8.0, 31.0]   963.394181      [1.0]  539.619141  2024-06-17            [8.0, 31.0]    907.600299    -5.791387       [1.0]  545.340637   1.060284  -6.851671    0

# %%
idx_row = find_first_non_nan_in_column(sorted_df_model_picks_calc_perf.copy(), "dif_%_chg")
print(f'idx_row: {idx_row}\n')

# TODO
if idx_row < 0:
  df_perf = sorted_df_model_picks_calc_perf.iloc[[]]  # Use empty list for slicing
  print(f'idx_row: {idx_row}, no non-NaN values are found\n')
else:
  df_perf = sorted_df_model_picks_calc_perf[idx_row:]

print(f'df_perf:\n{df_perf}')
# print(sorted_df_model_picks_calc_perf[idx_row:])
# Out:
# idx_row: 4
#
# df_perf:
#           date      days_lookback    syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell          sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 4   2024-08-26      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998  2024-08-30                  [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 5   2024-08-23      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978  2024-08-29                  [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 6   2024-08-22      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005  2024-08-28                  [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 7   2024-08-21      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971  2024-08-27                  [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 8   2024-08-20      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26            [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# 9   2024-08-19      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012  2024-08-23            [81.0, 4.0]    946.630002     0.727820       [1.0]  562.130005   0.613924   0.113896    1
# 10  2024-08-16      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985  2024-08-22            [86.0, 4.0]    961.239985     2.600117       [1.0]  556.219971  -0.605782   3.205899    1
# 11  2024-08-15      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998  2024-08-21            [83.0, 4.0]    950.510011     0.995601       [1.0]  560.619995   1.138352  -0.142751    0
# 12  2024-08-14      [30, 60, 120]   sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007  2024-08-20       [0.0, 58.0, 3.0]    687.930017     3.894949       [1.0]  558.700012   1.017955   2.876994    1
# 13  2024-08-13      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000  2024-08-19            [88.0, 4.0]    948.400009     0.966660       [1.0]  559.609985   2.916779  -1.950119    0
# 14  2024-08-12      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978  2024-08-16                  [9.0]    993.330025     0.054397       [1.0]  554.309998   2.263674  -2.209277    0
# 15  2024-08-12      [30, 60, 120]   sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978  2024-08-16                  [1.0]    560.130005     0.126921       [1.0]  554.309998   2.263674  -2.136753    0
# 16  2024-08-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020  2024-08-15                  [9.0]    992.879997     0.036272       [1.0]  553.070007   3.712938  -3.676666    0
# 17  2024-08-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020  2024-08-15  [4.0, 0.0, 53.0, 4.0]    773.284635     7.350752       [1.0]  553.070007   3.712938   3.637814    1
# 18  2024-08-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990  2024-08-14                  [9.0]    992.789978     0.054420       [1.0]  543.750000   2.018801  -1.964382    0
# 19  2024-08-08      [30, 60, 120]   sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990  2024-08-14       [5.0, 59.0, 5.0]    924.807663     0.141741       [1.0]  543.750000   2.018801  -1.877061    0
# 20  2024-08-07      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024  2024-08-13                  [9.0]    992.789978     0.090734       [1.0]  542.039978   2.146415  -2.055681    0
# 21  2024-08-07      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024  2024-08-13  [4.0, 0.0, 46.0, 4.0]    706.194141    -2.158728       [1.0]  542.039978   2.146415  -4.305144    0
# 22  2024-08-06      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973  2024-08-12                  [9.0]    992.519989     0.072597       [1.0]  533.270020   2.816883  -2.744286    0
# 23  2024-08-06      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973  2024-08-12                 [16.0]    953.978516     0.050134       [1.0]  533.270020   2.816883  -2.766749    0
# 24  2024-08-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-08-06             [8.0, 4.0]   917.390594      [1.0]  522.150024  2024-08-09             [8.0, 4.0]    917.829895     0.047886       [1.0]  532.989990   2.076025  -2.028139    0
# 25  2024-08-02      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-05             [8.0, 4.0]   917.709259      [1.0]  517.380005  2024-08-08             [8.0, 4.0]    917.510590    -0.021648       [1.0]  530.650024   2.564850  -2.586498    0
# 26  2024-08-01      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-02             [8.0, 4.0]   917.470245      [1.0]  532.900024  2024-08-07             [8.0, 4.0]    917.550232     0.008718       [1.0]  518.659973  -2.672181   2.680899    1
# 27  2024-07-31      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-01             [8.0, 4.0]   916.273560      [1.0]  543.010010  2024-08-06             [8.0, 4.0]    917.390594     0.121911       [1.0]  522.150024  -3.841547   3.963458    1
# 28  2024-07-30      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-31             [8.0, 4.0]   916.002228      [1.0]  550.809998  2024-08-05             [8.0, 4.0]    917.709259     0.186357       [1.0]  517.380005  -6.069242   6.255599    1
# 29  2024-07-29      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-30             [8.0, 4.0]   915.667572      [1.0]  542.000000  2024-08-02             [8.0, 4.0]    917.470245     0.196870       [1.0]  532.900024  -1.678962   1.875832    1
# 30  2024-07-26      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-29             [8.0, 4.0]   915.627747      [1.0]  544.760010  2024-08-01             [8.0, 4.0]    916.273560     0.070532       [1.0]  543.010010  -0.321242   0.391775    1
# 31  2024-07-25      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-26             [8.0, 4.0]   915.468750      [1.0]  544.440002  2024-07-31             [8.0, 4.0]    916.002228     0.058274       [1.0]  550.809998   1.170009  -1.111735    0
# 32  2024-07-24      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-25             [8.0, 4.0]   914.833130      [1.0]  538.409973  2024-07-30             [8.0, 4.0]    915.667572     0.091212       [1.0]  542.000000   0.666783  -0.575571    0
# 33  2024-07-23      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-24             [8.0, 4.0]   914.793304      [1.0]  541.229980  2024-07-29             [8.0, 4.0]    915.627747     0.091216       [1.0]  544.760010   0.652224  -0.561007    0
# 34  2024-07-22      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-23                  [9.0]   989.392799      [1.0]  553.780029  2024-07-26                  [9.0]    990.109589     0.072447       [1.0]  544.440002  -1.686595   1.759042    1
# 35  2024-07-22      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-23             [8.0, 4.0]   936.865326      [1.0]  553.780029  2024-07-26             [8.0, 4.0]    926.260040    -1.131997       [1.0]  544.440002  -1.686595   0.554598    1
# 36  2024-07-19      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-22                  [9.0]   989.213585      [1.0]  554.650024  2024-07-25                  [9.0]    989.572014     0.036234       [1.0]  538.409973  -2.927982   2.964215    1
# 37  2024-07-19      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-22             [8.0, 4.0]   933.505341      [1.0]  554.650024  2024-07-25             [8.0, 4.0]    926.823334    -0.715797       [1.0]  538.409973  -2.927982   2.212184    1
# 38  2024-07-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-19                  [9.0]   989.123978      [1.0]  548.989990  2024-07-24                  [9.0]    989.482407     0.036237       [1.0]  541.229980  -1.413507   1.449744    1
# 39  2024-07-18      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-19             [8.0, 4.0]   941.786652      [1.0]  548.989990  2024-07-24             [8.0, 4.0]    929.663361    -1.287265       [1.0]  541.229980  -1.413507   0.126241    1
# 40  2024-07-17      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-18             [4.0, 4.0]   902.331726      [1.0]  552.659973  2024-07-23             [4.0, 4.0]    901.810120    -0.057807       [1.0]  553.780029   0.202666  -0.260473    0
# 41  2024-07-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-18                 [16.0]   949.253296      [1.0]  552.659973  2024-07-23                 [16.0]    949.570679     0.033435       [1.0]  553.780029   0.202666  -0.169231    0
# 42  2024-07-16      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-17                  [9.0]   988.407120      [1.0]  556.940002  2024-07-22                  [9.0]    989.213585     0.081592       [1.0]  554.650024  -0.411171   0.492764    1
# 43  2024-07-16      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-17                 [16.0]   949.094604      [1.0]  556.940002  2024-07-22                 [16.0]    949.570679     0.050161       [1.0]  554.650024  -0.411171   0.461332    1
# 44  2024-07-15      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-16             [4.0, 4.0]   912.452271      [1.0]  564.859985  2024-07-19             [4.0, 4.0]    906.770660    -0.622675       [1.0]  548.989990  -2.809545   2.186870    1
# 45  2024-07-15      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-16                 [16.0]   948.935913      [1.0]  564.859985  2024-07-19                 [16.0]    949.253296     0.033446       [1.0]  548.989990  -2.809545   2.842991    1
# 46  2024-07-15  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-16                  [8.0]   946.400024      [1.0]  564.859985  2024-07-19                  [8.0]    934.320007    -1.276418       [1.0]  548.989990  -2.809545   1.533127    1
# 47  2024-07-12      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-15             [4.0, 4.0]   931.972443      [1.0]  561.530029  2024-07-18             [4.0, 4.0]    902.331726    -3.180428       [1.0]  552.659973  -1.579623  -1.600806    0
# 48  2024-07-12      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-15                 [16.0]   948.935913      [1.0]  561.530029  2024-07-18                 [16.0]    949.253296     0.033446       [1.0]  552.659973  -1.579623   1.613069    1
# 49  2024-07-12  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-15                  [8.0]   985.520020      [1.0]  561.530029  2024-07-18                  [8.0]    925.919983    -6.047572       [1.0]  552.659973  -1.579623  -4.467950    0
# 50  2024-07-11      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-12             [4.0, 4.0]   932.812744      [1.0]  559.989990  2024-07-17             [4.0, 4.0]    925.732056    -0.759069       [1.0]  556.940002  -0.544650  -0.214418    0
# 51  2024-07-11      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-12                 [16.0]   948.777283      [1.0]  559.989990  2024-07-17                 [16.0]    949.094604     0.033445       [1.0]  556.940002  -0.544650   0.578096    1
# 52  2024-07-11  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-12                  [8.0]   987.359985      [1.0]  559.989990  2024-07-17                  [8.0]    972.880005    -1.466535       [1.0]  556.940002  -0.544650  -0.921885    0
# 53  2024-07-10      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-11                  [9.0]   987.511116      [1.0]  556.479980  2024-07-16                  [9.0]    988.317581     0.081666       [1.0]  564.859985   1.505895  -1.424229    0
# 54  2024-07-10      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-11                 [16.0]   947.983887      [1.0]  556.479980  2024-07-16                 [16.0]    948.935913     0.100426       [1.0]  564.859985   1.505895  -1.405469    0
# 55  2024-07-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-10                  [9.0]   987.242294      [1.0]  561.320007  2024-07-15                  [9.0]    988.227974     0.099842       [1.0]  561.530029   0.037416   0.062426    1
# 56  2024-07-09      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-10                 [16.0]   947.666443      [1.0]  561.320007  2024-07-15                 [16.0]    948.935913     0.133957       [1.0]  561.530029   0.037416   0.096542    1
# 57  2024-07-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-09                  [9.0]   987.152687      [1.0]  555.820007  2024-07-12                  [9.0]    988.048691     0.090766       [1.0]  559.989990   0.750240  -0.659473    0
# 58  2024-07-08      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-09                 [16.0]   947.507751      [1.0]  555.820007  2024-07-12                 [16.0]    948.777283     0.133986       [1.0]  559.989990   0.750240  -0.616253    0
# 59  2024-07-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-08             [8.0, 4.0]   912.329712      [1.0]  555.280029  2024-07-11             [8.0, 4.0]    912.885773     0.060950       [1.0]  556.479980   0.216098  -0.155149    0
# 60  2024-07-03      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-05             [8.0, 4.0]   912.289612      [1.0]  554.640015  2024-07-10             [8.0, 4.0]    912.607574     0.034853       [1.0]  561.320007   1.204383  -1.169530    0
# 61  2024-07-02      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-03             [8.0, 4.0]   911.654266      [1.0]  551.460022  2024-07-09             [8.0, 4.0]    912.488403     0.091497       [1.0]  555.820007   0.790626  -0.699129    0
# 62  2024-07-01      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-02             [8.0, 4.0]   911.376068      [1.0]  549.010010  2024-07-08             [8.0, 4.0]    912.329712     0.104638       [1.0]  555.280029   1.142059  -1.037421    0
# 63  2024-06-28      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-01             [8.0, 4.0]   911.217133      [1.0]  545.340027  2024-07-05             [8.0, 4.0]    912.289612     0.117697       [1.0]  554.640015   1.705356  -1.587658    0
# 64  2024-06-27      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-28             [8.0, 4.0]   911.074036      [1.0]  544.219971  2024-07-03             [8.0, 4.0]    911.654266     0.063686       [1.0]  551.460022   1.330354  -1.266667    0
# 65  2024-06-26      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-27             [8.0, 4.0]   910.598083      [1.0]  546.369995  2024-07-02             [8.0, 4.0]    911.376068     0.085437       [1.0]  549.010010   0.483192  -0.397755    0
# 66  2024-06-26  [15, 30, 60, 120]  sym_freq_12                        ['SHV']  2024-06-27                  [9.0]   985.487984      [1.0]  546.369995  2024-07-02                  [9.0]    986.256683     0.078002       [1.0]  549.010010   0.483192  -0.405190    0
# 67  2024-06-25      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-26             [8.0, 4.0]   910.400024      [1.0]  545.510010  2024-07-01             [8.0, 4.0]    911.217133     0.089753       [1.0]  545.340027  -0.031160   0.120913    1
# 68  2024-06-24      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-25             [8.0, 4.0]   910.479095      [1.0]  544.830017  2024-06-28             [8.0, 4.0]    911.074036     0.065344       [1.0]  544.219971  -0.111970   0.177314    1
# 69  2024-06-21      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-24             [8.0, 4.0]   910.399811      [1.0]  542.739990  2024-06-27             [8.0, 4.0]    910.598083     0.021779       [1.0]  546.369995   0.668829  -0.647051    0
# 70  2024-06-20      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-21                  [9.0]   984.952606      [1.0]  544.510010  2024-06-26                  [9.0]    985.220261     0.027174       [1.0]  545.510010   0.183651  -0.156477    0
# 71  2024-06-20      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-21                 [16.0]   945.048706      [1.0]  544.510010  2024-06-26                 [16.0]    945.048706     0.000000       [1.0]  545.510010   0.183651  -0.183651    0
# 72  2024-06-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-20                  [9.0]   984.506493      [1.0]  545.240967  2024-06-25                  [9.0]    985.220261     0.072500       [1.0]  544.830017  -0.075370   0.147870    1
# 73  2024-06-18      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-20                 [16.0]   944.416565      [1.0]  545.240967  2024-06-25                 [16.0]    945.206848     0.083680       [1.0]  544.830017  -0.075370   0.159050    1
# 74  2024-06-17      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-18                  [9.0]   984.328102      [1.0]  546.726196  2024-06-24                  [9.0]    985.041870     0.072513       [1.0]  542.739990  -0.729105   0.801618    1
# 75  2024-06-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-18                 [16.0]   944.574646      [1.0]  546.726196  2024-06-24                 [16.0]    945.206848     0.066930       [1.0]  542.739990  -0.729105   0.796034    1
# 76  2024-06-14      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-17                  [9.0]   984.060379      [1.0]  545.340637  2024-06-21                  [9.0]    984.952606     0.090668       [1.0]  544.510010  -0.152314   0.242981    1
# 77  2024-06-14      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-17                 [16.0]   944.100586      [1.0]  545.340637  2024-06-21                 [16.0]    945.048706     0.100426       [1.0]  544.510010  -0.152314   0.252739    1
# 78  2024-06-13      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-14                  [9.0]   983.971184      [1.0]  541.034607  2024-06-20                  [9.0]    984.506493     0.054403       [1.0]  545.240967   0.777466  -0.723063    0
# 79  2024-06-13      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-14                 [16.0]   943.942505      [1.0]  541.034607  2024-06-20                 [16.0]    944.416565     0.050221       [1.0]  545.240967   0.777466  -0.727245    0
# 80  2024-06-12      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']  2024-06-13       [5.0, 22.0, 3.0]   953.923727      [1.0]  540.705627  2024-06-18       [5.0, 22.0, 3.0]    926.668943    -2.857124       [1.0]  546.726196   1.113465  -3.970589    0
# 81  2024-06-11      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-12                  [9.0]   983.435806      [1.0]  539.619141  2024-06-17                  [9.0]    984.060379     0.063509       [1.0]  545.340637   1.060284  -0.996775    0
# 82  2024-06-11      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']  2024-06-12            [8.0, 31.0]   963.394181      [1.0]  539.619141  2024-06-17            [8.0, 31.0]    907.600299    -5.791387       [1.0]  545.340637   1.060284  -6.851671    0

# %%
print(sorted_df_model_perf)
# Out:
#             date  days_lookback   syms_freq                  symbols    date_buy      sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell     sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0     2024-06-10  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-06-11             [9.0]   991.620003      [1.0]  536.950012  2024-06-14             [9.0]    992.519989     0.090759       [1.0]  542.780029   1.085765  -0.995006    0
# 1     2024-06-10  [30, 60, 120]  sym_freq_8         ['FTSM', 'NVAX']  2024-06-11       [8.0, 29.0]   962.609989      [1.0]  536.950012  2024-06-14       [8.0, 29.0]    895.439985    -6.977904       [1.0]  542.780029   1.085765  -8.063670    0
# 2     2024-06-07  [30, 60, 120]  sym_freq_9                  ['SHV']  2024-06-10             [9.0]   991.529984      [1.0]  535.659973  2024-06-13             [9.0]    992.070030     0.054466       [1.0]  542.450012   1.267602  -1.213136    0
# 3     2024-06-07  [30, 60, 120]  sym_freq_8         ['FTSM', 'NVAX']  2024-06-10       [8.0, 31.0]   973.669992      [1.0]  535.659973  2024-06-13       [8.0, 31.0]    944.390002    -3.007178       [1.0]  542.450012   1.267602  -4.274781    0
# 4     2024-06-06  [30, 60, 120]  sym_freq_8  ['FTSM', 'NVAX', 'SHV']  2024-06-07  [5.0, 18.0, 3.0]   955.810005      [1.0]  534.010010  2024-06-12  [5.0, 18.0, 3.0]    914.640001    -4.307342       [1.0]  541.359985   1.376374  -5.683716    0
# ...          ...            ...         ...                      ...         ...               ...          ...        ...         ...         ...               ...           ...          ...         ...         ...        ...        ...  ...
# 1615  2018-07-16  [30, 60, 120]  sym_freq_8                 ['TNDM']  2018-07-17            [37.0]   999.000000      [3.0]  767.439194  2018-07-20            [37.0]    994.929977    -0.407410       [3.0]  765.277634  -0.281659  -0.125751    0
# 1616  2018-07-13  [30, 60, 120]  sym_freq_8                 ['TNDM']  2018-07-16            [37.0]   996.410011      [3.0]  764.347366  2018-07-19            [37.0]    984.570023    -1.188265       [3.0]  766.153336   0.236276  -1.424541    0
# 1617  2018-07-12  [30, 60, 120]  sym_freq_8                 ['TNDM']  2018-07-13            [38.0]   983.819977      [3.0]  765.031540  2018-07-18            [38.0]    993.319977     0.965624       [3.0]  769.053680   0.525748   0.439875    1
# 1618  2018-07-11  [30, 60, 120]  sym_freq_8                 ['TNDM']  2018-07-12            [39.0]   992.550030      [3.0]  764.429352  2018-07-17            [39.0]   1053.000000     6.090370       [3.0]  767.439194   0.393737   5.696633    1
# 1619  2018-07-10  [30, 60, 120]  sym_freq_8                 ['TNDM']  2018-07-11            [41.0]   997.119987      [3.0]  757.561157  2018-07-16            [41.0]   1104.130013    10.731911       [3.0]  764.347366   0.895797   9.836114    1
#
# [1620 rows x 18 columns]

# %%
# Combine DataFrames vertically and reset index
stacked_df = pd.concat([df_perf, sorted_df_model_perf], ignore_index=True)

# Reset the index to create a new, continuous index
sorted_stacked_df = sort_df_columns(stacked_df)

# Print the entire DataFrame for comprehensive inspection
print(f"Complete stacked DataFrame:\n{sorted_stacked_df}\n")
# Out:
# Complete stacked DataFrame:
#             date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0     2024-08-26  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-27        [9.0]   994.769989      [1.0]  561.559998  2024-08-30         [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 1     2024-08-23  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-26        [9.0]   994.590019      [1.0]  560.789978  2024-08-29         [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 2     2024-08-22  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-23        [9.0]   994.500000      [1.0]  562.130005  2024-08-28         [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 3     2024-08-21  [30, 60, 120]  sym_freq_9          ['SHV']  2024-08-22        [9.0]   994.049973      [1.0]  556.219971  2024-08-27         [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 4     2024-08-20  [30, 60, 120]  sym_freq_8  ['LUMN', 'SHV']  2024-08-21  [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26   [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# ...          ...            ...         ...              ...         ...          ...          ...        ...         ...         ...           ...           ...          ...         ...         ...        ...        ...  ...
# 1694  2018-07-16  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-17       [37.0]   999.000000      [3.0]  767.439194  2018-07-20        [37.0]    994.929977    -0.407410       [3.0]  765.277634  -0.281659  -0.125751    0
# 1695  2018-07-13  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-16       [37.0]   996.410011      [3.0]  764.347366  2018-07-19        [37.0]    984.570023    -1.188265       [3.0]  766.153336   0.236276  -1.424541    0
# 1696  2018-07-12  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-13       [38.0]   983.819977      [3.0]  765.031540  2018-07-18        [38.0]    993.319977     0.965624       [3.0]  769.053680   0.525748   0.439875    1
# 1697  2018-07-11  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-12       [39.0]   992.550030      [3.0]  764.429352  2018-07-17        [39.0]   1053.000000     6.090370       [3.0]  767.439194   0.393737   5.696633    1
# 1698  2018-07-10  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-11       [41.0]   997.119987      [3.0]  757.561157  2018-07-16        [41.0]   1104.130013    10.731911       [3.0]  764.347366   0.895797   9.836114    1
#
# [1699 rows x 18 columns]

# %%
# Print the first 20 rows for focused analysis
print(f"First 20 rows of stacked DataFrame:\n{sorted_stacked_df.head(20)}")
# Out:
# First 20 rows of stacked DataFrame:
#           date  days_lookback   syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell          sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2024-08-26  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998  2024-08-30                  [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 1   2024-08-23  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978  2024-08-29                  [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 2   2024-08-22  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005  2024-08-28                  [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 3   2024-08-21  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971  2024-08-27                  [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 4   2024-08-20  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26            [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# 5   2024-08-19  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012  2024-08-23            [81.0, 4.0]    946.630002     0.727820       [1.0]  562.130005   0.613924   0.113896    1
# 6   2024-08-16  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985  2024-08-22            [86.0, 4.0]    961.239985     2.600117       [1.0]  556.219971  -0.605782   3.205899    1
# 7   2024-08-15  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998  2024-08-21            [83.0, 4.0]    950.510011     0.995601       [1.0]  560.619995   1.138352  -0.142751    0
# 8   2024-08-14  [30, 60, 120]  sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007  2024-08-20       [0.0, 58.0, 3.0]    687.930017     3.894949       [1.0]  558.700012   1.017955   2.876994    1
# 9   2024-08-13  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000  2024-08-19            [88.0, 4.0]    948.400009     0.966660       [1.0]  559.609985   2.916779  -1.950119    0
# 10  2024-08-12  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978  2024-08-16                  [9.0]    993.330025     0.054397       [1.0]  554.309998   2.263674  -2.209277    0
# 11  2024-08-12  [30, 60, 120]  sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978  2024-08-16                  [1.0]    560.130005     0.126921       [1.0]  554.309998   2.263674  -2.136753    0
# 12  2024-08-09  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020  2024-08-15                  [9.0]    992.879997     0.036272       [1.0]  553.070007   3.712938  -3.676666    0
# 13  2024-08-09  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020  2024-08-15  [4.0, 0.0, 53.0, 4.0]    773.284635     7.350752       [1.0]  553.070007   3.712938   3.637814    1
# 14  2024-08-08  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990  2024-08-14                  [9.0]    992.789978     0.054420       [1.0]  543.750000   2.018801  -1.964382    0
# 15  2024-08-08  [30, 60, 120]  sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990  2024-08-14       [5.0, 59.0, 5.0]    924.807663     0.141741       [1.0]  543.750000   2.018801  -1.877061    0
# 16  2024-08-07  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024  2024-08-13                  [9.0]    992.789978     0.090734       [1.0]  542.039978   2.146415  -2.055681    0
# 17  2024-08-07  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024  2024-08-13  [4.0, 0.0, 46.0, 4.0]    706.194141    -2.158728       [1.0]  542.039978   2.146415  -4.305144    0
# 18  2024-08-06  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973  2024-08-12                  [9.0]    992.519989     0.072597       [1.0]  533.270020   2.816883  -2.744286    0
# 19  2024-08-06  [30, 60, 120]  sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973  2024-08-12                 [16.0]    953.978516     0.050134       [1.0]  533.270020   2.816883  -2.766749    0

# %%
# Save the sorted_stacked_df DataFrame to a Pickle file
pickle_dump(sorted_stacked_df, path_data_dump, fp_df_model_perf)

# Load the DataFrame from the Pickle file
df_model_perf = pickle_load(path_data_dump, fp_df_model_perf)

# Print the entire DataFrame
print(f'df_model_perf:\n{df_model_perf}\n')

# Print the first 20 rows of the DataFrame
print(f'df_model_perf.head(20):\n{df_model_perf.head(20)}')
# Out:
# df_model_perf:
#             date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0     2024-08-26  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-27        [9.0]   994.769989      [1.0]  561.559998  2024-08-30         [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 1     2024-08-23  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-26        [9.0]   994.590019      [1.0]  560.789978  2024-08-29         [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 2     2024-08-22  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-23        [9.0]   994.500000      [1.0]  562.130005  2024-08-28         [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 3     2024-08-21  [30, 60, 120]  sym_freq_9          ['SHV']  2024-08-22        [9.0]   994.049973      [1.0]  556.219971  2024-08-27         [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 4     2024-08-20  [30, 60, 120]  sym_freq_8  ['LUMN', 'SHV']  2024-08-21  [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26   [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# ...          ...            ...         ...              ...         ...          ...          ...        ...         ...         ...           ...           ...          ...         ...         ...        ...        ...  ...
# 1694  2018-07-16  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-17       [37.0]   999.000000      [3.0]  767.439194  2018-07-20        [37.0]    994.929977    -0.407410       [3.0]  765.277634  -0.281659  -0.125751    0
# 1695  2018-07-13  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-16       [37.0]   996.410011      [3.0]  764.347366  2018-07-19        [37.0]    984.570023    -1.188265       [3.0]  766.153336   0.236276  -1.424541    0
# 1696  2018-07-12  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-13       [38.0]   983.819977      [3.0]  765.031540  2018-07-18        [38.0]    993.319977     0.965624       [3.0]  769.053680   0.525748   0.439875    1
# 1697  2018-07-11  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-12       [39.0]   992.550030      [3.0]  764.429352  2018-07-17        [39.0]   1053.000000     6.090370       [3.0]  767.439194   0.393737   5.696633    1
# 1698  2018-07-10  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-11       [41.0]   997.119987      [3.0]  757.561157  2018-07-16        [41.0]   1104.130013    10.731911       [3.0]  764.347366   0.895797   9.836114    1
#
# [1699 rows x 18 columns]
#
# df_model_perf.head(20):
#           date  days_lookback   syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell          sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2024-08-26  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998  2024-08-30                  [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 1   2024-08-23  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978  2024-08-29                  [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 2   2024-08-22  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005  2024-08-28                  [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 3   2024-08-21  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971  2024-08-27                  [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 4   2024-08-20  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26            [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# 5   2024-08-19  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012  2024-08-23            [81.0, 4.0]    946.630002     0.727820       [1.0]  562.130005   0.613924   0.113896    1
# 6   2024-08-16  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985  2024-08-22            [86.0, 4.0]    961.239985     2.600117       [1.0]  556.219971  -0.605782   3.205899    1
# 7   2024-08-15  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998  2024-08-21            [83.0, 4.0]    950.510011     0.995601       [1.0]  560.619995   1.138352  -0.142751    0
# 8   2024-08-14  [30, 60, 120]  sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007  2024-08-20       [0.0, 58.0, 3.0]    687.930017     3.894949       [1.0]  558.700012   1.017955   2.876994    1
# 9   2024-08-13  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000  2024-08-19            [88.0, 4.0]    948.400009     0.966660       [1.0]  559.609985   2.916779  -1.950119    0
# 10  2024-08-12  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978  2024-08-16                  [9.0]    993.330025     0.054397       [1.0]  554.309998   2.263674  -2.209277    0
# 11  2024-08-12  [30, 60, 120]  sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978  2024-08-16                  [1.0]    560.130005     0.126921       [1.0]  554.309998   2.263674  -2.136753    0
# 12  2024-08-09  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020  2024-08-15                  [9.0]    992.879997     0.036272       [1.0]  553.070007   3.712938  -3.676666    0
# 13  2024-08-09  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020  2024-08-15  [4.0, 0.0, 53.0, 4.0]    773.284635     7.350752       [1.0]  553.070007   3.712938   3.637814    1
# 14  2024-08-08  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990  2024-08-14                  [9.0]    992.789978     0.054420       [1.0]  543.750000   2.018801  -1.964382    0
# 15  2024-08-08  [30, 60, 120]  sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990  2024-08-14       [5.0, 59.0, 5.0]    924.807663     0.141741       [1.0]  543.750000   2.018801  -1.877061    0
# 16  2024-08-07  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024  2024-08-13                  [9.0]    992.789978     0.090734       [1.0]  542.039978   2.146415  -2.055681    0
# 17  2024-08-07  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024  2024-08-13  [4.0, 0.0, 46.0, 4.0]    706.194141    -2.158728       [1.0]  542.039978   2.146415  -4.305144    0
# 18  2024-08-06  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973  2024-08-12                  [9.0]    992.519989     0.072597       [1.0]  533.270020   2.816883  -2.744286    0
# 19  2024-08-06  [30, 60, 120]  sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973  2024-08-12                 [16.0]    953.978516     0.050134       [1.0]  533.270020   2.816883  -2.766749    0

# %%
# Sort the DataFrame by 'date' in descending order (most recent first)
df_model_perf = sort_df_columns(df_model_perf)

# Reset the index to have a clean, sequential numbering
df_model_perf = df_model_perf.reset_index(drop=True)

# Print the first 20 rows to focus on the most recent data
print(f"First 20 rows:\n{df_model_perf.head(20)}")
# Out:
# First 20 rows:
#           date  days_lookback   syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell          sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0   2024-08-26  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998  2024-08-30                  [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 1   2024-08-23  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978  2024-08-29                  [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 2   2024-08-22  [30, 60, 120]  sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005  2024-08-28                  [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 3   2024-08-21  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971  2024-08-27                  [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 4   2024-08-20  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26            [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# 5   2024-08-19  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012  2024-08-23            [81.0, 4.0]    946.630002     0.727820       [1.0]  562.130005   0.613924   0.113896    1
# 6   2024-08-16  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985  2024-08-22            [86.0, 4.0]    961.239985     2.600117       [1.0]  556.219971  -0.605782   3.205899    1
# 7   2024-08-15  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998  2024-08-21            [83.0, 4.0]    950.510011     0.995601       [1.0]  560.619995   1.138352  -0.142751    0
# 8   2024-08-14  [30, 60, 120]  sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007  2024-08-20       [0.0, 58.0, 3.0]    687.930017     3.894949       [1.0]  558.700012   1.017955   2.876994    1
# 9   2024-08-13  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000  2024-08-19            [88.0, 4.0]    948.400009     0.966660       [1.0]  559.609985   2.916779  -1.950119    0
# 10  2024-08-12  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978  2024-08-16                  [9.0]    993.330025     0.054397       [1.0]  554.309998   2.263674  -2.209277    0
# 11  2024-08-12  [30, 60, 120]  sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978  2024-08-16                  [1.0]    560.130005     0.126921       [1.0]  554.309998   2.263674  -2.136753    0
# 12  2024-08-09  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020  2024-08-15                  [9.0]    992.879997     0.036272       [1.0]  553.070007   3.712938  -3.676666    0
# 13  2024-08-09  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020  2024-08-15  [4.0, 0.0, 53.0, 4.0]    773.284635     7.350752       [1.0]  553.070007   3.712938   3.637814    1
# 14  2024-08-08  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990  2024-08-14                  [9.0]    992.789978     0.054420       [1.0]  543.750000   2.018801  -1.964382    0
# 15  2024-08-08  [30, 60, 120]  sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990  2024-08-14       [5.0, 59.0, 5.0]    924.807663     0.141741       [1.0]  543.750000   2.018801  -1.877061    0
# 16  2024-08-07  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024  2024-08-13                  [9.0]    992.789978     0.090734       [1.0]  542.039978   2.146415  -2.055681    0
# 17  2024-08-07  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024  2024-08-13  [4.0, 0.0, 46.0, 4.0]    706.194141    -2.158728       [1.0]  542.039978   2.146415  -4.305144    0
# 18  2024-08-06  [30, 60, 120]  sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973  2024-08-12                  [9.0]    992.519989     0.072597       [1.0]  533.270020   2.816883  -2.744286    0
# 19  2024-08-06  [30, 60, 120]  sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973  2024-08-12                 [16.0]    953.978516     0.050134       [1.0]  533.270020   2.816883  -2.766749    0

# %%
# Filter the DataFrame to keep only rows where 'date_sell' is not null
df_model_perf_with_date_sell = df_model_perf[
    ~df_model_perf["date_sell"].isnull()
]

# Print the filtered DataFrame with a descriptive label
print(f"DataFrame with non-null 'date_sell' values:\n{df_model_perf_with_date_sell}")
# Out:
# DataFrame with non-null 'date_sell' values:
#             date  days_lookback   syms_freq          symbols    date_buy sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win
# 0     2024-08-26  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-27        [9.0]   994.769989      [1.0]  561.559998  2024-08-30         [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0
# 1     2024-08-23  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-26        [9.0]   994.590019      [1.0]  560.789978  2024-08-29         [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1
# 2     2024-08-22  [30, 60, 120]  sym_freq_8          ['SHV']  2024-08-23        [9.0]   994.500000      [1.0]  562.130005  2024-08-28         [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1
# 3     2024-08-21  [30, 60, 120]  sym_freq_9          ['SHV']  2024-08-22        [9.0]   994.049973      [1.0]  556.219971  2024-08-27         [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0
# 4     2024-08-20  [30, 60, 120]  sym_freq_8  ['LUMN', 'SHV']  2024-08-21  [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26   [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0
# ...          ...            ...         ...              ...         ...          ...          ...        ...         ...         ...           ...           ...          ...         ...         ...        ...        ...  ...
# 1694  2018-07-16  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-17       [37.0]   999.000000      [3.0]  767.439194  2018-07-20        [37.0]    994.929977    -0.407410       [3.0]  765.277634  -0.281659  -0.125751    0
# 1695  2018-07-13  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-16       [37.0]   996.410011      [3.0]  764.347366  2018-07-19        [37.0]    984.570023    -1.188265       [3.0]  766.153336   0.236276  -1.424541    0
# 1696  2018-07-12  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-13       [38.0]   983.819977      [3.0]  765.031540  2018-07-18        [38.0]    993.319977     0.965624       [3.0]  769.053680   0.525748   0.439875    1
# 1697  2018-07-11  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-12       [39.0]   992.550030      [3.0]  764.429352  2018-07-17        [39.0]   1053.000000     6.090370       [3.0]  767.439194   0.393737   5.696633    1
# 1698  2018-07-10  [30, 60, 120]  sym_freq_8         ['TNDM']  2018-07-11       [41.0]   997.119987      [3.0]  757.561157  2018-07-16        [41.0]   1104.130013    10.731911       [3.0]  764.347366   0.895797   9.836114    1
#
# [1687 rows x 18 columns]

# %% [markdown]
# #### Model Performance Not Good

# %%
"""
Calculates win rate and overall performance relative to SPY.
"""

# Count the number of wins (outperformances of SPY):
wins = df_model_perf_with_date_sell['win'].sum()  # Sum the "win" column to get the total wins

# Count the number of valid attempts (excluding missing data):
attempts = len(df_model_perf_with_date_sell['dif_%_chg'].dropna())  # Count rows with non-null values in 'dif_%_chg'

# Calculate the win rate:
win_rate = wins / attempts  # Divide wins by attempts to get the win rate

# # Print the win rate, wins, and attempts:
print(f'win_rate: {win_rate:0.6f}, wins: {wins}, attempts: {attempts}')

# # Print the overall difference in percentage change between the portfolio and SPY:
print(f'sum(df_model_perf_with_date_sell_dif_%_chg):  {df_model_perf_with_date_sell["dif_%_chg"].sum():12.6f}')
print(f'mean(df_model_perf_with_date_sell_dif_%_chg): {df_model_perf_with_date_sell["dif_%_chg"].mean():12.6f}')
# Out:
# win_rate: 0.484375, wins: 806, attempts: 1664
# sum(df_model_perf_with_date_sell_dif_%_chg):   -122.711333
# mean(df_model_perf_with_date_sell_dif_%_chg):    -0.073745

# %%
# Get today's date
today = datetime.date.today()

# Format today's date as 'yyyy-mm-dd'
today_str = today.strftime("%Y-%m-%d")

# Define the number of days back from today
n_days_back = 365 * 2
# n_days_back = 100

# Calculate the date n days back from today
previous_date_str = calculate_date_n_days_back(today, n_days_back)

# Print the result
print(f"Today: {today_str}, {n_days_back} days ago: {previous_date_str}")
# Out:
# Today: 2024-09-01, 730 days ago: 2022-09-02

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates


# Load and filter data
df = df_model_perf_with_date_sell.copy()  # Create a copy to avoid modifying the original data

# TODO
# Sort by date
# df = df.sort_values(by="date")
df = df.sort_values(by="date").reset_index(drop=True)
# TODO


# Select data between specified dates (inclusive)
date_start = previous_date_str
date_end = today_str
df = df[(df['date'] >= date_start) & (df['date'] <= date_end)]

# Calculate the rolling average
n_day_window = 20
df["Rolling Average"] = df["dif_%_chg"].rolling(window=n_day_window).mean()

# Convert date column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the data and rolling average
plt.plot(df["date"], df["dif_%_chg"], label="dif_%_chg")
plt.plot(df["date"], df["Rolling Average"], label=f"{n_day_window}-day Rolling Average")

# Customize the plot
plt.xlabel("Date")
plt.ylabel("% Portf. Change - % SPY Change")
plt.title(f"% Portf. Change - % SPY Change, N-Day Rolling Average (n={n_day_window})")

# Set major tick locations to monthly intervals
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))

# Format date labels
date_form = mdates.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(date_form)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust spacing for better fit

plt.legend()
plt.grid(True)
plt.show()

# %%
print(df.tail(100))
# Out:
#            date      days_lookback    syms_freq                        symbols    date_buy           sh_portf_buy  $_portf_buy sh_SPY_buy   $_SPY_buy   date_sell          sh_portf_sell  $_portf_sell  %_portf_chg sh_SPY_sell  $_SPY_sell  %_SPY_chg  dif_%_chg  win  Rolling Average
# 1587 2024-05-17      [30, 60, 120]   sym_freq_8                         ['PI']  2024-05-20                  [5.0]   848.050003      [1.0]  530.059998  2024-05-23                  [5.0]    842.450027    -0.660336       [1.0]  525.960022  -0.773493   0.113157    1        -0.795466
# 1588 2024-05-17      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-05-20                  [9.0]   993.059967      [1.0]  530.059998  2024-05-23                  [9.0]    993.825027     0.077041       [1.0]  525.960022  -0.773493   0.850533    1        -0.697338
# 1589 2024-05-20      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-05-21                  [9.0]   993.149986      [1.0]  531.359985  2024-05-24                  [9.0]    993.960022     0.081562       [1.0]  529.440002  -0.361334   0.442896    1        -0.619313
# 1590 2024-05-21      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-05-22                 [16.0]   956.159973      [1.0]  529.830017  2024-05-28                 [16.0]    956.799988     0.066936       [1.0]  529.809998  -0.003778   0.070714    1        -0.583447
# 1591 2024-05-21      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-05-22                  [9.0]   993.330025      [1.0]  529.830017  2024-05-28                  [9.0]    993.870003     0.054360       [1.0]  529.809998  -0.003778   0.058139    1        -0.548873
# 1592 2024-05-22      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-05-23                 [16.0]   956.320007      [1.0]  525.960022  2024-05-29                 [16.0]    956.799988     0.050190       [1.0]  526.099976   0.026609   0.023581    1        -0.515552
# 1593 2024-05-22      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-05-23                  [9.0]   993.870003      [1.0]  525.960022  2024-05-29                  [9.0]    993.960022     0.009057       [1.0]  526.099976   0.026609  -0.017552    0        -0.484098
# 1594 2024-05-23      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-05-24                  [9.0]   989.714699      [1.0]  529.440002  2024-05-30                  [9.0]    989.983589     0.027168       [1.0]  522.609985  -1.290046   1.317214    1        -0.385208
# 1595 2024-05-24      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-05-28                  [9.0]   989.625092      [1.0]  529.809998  2024-05-31                  [9.0]    990.342018     0.072444       [1.0]  527.369995  -0.460543   0.532987    1        -0.331823
# 1596 2024-05-28      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-05-29             [8.0, 4.0]   916.273193      [1.0]  526.099976  2024-06-03             [8.0, 4.0]    917.279999     0.109880       [1.0]  527.799988   0.323135  -0.213254    0        -0.314668
# 1597 2024-05-29      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-05-30                  [9.0]   989.983589      [1.0]  522.609985  2024-06-04                  [9.0]    990.720016     0.074388       [1.0]  528.390015   1.105993  -1.031605    0        -0.284301
# 1598 2024-05-30      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-05-31                  [9.0]   990.342018      [1.0]  527.369995  2024-06-05                  [9.0]    990.809967     0.047251       [1.0]  534.669983   1.384225  -1.336974    0        -0.268048
# 1599 2024-05-31      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-06-03                  [9.0]   990.539978      [1.0]  527.799988  2024-06-06                  [9.0]    991.080025     0.054520       [1.0]  534.659973   1.299732  -1.245212    0        -0.259820
# 1600 2024-06-03      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-06-04                  [9.0]   990.720016      [1.0]  528.390015  2024-06-07                  [9.0]    991.350014     0.063590       [1.0]  534.010010   1.063607  -1.000018    0        -0.238319
# 1601 2024-06-04      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-06-05             [8.0, 4.0]   917.719971      [1.0]  534.669983  2024-06-10             [8.0, 4.0]    918.039978     0.034870       [1.0]  535.659973   0.185159  -0.150289    0        -0.188746
# 1602 2024-06-05      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']  2024-06-06       [5.0, 17.0, 3.0]   961.280001      [1.0]  534.659973  2024-06-11       [5.0, 17.0, 3.0]    913.349995    -4.986061       [1.0]  536.950012   0.428317  -5.414378    0        -0.404332
# 1603 2024-06-06      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']  2024-06-07       [5.0, 18.0, 3.0]   955.810005      [1.0]  534.010010  2024-06-12       [5.0, 18.0, 3.0]    914.640001    -4.307342       [1.0]  541.359985   1.376374  -5.683716    0        -0.689049
# 1604 2024-06-07      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']  2024-06-10            [8.0, 31.0]   973.669992      [1.0]  535.659973  2024-06-13            [8.0, 31.0]    944.390002    -3.007178       [1.0]  542.450012   1.267602  -4.274781    0        -0.854857
# 1605 2024-06-07      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-10                  [9.0]   991.529984      [1.0]  535.659973  2024-06-13                  [9.0]    992.070030     0.054466       [1.0]  542.450012   1.267602  -1.213136    0        -0.909907
# 1606 2024-06-10      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']  2024-06-11            [8.0, 29.0]   962.609989      [1.0]  536.950012  2024-06-14            [8.0, 29.0]    895.439985    -6.977904       [1.0]  542.780029   1.085765  -8.063670    0        -1.311768
# 1607 2024-06-10      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-11                  [9.0]   991.620003      [1.0]  536.950012  2024-06-14                  [9.0]    992.519989     0.090759       [1.0]  542.780029   1.085765  -0.995006    0        -1.367176
# 1608 2024-06-11      [30, 60, 120]   sym_freq_8               ['FTSM', 'NVAX']  2024-06-12            [8.0, 31.0]   963.394181      [1.0]  539.619141  2024-06-17            [8.0, 31.0]    907.600299    -5.791387       [1.0]  545.340637   1.060284  -6.851671    0        -1.752286
# 1609 2024-06-11      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-12                  [9.0]   983.435806      [1.0]  539.619141  2024-06-17                  [9.0]    984.060379     0.063509       [1.0]  545.340637   1.060284  -0.996775    0        -1.824270
# 1610 2024-06-12      [30, 60, 120]   sym_freq_8        ['FTSM', 'NVAX', 'SHV']  2024-06-13       [5.0, 22.0, 3.0]   953.923727      [1.0]  540.705627  2024-06-18       [5.0, 22.0, 3.0]    926.668943    -2.857124       [1.0]  546.726196   1.113465  -3.970589    0        -2.026335
# 1611 2024-06-13      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-14                  [9.0]   983.971184      [1.0]  541.034607  2024-06-20                  [9.0]    984.506493     0.054403       [1.0]  545.240967   0.777466  -0.723063    0        -2.065395
# 1612 2024-06-13      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-14                 [16.0]   943.942505      [1.0]  541.034607  2024-06-20                 [16.0]    944.416565     0.050221       [1.0]  545.240967   0.777466  -0.727245    0        -2.102937
# 1613 2024-06-14      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-17                  [9.0]   984.060379      [1.0]  545.340637  2024-06-21                  [9.0]    984.952606     0.090668       [1.0]  544.510010  -0.152314   0.242981    1        -2.089910
# 1614 2024-06-14      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-17                 [16.0]   944.100586      [1.0]  545.340637  2024-06-21                 [16.0]    945.048706     0.100426       [1.0]  544.510010  -0.152314   0.252739    1        -2.143134
# 1615 2024-06-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-18                 [16.0]   944.574646      [1.0]  546.726196  2024-06-24                 [16.0]    945.206848     0.066930       [1.0]  542.739990  -0.729105   0.796034    1        -2.129981
# 1616 2024-06-17      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-18                  [9.0]   984.328102      [1.0]  546.726196  2024-06-24                  [9.0]    985.041870     0.072513       [1.0]  542.739990  -0.729105   0.801618    1        -2.079238
# 1617 2024-06-18      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-20                 [16.0]   944.416565      [1.0]  545.240967  2024-06-25                 [16.0]    945.206848     0.083680       [1.0]  544.830017  -0.075370   0.159050    1        -2.019705
# 1618 2024-06-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-20                  [9.0]   984.506493      [1.0]  545.240967  2024-06-25                  [9.0]    985.220261     0.072500       [1.0]  544.830017  -0.075370   0.147870    1        -1.945463
# 1619 2024-06-20      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-06-21                 [16.0]   945.048706      [1.0]  544.510010  2024-06-26                 [16.0]    945.048706     0.000000       [1.0]  545.510010   0.183651  -0.183651    0        -1.892385
# 1620 2024-06-20      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-06-21                  [9.0]   984.952606      [1.0]  544.510010  2024-06-26                  [9.0]    985.220261     0.027174       [1.0]  545.510010   0.183651  -0.156477    0        -1.850208
# 1621 2024-06-21      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-24             [8.0, 4.0]   910.399811      [1.0]  542.739990  2024-06-27             [8.0, 4.0]    910.598083     0.021779       [1.0]  546.369995   0.668829  -0.647051    0        -1.875046
# 1622 2024-06-24      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-25             [8.0, 4.0]   910.479095      [1.0]  544.830017  2024-06-28             [8.0, 4.0]    911.074036     0.065344       [1.0]  544.219971  -0.111970   0.177314    1        -1.595461
# 1623 2024-06-25      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-26             [8.0, 4.0]   910.400024      [1.0]  545.510010  2024-07-01             [8.0, 4.0]    911.217133     0.089753       [1.0]  545.340027  -0.031160   0.120913    1        -1.305230
# 1624 2024-06-26      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-27             [8.0, 4.0]   910.598083      [1.0]  546.369995  2024-07-02             [8.0, 4.0]    911.376068     0.085437       [1.0]  549.010010   0.483192  -0.397755    0        -1.111378
# 1625 2024-06-26  [15, 30, 60, 120]  sym_freq_12                        ['SHV']  2024-06-27                  [9.0]   985.487984      [1.0]  546.369995  2024-07-02                  [9.0]    986.256683     0.078002       [1.0]  549.010010   0.483192  -0.405190    0        -1.070981
# 1626 2024-06-27      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-06-28             [8.0, 4.0]   911.074036      [1.0]  544.219971  2024-07-03             [8.0, 4.0]    911.654266     0.063686       [1.0]  551.460022   1.330354  -1.266667    0        -0.731131
# 1627 2024-06-28      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-01             [8.0, 4.0]   911.217133      [1.0]  545.340027  2024-07-05             [8.0, 4.0]    912.289612     0.117697       [1.0]  554.640015   1.705356  -1.587658    0        -0.760764
# 1628 2024-07-01      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-02             [8.0, 4.0]   911.376068      [1.0]  549.010010  2024-07-08             [8.0, 4.0]    912.329712     0.104638       [1.0]  555.280029   1.142059  -1.037421    0        -0.470051
# 1629 2024-07-02      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-03             [8.0, 4.0]   911.654266      [1.0]  551.460022  2024-07-09             [8.0, 4.0]    912.488403     0.091497       [1.0]  555.820007   0.790626  -0.699129    0        -0.455169
# 1630 2024-07-03      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-05             [8.0, 4.0]   912.289612      [1.0]  554.640015  2024-07-10             [8.0, 4.0]    912.607574     0.034853       [1.0]  561.320007   1.204383  -1.169530    0        -0.315116
# 1631 2024-07-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-07-08             [8.0, 4.0]   912.329712      [1.0]  555.280029  2024-07-11             [8.0, 4.0]    912.885773     0.060950       [1.0]  556.479980   0.216098  -0.155149    0        -0.286720
# 1632 2024-07-08      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-09                 [16.0]   947.507751      [1.0]  555.820007  2024-07-12                 [16.0]    948.777283     0.133986       [1.0]  559.989990   0.750240  -0.616253    0        -0.281171
# 1633 2024-07-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-09                  [9.0]   987.152687      [1.0]  555.820007  2024-07-12                  [9.0]    988.048691     0.090766       [1.0]  559.989990   0.750240  -0.659473    0        -0.326293
# 1634 2024-07-09      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-10                 [16.0]   947.666443      [1.0]  561.320007  2024-07-15                 [16.0]    948.935913     0.133957       [1.0]  561.530029   0.037416   0.096542    1        -0.334103
# 1635 2024-07-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-10                  [9.0]   987.242294      [1.0]  561.320007  2024-07-15                  [9.0]    988.227974     0.099842       [1.0]  561.530029   0.037416   0.062426    1        -0.370784
# 1636 2024-07-10      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-11                 [16.0]   947.983887      [1.0]  556.479980  2024-07-16                 [16.0]    948.935913     0.100426       [1.0]  564.859985   1.505895  -1.405469    0        -0.481138
# 1637 2024-07-10      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-11                  [9.0]   987.511116      [1.0]  556.479980  2024-07-16                  [9.0]    988.317581     0.081666       [1.0]  564.859985   1.505895  -1.424229    0        -0.560302
# 1638 2024-07-11      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-12             [4.0, 4.0]   932.812744      [1.0]  559.989990  2024-07-17             [4.0, 4.0]    925.732056    -0.759069       [1.0]  556.940002  -0.544650  -0.214418    0        -0.578416
# 1639 2024-07-11  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-12                  [8.0]   987.359985      [1.0]  559.989990  2024-07-17                  [8.0]    972.880005    -1.466535       [1.0]  556.940002  -0.544650  -0.921885    0        -0.615328
# 1640 2024-07-11      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-12                 [16.0]   948.777283      [1.0]  559.989990  2024-07-17                 [16.0]    949.094604     0.033445       [1.0]  556.940002  -0.544650   0.578096    1        -0.578599
# 1641 2024-07-12  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-15                  [8.0]   985.520020      [1.0]  561.530029  2024-07-18                  [8.0]    925.919983    -6.047572       [1.0]  552.659973  -1.579623  -4.467950    0        -0.769644
# 1642 2024-07-12      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-15                 [16.0]   948.935913      [1.0]  561.530029  2024-07-18                 [16.0]    949.253296     0.033446       [1.0]  552.659973  -1.579623   1.613069    1        -0.697857
# 1643 2024-07-12      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-15             [4.0, 4.0]   931.972443      [1.0]  561.530029  2024-07-18             [4.0, 4.0]    902.331726    -3.180428       [1.0]  552.659973  -1.579623  -1.600806    0        -0.783942
# 1644 2024-07-15  [15, 30, 60, 120]  sym_freq_12                       ['LNTH']  2024-07-16                  [8.0]   946.400024      [1.0]  564.859985  2024-07-19                  [8.0]    934.320007    -1.276418       [1.0]  548.989990  -2.809545   1.533127    1        -0.687398
# 1645 2024-07-15      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-16                 [16.0]   948.935913      [1.0]  564.859985  2024-07-19                 [16.0]    949.253296     0.033446       [1.0]  548.989990  -2.809545   2.842991    1        -0.524989
# 1646 2024-07-15      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-16             [4.0, 4.0]   912.452271      [1.0]  564.859985  2024-07-19             [4.0, 4.0]    906.770660    -0.622675       [1.0]  548.989990  -2.809545   2.186870    1        -0.352312
# 1647 2024-07-16      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-17                 [16.0]   949.094604      [1.0]  556.940002  2024-07-22                 [16.0]    949.570679     0.050161       [1.0]  554.650024  -0.411171   0.461332    1        -0.249863
# 1648 2024-07-16      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-17                  [9.0]   988.407120      [1.0]  556.940002  2024-07-22                  [9.0]    989.213585     0.081592       [1.0]  554.650024  -0.411171   0.492764    1        -0.173354
# 1649 2024-07-17      [30, 60, 120]   sym_freq_9                ['LNTH', 'SHV']  2024-07-18             [4.0, 4.0]   902.331726      [1.0]  552.659973  2024-07-23             [4.0, 4.0]    901.810120    -0.057807       [1.0]  553.780029   0.202666  -0.260473    0        -0.151421
# 1650 2024-07-17      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-07-18                 [16.0]   949.253296      [1.0]  552.659973  2024-07-23                 [16.0]    949.570679     0.033435       [1.0]  553.780029   0.202666  -0.169231    0        -0.101406
# 1651 2024-07-18      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-19                  [9.0]   989.123978      [1.0]  548.989990  2024-07-24                  [9.0]    989.482407     0.036237       [1.0]  541.229980  -1.413507   1.449744    1        -0.021161
# 1652 2024-07-18      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-19             [8.0, 4.0]   941.786652      [1.0]  548.989990  2024-07-24             [8.0, 4.0]    929.663361    -1.287265       [1.0]  541.229980  -1.413507   0.126241    1         0.015963
# 1653 2024-07-19      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-22             [8.0, 4.0]   933.505341      [1.0]  554.650024  2024-07-25             [8.0, 4.0]    926.823334    -0.715797       [1.0]  538.409973  -2.927982   2.212184    1         0.159546
# 1654 2024-07-19      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-22                  [9.0]   989.213585      [1.0]  554.650024  2024-07-25                  [9.0]    989.572014     0.036234       [1.0]  538.409973  -2.927982   2.964215    1         0.302930
# 1655 2024-07-22      [30, 60, 120]   sym_freq_8               ['FTSM', 'LNTH']  2024-07-23             [8.0, 4.0]   936.865326      [1.0]  553.780029  2024-07-26             [8.0, 4.0]    926.260040    -1.131997       [1.0]  544.440002  -1.686595   0.554598    1         0.327539
# 1656 2024-07-22      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-07-23                  [9.0]   989.392799      [1.0]  553.780029  2024-07-26                  [9.0]    990.109589     0.072447       [1.0]  544.440002  -1.686595   1.759042    1         0.485764
# 1657 2024-07-23      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-24             [8.0, 4.0]   914.793304      [1.0]  541.229980  2024-07-29             [8.0, 4.0]    915.627747     0.091216       [1.0]  544.760010   0.652224  -0.561007    0         0.528925
# 1658 2024-07-24      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-25             [8.0, 4.0]   914.833130      [1.0]  538.409973  2024-07-30             [8.0, 4.0]    915.667572     0.091212       [1.0]  542.000000   0.666783  -0.575571    0         0.510868
# 1659 2024-07-25      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-26             [8.0, 4.0]   915.468750      [1.0]  544.440002  2024-07-31             [8.0, 4.0]    916.002228     0.058274       [1.0]  550.809998   1.170009  -1.111735    0         0.501375
# 1660 2024-07-26      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-29             [8.0, 4.0]   915.627747      [1.0]  544.760010  2024-08-01             [8.0, 4.0]    916.273560     0.070532       [1.0]  543.010010  -0.321242   0.391775    1         0.492059
# 1661 2024-07-29      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-30             [8.0, 4.0]   915.667572      [1.0]  542.000000  2024-08-02             [8.0, 4.0]    917.470245     0.196870       [1.0]  532.900024  -1.678962   1.875832    1         0.809248
# 1662 2024-07-30      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-07-31             [8.0, 4.0]   916.002228      [1.0]  550.809998  2024-08-05             [8.0, 4.0]    917.709259     0.186357       [1.0]  517.380005  -6.069242   6.255599    1         1.041375
# 1663 2024-07-31      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-01             [8.0, 4.0]   916.273560      [1.0]  543.010010  2024-08-06             [8.0, 4.0]    917.390594     0.121911       [1.0]  522.150024  -3.841547   3.963458    1         1.319588
# 1664 2024-08-01      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-02             [8.0, 4.0]   917.470245      [1.0]  532.900024  2024-08-07             [8.0, 4.0]    917.550232     0.008718       [1.0]  518.659973  -2.672181   2.680899    1         1.376976
# 1665 2024-08-02      [30, 60, 120]   sym_freq_8                ['FTSM', 'SHV']  2024-08-05             [8.0, 4.0]   917.709259      [1.0]  517.380005  2024-08-08             [8.0, 4.0]    917.510590    -0.021648       [1.0]  530.650024   2.564850  -2.586498    0         1.105502
# 1666 2024-08-05      [30, 60, 120]   sym_freq_9                ['FTSM', 'SHV']  2024-08-06             [8.0, 4.0]   917.390594      [1.0]  522.150024  2024-08-09             [8.0, 4.0]    917.829895     0.047886       [1.0]  532.989990   2.076025  -2.028139    0         0.894751
# 1667 2024-08-06      [30, 60, 120]   sym_freq_8                       ['FTSM']  2024-08-07                 [16.0]   953.500488      [1.0]  518.659973  2024-08-12                 [16.0]    953.978516     0.050134       [1.0]  533.270020   2.816883  -2.766749    0         0.733347
# 1668 2024-08-06      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-07                  [9.0]   991.799973      [1.0]  518.659973  2024-08-12                  [9.0]    992.519989     0.072597       [1.0]  533.270020   2.816883  -2.744286    0         0.571495
# 1669 2024-08-07      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-08  [4.0, 0.0, 46.0, 4.0]   721.775309      [1.0]  530.650024  2024-08-13  [4.0, 0.0, 46.0, 4.0]    706.194141    -2.158728       [1.0]  542.039978   2.146415  -4.305144    0         0.369261
# 1670 2024-08-07      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-08                  [9.0]   991.889992      [1.0]  530.650024  2024-08-13                  [9.0]    992.789978     0.090734       [1.0]  542.039978   2.146415  -2.055681    0         0.274939
# 1671 2024-08-08      [30, 60, 120]   sym_freq_8        ['FTSM', 'LUMN', 'VTR']  2024-08-09       [5.0, 59.0, 5.0]   923.498689      [1.0]  532.989990  2024-08-14       [5.0, 59.0, 5.0]    924.807663     0.141741       [1.0]  543.750000   2.018801  -1.877061    0         0.108599
# 1672 2024-08-08      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-09                  [9.0]   992.250000      [1.0]  532.989990  2024-08-14                  [9.0]    992.789978     0.054420       [1.0]  543.750000   2.018801  -1.964382    0         0.004067
# 1673 2024-08-09      [30, 60, 120]   sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...  2024-08-12  [4.0, 0.0, 53.0, 4.0]   720.334620      [1.0]  533.270020  2024-08-15  [4.0, 0.0, 53.0, 4.0]    773.284635     7.350752       [1.0]  553.070007   3.712938   3.637814    1         0.075349
# 1674 2024-08-09      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-12                  [9.0]   992.519989      [1.0]  533.270020  2024-08-15                  [9.0]    992.879997     0.036272       [1.0]  553.070007   3.712938  -3.676666    0        -0.256695
# 1675 2024-08-12      [30, 60, 120]   sym_freq_8                        ['LMT']  2024-08-13                  [1.0]   559.419983      [1.0]  542.039978  2024-08-16                  [1.0]    560.130005     0.126921       [1.0]  554.309998   2.263674  -2.136753    0        -0.391263
# 1676 2024-08-12      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-13                  [9.0]   992.789978      [1.0]  542.039978  2024-08-16                  [9.0]    993.330025     0.054397       [1.0]  554.309998   2.263674  -2.209277    0        -0.589679
# 1677 2024-08-13      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-14            [88.0, 4.0]   939.319977      [1.0]  543.750000  2024-08-19            [88.0, 4.0]    948.400009     0.966660       [1.0]  559.609985   2.916779  -1.950119    0        -0.659134
# 1678 2024-08-14      [30, 60, 120]   sym_freq_8         ['LMT', 'LUMN', 'SHV']  2024-08-15       [0.0, 58.0, 3.0]   662.140001      [1.0]  553.070007  2024-08-20       [0.0, 58.0, 3.0]    687.930017     3.894949       [1.0]  558.700012   1.017955   2.876994    1        -0.486506
# 1679 2024-08-15      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-16            [83.0, 4.0]   941.140009      [1.0]  554.309998  2024-08-21            [83.0, 4.0]    950.510011     0.995601       [1.0]  560.619995   1.138352  -0.142751    0        -0.438057
# 1680 2024-08-16      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-19            [86.0, 4.0]   936.880009      [1.0]  559.609985  2024-08-22            [86.0, 4.0]    961.239985     2.600117       [1.0]  556.219971  -0.605782   3.205899    1        -0.297351
# 1681 2024-08-19      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-20            [81.0, 4.0]   939.790022      [1.0]  558.700012  2024-08-23            [81.0, 4.0]    946.630002     0.727820       [1.0]  562.130005   0.613924   0.113896    1        -0.385447
# 1682 2024-08-20      [30, 60, 120]   sym_freq_8                ['LUMN', 'SHV']  2024-08-21            [81.0, 4.0]   938.250010      [1.0]  560.619995  2024-08-26            [81.0, 4.0]    937.759999    -0.052226       [1.0]  560.789978   0.030321  -0.082547    0        -0.702355
# 1683 2024-08-21      [30, 60, 120]   sym_freq_9                        ['SHV']  2024-08-22                  [9.0]   994.049973      [1.0]  556.219971  2024-08-27                  [9.0]    994.769989     0.072433       [1.0]  561.559998   0.960057  -0.887624    0        -0.944909
# 1684 2024-08-22      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-23                  [9.0]   994.500000      [1.0]  562.130005  2024-08-28                  [9.0]    994.950027     0.045252       [1.0]  558.299988  -0.681340   0.726592    1        -1.042624
# 1685 2024-08-23      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-26                  [9.0]   994.590019      [1.0]  560.789978  2024-08-29                  [9.0]    995.039978     0.045241       [1.0]  558.349976  -0.435101   0.480342    1        -0.889282
# 1686 2024-08-26      [30, 60, 120]   sym_freq_8                        ['SHV']  2024-08-27                  [9.0]   994.769989      [1.0]  561.559998  2024-08-30                  [9.0]    995.399986     0.063331       [1.0]  563.679993   0.377519  -0.314188    0        -0.803585
