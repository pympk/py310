# %%
import pandas as pd

import pprint

from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import eval_grp_top_syms_n_freq
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq

pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"

path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = "df_close_clean"

# %% [markdown]
# ### Run below cell for Colab

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
run_type = "train"
# run_type = 'validate'
# run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
# days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
# days_eval = 4
days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
# https://www.calculator.net/sample-size-calculator.html?type=1&cl=95&ci=5&pp=50&ps=&x=Calculate
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
# syms_start = 1, syms_end = 11 will keep the 2nd to 11th best performing symbols  
syms_start = 0
syms_end = 10


##########################################################
fp_df_eval_results = f"df_eval_results_{run_type}"
# fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
# delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
print(f'path_data_dump: {path_data_dump}')
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"filename of run results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# path_data_dump: C:/Users/ping/MyDrive/stocks/yfinance/VSCode_dump/
# verbose : True
# store_results: True
# run_type: train
# n_samples: 2
# days_lookbacks: [15, 30, 60]
# days_eval: 5
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# filename of run results: df_eval_results_train

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
random_max_lookback_tuples = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
list_random_lookback_slices = lookback_slices(
    max_slices=random_max_lookback_tuples, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: train, df.tail(3):
#                      A         AA    AAL         AAP        AAPL         AB        ABBV        ABR         ABT       ACGL       ACHC       ACIW       ACLS   ACRS        ADBE  ...        XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION          ZS        ZTO         ZTS       ZUMZ        ZWS
# Date                                                                                                                                                                           ...
# 2022-06-10  119.104561  51.959156  14.71  170.152206  135.779831  37.530380  133.712997  12.373527  105.989700  45.230000  68.230003  27.059999  57.840000  14.44  393.839996  ...  78.412560  29.610001  110.685379  42.082466  29.880020  111.580818  305.350006  73.040001  35.610001  49.004021  153.610001  25.319897  159.037674  28.860001  27.888142
# 2022-06-13  114.866692  48.851997  13.32  163.286560  130.581512  35.392025  130.183395  11.371590  102.393250  43.990002  65.860001  26.000000  54.220001  12.94  371.649994  ...  75.301102  27.629999  107.473473  37.968472  28.316055  108.352867  293.079987  69.639999  32.220001  47.425945  140.979996  24.411736  153.601501  28.459999  26.857790
# 2022-06-14  114.599976  47.950237  12.95  162.613266  131.452866  35.217464  128.502655  10.866549   99.521858  44.549999  63.689999  26.020000  55.580002  13.99  370.820007  ...  74.851028  27.780001  106.641464  39.726002  28.425806  103.599510  300.739990  69.580002  30.219999  48.103592  142.110001  24.431479  155.403732  28.230000  27.387684
#
# [3 rows x 1264 columns]
#
# run_type: train, len(df): 1050
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"days_lookbacks: {days_lookbacks}")
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of random_max_lookback_tuples is equal to n_samples = {n_samples}")
    print(f"The {n_samples} random_max_lookback_tuples:\n{random_max_lookback_tuples}\n")
    print(f"list_random_lookback_slice has {n_samples} lists corresponds to:\n - n_samples = {n_samples}\n - days_lookbacks: {days_lookbacks}\n - days_eval: {days_eval}")
    print(f"list_random_lookback_slices:\n{list_random_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the random_max_lookback_tuples. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in random_max_lookback_tuples. There are as many sub-lists as there are tuples in random_max_lookback_tuples.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, list_random_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# # #### print the best performing symbols for each set in list_random_lookback_slices
# for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
#     l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
#     if verbose:
#         print(f"random_max_lookback_tuples:      {random_max_lookback_tuples}")
#         # print(f'set_lookback_slices: {list_random_lookback_slices[i]}\n')
#         print(
#             f"set_lookback_slices {i + 1} of {len(list_random_lookback_slices):>3}:    {list_random_lookback_slices[i]}\n"
#         )
#         print(f"max_days_lookbacks:              {max_days_lookbacks}")
#         print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
#         print(f"days_lookbacks:                  {days_lookbacks}")
#         print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
#         print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
#         print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
#         print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
#         print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
#         print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
#         print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
#         print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
#         print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
#         print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
#         print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
#         print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
#         print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
#         print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# # #### Evaluate performance of symbols in set_lookback_slices versus SPY
# l_row_add_total = eval_grp_top_syms_n_freq(
#     df, random_max_lookback_tuples, list_random_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
# )

# for row_add_total in l_row_add_total:
#     print(f"row_add_total: {row_add_total}")

# if store_results:  # record results to df
#     df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
#     print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

#     for row_add_total in l_row_add_total:
#         # print(f'row_add_total: {row_add_total}')
#         df_eval_results.loc[len(df_eval_results)] = row_add_total
#         print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

#     pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
#     print(f"Save results to: {fp_df_eval_results}")
#     df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
#     print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# days_lookbacks: [15, 30, 60]
# max_days_lookbacks: 60
# number of random_max_lookback_tuples is equal to n_samples = 2
# The 2 random_max_lookback_tuples:
# [(653, 713, 718), (694, 754, 759)]
#
# list_random_lookback_slice has 2 lists corresponds to:
#  - n_samples = 2
#  - days_lookbacks: [15, 30, 60]
#  - days_eval: 5
# list_random_lookback_slices:
# [[(698, 713, 718), (683, 713, 718), (653, 713, 718)], [(739, 754, 759), (724, 754, 759), (694, 754, 759)]]
#
# days_lookbacks: [15, 30, 60]
# number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): 3
#
# ########## 1 of 2 lb_slices: [(698, 713, 718), (683, 713, 718), (653, 713, 718)] in list_random_lookback_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(698, 713, 718), (683, 713, 718), (653, 713, 718)]
# lb_slice:            (698, 713, 718)
# days eval:           5
# iloc_start_train:    698
# iloc_end_train:      713
# date_start_df_train: 2021-01-22
# date_end_df_train:   2021-02-11
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['NVAX', 'MARA', 'AVXL', 'PERI', 'CPE', 'YY', 'BTC-USD', 'ETH-USD',
#        'IAC', 'STAA', 'STNG', 'ERF', 'NWS', 'NWSA', 'GBTC', 'WDC', 'WB',
#        'PRFT', 'DNOW', 'STKL'], dtype=object), 'r_CAGR/retnStd': array(['NVAX', 'AVXL', 'MARA', 'PERI', 'CPE', 'YY', 'ETH-USD', 'BTC-USD',
#        'ERF', 'WB', 'GBTC', 'IAC', 'STNG', 'STAA', 'BBW', 'NWS', 'SM',
#        'SSYS', 'NWSA', 'GPRE'], dtype=object), 'r_retnStd/UI': array(['MYI', 'NVAX', 'PRFT', 'NWS', 'STAA', 'NMZ', 'IAC', 'MARA', 'CVLT',
#        'STNG', 'NWSA', 'CPE', 'HAFC', 'BX', 'WDC', 'SCVL', 'BSM', 'YY',
#        'DNOW', 'STKL'], dtype=object)}}
# most_freq_syms: [('NVAX', 3), ('MARA', 3), ('CPE', 3), ('YY', 3), ('IAC', 3), ('STAA', 3), ('STNG', 3), ('NWS', 3), ('NWSA', 3), ('AVXL', 2), ('PERI', 2), ('BTC-USD', 2), ('ETH-USD', 2), ('ERF', 2), ('GBTC', 2), ('WDC', 2), ('WB', 2), ('PRFT', 2), ('DNOW', 2), ('STKL', 2), ('BBW', 1), ('SM', 1), ('SSYS', 1), ('GPRE', 1), ('MYI', 1), ('NMZ', 1), ('CVLT', 1), ('HAFC', 1), ('BX', 1), ('SCVL', 1), ('BSM', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(698, 713, 718), (683, 713, 718), (653, 713, 718)]
# lb_slice:            (683, 713, 718)
# days eval:           5
# iloc_start_train:    683
# iloc_end_train:      713
# date_start_df_train: 2020-12-30
# date_end_df_train:   2021-02-11
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['ACRS', 'MARA', 'NVAX', 'SSYS', 'ETH-USD', 'AVXL', 'GME', 'DQ',
#        'YY', 'GPRE', 'HY', 'BSM', 'SPWR', 'STAA', 'PERI', 'PLUG', 'SM',
#        'AXON', 'LNTH', 'PI'], dtype=object), 'r_CAGR/retnStd': array(['MARA', 'ACRS', 'SSYS', 'NVAX', 'ETH-USD', 'AVXL', 'GME', 'DQ',
#        'SM', 'GPRE', 'SPWR', 'YY', 'PERI', 'PLUG', 'HY', 'AXON', 'UNFI',
#        'LNTH', 'PI', 'VCEL'], dtype=object), 'r_retnStd/UI': array(['ACRS', 'NVAX', 'BSM', 'SSYS', 'YY', 'STAA', 'HY', 'AVXL', 'CVLT',
#        'MFIC', 'GPRE', 'IAC', 'EXTR', 'ETH-USD', 'HBI', 'CPRX', 'HAFC',
#        'PTC', 'MTZ', 'EBS'], dtype=object)}}
# most_freq_syms: [('ACRS', 3), ('NVAX', 3), ('SSYS', 3), ('ETH-USD', 3), ('AVXL', 3), ('YY', 3), ('GPRE', 3), ('HY', 3), ('MARA', 2), ('GME', 2), ('DQ', 2), ('BSM', 2), ('SPWR', 2), ('STAA', 2), ('PERI', 2), ('PLUG', 2), ('SM', 2), ('AXON', 2), ('LNTH', 2), ('PI', 2), ('UNFI', 1), ('VCEL', 1), ('CVLT', 1), ('MFIC', 1), ('IAC', 1), ('EXTR', 1), ('HBI', 1), ('CPRX', 1), ('HAFC', 1), ('PTC', 1), ('MTZ', 1), ('EBS', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(698, 713, 718), (683, 713, 718), (653, 713, 718)]
# lb_slice:            (653, 713, 718)
# days eval:           5
# iloc_start_train:    653
# iloc_end_train:      713
# date_start_df_train: 2020-11-16
# date_end_df_train:   2021-02-11
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['CHRD', 'MARA', 'ACRS', 'SSYS', 'SM', 'ETH-USD', 'PERI', 'NVAX',
#        'GME', 'IPI', 'IAC', 'CPE', 'DQ', 'BTC-USD', 'PLCE', 'PLUG',
#        'ATKR', 'WBD', 'SPWR', 'APPS'], dtype=object), 'r_CAGR/retnStd': array(['CHRD', 'MARA', 'ACRS', 'SM', 'SSYS', 'ETH-USD', 'PERI', 'GME',
#        'NVAX', 'CPE', 'BTC-USD', 'IPI', 'DQ', 'SPWR', 'GBTC', 'PLUG',
#        'ATKR', 'PLCE', 'APPS', 'NOG'], dtype=object), 'r_retnStd/UI': array(['CHRD', 'ACRS', 'IAC', 'PTC', 'RCKT', 'SSYS', 'ETH-USD', 'CORT',
#        'EXTR', 'STKL', 'MTZ', 'COMM', 'SMG', 'PI', 'NOAH', 'HTGC', 'BANC',
#        'FSD', 'SHYF', 'PLCE'], dtype=object)}}
# most_freq_syms: [('CHRD', 3), ('ACRS', 3), ('SSYS', 3), ('ETH-USD', 3), ('PLCE', 3), ('MARA', 2), ('SM', 2), ('PERI', 2), ('NVAX', 2), ('GME', 2), ('IPI', 2), ('IAC', 2), ('CPE', 2), ('DQ', 2), ('BTC-USD', 2), ('PLUG', 2), ('ATKR', 2), ('SPWR', 2), ('APPS', 2), ('WBD', 1), ('GBTC', 1), ('NOG', 1), ('PTC', 1), ('RCKT', 1), ('CORT', 1), ('EXTR', 1), ('STKL', 1), ('MTZ', 1), ('COMM', 1), ('SMG', 1), ('PI', 1), ('NOAH', 1), ('HTGC', 1), ('BANC', 1), ('FSD', 1), ('SHYF', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('NVAX', 3), ('MARA', 3), ('CPE', 3), ('YY', 3), ('IAC', 3), ('STAA', 3), ('STNG', 3), ('NWS', 3), ('NWSA', 3), ('AVXL', 2), ('PERI', 2), ('BTC-USD', 2), ('ETH-USD', 2), ('ERF', 2), ('GBTC', 2), ('WDC', 2), ('WB', 2), ('PRFT', 2), ('DNOW', 2), ('STKL', 2), ('BBW', 1), ('SM', 1), ('SSYS', 1), ('GPRE', 1), ('MYI', 1), ('NMZ', 1), ('CVLT', 1), ('HAFC', 1), ('BX', 1), ('SCVL', 1), ('BSM', 1)], [('ACRS', 3), ('NVAX', 3), ('SSYS', 3), ('ETH-USD', 3), ('AVXL', 3), ('YY', 3), ('GPRE', 3), ('HY', 3), ('MARA', 2), ('GME', 2), ('DQ', 2), ('BSM', 2), ('SPWR', 2), ('STAA', 2), ('PERI', 2), ('PLUG', 2), ('SM', 2), ('AXON', 2), ('LNTH', 2), ('PI', 2), ('UNFI', 1), ('VCEL', 1), ('CVLT', 1), ('MFIC', 1), ('IAC', 1), ('EXTR', 1), ('HBI', 1), ('CPRX', 1), ('HAFC', 1), ('PTC', 1), ('MTZ', 1), ('EBS', 1)], [('CHRD', 3), ('ACRS', 3), ('SSYS', 3), ('ETH-USD', 3), ('PLCE', 3), ('MARA', 2), ('SM', 2), ('PERI', 2), ('NVAX', 2), ('GME', 2), ('IPI', 2), ('IAC', 2), ('CPE', 2), ('DQ', 2), ('BTC-USD', 2), ('PLUG', 2), ('ATKR', 2), ('SPWR', 2), ('APPS', 2), ('WBD', 1), ('GBTC', 1), ('NOG', 1), ('PTC', 1), ('RCKT', 1), ('CORT', 1), ('EXTR', 1), ('STKL', 1), ('MTZ', 1), ('COMM', 1), ('SMG', 1), ('PI', 1), ('NOAH', 1), ('HTGC', 1), ('BANC', 1), ('FSD', 1), ('SHYF', 1)]]
# **** finish lookback slices [(698, 713, 718), (683, 713, 718), (653, 713, 718)] ****
#
# top 20 ranked symbols and frequency from set [(698, 713, 718), (683, 713, 718), (653, 713, 718)]:
# [('ETH-USD', 8), ('NVAX', 8), ('MARA', 7), ('SSYS', 7), ('ACRS', 6), ('IAC', 6), ('PERI', 6), ('YY', 6), ('AVXL', 5), ('CPE', 5), ('SM', 5), ('STAA', 5), ('BTC-USD', 4), ('DQ', 4), ('GME', 4), ('GPRE', 4), ('PLUG', 4), ('SPWR', 4), ('BSM', 3), ('CHRD', 3)]
# top 0 to 10 symbols from the top 20 ranked symbols from set [(698, 713, 718), (683, 713, 718), (653, 713, 718)]:
# ['ETH-USD', 'NVAX', 'MARA', 'SSYS', 'ACRS', 'IAC', 'PERI', 'YY', 'AVXL', 'CPE']
# ===== finish top 20 ranked symbols from days_lookback set [(698, 713, 718), (683, 713, 718), (653, 713, 718)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(739, 754, 759), (724, 754, 759), (694, 754, 759)] in list_random_lookback_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(739, 754, 759), (724, 754, 759), (694, 754, 759)]
# lb_slice:            (739, 754, 759)
# days eval:           5
# iloc_start_train:    739
# iloc_end_train:      754
# date_start_df_train: 2021-03-23
# date_end_df_train:   2021-04-13
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['STEW', 'MOV', 'PCH', 'CARA', 'ETH-USD', 'NVCR', 'KBR', 'TY',
#        'MRCY', 'UPS', 'FBIN', 'WCN', 'GMED', 'BSIG', 'FNF', 'LPX', 'ANF',
#        'MMC', 'SYK', 'ICHR'], dtype=object), 'r_CAGR/retnStd': array(['MOV', 'CARA', 'ETH-USD', 'NVCR', 'MARA', 'ICHR', 'KBR', 'LPX',
#        'PCH', 'CATO', 'SQ', 'BSIG', 'NVDA', 'ANF', 'MRCY', 'AZTA', 'AEO',
#        'OI', 'COHR', 'ORCL'], dtype=object), 'r_retnStd/UI': array(['STEW', 'PCH', 'TY', 'NAD', 'UPS', 'MMC', 'MRCY', 'EXR', 'SYK',
#        'WCN', 'NVG', 'MOV', 'FBIN', 'KKR', 'GMED', 'VOYA', 'FNF', 'IVV',
#        'ISD', 'SPY'], dtype=object)}}
# most_freq_syms: [('MOV', 3), ('PCH', 3), ('MRCY', 3), ('STEW', 2), ('CARA', 2), ('ETH-USD', 2), ('NVCR', 2), ('KBR', 2), ('TY', 2), ('UPS', 2), ('FBIN', 2), ('WCN', 2), ('GMED', 2), ('BSIG', 2), ('FNF', 2), ('LPX', 2), ('ANF', 2), ('MMC', 2), ('SYK', 2), ('ICHR', 2), ('MARA', 1), ('CATO', 1), ('SQ', 1), ('NVDA', 1), ('AZTA', 1), ('AEO', 1), ('OI', 1), ('COHR', 1), ('ORCL', 1), ('NAD', 1), ('EXR', 1), ('NVG', 1), ('KKR', 1), ('VOYA', 1), ('IVV', 1), ('ISD', 1), ('SPY', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(739, 754, 759), (724, 754, 759), (694, 754, 759)]
# lb_slice:            (724, 754, 759)
# days eval:           5
# iloc_start_train:    724
# iloc_end_train:      754
# date_start_df_train: 2021-03-02
# date_end_df_train:   2021-04-13
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['CARA', 'FCN', 'LGIH', 'ETH-USD', 'NOMD', 'AZO', 'HD', 'WCN',
#        'LPX', 'NUE', 'EXC', 'TGT', 'LMT', 'PEG', 'DTE', 'ORLY', 'ETR',
#        'LRN', 'HIG', 'WM'], dtype=object), 'r_CAGR/retnStd': array(['ETH-USD', 'CARA', 'LGIH', 'ANF', 'FCN', 'HD', 'LPX', 'NOMD',
#        'MOV', 'EXC', 'LRN', 'UFPI', 'AZO', 'LOW', 'DTE', 'TDS', 'WCN',
#        'BTC-USD', 'MARA', 'AEO'], dtype=object), 'r_retnStd/UI': array(['ORLY', 'TGT', 'AZO', 'NOMD', 'PEG', 'LMT', 'HIG', 'WCN', 'RELX',
#        'CARA', 'ETR', 'FCN', 'NUE', 'WM', 'FMX', 'ED', 'LOB', 'MCD',
#        'MAS', 'CCOI'], dtype=object)}}
# most_freq_syms: [('CARA', 3), ('FCN', 3), ('NOMD', 3), ('AZO', 3), ('WCN', 3), ('LGIH', 2), ('ETH-USD', 2), ('HD', 2), ('LPX', 2), ('NUE', 2), ('EXC', 2), ('TGT', 2), ('LMT', 2), ('PEG', 2), ('DTE', 2), ('ORLY', 2), ('ETR', 2), ('LRN', 2), ('HIG', 2), ('WM', 2), ('ANF', 1), ('MOV', 1), ('UFPI', 1), ('LOW', 1), ('TDS', 1), ('BTC-USD', 1), ('MARA', 1), ('AEO', 1), ('RELX', 1), ('FMX', 1), ('ED', 1), ('LOB', 1), ('MCD', 1), ('MAS', 1), ('CCOI', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(739, 754, 759), (724, 754, 759), (694, 754, 759)]
# lb_slice:            (694, 754, 759)
# days eval:           5
# iloc_start_train:    694
# iloc_end_train:      754
# date_start_df_train: 2021-01-15
# date_end_df_train:   2021-04-13
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['ACRS', 'GME', 'CAR', 'DBI', 'LPX', 'AVXL', 'CPE', 'CLMT', 'STWD',
#        'SEAS', 'SNA', 'SM', 'MARA', 'LGIH', 'JYNT', 'ETH-USD', 'MAIN',
#        'SFBS', 'PTMN', 'SIG'], dtype=object), 'r_CAGR/retnStd': array(['ACRS', 'GME', 'CPE', 'CAR', 'AVXL', 'LPX', 'MARA', 'JYNT',
#        'ETH-USD', 'DBI', 'CLMT', 'LGIH', 'HAFC', 'SM', 'SEAS', 'ANF',
#        'SFBS', 'BTC-USD', 'STWD', 'CHRD'], dtype=object), 'r_retnStd/UI': array(['ACRS', 'DBI', 'SNA', 'STWD', 'LPX', 'AFG', 'SLM', 'HPQ', 'PTMN',
#        'MHK', 'CAR', 'HRB', 'SPGI', 'WU', 'GD', 'MO', 'SEAS', 'TROW',
#        'CLMT', 'SCVL'], dtype=object)}}
# most_freq_syms: [('ACRS', 3), ('CAR', 3), ('DBI', 3), ('LPX', 3), ('CLMT', 3), ('STWD', 3), ('SEAS', 3), ('GME', 2), ('AVXL', 2), ('CPE', 2), ('SNA', 2), ('SM', 2), ('MARA', 2), ('LGIH', 2), ('JYNT', 2), ('ETH-USD', 2), ('SFBS', 2), ('PTMN', 2), ('MAIN', 1), ('SIG', 1), ('HAFC', 1), ('ANF', 1), ('BTC-USD', 1), ('CHRD', 1), ('AFG', 1), ('SLM', 1), ('HPQ', 1), ('MHK', 1), ('HRB', 1), ('SPGI', 1), ('WU', 1), ('GD', 1), ('MO', 1), ('TROW', 1), ('SCVL', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('MOV', 3), ('PCH', 3), ('MRCY', 3), ('STEW', 2), ('CARA', 2), ('ETH-USD', 2), ('NVCR', 2), ('KBR', 2), ('TY', 2), ('UPS', 2), ('FBIN', 2), ('WCN', 2), ('GMED', 2), ('BSIG', 2), ('FNF', 2), ('LPX', 2), ('ANF', 2), ('MMC', 2), ('SYK', 2), ('ICHR', 2), ('MARA', 1), ('CATO', 1), ('SQ', 1), ('NVDA', 1), ('AZTA', 1), ('AEO', 1), ('OI', 1), ('COHR', 1), ('ORCL', 1), ('NAD', 1), ('EXR', 1), ('NVG', 1), ('KKR', 1), ('VOYA', 1), ('IVV', 1), ('ISD', 1), ('SPY', 1)], [('CARA', 3), ('FCN', 3), ('NOMD', 3), ('AZO', 3), ('WCN', 3), ('LGIH', 2), ('ETH-USD', 2), ('HD', 2), ('LPX', 2), ('NUE', 2), ('EXC', 2), ('TGT', 2), ('LMT', 2), ('PEG', 2), ('DTE', 2), ('ORLY', 2), ('ETR', 2), ('LRN', 2), ('HIG', 2), ('WM', 2), ('ANF', 1), ('MOV', 1), ('UFPI', 1), ('LOW', 1), ('TDS', 1), ('BTC-USD', 1), ('MARA', 1), ('AEO', 1), ('RELX', 1), ('FMX', 1), ('ED', 1), ('LOB', 1), ('MCD', 1), ('MAS', 1), ('CCOI', 1)], [('ACRS', 3), ('CAR', 3), ('DBI', 3), ('LPX', 3), ('CLMT', 3), ('STWD', 3), ('SEAS', 3), ('GME', 2), ('AVXL', 2), ('CPE', 2), ('SNA', 2), ('SM', 2), ('MARA', 2), ('LGIH', 2), ('JYNT', 2), ('ETH-USD', 2), ('SFBS', 2), ('PTMN', 2), ('MAIN', 1), ('SIG', 1), ('HAFC', 1), ('ANF', 1), ('BTC-USD', 1), ('CHRD', 1), ('AFG', 1), ('SLM', 1), ('HPQ', 1), ('MHK', 1), ('HRB', 1), ('SPGI', 1), ('WU', 1), ('GD', 1), ('MO', 1), ('TROW', 1), ('SCVL', 1)]]
# **** finish lookback slices [(739, 754, 759), (724, 754, 759), (694, 754, 759)] ****
#
# top 20 ranked symbols and frequency from set [(739, 754, 759), (724, 754, 759), (694, 754, 759)]:
# [('LPX', 7), ('ETH-USD', 6), ('CARA', 5), ('WCN', 5), ('ANF', 4), ('LGIH', 4), ('MARA', 4), ('MOV', 4), ('ACRS', 3), ('AZO', 3), ('CAR', 3), ('CLMT', 3), ('DBI', 3), ('FCN', 3), ('MRCY', 3), ('NOMD', 3), ('PCH', 3), ('SEAS', 3), ('STWD', 3), ('AEO', 2)]
# top 0 to 10 symbols from the top 20 ranked symbols from set [(739, 754, 759), (724, 754, 759), (694, 754, 759)]:
# ['LPX', 'ETH-USD', 'CARA', 'WCN', 'ANF', 'LGIH', 'MARA', 'MOV', 'ACRS', 'AZO']
# ===== finish top 20 ranked symbols from days_lookback set [(739, 754, 759), (724, 754, 759), (694, 754, 759)] =====

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"days_lookbacks: {days_lookbacks}")
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of random_max_lookback_tuples is equal to n_samples = {n_samples}")
    print(f"The {n_samples} random_max_lookback_tuples:\n{random_max_lookback_tuples}\n")
    print(f"list_random_lookback_slice has {n_samples} lists corresponds to:\n - n_samples = {n_samples}\n - days_lookbacks: {days_lookbacks}\n - days_eval: {days_eval}")
    print(f"list_random_lookback_slices:\n{list_random_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the random_max_lookback_tuples. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in random_max_lookback_tuples. There are as many sub-lists as there are tuples in random_max_lookback_tuples.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, list_random_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in list_random_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"random_max_lookback_tuples:      {random_max_lookback_tuples}")
        # print(f'set_lookback_slices: {list_random_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(list_random_lookback_slices):>3}:    {list_random_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, random_max_lookback_tuples, list_random_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")

# %%
df_eval_results
