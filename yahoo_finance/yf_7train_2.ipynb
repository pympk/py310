# %%
import os


# Get the user's home directory Documents folder
path_dir = os.path.join(os.path.expanduser('~'), 'Documents/')
path_data_dump = path_dir + "VSCode_dump/"

print(f'path_dir: {path_dir}')
print(f'path_data_dump: {path_data_dump}')

# %%
import pandas as pd
from myUtils import pickle_load, pickle_dump, delete_all_rows
from yf_utils import split_train_val_test, random_slices, lookback_slices
from yf_utils import eval_grp_top_syms_n_freq
from yf_utils import top_set_sym_freq_cnt, get_grp_top_syms_n_freq

pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.width", 500)  # code-runner format

# path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
# path_data_dump = path_dir + "VSCode_dump/"

fp_df_close_clean = "df_close_clean"

# %% [markdown]
# ### Run below cell for Colab

# %%
#######################################################################
## SELECT RUN PARAMETERS.async Parameters can also be passed using papermill by running yf_7_freq_cnt_pm_.ipynb
verbose = True  # True prints more output
# verbose = False  # True prints more output

# write run results to df_eval_results
# store_results = False
store_results = True

# select run type
# run_type = "train"
# run_type = 'validate'
run_type = "test"

# number of max lookback tuples to create for iloc iloc_start_train:iloc_end_train:iloc_end_eval
# i.e. number of grp_top_set_syms_n_freq and grp_top_set_syms
# n_samples = 400
n_samples = 2

# for training, the number of days to lookback from iloc max-lookback iloc_end_train
days_lookbacks = [15, 30, 60]
# days_lookbacks = [30, 60, 120]
# days_lookbacks = [15, 30, 60, 120]
days_lookbacks.sort()

# number of days in dataframe to evaluate effectiveness of the training, days_eval = len(df_eval)
#  days_eval = 4 means buy at close on 1st day after the signal, hold for 2nd and 3rd day, sell at close on 4th day
days_eval = 4
# days_eval = 5

# number of the most-common symbols from days_lookbacks' performance rankings to keep
n_top_syms = 20
# n_top_syms = 5

# slice starts and ends for selecting the best performing symbols
# syms_start = 1, syms_end = 11 will keep the 2nd to 11th best performing symbols  
syms_start = 0
syms_end = 10


##########################################################
fp_df_eval_results = f"df_eval_results_{run_type}"
# fp_df_eval_results = "test_df_eval"
##########################################################

#### Delete all rows in df_eval_results ##################
delete_all_rows(path_data_dump, fp_df_eval_results)
##########################################################

# %%
print(f'path_data_dump: {path_data_dump}')
print(f"verbose : {verbose }")
print(f"store_results: {store_results}")
print(f"run_type: {run_type}")
print(f"n_samples: {n_samples}")
print(f"days_lookbacks: {days_lookbacks}")
print(f"days_eval: {days_eval}")
print(f"n_top_syms: {n_top_syms}")
print(f"syms_start: {syms_start}")
print(f"syms_end: {syms_end}")
print(f"filename of run results: {fp_df_eval_results}")

df_close_clean = pickle_load(path_data_dump, fp_df_close_clean)

# Split df_close_clean into training (df_train), validation (df_val) and test (df_test) set.
# The default split is 0.7, 0.2, 0.1 respectively.
df_train, df_val, df_test = split_train_val_test(df_close_clean)
# Out:
# path_data_dump: C:/Users/ping/MyDrive/stocks/yfinance/VSCode_dump/
# verbose : True
# store_results: True
# run_type: test
# n_samples: 2
# days_lookbacks: [15, 30, 60]
# days_eval: 4
# n_top_syms: 20
# syms_start: 0
# syms_end: 10
# filename of run results: df_eval_results_test

# %%
# max_days_lookbacks = max(days_lookbacks)
# print(f"max_days_lookbacks: {max_days_lookbacks}")

# Load df according to run_type
if run_type == "train":
    df = df_train.copy()
elif run_type == "validate":
    df = df_val.copy()
elif run_type == "test":
    df = df_test.copy()
else:
    msg_stop = f"ERROR run_type must be 'train', 'validate', or 'test', run_type is: {run_type}"
    raise SystemExit(msg_stop)

# Print dataframe for the run, and lengths of other dataframes
print(f"run_type: {run_type}, df.tail(3):\n{df.tail(3)}\n")
len_df = len(df)
len_df_train = len(df_train)
len_df_val = len(df_val)
len_df_test = len(df_test)
print(f"run_type: {run_type}, len(df): {len(df)}")
print(
    f"len_df_train: {len_df_train}, len_df_val: {len_df_val}, len_df_test: {len_df_test}"
)

# return n_samples slices
random_max_lookback_tuples = random_slices(
    len_df,
    n_samples=n_samples,
    days_lookback=max(days_lookbacks),
    days_eval=days_eval,
    verbose=False,
)
# return n_samples * len(days_lookbacks) slices
list_random_lookback_slices = lookback_slices(
    max_slices=random_max_lookback_tuples, days_lookbacks=days_lookbacks, verbose=False
)
# Out:
# run_type: test, df.tail(3):
#                      A         AA    AAL        AAP        AAPL         AB        ABBV    ABR         ABT       ACGL       ACHC       ACIW        ACLS  ACRS        ADBE  ...         XYL       YELP         YUM       YUMC         YY         ZBH        ZBRA         ZD         ZG       ZION          ZS        ZTO         ZTS   ZUMZ        ZWS
# Date                                                                                                                                                                      ...
# 2024-03-14  145.210007  30.020000  13.99  79.529999  173.000000  33.369999  181.199997  12.68  118.849998  91.029999  78.870003  31.469999  108.110001  1.15  570.450012  ...  127.959999  37.869999  137.160004  42.220001  31.870001  125.730003  281.769989  64.110001  53.139999  39.799999  198.830002  21.580000  173.880005  14.73  31.360001
# 2024-03-15  147.479996  30.440001  13.96  81.769997  172.619995  33.290001  177.880005  12.96  115.489998  91.879997  77.790001  31.830000  107.610001  1.17  492.459991  ...  127.269997  37.520000  136.839996  41.950001  32.259998  125.169998  285.859985  62.619999  46.220001  39.790001  194.029999  21.809999  172.570007  13.60  31.520000
# 2024-03-18  146.089996  31.030001  14.11  84.190002  173.720001  33.480000  178.490005  12.79  112.440002  91.400002  78.150002  31.740000  110.209999  1.15  513.859985  ...  127.489998  37.950001  136.270004  41.200001  33.369999  125.959999  285.970001  62.049999  46.660000  39.730000  195.940002  21.670000  170.690002  13.32  31.129999
#
# [3 rows x 1264 columns]
#
# run_type: test, len(df): 150
# len_df_train: 1050, len_df_val: 300, len_df_test: 150

# %% [markdown]
# ### Run below cell to use test data to debug code, results should match yf_test.ipynb

# %%
# ####### RUN THIS CELL TO USE TEST DATA TO DEBUG CODE, RESULTS SHOULD MATCH yf_test.ipynb ################# 

# # load test data to debug code if needed
# test_dic = pickle_load(path_data_dump, 'yf_test_dic')
# for i, key in enumerate(test_dic.keys()):
#   print(f'{i}: {key}')

# # convert dictionary entries into variables
# locals().update(test_dic)
# del df_eval_results  # delete df_eval_results loaded from locals().update(test_dic)

# # Delete all rows in df_eval_results
# delete_all_rows(path_data_dump, fp_df_eval_results)

# %%
max_days_lookbacks = max(days_lookbacks)
print(f"days_lookbacks: {days_lookbacks}")
print(f"max_days_lookbacks: {max_days_lookbacks}")

if verbose:
    print(f"number of random_max_lookback_tuples is equal to n_samples = {n_samples}")
    print(f"The {n_samples} random_max_lookback_tuples:\n{random_max_lookback_tuples}\n")
    print(f"list_random_lookback_slice has {n_samples} lists corresponds to:\n - n_samples = {n_samples}\n - days_lookbacks: {days_lookbacks}\n - days_eval: {days_eval}")
    print(f"list_random_lookback_slices:\n{list_random_lookback_slices}\n")
    print(f"days_lookbacks: {days_lookbacks}")
    print(
        f'number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): {len(days_lookbacks)}'
    )

# #### Generate grp_top_set_syms_n_freq. It is a list of sub-lists, e.g.:
#  - [[('AGY', 7), ('PCG', 7), ('KDN', 6), ..., ('CYT', 3)], ..., [('FCN', 9), ('HIG', 9), ('SJR', 8), ..., ('BFH', 2)]]
# #### grp_top_set_syms_n_freq has n_samples sub-lists. Each sub-list corresponds to a tuple in the random_max_lookback_tuples. Each sub-list has n_top_syms tuples of (symbol, frequency) pairs, and is sorted in descending order of frequency. The frequency is the number of times the symbol appears in the top n_top_syms performance rankings of CAGR/UI, CAGR/retnStd and retnStd/UI.
# #### Therefore, symbols in the sub-list are the best performing symbols for the periods in days_lookbacks. Each sub-list corresponds to a tuple in random_max_lookback_tuples. There are as many sub-lists as there are tuples in random_max_lookback_tuples.
grp_top_set_syms_n_freq, grp_top_set_syms, dates_end_df_train = get_grp_top_syms_n_freq(
    df, list_random_lookback_slices, days_lookbacks, n_top_syms, syms_start, syms_end, verbose
)

# #### print the best performing symbols for each set in list_random_lookback_slices
for i, top_set_syms_n_freq in enumerate(grp_top_set_syms_n_freq):
    l_sym_freq_cnt = top_set_sym_freq_cnt(top_set_syms_n_freq)
    if verbose:
        print(f"random_max_lookback_tuples:      {random_max_lookback_tuples}")
        # print(f'set_lookback_slices: {list_random_lookback_slices[i]}\n')
        print(
            f"set_lookback_slices {i + 1} of {len(list_random_lookback_slices):>3}:    {list_random_lookback_slices[i]}\n"
        )
        print(f"max_days_lookbacks:              {max_days_lookbacks}")
        print(f"df end date for days_lookbacks:  {dates_end_df_train[i]}")
        print(f"days_lookbacks:                  {days_lookbacks}")
        print(f"sym_freq_15:                     {l_sym_freq_cnt[0]}")
        print(f"sym_freq_14:                     {l_sym_freq_cnt[1]}")
        print(f"sym_freq_13:                     {l_sym_freq_cnt[2]}")
        print(f"sym_freq_12:                     {l_sym_freq_cnt[3]}")
        print(f"sym_freq_11:                     {l_sym_freq_cnt[4]}")
        print(f"sym_freq_10:                     {l_sym_freq_cnt[5]}")
        print(f"sym_freq_9:                      {l_sym_freq_cnt[6]}")
        print(f"sym_freq_8:                      {l_sym_freq_cnt[7]}")
        print(f"sym_freq_7:                      {l_sym_freq_cnt[8]}")
        print(f"sym_freq_6:                      {l_sym_freq_cnt[9]}")
        print(f"sym_freq_5:                      {l_sym_freq_cnt[10]}")
        print(f"sym_freq_4:                      {l_sym_freq_cnt[11]}")
        print(f"sym_freq_3:                      {l_sym_freq_cnt[12]}")
        print(f"sym_freq_2:                      {l_sym_freq_cnt[13]}\n")


# #### Evaluate performance of symbols in set_lookback_slices versus SPY
l_row_add_total = eval_grp_top_syms_n_freq(
    df, random_max_lookback_tuples, list_random_lookback_slices, grp_top_set_syms_n_freq, days_lookbacks, days_eval, n_samples, n_top_syms, syms_start, syms_end, verbose
)

for row_add_total in l_row_add_total:
    print(f"row_add_total: {row_add_total}")

if store_results:  # record results to df
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results BEFORW store results:\n{df_eval_results}\n")

    for row_add_total in l_row_add_total:
        # print(f'row_add_total: {row_add_total}')
        df_eval_results.loc[len(df_eval_results)] = row_add_total
        print(f"appended row_add_total to df_eval_results:\n{row_add_total}\n")

    pickle_dump(df_eval_results, path_data_dump, fp_df_eval_results)
    print(f"Save results to: {fp_df_eval_results}")
    df_eval_results = pickle_load(path_data_dump, fp_df_eval_results)
    print(f"df_eval_results AFTER store results:\n{df_eval_results}\n")
# Out:
# days_lookbacks: [15, 30, 60]
# max_days_lookbacks: 60
# number of random_max_lookback_tuples is equal to n_samples = 2
# The 2 random_max_lookback_tuples:
# [(80, 140, 144), (50, 110, 114)]
#
# list_random_lookback_slice has 2 lists corresponds to:
#  - n_samples = 2
#  - days_lookbacks: [15, 30, 60]
#  - days_eval: 4
# list_random_lookback_slices:
# [[(125, 140, 144), (110, 140, 144), (80, 140, 144)], [(95, 110, 114), (80, 110, 114), (50, 110, 114)]]
#
# days_lookbacks: [15, 30, 60]
# number of tuples in each list in list_random_lookback_slices is equal to len(days_lookbacks): 3
#
# ########## 1 of 2 lb_slices: [(125, 140, 144), (110, 140, 144), (80, 140, 144)] in list_random_lookback_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(125, 140, 144), (110, 140, 144), (80, 140, 144)]
# lb_slice:            (125, 140, 144)
# days eval:           4
# iloc_start_train:    125
# iloc_end_train:      140
# date_start_df_train: 2024-02-12
# date_end_df_train:   2024-03-04
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['VST', 'EBS', 'CARA', 'EME', 'CELH', 'DNOW', 'ETH-USD', 'EVBG',
#        'BTC-USD', 'GBTC', 'BMA', 'DELL', 'BRKR', 'STRL', 'BWXT', 'HCSG',
#        'SHAK', 'GE', 'SFM', 'NTRA'], dtype=object), 'r_CAGR/retnStd': array(['CARA', 'EBS', 'CELH', 'VST', 'DNOW', 'ETH-USD', 'BTC-USD', 'GBTC',
#        'EME', 'DELL', 'STRL', 'BMA', 'BRKR', 'BIG', 'SMCI', 'MERC',
#        'NTRA', 'WING', 'HCSG', 'TNDM'], dtype=object), 'r_retnStd/UI': array(['VST', 'EVBG', 'EME', 'HII', 'BWXT', 'TGH', 'SPLK', 'AZO', 'VIRT',
#        'GE', 'HWM', 'SFM', 'AME', 'HCSG', 'BRKR', 'BMA', 'ALSN', 'SHAK',
#        'DNOW', 'SHV'], dtype=object)}}
# most_freq_syms: [('VST', 3), ('EME', 3), ('DNOW', 3), ('BMA', 3), ('BRKR', 3), ('HCSG', 3), ('EBS', 2), ('CARA', 2), ('CELH', 2), ('ETH-USD', 2), ('EVBG', 2), ('BTC-USD', 2), ('GBTC', 2), ('DELL', 2), ('STRL', 2), ('BWXT', 2), ('SHAK', 2), ('GE', 2), ('SFM', 2), ('NTRA', 2), ('BIG', 1), ('SMCI', 1), ('MERC', 1), ('WING', 1), ('TNDM', 1), ('HII', 1), ('TGH', 1), ('SPLK', 1), ('AZO', 1), ('VIRT', 1), ('HWM', 1), ('AME', 1), ('ALSN', 1), ('SHV', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(125, 140, 144), (110, 140, 144), (80, 140, 144)]
# lb_slice:            (110, 140, 144)
# days eval:           4
# iloc_start_train:    110
# iloc_end_train:      140
# date_start_df_train: 2024-01-22
# date_end_df_train:   2024-03-04
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['SMCI', 'BTC-USD', 'GBTC', 'EVBG', 'EME', 'CELH', 'ETH-USD',
#        'CARA', 'BWXT', 'SHAK', 'DOOR', 'DELL', 'ALSN', 'CLS', 'VST', 'GE',
#        'XPO', 'STRL', 'SKYW', 'NTRA'], dtype=object), 'r_CAGR/retnStd': array(['SMCI', 'BTC-USD', 'GBTC', 'CARA', 'CELH', 'ETH-USD', 'EME', 'VST',
#        'CLS', 'EVBG', 'SHAK', 'EDU', 'STRL', 'NVDA', 'DELL', 'DNOW', 'GE',
#        'COHR', 'RGNX', 'ELF'], dtype=object), 'r_retnStd/UI': array(['EVBG', 'DOOR', 'BWXT', 'ALSN', 'EME', 'BTC-USD', 'AXP', 'SHV',
#        'DELL', 'WM', 'TGH', 'SKYW', 'ETN', 'SHAK', 'XPO', 'GBTC', 'TXRH',
#        'META', 'GE', 'HII'], dtype=object)}}
# most_freq_syms: [('BTC-USD', 3), ('GBTC', 3), ('EVBG', 3), ('EME', 3), ('SHAK', 3), ('DELL', 3), ('GE', 3), ('SMCI', 2), ('CELH', 2), ('ETH-USD', 2), ('CARA', 2), ('BWXT', 2), ('DOOR', 2), ('ALSN', 2), ('CLS', 2), ('VST', 2), ('XPO', 2), ('STRL', 2), ('SKYW', 2), ('NTRA', 1), ('EDU', 1), ('NVDA', 1), ('DNOW', 1), ('COHR', 1), ('RGNX', 1), ('ELF', 1), ('AXP', 1), ('SHV', 1), ('WM', 1), ('TGH', 1), ('ETN', 1), ('TXRH', 1), ('META', 1), ('HII', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(125, 140, 144), (110, 140, 144), (80, 140, 144)]
# lb_slice:            (80, 140, 144)
# days eval:           4
# iloc_start_train:    80
# iloc_end_train:      140
# date_start_df_train: 2023-12-06
# date_end_df_train:   2024-03-04
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['SMCI', 'FATE', 'SHV', 'NVDA', 'DELL', 'ANF', 'VST', 'EME', 'CLS',
#        'META', 'FTSM', 'GE', 'AMD', 'PSTG', 'NTRA', 'AGO', 'ICHR', 'EXP',
#        'ETN', 'WING'], dtype=object), 'r_CAGR/retnStd': array(['SMCI', 'FATE', 'NVDA', 'ANF', 'CLS', 'VST', 'EME', 'AMD', 'GBTC',
#        'ICHR', 'ELF', 'COHR', 'SHV', 'UCTT', 'DELL', 'PSTG', 'AVGO', 'GE',
#        'STRL', 'WING'], dtype=object), 'r_retnStd/UI': array(['SHV', 'DELL', 'JNPR', 'FTSM', 'META', 'AGO', 'PH', 'TRV', 'ETN',
#        'EME', 'NVDA', 'WM', 'MDC', 'VST', 'TT', 'WMT', 'H', 'BSX', 'SFM',
#        'TGH'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('NVDA', 3), ('DELL', 3), ('VST', 3), ('EME', 3), ('SMCI', 2), ('FATE', 2), ('ANF', 2), ('CLS', 2), ('META', 2), ('FTSM', 2), ('GE', 2), ('AMD', 2), ('PSTG', 2), ('AGO', 2), ('ICHR', 2), ('ETN', 2), ('WING', 2), ('NTRA', 1), ('EXP', 1), ('GBTC', 1), ('ELF', 1), ('COHR', 1), ('UCTT', 1), ('AVGO', 1), ('STRL', 1), ('JNPR', 1), ('PH', 1), ('TRV', 1), ('WM', 1), ('MDC', 1), ('TT', 1), ('WMT', 1), ('H', 1), ('BSX', 1), ('SFM', 1), ('TGH', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('VST', 3), ('EME', 3), ('DNOW', 3), ('BMA', 3), ('BRKR', 3), ('HCSG', 3), ('EBS', 2), ('CARA', 2), ('CELH', 2), ('ETH-USD', 2), ('EVBG', 2), ('BTC-USD', 2), ('GBTC', 2), ('DELL', 2), ('STRL', 2), ('BWXT', 2), ('SHAK', 2), ('GE', 2), ('SFM', 2), ('NTRA', 2), ('BIG', 1), ('SMCI', 1), ('MERC', 1), ('WING', 1), ('TNDM', 1), ('HII', 1), ('TGH', 1), ('SPLK', 1), ('AZO', 1), ('VIRT', 1), ('HWM', 1), ('AME', 1), ('ALSN', 1), ('SHV', 1)], [('BTC-USD', 3), ('GBTC', 3), ('EVBG', 3), ('EME', 3), ('SHAK', 3), ('DELL', 3), ('GE', 3), ('SMCI', 2), ('CELH', 2), ('ETH-USD', 2), ('CARA', 2), ('BWXT', 2), ('DOOR', 2), ('ALSN', 2), ('CLS', 2), ('VST', 2), ('XPO', 2), ('STRL', 2), ('SKYW', 2), ('NTRA', 1), ('EDU', 1), ('NVDA', 1), ('DNOW', 1), ('COHR', 1), ('RGNX', 1), ('ELF', 1), ('AXP', 1), ('SHV', 1), ('WM', 1), ('TGH', 1), ('ETN', 1), ('TXRH', 1), ('META', 1), ('HII', 1)], [('SHV', 3), ('NVDA', 3), ('DELL', 3), ('VST', 3), ('EME', 3), ('SMCI', 2), ('FATE', 2), ('ANF', 2), ('CLS', 2), ('META', 2), ('FTSM', 2), ('GE', 2), ('AMD', 2), ('PSTG', 2), ('AGO', 2), ('ICHR', 2), ('ETN', 2), ('WING', 2), ('NTRA', 1), ('EXP', 1), ('GBTC', 1), ('ELF', 1), ('COHR', 1), ('UCTT', 1), ('AVGO', 1), ('STRL', 1), ('JNPR', 1), ('PH', 1), ('TRV', 1), ('WM', 1), ('MDC', 1), ('TT', 1), ('WMT', 1), ('H', 1), ('BSX', 1), ('SFM', 1), ('TGH', 1)]]
# **** finish lookback slices [(125, 140, 144), (110, 140, 144), (80, 140, 144)] ****
#
# top 20 ranked symbols and frequency from set [(125, 140, 144), (110, 140, 144), (80, 140, 144)]:
# [('EME', 9), ('DELL', 8), ('VST', 8), ('GE', 7), ('GBTC', 6), ('BTC-USD', 5), ('EVBG', 5), ('SHAK', 5), ('SHV', 5), ('SMCI', 5), ('STRL', 5), ('BWXT', 4), ('CARA', 4), ('CELH', 4), ('CLS', 4), ('DNOW', 4), ('ETH-USD', 4), ('NTRA', 4), ('NVDA', 4), ('ALSN', 3)]
# top 0 to 10 symbols from the top 20 ranked symbols from set [(125, 140, 144), (110, 140, 144), (80, 140, 144)]:
# ['EME', 'DELL', 'VST', 'GE', 'GBTC', 'BTC-USD', 'EVBG', 'SHAK', 'SHV', 'SMCI']
# ===== finish top 20 ranked symbols from days_lookback set [(125, 140, 144), (110, 140, 144), (80, 140, 144)] =====
#
#
#
# ########## 2 of 2 lb_slices: [(95, 110, 114), (80, 110, 114), (50, 110, 114)] in list_random_lookback_slices ##########
# days lookback:       15,  1 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(95, 110, 114), (80, 110, 114), (50, 110, 114)]
# lb_slice:            (95, 110, 114)
# days eval:           4
# iloc_start_train:    95
# iloc_end_train:      110
# date_start_df_train: 2023-12-28
# date_end_df_train:   2024-01-19
# perf_ranks: {'period-15': {'r_CAGR/UI': array(['SMCI', 'JNPR', 'CIEN', 'TRV', 'ALL', 'BSX', 'SHV', 'MRK', 'NVS',
#        'NVDA', 'AXGN', 'PGR', 'MMC', 'TM', 'TNK', 'AON', 'BCE', 'SRPT',
#        'ACGL', 'LAZ'], dtype=object), 'r_CAGR/retnStd': array(['SMCI', 'CIEN', 'JNPR', 'NVDA', 'AXGN', 'TNK', 'ALL', 'NTNX',
#        'PANW', 'MRVL', 'AMD', 'GKOS', 'PGR', 'BSX', 'ACGL', 'SRPT', 'TM',
#        'TRV', 'MRK', 'SAGE'], dtype=object), 'r_retnStd/UI': array(['TRV', 'JNPR', 'SHV', 'BSX', 'NVS', 'MRK', 'ALL', 'MMC', 'CIEN',
#        'PGR', 'TGH', 'BCE', 'PDCO', 'SMCI', 'AON', 'TM', 'ABT', 'AJG',
#        'LAZ', 'CINF'], dtype=object)}}
# most_freq_syms: [('SMCI', 3), ('JNPR', 3), ('CIEN', 3), ('TRV', 3), ('ALL', 3), ('BSX', 3), ('MRK', 3), ('PGR', 3), ('TM', 3), ('SHV', 2), ('NVS', 2), ('NVDA', 2), ('AXGN', 2), ('MMC', 2), ('TNK', 2), ('AON', 2), ('BCE', 2), ('SRPT', 2), ('ACGL', 2), ('LAZ', 2), ('NTNX', 1), ('PANW', 1), ('MRVL', 1), ('AMD', 1), ('GKOS', 1), ('SAGE', 1), ('TGH', 1), ('PDCO', 1), ('ABT', 1), ('AJG', 1), ('CINF', 1)]
# +++ finish lookback slice 15 +++
#
# days lookback:       30,  2 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(95, 110, 114), (80, 110, 114), (50, 110, 114)]
# lb_slice:            (80, 110, 114)
# days eval:           4
# iloc_start_train:    80
# iloc_end_train:      110
# date_start_df_train: 2023-12-06
# date_end_df_train:   2024-01-19
# perf_ranks: {'period-30': {'r_CAGR/UI': array(['CYTK', 'FATE', 'SHV', 'MBI', 'FFWM', 'SMCI', 'JNPR', 'AMD',
#        'MRVL', 'HY', 'LAZ', 'GKOS', 'PLAB', 'TRV', 'AGO', 'VRTX', 'BK',
#        'PDCO', 'GMED', 'ANF'], dtype=object), 'r_CAGR/retnStd': array(['CYTK', 'FATE', 'MBI', 'SMCI', 'FFWM', 'AMD', 'PLAB', 'MRVL',
#        'ICHR', 'GKOS', 'AVGO', 'HY', 'NVDA', 'UCTT', 'ARWR', 'GMED',
#        'LITE', 'ANF', 'MATX', 'MKSI'], dtype=object), 'r_retnStd/UI': array(['SHV', 'JNPR', 'TRV', 'VRTX', 'PDCO', 'FTSM', 'LAZ', 'BK', 'CI',
#        'AGO', 'X', 'DELL', 'ABT', 'NXST', 'SRPT', 'MRK', 'MMSI', 'FFWM',
#        'CYTK', 'HY'], dtype=object)}}
# most_freq_syms: [('CYTK', 3), ('FFWM', 3), ('HY', 3), ('FATE', 2), ('SHV', 2), ('MBI', 2), ('SMCI', 2), ('JNPR', 2), ('AMD', 2), ('MRVL', 2), ('LAZ', 2), ('GKOS', 2), ('PLAB', 2), ('TRV', 2), ('AGO', 2), ('VRTX', 2), ('BK', 2), ('PDCO', 2), ('GMED', 2), ('ANF', 2), ('ICHR', 1), ('AVGO', 1), ('NVDA', 1), ('UCTT', 1), ('ARWR', 1), ('LITE', 1), ('MATX', 1), ('MKSI', 1), ('FTSM', 1), ('CI', 1), ('X', 1), ('DELL', 1), ('ABT', 1), ('NXST', 1), ('SRPT', 1), ('MRK', 1), ('MMSI', 1)]
# +++ finish lookback slice 30 +++
#
# days lookback:       60,  3 of 3 days_lookbacks: [15, 30, 60]
# lb_slices:           [(95, 110, 114), (80, 110, 114), (50, 110, 114)]
# lb_slice:            (50, 110, 114)
# days eval:           4
# iloc_start_train:    50
# iloc_end_train:      110
# date_start_df_train: 2023-10-24
# date_end_df_train:   2024-01-19
# perf_ranks: {'period-60': {'r_CAGR/UI': array(['SHV', 'HA', 'FTSM', 'HY', 'CYTK', 'AXGN', 'FATE', 'TRV', 'IBP',
#        'BK', 'JNPR', 'BURL', 'DHI', 'FFWM', 'AGO', 'ANF', 'MDC', 'BCC',
#        'MBI', 'AMD'], dtype=object), 'r_CAGR/retnStd': array(['FATE', 'HA', 'AXGN', 'CYTK', 'FFWM', 'HY', 'IBP', 'SHV', 'WING',
#        'DHI', 'AMD', 'ANF', 'NTNX', 'RCL', 'MDC', 'PI', 'BCC', 'KKR',
#        'COLL', 'NTRA'], dtype=object), 'r_retnStd/UI': array(['SHV', 'HA', 'FTSM', 'JNPR', 'TRV', 'TT', 'BURL', 'PLNT', 'BK',
#        'NOMD', 'X', 'PH', 'AGO', 'PFGC', 'HY', 'MDC', 'TGT', 'WM', 'WAB',
#        'RCI'], dtype=object)}}
# most_freq_syms: [('SHV', 3), ('HA', 3), ('HY', 3), ('MDC', 3), ('FTSM', 2), ('CYTK', 2), ('AXGN', 2), ('FATE', 2), ('TRV', 2), ('IBP', 2), ('BK', 2), ('JNPR', 2), ('BURL', 2), ('DHI', 2), ('FFWM', 2), ('AGO', 2), ('ANF', 2), ('BCC', 2), ('AMD', 2), ('MBI', 1), ('WING', 1), ('NTNX', 1), ('RCL', 1), ('PI', 1), ('KKR', 1), ('COLL', 1), ('NTRA', 1), ('TT', 1), ('PLNT', 1), ('NOMD', 1), ('X', 1), ('PH', 1), ('PFGC', 1), ('TGT', 1), ('WM', 1), ('WAB', 1), ('RCI', 1)]
# +++ finish lookback slice 60 +++
#
# grp_most_freq_syms: [[('SMCI', 3), ('JNPR', 3), ('CIEN', 3), ('TRV', 3), ('ALL', 3), ('BSX', 3), ('MRK', 3), ('PGR', 3), ('TM', 3), ('SHV', 2), ('NVS', 2), ('NVDA', 2), ('AXGN', 2), ('MMC', 2), ('TNK', 2), ('AON', 2), ('BCE', 2), ('SRPT', 2), ('ACGL', 2), ('LAZ', 2), ('NTNX', 1), ('PANW', 1), ('MRVL', 1), ('AMD', 1), ('GKOS', 1), ('SAGE', 1), ('TGH', 1), ('PDCO', 1), ('ABT', 1), ('AJG', 1), ('CINF', 1)], [('CYTK', 3), ('FFWM', 3), ('HY', 3), ('FATE', 2), ('SHV', 2), ('MBI', 2), ('SMCI', 2), ('JNPR', 2), ('AMD', 2), ('MRVL', 2), ('LAZ', 2), ('GKOS', 2), ('PLAB', 2), ('TRV', 2), ('AGO', 2), ('VRTX', 2), ('BK', 2), ('PDCO', 2), ('GMED', 2), ('ANF', 2), ('ICHR', 1), ('AVGO', 1), ('NVDA', 1), ('UCTT', 1), ('ARWR', 1), ('LITE', 1), ('MATX', 1), ('MKSI', 1), ('FTSM', 1), ('CI', 1), ('X', 1), ('DELL', 1), ('ABT', 1), ('NXST', 1), ('SRPT', 1), ('MRK', 1), ('MMSI', 1)], [('SHV', 3), ('HA', 3), ('HY', 3), ('MDC', 3), ('FTSM', 2), ('CYTK', 2), ('AXGN', 2), ('FATE', 2), ('TRV', 2), ('IBP', 2), ('BK', 2), ('JNPR', 2), ('BURL', 2), ('DHI', 2), ('FFWM', 2), ('AGO', 2), ('ANF', 2), ('BCC', 2), ('AMD', 2), ('MBI', 1), ('WING', 1), ('NTNX', 1), ('RCL', 1), ('PI', 1), ('KKR', 1), ('COLL', 1), ('NTRA', 1), ('TT', 1), ('PLNT', 1), ('NOMD', 1), ('X', 1), ('PH', 1), ('PFGC', 1), ('TGT', 1), ('WM', 1), ('WAB', 1), ('RCI', 1)]]
# **** finish lookback slices [(95, 110, 114), (80, 110, 114), (50, 110, 114)] ****
#
# top 20 ranked symbols and frequency from set [(95, 110, 114), (80, 110, 114), (50, 110, 114)]:
# [('JNPR', 7), ('SHV', 7), ('TRV', 7), ('HY', 6), ('AMD', 5), ('CYTK', 5), ('FFWM', 5), ('SMCI', 5), ('AGO', 4), ('ANF', 4), ('AXGN', 4), ('BK', 4), ('FATE', 4), ('LAZ', 4), ('MRK', 4), ('ALL', 3), ('BSX', 3), ('CIEN', 3), ('FTSM', 3), ('GKOS', 3)]
# top 0 to 10 symbols from the top 20 ranked symbols from set [(95, 110, 114), (80, 110, 114), (50, 110, 114)]:
# ['JNPR', 'SHV', 'TRV', 'HY', 'AMD', 'CYTK', 'FFWM', 'SMCI', 'AGO', 'ANF']
# ===== finish top 20 ranked symbols from days_lookback set [(95, 110, 114), (80, 110, 114), (50, 110, 114)] =====
#
#
# random_max_lookback_tuples:      [(80, 140, 144), (50, 110, 114)]
# set_lookback_slices 1 of   2:    [(125, 140, 144), (110, 140, 144), (80, 140, 144)]
#
# max_days_lookbacks:              60
# df end date for days_lookbacks:  2024-03-04
# days_lookbacks:                  [15, 30, 60]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      ['EME']
# sym_freq_8:                      ['DELL', 'VST']
# sym_freq_7:                      ['GE']
# sym_freq_6:                      ['GBTC']
# sym_freq_5:                      ['BTC-USD', 'EVBG', 'SHAK', 'SHV', 'SMCI', 'STRL']
# sym_freq_4:                      ['BWXT', 'CARA', 'CELH', 'CLS', 'DNOW', 'ETH-USD', 'NTRA', 'NVDA']
# sym_freq_3:                      ['ALSN']
# sym_freq_2:                      []
#
# random_max_lookback_tuples:      [(80, 140, 144), (50, 110, 114)]
# set_lookback_slices 2 of   2:    [(95, 110, 114), (80, 110, 114), (50, 110, 114)]
#
# max_days_lookbacks:              60
# df end date for days_lookbacks:  2024-01-19
# days_lookbacks:                  [15, 30, 60]
# sym_freq_15:                     []
# sym_freq_14:                     []
# sym_freq_13:                     []
# sym_freq_12:                     []
# sym_freq_11:                     []
# sym_freq_10:                     []
# sym_freq_9:                      []
# sym_freq_8:                      []
# sym_freq_7:                      ['JNPR', 'SHV', 'TRV']
# sym_freq_6:                      ['HY']
# sym_freq_5:                      ['AMD', 'CYTK', 'FFWM', 'SMCI']
# sym_freq_4:                      ['AGO', 'ANF', 'AXGN', 'BK', 'FATE', 'LAZ', 'MRK']
# sym_freq_3:                      ['ALL', 'BSX', 'CIEN', 'FTSM', 'GKOS']
# sym_freq_2:                      []
#
# z_grp_top_set_syms_n_freq:
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
#
#
# 1 of 2 max_lookback_slice: (80, 140, 144)
#
# len(idx_train): 60
# idx_train: DatetimeIndex(['2023-12-06', '2023-12-07', '2023-12-08', '2023-12-11', '2023-12-12', '2023-12-13', '2023-12-14', '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05', '2024-01-08', '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25',
#                '2024-01-26', '2024-01-29', '2024-01-30', '2024-01-31', '2024-02-01', '2024-02-02', '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09', '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16', '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23', '2024-02-26', '2024-02-27', '2024-02-28', '2024-02-29', '2024-03-01', '2024-03-04'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-12-06 - 2024-03-04
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2024-03-05 - 2024-03-08
#
# top_set_syms_n_freq: [('EME', 9), ('DELL', 8), ('VST', 8), ('GE', 7), ('GBTC', 6), ('BTC-USD', 5), ('EVBG', 5), ('SHAK', 5), ('SHV', 5), ('SMCI', 5), ('STRL', 5), ('BWXT', 4), ('CARA', 4), ('CELH', 4), ('CLS', 4), ('DNOW', 4), ('ETH-USD', 4), ('NTRA', 4), ('NVDA', 4), ('ALSN', 3)]
#
# set_lookback_slices: [(125, 140, 144), (110, 140, 144), (80, 140, 144)]
# max_lookback_slice:  (80, 140, 144)
# days_lookbacks:      [15, 30, 60]
# date_end_df_train:   2024-03-04
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          ['EME']
# sym_freq_8:          ['DELL', 'VST']
# sym_freq_7:          ['GE']
# sym_freq_6:          ['GBTC']
# sym_freq_5:          ['BTC-USD', 'EVBG', 'SHAK', 'SHV', 'SMCI', 'STRL']
# sym_freq_4:          ['BWXT', 'CARA', 'CELH', 'CLS', 'DNOW', 'ETH-USD', 'NTRA', 'NVDA']
# sym_freq_3:          ['ALSN']
# sym_freq_2:          []
#
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 9
#
# df_eval_n_SPY:
#                    EME         SPY
# Date
# 2024-03-05  324.660004  505.609039
# 2024-03-06  325.730011  508.171082
# 2024-03-07  325.839996  513.215393
# 2024-03-08  325.010010  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              0.0947
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean                          74.3802
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean                     39.7121
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                        1.8730
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: []
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 8
#
# df_eval_n_SPY:
#               DELL        VST         SPY
# Date
# 2024-03-05  117.75  58.889999  505.609039
# 2024-03-06  118.50  60.900002  508.171082
# 2024-03-07  120.50  61.680000  513.215393
# 2024-03-08  116.25  60.490002  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                              3.9226
# grp(CAGR)_std                               4.5820
# grp(CAGR)_mean/std                          0.8561
# grp(CAGR/UI)_mean                         422.1133
# grp(CAGR/UI)_std                          459.5031
# grp(CAGR/UI)_mean/std                       0.9186
# grp(CAGR/retnStd)_mean                    179.0151
# grp(CAGR/retnStd)_std                     208.2965
# grp(CAGR/retnStd)_mean/std                  0.8594
# grp(retnStd/UI)_mean                        1.7766
# grp(retnStd/UI)_std                         0.4997
# grp(retnStd/UI)_mean/std                    3.5555
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                     GE         SPY
# Date
# 2024-03-05  157.860001  505.609039
# 2024-03-06  159.500000  508.171082
# 2024-03-07  166.500000  513.215393
# 2024-03-08  167.960007  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            181.9944
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean                 363,988,789.2678
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean                 11,243.5276
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                   32,373.1842
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                  GBTC         SPY
# Date
# 2024-03-05  55.230000  505.609039
# 2024-03-06  59.799999  508.171082
# 2024-03-07  60.450001  513.215393
# 2024-03-08  61.900002  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                         14,430.5204
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                             inf
# grp(CAGR/UI)_mean              28,861,040,861.8052
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                          inf
# grp(CAGR/retnStd)_mean                461,735.4191
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                     inf
# grp(retnStd/UI)_mean                   62,505.5815
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                  BTC-USD       EVBG        SHAK         SHV         SMCI        STRL         SPY
# Date
# 2024-03-05  63801.199219  35.290001  100.190002  110.139999  1090.829956  108.410004  505.609039
# 2024-03-06  66106.804688  35.150002  100.959999  110.160004  1124.699951  110.139999  508.171082
# 2024-03-07  66925.484375  35.099998  104.440002  110.199997  1159.760010  109.639999  513.215393
# 2024-03-08  68300.093750  35.009998  103.629997  110.209999  1140.010010  111.160004  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             61.2436
# grp(CAGR)_std                             109.8627
# grp(CAGR)_mean/std                          0.5575
# grp(CAGR/UI)_mean                 101,697,496.4900
# grp(CAGR/UI)_std                  227,348,179.1336
# grp(CAGR/UI)_mean/std                       0.4473
# grp(CAGR/retnStd)_mean                  5,736.0363
# grp(CAGR/retnStd)_std                  11,296.4108
# grp(CAGR/retnStd)_mean/std                  0.5078
# grp(retnStd/UI)_mean                    3,324.4935
# grp(retnStd/UI)_std                     7,327.9000
# grp(retnStd/UI)_mean/std                    0.4537
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 4
#
# df_eval_n_SPY:
#                   BWXT   CARA       CELH        CLS   DNOW      ETH-USD       NTRA        NVDA         SPY
# Date
# 2024-03-05  104.601608  0.910  86.730003  45.779999  14.29  3554.964600  87.620003  859.640015  505.609039
# 2024-03-06  105.359886  0.990  87.489998  47.200001  14.58  3819.226318  90.220001  887.000000  508.171082
# 2024-03-07  105.310005  1.050  89.559998  47.369999  14.84  3874.347656  91.660004  926.690002  513.215393
# 2024-03-08  103.190002  0.981  88.889999  46.099998  14.73  3892.061035  89.059998  875.280029  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            323.9675
# grp(CAGR)_std                             664.3467
# grp(CAGR)_mean/std                          0.4876
# grp(CAGR/UI)_mean                 504,258,839.6912
# grp(CAGR/UI)_std                1,334,135,144.2711
# grp(CAGR/UI)_mean/std                       0.3780
# grp(CAGR/retnStd)_mean                  9,412.0884
# grp(CAGR/retnStd)_std                  21,333.9500
# grp(CAGR/retnStd)_mean/std                  0.4412
# grp(retnStd/UI)_mean                    7,708.5976
# grp(retnStd/UI)_std                    20,389.3449
# grp(retnStd/UI)_mean/std                    0.3781
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 323.96750236569784, 664.3467365673824, 0.4876482182175044, 504258839.69122034, 1334135144.271065, 0.3779668363108249, 9412.088404154136, 21333.950046692276, 0.4411788901518232, 7708.597574432054, 20389.3448863839, 0.37806989961604365, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# iloc_start_eval:    140,  df_eval first date: 2024-03-05
# iloc_end_eval:      144,  df_eval last date:  2024-03-08
# frequency count of symbol(s): 3
#
# df_eval_n_SPY:
#                  ALSN         SPY
# Date
# 2024-03-05  75.309998  505.609039
# 2024-03-06  76.230003  508.171082
# 2024-03-07  75.389999  513.215393
# 2024-03-08  74.040001  510.134979
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.7604
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -49.4227
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -59.0010
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.8377
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.1140
# SPY_CAGR/UI                               371.1949
# SPY_CAGR/retnStd                          167.1271
# SPY_retnStd/UI                              2.2210
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 323.96750236569784, 664.3467365673824, 0.4876482182175044, 504258839.69122034, 1334135144.271065, 0.3779668363108249, 9412.088404154136, 21333.950046692276, 0.4411788901518232, 7708.597574432054, 20389.3448863839, 0.37806989961604365, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.7603608988154025, 0.0, -inf, -49.422711909980784, 0.0, -inf, -59.00098821408546, 0.0, -inf, 0.8376590529407772, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# ================================================================================
#
#
#
# 2 of 2 max_lookback_slice: (50, 110, 114)
#
# len(idx_train): 60
# idx_train: DatetimeIndex(['2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-30', '2023-10-31', '2023-11-01', '2023-11-02', '2023-11-03', '2023-11-06', '2023-11-07', '2023-11-08', '2023-11-09', '2023-11-10', '2023-11-13', '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17', '2023-11-20', '2023-11-21', '2023-11-22', '2023-11-24', '2023-11-27', '2023-11-28', '2023-11-29', '2023-11-30', '2023-12-01', '2023-12-04', '2023-12-05', '2023-12-06', '2023-12-07', '2023-12-08', '2023-12-11',
#                '2023-12-12', '2023-12-13', '2023-12-14', '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20', '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05', '2024-01-08', '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# df_train_dates (inclusive): 2023-10-24 - 2024-01-19
#
# len(idx_eval): 4
# idx_eval: DatetimeIndex(['2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25'], dtype='datetime64[ns]', name='Date', freq=None)
# df_eval dates (inclusive): 2024-01-22 - 2024-01-25
#
# top_set_syms_n_freq: [('JNPR', 7), ('SHV', 7), ('TRV', 7), ('HY', 6), ('AMD', 5), ('CYTK', 5), ('FFWM', 5), ('SMCI', 5), ('AGO', 4), ('ANF', 4), ('AXGN', 4), ('BK', 4), ('FATE', 4), ('LAZ', 4), ('MRK', 4), ('ALL', 3), ('BSX', 3), ('CIEN', 3), ('FTSM', 3), ('GKOS', 3)]
#
# set_lookback_slices: [(95, 110, 114), (80, 110, 114), (50, 110, 114)]
# max_lookback_slice:  (50, 110, 114)
# days_lookbacks:      [15, 30, 60]
# date_end_df_train:   2024-01-19
# sym_freq_15:         []
# sym_freq_14:         []
# sym_freq_13:         []
# sym_freq_12:         []
# sym_freq_10:         []
# sym_freq_9:          []
# sym_freq_8:          []
# sym_freq_7:          ['JNPR', 'SHV', 'TRV']
# sym_freq_6:          ['HY']
# sym_freq_5:          ['AMD', 'CYTK', 'FFWM', 'SMCI']
# sym_freq_4:          ['AGO', 'ANF', 'AXGN', 'BK', 'FATE', 'LAZ', 'MRK']
# sym_freq_3:          ['ALL', 'BSX', 'CIEN', 'FTSM', 'GKOS']
# sym_freq_2:          []
#
# iloc_start_eval:    110,  df_eval first date: 2024-01-22
# iloc_end_eval:      114,  df_eval last date:  2024-01-25
# frequency count of symbol(s): 7
#
# df_eval_n_SPY:
#                  JNPR         SHV         TRV         SPY
# Date
# 2024-01-22  37.247505  109.521843  212.890640  481.952576
# 2024-01-23  37.068577  109.521843  210.023682  483.358185
# 2024-01-24  36.969166  109.531754  210.023682  483.886566
# 2024-01-25  37.008930  109.591263  210.561249  486.518372
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.3219
# grp(CAGR)_std                               0.2769
# grp(CAGR)_mean/std                         -1.1625
# grp(CAGR/UI)_mean                      36,401.6914
# grp(CAGR/UI)_std                       51,572.4624
# grp(CAGR/UI)_mean/std                       0.7058
# grp(CAGR/retnStd)_mean                     -9.1230
# grp(CAGR/retnStd)_std                     172.6810
# grp(CAGR/retnStd)_mean/std                 -0.0528
# grp(retnStd/UI)_mean                      158.8126
# grp(retnStd/UI)_std                       223.8284
# grp(retnStd/UI)_mean/std                    0.7095
# SPY_CAGR                                    1.2079
# SPY_CAGR/UI                         2,415,753.8811
# SPY_CAGR/retnStd                          677.9058
# SPY_retnStd/UI                          3,563.5538
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 323.96750236569784, 664.3467365673824, 0.4876482182175044, 504258839.69122034, 1334135144.271065, 0.3779668363108249, 9412.088404154136, 21333.950046692276, 0.4411788901518232, 7708.597574432054, 20389.3448863839, 0.37806989961604365, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.7603608988154025, 0.0, -inf, -49.422711909980784, 0.0, -inf, -59.00098821408546, 0.0, -inf, 0.8376590529407772, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.32186130715196304, 0.27686614839939555, -1.1625159269657601, 36401.691410792664, 51572.46243892864, 0.7058358218574305, -9.12299437752237, 172.68099903976074, -0.052831489441532306, 158.81262378511101, 223.82844446773188, 0.7095283361449897, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# iloc_start_eval:    110,  df_eval first date: 2024-01-22
# iloc_end_eval:      114,  df_eval last date:  2024-01-25
# frequency count of symbol(s): 6
#
# df_eval_n_SPY:
#                    HY         SPY
# Date
# 2024-01-22  68.963600  481.952576
# 2024-01-23  67.034416  483.358185
# 2024-01-24  66.059868  483.886566
# 2024-01-25  67.760345  486.518372
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                             -0.7720
# grp(CAGR)_std                               0.0000
# grp(CAGR)_mean/std                            -inf
# grp(CAGR/UI)_mean                         -28.8732
# grp(CAGR/UI)_std                            0.0000
# grp(CAGR/UI)_mean/std                         -inf
# grp(CAGR/retnStd)_mean                    -33.8258
# grp(CAGR/retnStd)_std                       0.0000
# grp(CAGR/retnStd)_mean/std                    -inf
# grp(retnStd/UI)_mean                        0.8536
# grp(retnStd/UI)_std                         0.0000
# grp(retnStd/UI)_mean/std                       inf
# SPY_CAGR                                    1.2079
# SPY_CAGR/UI                         2,415,753.8811
# SPY_CAGR/retnStd                          677.9058
# SPY_retnStd/UI                          3,563.5538
#
# type(l_row_add_total): <class 'list'>
# l_row_add_total: [[2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 323.96750236569784, 664.3467365673824, 0.4876482182175044, 504258839.69122034, 1334135144.271065, 0.3779668363108249, 9412.088404154136, 21333.950046692276, 0.4411788901518232, 7708.597574432054, 20389.3448863839, 0.37806989961604365, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.7603608988154025, 0.0, -inf, -49.422711909980784, 0.0, -inf, -59.00098821408546, 0.0, -inf, 0.8376590529407772, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413], [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.32186130715196304, 0.27686614839939555, -1.1625159269657601, 36401.691410792664, 51572.46243892864, 0.7058358218574305, -9.12299437752237, 172.68099903976074, -0.052831489441532306, 158.81262378511101, 223.82844446773188, 0.7095283361449897, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]]
# type(row_add_total): <class 'list'>
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.7720300280730549, 0.0, -inf, -28.873202642859553, 0.0, -inf, -33.82575187420689, 0.0, -inf, 0.8535864258164858, 0.0, inf, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# iloc_start_eval:    110,  df_eval first date: 2024-01-22
# iloc_end_eval:      114,  df_eval last date:  2024-01-25
# frequency count of symbol(s): 5
#
# df_eval_n_SPY:
#                    AMD       CYTK       FFWM        SMCI         SPY
# Date
# 2024-01-22  168.179993  83.690002  10.758086  436.239990  481.952576
# 2024-01-23  168.419998  84.800003  10.738109  457.380005  483.358185
# 2024-01-24  178.289993  81.769997  10.917910  470.190002  483.886566
# 2024-01-25  180.330002  82.910004  10.208694  475.579987  486.518372
#
# Function compare_picks_v_SPY returned column_name:value pairs
# column_name                                  value
# grp(CAGR)_mean                            439.7420
# grp(CAGR)_std                             578.7092
# grp(CAGR)_mean/std                          0.7599
# grp(CAGR/UI)_mean                 880,250,242.0059
# grp(CAGR/UI)_std                1,156,835,242.6575
# grp(CAGR/UI)_mean/std                       0.7609
# grp(CAGR/retnStd)_mean                 26,803.9814
# grp(CAGR/retnStd)_std                  38,788.2203
# grp(CAGR/retnStd)_mean/std                  0.6910
# grp(retnStd/UI)_mean                   20,031.4945
# grp(retnStd/UI)_std                    21,194.8692
# grp(retnStd/UI)_mean/std                    0.9451
# SPY_CAGR                                    1.2079
# SPY_CAGR/UI                         2,415,753.8811
# SPY_CAGR/retnStd                          677.9058
# SPY_retnStd/UI                          3,563.5538
#
# ...
#
#
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 323.96750236569784, 664.3467365673824, 0.4876482182175044, 504258839.69122034, 1334135144.271065, 0.3779668363108249, 9412.088404154136, 21333.950046692276, 0.4411788901518232, 7708.597574432054, 20389.3448863839, 0.37806989961604365, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.7603608988154025, 0.0, -inf, -49.422711909980784, 0.0, -inf, -59.00098821408546, 0.0, -inf, 0.8376590529407772, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.32186130715196304, 0.27686614839939555, -1.1625159269657601, 36401.691410792664, 51572.46243892864, 0.7058358218574305, -9.12299437752237, 172.68099903976074, -0.052831489441532306, 158.81262378511101, 223.82844446773188, 0.7095283361449897, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.7720300280730549, 0.0, -inf, -28.873202642859553, 0.0, -inf, -33.82575187420689, 0.0, -inf, 0.8535864258164858, 0.0, inf, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 439.74204013284657, 578.7091869012563, 0.759867045635615, 880250242.00591, 1156835242.6575255, 0.760912366383104, 26803.98139601465, 38788.220269866244, 0.69103406161788, 20031.494463556566, 21194.869219246506, 0.945110548045585, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 9.986067056466895, 24.361325683824234, 0.40991476350967143, 1941.5669723950025, 3027.803901058957, 0.6412459445329173, 423.7087799582491, 911.063352832894, 0.4650705998005006, 3.9923558598787747, 6.1632438309777555, 0.6477686051965618, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# row_add_total: [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.0280164683189228, 2.5659609243034054, 0.400636057463737, 41567.4251506376, 82426.7489237208, 0.504295337295237, 150.18910282882544, 295.5253820298541, 0.5082105022493577, 84.56490709278387, 166.07394592564506, 0.5092003241173388, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
# df_eval_results BEFORW store results:
# Empty DataFrame
# Columns: [n_samples, days_lookbacks, days_eval, n_top_syms, syms_start, syms_end, sym_freq_cnt, grp(CAGR)_mean, grp(CAGR)_std, grp(CAGR)_mean/std, grp(CAGR/UI)_mean, grp(CAGR/UI)_std, grp(CAGR/UI)_mean/std, grp(CAGR/retnStd)_mean, grp(CAGR/retnStd)_std, grp(CAGR/retnStd)_mean/std, grp(retnStd/UI)_mean, grp(retnStd/UI)_std, grp(retnStd/UI)_mean/std, SPY_CAGR, SPY_CAGR/UI, SPY_CAGR/retnStd, SPY_retnStd/UI]
# Index: []
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 9, 0.09473144078293827, 0.0, inf, 74.38022095595782, 0.0, inf, 39.712072845214415, 0.0, inf, 1.872987623835938, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 8, 3.922597519345322, 4.581960500001838, 0.8560958828308862, 422.1133106044475, 459.50307021344054, 0.9186300113476383, 179.01507478218147, 208.29653289671285, 0.8594241694409237, 1.7765773867962316, 0.4996683113414897, 3.5555134205460157, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 7, 181.994394633879, 0.0, inf, 363988789.267758, 0.0, inf, 11243.52758902205, 0.0, inf, 32373.184161806057, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 6, 14430.520430902587, 0.0, inf, 28861040861.805176, 0.0, inf, 461735.419080339, 0.0, inf, 62505.5814849316, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 61.2435738572239, 109.86269382208869, 0.5574555995905358, 101697496.49000667, 227348179.1335633, 0.4473204794407483, 5736.036336639757, 11296.41081872188, 0.5077751180165342, 3324.4934878541567, 7327.899996969401, 0.45367615404537004, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 323.96750236569784, 664.3467365673824, 0.4876482182175044, 504258839.69122034, 1334135144.271065, 0.3779668363108249, 9412.088404154136, 21333.950046692276, 0.4411788901518232, 7708.597574432054, 20389.3448863839, 0.37806989961604365, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 3, -0.7603608988154025, 0.0, -inf, -49.422711909980784, 0.0, -inf, -59.00098821408546, 0.0, -inf, 0.8376590529407772, 0.0, inf, 1.1139903591320697, 371.19493272411063, 167.12705068086387, 2.2210344238822413]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 7, -0.32186130715196304, 0.27686614839939555, -1.1625159269657601, 36401.691410792664, 51572.46243892864, 0.7058358218574305, -9.12299437752237, 172.68099903976074, -0.052831489441532306, 158.81262378511101, 223.82844446773188, 0.7095283361449897, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 6, -0.7720300280730549, 0.0, -inf, -28.873202642859553, 0.0, -inf, -33.82575187420689, 0.0, -inf, 0.8535864258164858, 0.0, inf, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 5, 439.74204013284657, 578.7091869012563, 0.759867045635615, 880250242.00591, 1156835242.6575255, 0.760912366383104, 26803.98139601465, 38788.220269866244, 0.69103406161788, 20031.494463556566, 21194.869219246506, 0.945110548045585, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 4, 9.986067056466895, 24.361325683824234, 0.40991476350967143, 1941.5669723950025, 3027.803901058957, 0.6412459445329173, 423.7087799582491, 911.063352832894, 0.4650705998005006, 3.9923558598787747, 6.1632438309777555, 0.6477686051965618, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
#
# appended row_add_total to df_eval_results:
# [2, '[15, 30, 60]', 4, 20, 0, 10, 3, 1.0280164683189228, 2.5659609243034054, 0.400636057463737, 41567.4251506376, 82426.7489237208, 0.504295337295237, 150.18910282882544, 295.5253820298541, 0.5082105022493577, 84.56490709278387, 166.07394592564506, 0.5092003241173388, 1.2078769405359688, 2415753.8810719377, 677.9058289416636, 3563.5537827479325]
#
# Save results to: df_eval_results_test
# df_eval_results AFTER store results:
#     n_samples days_lookbacks  days_eval  n_top_syms  syms_start  syms_end  sym_freq_cnt  grp(CAGR)_mean  grp(CAGR)_std  grp(CAGR)_mean/std  grp(CAGR/UI)_mean  grp(CAGR/UI)_std  grp(CAGR/UI)_mean/std  grp(CAGR/retnStd)_mean  grp(CAGR/retnStd)_std  grp(CAGR/retnStd)_mean/std  grp(retnStd/UI)_mean  grp(retnStd/UI)_std  grp(retnStd/UI)_mean/std  SPY_CAGR   SPY_CAGR/UI  SPY_CAGR/retnStd  SPY_retnStd/UI
# 0           2   [15, 30, 60]          4          20           0        10             9        0.094731       0.000000                 inf       7.438022e+01      0.000000e+00                  inf              39.712073                0.000000                    inf                    1.872988              0.000000                  inf       1.113990  3.711949e+02        167.127051        2.221034
# 1           2   [15, 30, 60]          4          20           0        10             8        3.922598       4.581961            0.856096       4.221133e+02      4.595031e+02             0.918630             179.015075              208.296533               0.859424                    1.776577              0.499668             3.555513       1.113990  3.711949e+02        167.127051        2.221034
# 2           2   [15, 30, 60]          4          20           0        10             7      181.994395       0.000000                 inf       3.639888e+08      0.000000e+00                  inf           11243.527589                0.000000                    inf                32373.184162              0.000000                  inf       1.113990  3.711949e+02        167.127051        2.221034
# 3           2   [15, 30, 60]          4          20           0        10             6    14430.520431       0.000000                 inf       2.886104e+10      0.000000e+00                  inf          461735.419080                0.000000                    inf                62505.581485              0.000000                  inf       1.113990  3.711949e+02        167.127051        2.221034
# 4           2   [15, 30, 60]          4          20           0        10             5       61.243574     109.862694            0.557456       1.016975e+08      2.273482e+08             0.447320            5736.036337            11296.410819               0.507775                 3324.493488           7327.899997             0.453676       1.113990  3.711949e+02        167.127051        2.221034
# ..        ...            ...        ...         ...         ...       ...           ...             ...            ...                 ...                ...               ...                  ...                    ...                     ...                    ...                         ...                   ...                  ...            ...           ...               ...             ...
# 7           2   [15, 30, 60]          4          20           0        10             7       -0.321861       0.276866           -1.162516       3.640169e+04      5.157246e+04             0.705836              -9.122994              172.680999              -0.052831                  158.812624            223.828444             0.709528       1.207877  2.415754e+06        677.905829     3563.553783
# 8           2   [15, 30, 60]          4          20           0        10             6       -0.772030       0.000000                -inf      -2.887320e+01      0.000000e+00                 -inf             -33.825752                0.000000                   -inf                    0.853586              0.000000                  inf       1.207877  2.415754e+06        677.905829     3563.553783
# 9           2   [15, 30, 60]          4          20           0        10             5      439.742040     578.709187            0.759867       8.802502e+08      1.156835e+09             0.760912           26803.981396            38788.220270               0.691034                20031.494464          21194.869219             0.945111       1.207877  2.415754e+06        677.905829     3563.553783
# 10          2   [15, 30, 60]          4          20           0        10             4        9.986067      24.361326            0.409915       1.941567e+03      3.027804e+03             0.641246             423.708780              911.063353               0.465071                    3.992356              6.163244             0.647769       1.207877  2.415754e+06        677.905829     3563.553783
# 11          2   [15, 30, 60]          4          20           0        10             3        1.028016       2.565961            0.400636       4.156743e+04      8.242675e+04             0.504295             150.189103              295.525382               0.508211                   84.564907            166.073946             0.509200       1.207877  2.415754e+06        677.905829     3563.553783
#
# [12 rows x 23 columns]
