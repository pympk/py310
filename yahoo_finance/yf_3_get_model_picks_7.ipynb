# %% [markdown]
# #### The code finds the recent dates in df_picks that are missing in df_model_top_picks. For those missing dates, it finds stock picks in df_picks that meet the 'criteria_model_top_picks' and append them to df_model_top_picks.

# %%
import os


# Get the user's home directory Documents folder
path_dir = os.path.join(os.path.expanduser('~'), 'Documents/')
path_data_dump = path_dir + "VSCode_dump/"

print(f'path_dir: {path_dir}')
print(f'path_data_dump: {path_data_dump}')

# %%
import pandas as pd
from itertools import product
from ast import literal_eval
from datetime import datetime
from myUtils import pickle_load, pickle_dump

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.width', 900)

# # path_dir = "C:/Users/ping/MyDrive/stocks/yfinance/"
# path_dir = "G:/My Drive/stocks/yfinance/"
# path_data_dump = path_dir + "VSCode_dump/"

fp_df_picks  = f'df_picks'  # stock picks by criteria: CAGR/UI, CAGR/rtn_std, rtd/UI
fp_df_model_top_picks = f'df_model_top_picks'  # top stock picks from model developed by back test

verbose = True
# verbose = False

# %%
print(f'Model predicts the best performing symbols are from df_filtered_picks  columns:')
print(f'performance   {"days_lookbacks":<20}{"sym_freq":<14}{"days_eval":<20}')
print(f'1st           {"[30, 60, 120]":<20}{"sym_freq_9":<14}{"days_eval = 4":<20}')
print(f'2nd           {"[15, 30, 60, 120]":<20}{"sym_freq_12":<14}{"days_eval = 5":<20}')
print(f'3rd           {"[30, 60, 120]":<20}{"sym_freq_8":<14}{"days_eval = 4":<20}')

criteria_model_top_picks = [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]
print(f'\nmodel criteria for top picks:\n{criteria_model_top_picks}')
# Out:
# Model predicts the best performing symbols are from df_filtered_picks  columns:
# performance   days_lookbacks      sym_freq      days_eval
# 1st           [30, 60, 120]       sym_freq_9    days_eval = 4
# 2nd           [15, 30, 60, 120]   sym_freq_12   days_eval = 5
# 3rd           [30, 60, 120]       sym_freq_8    days_eval = 4
#
# model criteria for top picks:
# [([30, 60, 120], 'sym_freq_9'), ([15, 30, 60, 120], 'sym_freq_12'), ([30, 60, 120], 'sym_freq_8')]

# %% [markdown]
# #### Criteria of the best stocks from the model

# %%
# Define lists for lookback periods and column names:

# 1. Lookback periods (in days) for two potential scenarios:
my_days_lookbacks = [
    [30, 60, 120],  # Scenario 1: Lookbacks of 30, 60, and 120 days
    [15, 30, 60, 120]  # Scenario 2: Lookbacks of 15, 30, 60, and 120 days
]

# 2. Columns to be used in the analysis:
my_cols = ['sym_freq_12', 'sym_freq_9', 'sym_freq_8']  # Columns representing frequencies

# %%
# Load the DataFrame from a pickle file
df_model_top_picks = pickle_load(path_data_dump, fp_df_model_top_picks)

# Print the length of the DataFrame
print(f'Length of df_model_top_picks: {len(df_model_top_picks)}')

# Print the first 5 rows of the DataFrame
print(df_model_top_picks.head(), '\n')

# Print the last 5 rows of the DataFrame
print(df_model_top_picks.tail())
# Out:
# Length of df_model_top_picks: 1629
#          date  days_lookback   syms_freq                  symbols
# 0  2024-06-14  [30, 60, 120]  sym_freq_9                  ['SHV']
# 1  2024-06-14  [30, 60, 120]  sym_freq_8                 ['FTSM']
# 2  2024-06-13  [30, 60, 120]  sym_freq_9                  ['SHV']
# 3  2024-06-13  [30, 60, 120]  sym_freq_8                 ['FTSM']
# 4  2024-06-12  [30, 60, 120]  sym_freq_8  ['FTSM', 'NVAX', 'SHV']
#
#             date  days_lookback   syms_freq   symbols
# 1624  2018-07-12  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1625  2018-07-11  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1626  2018-07-10  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1627  2018-07-09  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1628  2018-07-06  [30, 60, 120]  sym_freq_8  ['TNDM']

# %%
# 1. Extract dates from DataFrame:
dates_in_model = df_model_top_picks.date.tolist()  # Convert date column to a list

# 2. Find the latest date:
latest_date_in_model = max(dates_in_model, key=lambda x: datetime.strptime(x, "%Y-%m-%d"))

# 3. Print the latest date:
print(f"Latest date in model: {latest_date_in_model}")
# Out:
# Latest date in model: 2024-06-14

# %% [markdown]
# #### Clean df_picks_pick data:<br>- drop duplicates<br>- sort on date<br>- re-index<br>- save

# %%
# 1. Load data from pickle file fpdf_model_top_picks_picks
print(f"Load the DataFrame from a pickle file {fp_df_picks }")
df_picks  = pickle_load(path_data_dump, fp_df_picks)

# 2. Drop duplicates, keeping the last occurrence
print("Dropping duplicates, keeping last occurrence...")
df_picks = df_picks.drop_duplicates(subset=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], keep='last')

# 3. Sort by date, max lookback, then lookback (descending)
print("Sorting by date, max lookback, then lookback (descending)...")
df_picks = df_picks.sort_values(by=['date_end_df_train', 'max_days_lookbacks', 'days_lookbacks'], ascending=False)

# 4. Reset index (optional)
print("Resetting index...")
df_picks = df_picks.reset_index(drop=True)

# 5. Save data to pickle (replace with actual saving)
# Comment: Save the modified DataFrame back to a pickle file
print(f"Save the modified DataFrame back to a pickle file {fp_df_picks}")
pickle_dump(df_picks, path_data_dump, fp_df_picks)

# 6. Print information about the DataFrame
print(f"Number of rows: {len(df_picks)}")
print(df_picks)
# Out:
# Load the DataFrame from a pickle file df_picks
# Dropping duplicates, keeping last occurrence...
# Sorting by date, max lookback, then lookback (descending)...
# Resetting index...
# Save the modified DataFrame back to a pickle file df_picks
# Number of rows: 3104
#      date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11 sym_freq_10        sym_freq_9                     sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0           2024-08-30                 120      [30, 60, 120]          []          []          []          []          []          []           ['SHV']                             []                       ['FTSM']  ['EVRI', 'LMT', 'MMM', 'VTR']  ['ACIW', 'ALNY', 'GDS', 'L...  ['CNK', 'COMM', 'MD', 'RVNC']  ['ADC', 'AFL', 'AXGN', 'CR...         []
# 1           2024-08-30                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']          []                []                             []                ['FTSM', 'GDS']  ['EVRI', 'LMT', 'MMM', 'VTR']  ['ACIW', 'ALNY', 'COMM', '...  ['CNK', 'K', 'MD', 'RVNC',...  ['ACGL', 'ADC', 'AFL', 'AX...         []
# 2           2024-08-29                 120      [30, 60, 120]          []          []          []          []          []          []                []                        ['SHV']                ['FTSM', 'MMM']        ['ACIW', 'EVRI', 'VTR']  ['ALNY', 'CNK', 'COMM', 'L...  ['APPS', 'GDS', 'RVNC', 'T...  ['BGNE', 'CRS', 'CVLT', 'G...         []
# 3           2024-08-29                 120  [15, 30, 60, 120]          []          []          []          []          []     ['SHV']                []                             []  ['COMM', 'FTSM', 'MMM', 'R...  ['ACIW', 'EVRI', 'GDS', 'V...  ['ALNY', 'CNK', 'LMT', 'LU...   ['APPS', 'K', 'SMTC', 'TSE']                ['AFL', 'BGNE']         []
# 4           2024-08-28                 120      [30, 60, 120]          []          []          []          []          []          []           ['SHV']                             []                ['FTSM', 'MMM']  ['ACIW', 'CNK', 'COMM', 'E...  ['ALNY', 'GDS', 'LMT', 'LU...       ['APPS', 'RVNC', 'TRUP']  ['BGNE', 'CRS', 'CVLT', 'G...         []
# ...                ...                 ...                ...         ...         ...         ...         ...         ...         ...               ...                            ...                            ...                            ...                            ...                            ...                            ...        ...
# 3099        2018-07-05                 120  [15, 30, 60, 120]          []          []          []          []          []          []          ['RAMP']  ['ARWR', 'BLFS', 'NTRA', '...        ['RGNX', 'SHV', 'SRPT']               ['CATO', 'ETSY']        ['CYRX', 'FTSM', 'RUN']   ['DRI', 'MSGS', 'STAA', 'W']                ['AEE', 'AXGN']         []
# 3100        2018-07-03                 120      [30, 60, 120]          []          []          []          []          []          []                []                             []       ['CATO', 'RGNX', 'TNDM']  ['ARWR', 'BLFS', 'ETSY', '...  ['CYRX', 'FTSM', 'RUN', 'S...          ['CARA', 'MSGS', 'W']       ['AXGN', 'AXON', 'EVTC']         []
# 3101        2018-07-03                 120  [15, 30, 60, 120]          []          []          []          []          []          []  ['RAMP', 'RGNX']  ['ARWR', 'BLFS', 'ETSY', '...        ['CATO', 'SHV', 'SRPT']                       ['XENE']  ['CARA', 'CYRX', 'FTSM', '...                  ['MSGS', 'W']        ['AEE', 'AXGN', 'AXON']         []
# 3102        2018-07-02                 120      [30, 60, 120]          []          []          []          []          []          []                []                             []               ['TNDM', 'XENE']  ['ARWR', 'BLFS', 'CATO', '...                ['RUN', 'SRPT']  ['CARA', 'CYRX', 'FTSM', '...        ['AXON', 'LULU', 'NSP']         []
# 3103        2018-07-02                 120  [15, 30, 60, 120]          []          []          []          []          []          []                []  ['ARWR', 'BLFS', 'ETSY', '...                ['SHV', 'SRPT']                       ['CATO']                ['CARA', 'RUN']  ['CYRX', 'ENPH', 'FTSM', '...                ['AEE', 'AXON']         []
#
# [3104 rows x 17 columns]

# %%
# Convert the date column to datetime format for accurate filtering
df_picks['date_end_df_train'] = pd.to_datetime(df_picks['date_end_df_train'])

# Filter rows after '2013-12-31' (exclusive)
df_filtered_picks = df_picks[df_picks['date_end_df_train'] > latest_date_in_model]

# SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
pd.options.mode.chained_assignment = None  # default='warn'

# Convert the date column back to '%Y-%m-%d' format
df_filtered_picks['date_end_df_train'] = df_filtered_picks['date_end_df_train'].dt.strftime('%Y-%m-%d')

# # Print the filtered DataFrame
print(df_filtered_picks)
# Out:
#     date_end_df_train  max_days_lookbacks     days_lookbacks sym_freq_15 sym_freq_14 sym_freq_13 sym_freq_12 sym_freq_11 sym_freq_10 sym_freq_9 sym_freq_8                     sym_freq_7                     sym_freq_6                     sym_freq_5                     sym_freq_4                     sym_freq_3 sym_freq_2
# 0          2024-08-30                 120      [30, 60, 120]          []          []          []          []          []          []    ['SHV']         []                       ['FTSM']  ['EVRI', 'LMT', 'MMM', 'VTR']  ['ACIW', 'ALNY', 'GDS', 'L...  ['CNK', 'COMM', 'MD', 'RVNC']  ['ADC', 'AFL', 'AXGN', 'CR...         []
# 1          2024-08-30                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']          []         []         []                ['FTSM', 'GDS']  ['EVRI', 'LMT', 'MMM', 'VTR']  ['ACIW', 'ALNY', 'COMM', '...  ['CNK', 'K', 'MD', 'RVNC',...  ['ACGL', 'ADC', 'AFL', 'AX...         []
# 2          2024-08-29                 120      [30, 60, 120]          []          []          []          []          []          []         []    ['SHV']                ['FTSM', 'MMM']        ['ACIW', 'EVRI', 'VTR']  ['ALNY', 'CNK', 'COMM', 'L...  ['APPS', 'GDS', 'RVNC', 'T...  ['BGNE', 'CRS', 'CVLT', 'G...         []
# 3          2024-08-29                 120  [15, 30, 60, 120]          []          []          []          []          []     ['SHV']         []         []  ['COMM', 'FTSM', 'MMM', 'R...  ['ACIW', 'EVRI', 'GDS', 'V...  ['ALNY', 'CNK', 'LMT', 'LU...   ['APPS', 'K', 'SMTC', 'TSE']                ['AFL', 'BGNE']         []
# 4          2024-08-28                 120      [30, 60, 120]          []          []          []          []          []          []    ['SHV']         []                ['FTSM', 'MMM']  ['ACIW', 'CNK', 'COMM', 'E...  ['ALNY', 'GDS', 'LMT', 'LU...       ['APPS', 'RVNC', 'TRUP']  ['BGNE', 'CRS', 'CVLT', 'G...         []
# ..                ...                 ...                ...         ...         ...         ...         ...         ...         ...        ...        ...                            ...                            ...                            ...                            ...                            ...        ...
# 101        2024-06-20                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']          []         []   ['FTSM']                       ['NVDA']                ['EBS', 'NEOG']  ['BOOT', 'BSX', 'COST', 'N...  ['CRUS', 'FSLR', 'PRMW', '...  ['ANF', 'ASC', 'AVGO', 'EA...         []
# 102        2024-06-18                 120      [30, 60, 120]          []          []          []          []          []          []    ['SHV']   ['FTSM']                             []                       ['NVDA']  ['BOOT', 'BSX', 'CRUS', 'N...  ['ANF', 'COST', 'FSLR', 'K...  ['APH', 'CMG', 'EBS', 'GE'...         []
# 103        2024-06-18                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']          []         []   ['FTSM']                             []               ['NEOG', 'NVDA']  ['BOOT', 'BSX', 'CRUS', 'N...  ['ACLS', 'ANF', 'AVGO', 'C...                 ['APH', 'BBY']         []
# 104        2024-06-17                 120      [30, 60, 120]          []          []          []          []          []          []    ['SHV']   ['FTSM']                             []                             []  ['BOOT', 'BSX', 'COST', 'C...  ['GMED', 'NTRA', 'PSTG', '...  ['AAPL', 'ANF', 'AZN', 'GE...         []
# 105        2024-06-17                 120  [15, 30, 60, 120]          []          []          []          []     ['SHV']          []   ['FTSM']         []                             []        ['BOOT', 'EBS', 'NEOG']  ['AAPL', 'BSX', 'COST', 'C...  ['AVGO', 'GMED', 'NTRA', '...                        ['ANF']         []
#
# [106 rows x 17 columns]

# %% [markdown]
# #### Get dates in df_filtered_picks where values in column "days_lookbacks" matched items in my_days_lookbacks.

# %%
# Initialize an empty list to store the dates
dates_in_days_lookbacks = []

# Iterate through each days lookback configuration
for my_days_lookback in my_days_lookbacks:
    # Create a mask to filter rows based on the current days lookback
    mask_days_lookback = df_filtered_picks ['days_lookbacks'] == str(my_days_lookback)

    # Extract the ending dates for the training datasets that match the lookback
    l_dates = df_filtered_picks.loc[mask_days_lookback, 'date_end_df_train'].tolist()

    # Extend the dates list with the extracted dates (avoiding nested lists)
    dates_in_days_lookbacks.extend(l_dates)

# Remove duplicates and sort the dates from newest to oldest
dates_in_days_lookbacks = sorted(set(dates_in_days_lookbacks), reverse=True)

# Print the list of dates along with its length
print(f'dates_in_days_lookbacks, len({len(dates_in_days_lookbacks)}):\n{dates_in_days_lookbacks}')
# Out:
# dates_in_days_lookbacks, len(53):
# ['2024-08-30', '2024-08-29', '2024-08-28', '2024-08-27', '2024-08-26', '2024-08-23', '2024-08-22', '2024-08-21', '2024-08-20', '2024-08-19', '2024-08-16', '2024-08-15', '2024-08-14', '2024-08-13', '2024-08-12', '2024-08-09', '2024-08-08', '2024-08-07', '2024-08-06', '2024-08-05', '2024-08-02', '2024-08-01', '2024-07-31', '2024-07-30', '2024-07-29', '2024-07-26', '2024-07-25', '2024-07-24', '2024-07-23', '2024-07-22', '2024-07-19', '2024-07-18', '2024-07-17', '2024-07-16', '2024-07-15', '2024-07-12', '2024-07-11', '2024-07-10', '2024-07-09', '2024-07-08', '2024-07-05', '2024-07-03', '2024-07-02', '2024-07-01', '2024-06-28', '2024-06-27', '2024-06-26', '2024-06-25', '2024-06-24', '2024-06-21', '2024-06-20', '2024-06-18', '2024-06-17']

# %% [markdown]
# #### Create list of tuples of all combination of dates_in_days_lookbacks and criteria_model_top_picks

# %%
# Generate all possible combinations of dates, lookbacks, and top features
date_lookback_symfreq = list(product(
    dates_in_days_lookbacks,  # List of dates
    criteria_model_top_picks  # List of (lookback, top feature) tuples
))

# Print the resulting list of tuples, along with its length
print(f'date_lookback_symfreq, len({len(date_lookback_symfreq)}):\n{date_lookback_symfreq}')
# Out:
# date_lookback_symfreq, len(159):
# [('2024-08-30', ([30, 60, 120], 'sym_freq_9')), ('2024-08-30', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-30', ([30, 60, 120], 'sym_freq_8')), ('2024-08-29', ([30, 60, 120], 'sym_freq_9')), ('2024-08-29', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-29', ([30, 60, 120], 'sym_freq_8')), ('2024-08-28', ([30, 60, 120], 'sym_freq_9')), ('2024-08-28', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-28', ([30, 60, 120], 'sym_freq_8')), ('2024-08-27', ([30, 60, 120], 'sym_freq_9')), ('2024-08-27', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-27', ([30, 60, 120], 'sym_freq_8')), ('2024-08-26', ([30, 60, 120], 'sym_freq_9')), ('2024-08-26', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-26', ([30, 60, 120], 'sym_freq_8')), ('2024-08-23', ([30, 60, 120], 'sym_freq_9')), ('2024-08-23', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-23', ([30, 60, 120], 'sym_freq_8')), ('2024-08-22', ([30, 60, 120], 'sym_freq_9')), ('2024-08-22', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-22', ([30, 60, 120], 'sym_freq_8')), ('2024-08-21', ([30, 60, 120], 'sym_freq_9')), ('2024-08-21', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-21', ([30, 60, 120], 'sym_freq_8')), ('2024-08-20', ([30, 60, 120], 'sym_freq_9')), ('2024-08-20', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-20', ([30, 60, 120], 'sym_freq_8')), ('2024-08-19', ([30, 60, 120], 'sym_freq_9')), ('2024-08-19', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-19', ([30, 60, 120], 'sym_freq_8')), ('2024-08-16', ([30, 60, 120], 'sym_freq_9')), ('2024-08-16', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-16', ([30, 60, 120], 'sym_freq_8')), ('2024-08-15', ([30, 60, 120], 'sym_freq_9')), ('2024-08-15', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-15', ([30, 60, 120], 'sym_freq_8')), ('2024-08-14', ([30, 60, 120], 'sym_freq_9')), ('2024-08-14', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-14', ([30, 60, 120], 'sym_freq_8')), ('2024-08-13', ([30, 60, 120], 'sym_freq_9')), ('2024-08-13', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-13', ([30, 60, 120], 'sym_freq_8')), ('2024-08-12', ([30, 60, 120], 'sym_freq_9')), ('2024-08-12', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-12', ([30, 60, 120], 'sym_freq_8')), ('2024-08-09', ([30, 60, 120], 'sym_freq_9')), ('2024-08-09', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-09', ([30, 60, 120], 'sym_freq_8')), ('2024-08-08', ([30, 60, 120], 'sym_freq_9')), ('2024-08-08', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-08', ([30, 60, 120], 'sym_freq_8')), ('2024-08-07', ([30, 60, 120], 'sym_freq_9')), ('2024-08-07', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-07', ([30, 60, 120], 'sym_freq_8')), ('2024-08-06', ([30, 60, 120], 'sym_freq_9')), ('2024-08-06', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-06', ([30, 60, 120], 'sym_freq_8')), ('2024-08-05', ([30, 60, 120], 'sym_freq_9')), ('2024-08-05', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-05', ([30, 60, 120], 'sym_freq_8')), ('2024-08-02', ([30, 60, 120], 'sym_freq_9')), ('2024-08-02', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-02', ([30, 60, 120], 'sym_freq_8')), ('2024-08-01', ([30, 60, 120], 'sym_freq_9')), ('2024-08-01', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-08-01', ([30, 60, 120], 'sym_freq_8')), ('2024-07-31', ([30, 60, 120], 'sym_freq_9')), ('2024-07-31', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-07-31', ([30, 60, 120], 'sym_freq_8')), ('2024-07-30', ([30, 60, 120], 'sym_freq_9')), ('2024-07-30', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-07-30', ([30, 60, 120], 'sym_freq_8')), ('2024-07-29', ([30, 60, 120], 'sym_freq_9')), ('2024-07-29', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-07-29', ([30, 60, 120], 'sym_freq_8')), ('2024-07-26', ([30, 60, 120], 'sym_freq_9')), ('2024-07-26', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-07-26', ([30, 60, 120], 'sym_freq_8')), ('2024-07-25', ([30, 60, 120], 'sym_freq_9')), ('2024-07-25', ([15, 30, 60, 120], 'sym_freq_12')), ('2024-07-25', ([30, 60, 120], 'sym_freq_8')), ('2024-07-24', ([30, 60, 120], 'sym_freq_9')), ('2024-07- ...

# %% [markdown]
# #### Get symbols in my_cols where values of "date_end_df_picks_train" equals to dates_in_days_lookbacks, and "days_lookbacks" equals to my_days_lookbacks.

# %%
# Initialize a list to store the picked symbols
picks = []

# Track the previous date for formatting output
prev_date = ''

# Iterate through each combination of date, lookback, and top feature,
# now handling the nested tuple structure
for i, (_date, (my_days_lookback, my_col)) in enumerate(date_lookback_symfreq):
    # Create a mask to filter rows in the DataFrame based on the date and lookback criteria
    mask = (df_filtered_picks['date_end_df_train'] == _date) & (df_filtered_picks['days_lookbacks'] == str(my_days_lookback))

    # Extract the list of symbols picked by the model for the current criteria
    list_in_df_filtered_picks = df_filtered_picks.loc[mask, my_col]
    my_str = list_in_df_filtered_picks.tolist()[0]  # Convert the Pandas Series to a string
    my_list = literal_eval(my_str)  # Convert the string representation of the list to an actual list

    # Print the model's picks in a formatted way, grouping by date
    if _date != prev_date:
        if prev_date == '':
            print("\nModel Results:")  # Print a header for the results
        else:
            print("\n")  # Separate results for different dates
        print(f"{i:<6}{_date:<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}")
    else:
        print(f"{i:<6}{' ':<14}{str(my_days_lookback):<21}{my_col:<11}: {my_list}")

    # Add the picked symbols to the list of picks
    picks.append((i, my_list))

    # Update the previous date for the next iteration
    prev_date = _date
# Out:
# Model Results:
# 0     2024-08-30    [30, 60, 120]        sym_freq_9 : ['SHV']
# 1                   [15, 30, 60, 120]    sym_freq_12: []
# 2                   [30, 60, 120]        sym_freq_8 : []
#
#
# 3     2024-08-29    [30, 60, 120]        sym_freq_9 : []
# 4                   [15, 30, 60, 120]    sym_freq_12: []
# 5                   [30, 60, 120]        sym_freq_8 : ['SHV']
#
#
# 6     2024-08-28    [30, 60, 120]        sym_freq_9 : ['SHV']
# 7                   [15, 30, 60, 120]    sym_freq_12: []
# 8                   [30, 60, 120]        sym_freq_8 : []
#
#
# 9     2024-08-27    [30, 60, 120]        sym_freq_9 : ['SHV']
# 10                  [15, 30, 60, 120]    sym_freq_12: []
# 11                  [30, 60, 120]        sym_freq_8 : []
#
#
# 12    2024-08-26    [30, 60, 120]        sym_freq_9 : []
# 13                  [15, 30, 60, 120]    sym_freq_12: []
# 14                  [30, 60, 120]        sym_freq_8 : ['SHV']
#
#
# 15    2024-08-23    [30, 60, 120]        sym_freq_9 : []
# 16                  [15, 30, 60, 120]    sym_freq_12: []
# 17                  [30, 60, 120]        sym_freq_8 : ['SHV']
#
#
# 18    2024-08-22    [30, 60, 120]        sym_freq_9 : []
# 19                  [15, 30, 60, 120]    sym_freq_12: []
# 20                  [30, 60, 120]        sym_freq_8 : ['SHV']
#
#
# 21    2024-08-21    [30, 60, 120]        sym_freq_9 : ['SHV']
# 22                  [15, 30, 60, 120]    sym_freq_12: []
# 23                  [30, 60, 120]        sym_freq_8 : []
#
#
# 24    2024-08-20    [30, 60, 120]        sym_freq_9 : []
# 25                  [15, 30, 60, 120]    sym_freq_12: []
# 26                  [30, 60, 120]        sym_freq_8 : ['LUMN', 'SHV']
#
#
# 27    2024-08-19    [30, 60, 120]        sym_freq_9 : []
# 28                  [15, 30, 60, 120]    sym_freq_12: []
# 29                  [30, 60, 120]        sym_freq_8 : ['LUMN', 'SHV']
#
#
# 30    2024-08-16    [30, 60, 120]        sym_freq_9 : []
# 31                  [15, 30, 60, 120]    sym_freq_12: []
# 32                  [30, 60, 120]        sym_freq_8 : ['LUMN', 'SHV']
#
#
# 33    2024-08-15    [30, 60, 120]        sym_freq_9 : []
# 34                  [15, 30, 60, 120]    sym_freq_12: []
# 35                  [30, 60, 120]        sym_freq_8 : ['LUMN', 'SHV']
#
#
# 36    2024-08-14    [30, 60, 120]        sym_freq_9 : []
# 37                  [15, 30, 60, 120]    sym_freq_12: []
# 38                  [30, 60, 120]        sym_freq_8 : ['LMT', 'LUMN', 'SHV']
#
#
# 39    2024-08-13    [30, 60, 120]        sym_freq_9 : []
# 40                  [15, 30, 60, 120]    sym_freq_12: []
# 41                  [30, 60, 120]        sym_freq_8 : ['LUMN', 'SHV']
#
#
# 42    2024-08-12    [30, 60, 120]        sym_freq_9 : ['SHV']
# 43                  [15, 30, 60, 120]    sym_freq_12: []
# 44                  [30, 60, 120]        sym_freq_8 : ['LMT']
#
#
# 45    2024-08-09    [30, 60, 120]        sym_freq_9 : ['SHV']
# 46                  [15, 30, 60, 120]    sym_freq_12: []
# 47                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'LMT', 'LUMN', 'VTR']
#
#
# 48    2024-08-08    [30, 60, 120]        sym_freq_9 : ['SHV']
# 49                  [15, 30, 60, 120]    sym_freq_12: []
# 50                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'LUMN', 'VTR']
#
#
# 51    2024-08-07    [30, 60, 120]        sym_freq_9 : ['SHV']
# 52                  [15, 30, 60, 120]    sym_freq_12: []
# 53                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'LMT', 'LUMN', 'VTR']
#
#
# 54    2024-08-06    [30, 60, 120]        sym_freq_9 : ['SHV']
# 55                  [15, 30, 60, 120]    sym_freq_12: []
# 56                  [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 57    2024-08-05    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 58                  [15, 30, 60, 120]    sym_freq_12: []
# 59                  [30, 60, 120]        sym_freq_8 : []
#
#
# 60    2024-08-02    [30, 60, 120]        sym_freq_9 : []
# 61                  [15, 30, 60, 120]    sym_freq_12: []
# 62                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 63    2024-08-01    [30, 60, 120]        sym_freq_9 : []
# 64                  [15, 30, 60, 120]    sym_freq_12: []
# 65                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 66    2024-07-31    [30, 60, 120]        sym_freq_9 : []
# 67                  [15, 30, 60, 120]    sym_freq_12: []
# 68                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 69    2024-07-30    [30, 60, 120]        sym_freq_9 : []
# 70                  [15, 30, 60, 120]    sym_freq_12: []
# 71                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 72    2024-07-29    [30, 60, 120]        sym_freq_9 : []
# 73                  [15, 30, 60, 120]    sym_freq_12: []
# 74                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 75    2024-07-26    [30, 60, 120]        sym_freq_9 : []
# 76                  [15, 30, 60, 120]    sym_freq_12: []
# 77                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 78    2024-07-25    [30, 60, 120]        sym_freq_9 : []
# 79                  [15, 30, 60, 120]    sym_freq_12: []
# 80                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 81    2024-07-24    [30, 60, 120]        sym_freq_9 : []
# 82                  [15, 30, 60, 120]    sym_freq_12: []
# 83                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 84    2024-07-23    [30, 60, 120]        sym_freq_9 : []
# 85                  [15, 30, 60, 120]    sym_freq_12: []
# 86                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'SHV']
#
#
# 87    2024-07-22    [30, 60, 120]        sym_freq_9 : ['SHV']
# 88                  [15, 30, 60, 120]    sym_freq_12: []
# 89                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'LNTH']
#
#
# 90    2024-07-19    [30, 60, 120]        sym_freq_9 : ['SHV']
# 91                  [15, 30, 60, 120]    sym_freq_12: []
# 92                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'LNTH']
#
#
# 93    2024-07-18    [30, 60, 120]        sym_freq_9 : ['SHV']
# 94                  [15, 30, 60, 120]    sym_freq_12: []
# 95                  [30, 60, 120]        sym_freq_8 : ['FTSM', 'LNTH']
#
#
# 96    2024-07-17    [30, 60, 120]        sym_freq_9 : ['LNTH', 'SHV']
# 97                  [15, 30, 60, 120]    sym_freq_12: []
# 98                  [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 99    2024-07-16    [30, 60, 120]        sym_freq_9 : ['SHV']
# 100                 [15, 30, 60, 120]    sym_freq_12: []
# 101                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 102   2024-07-15    [30, 60, 120]        sym_freq_9 : ['LNTH', 'SHV']
# 103                 [15, 30, 60, 120]    sym_freq_12: ['LNTH']
# 104                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 105   2024-07-12    [30, 60, 120]        sym_freq_9 : ['LNTH', 'SHV']
# 106                 [15, 30, 60, 120]    sym_freq_12: ['LNTH']
# 107                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 108   2024-07-11    [30, 60, 120]        sym_freq_9 : ['LNTH', 'SHV']
# 109                 [15, 30, 60, 120]    sym_freq_12: ['LNTH']
# 110                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 111   2024-07-10    [30, 60, 120]        sym_freq_9 : ['SHV']
# 112                 [15, 30, 60, 120]    sym_freq_12: []
# 113                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 114   2024-07-09    [30, 60, 120]        sym_freq_9 : ['SHV']
# 115                 [15, 30, 60, 120]    sym_freq_12: []
# 116                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 117   2024-07-08    [30, 60, 120]        sym_freq_9 : ['SHV']
# 118                 [15, 30, 60, 120]    sym_freq_12: []
# 119                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 120   2024-07-05    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 121                 [15, 30, 60, 120]    sym_freq_12: []
# 122                 [30, 60, 120]        sym_freq_8 : []
#
#
# 123   2024-07-03    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 124                 [15, 30, 60, 120]    sym_freq_12: []
# 125                 [30, 60, 120]        sym_freq_8 : []
#
#
# 126   2024-07-02    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 127                 [15, 30, 60, 120]    sym_freq_12: []
# 128                 [30, 60, 120]        sym_freq_8 : []
#
#
# 129   2024-07-01    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 130                 [15, 30, 60, 120]    sym_freq_12: []
# 131                 [30, 60, 120]        sym_freq_8 : []
#
#
# 132   2024-06-28    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 133                 [15, 30, 60, 120]    sym_freq_12: []
# 134                 [30, 60, 120]        sym_freq_8 : []
#
#
# 135   2024-06-27    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 136                 [15, 30, 60, 120]    sym_freq_12: []
# 137                 [30, 60, 120]        sym_freq_8 : []
#
#
# 138   2024-06-26    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 139                 [15, 30, 60, 120]    sym_freq_12: ['SHV']
# 140                 [30, 60, 120]        sym_freq_8 : []
#
#
# 141   2024-06-25    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 142                 [15, 30, 60, 120]    sym_freq_12: []
# 143                 [30, 60, 120]        sym_freq_8 : []
#
#
# 144   2024-06-24    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 145                 [15, 30, 60, 120]    sym_freq_12: []
# 146                 [30, 60, 120]        sym_freq_8 : []
#
#
# 147   2024-06-21    [30, 60, 120]        sym_freq_9 : ['FTSM', 'SHV']
# 148                 [15, 30, 60, 120]    sym_freq_12: []
# 149                 [30, 60, 120]        sym_freq_8 : []
#
#
# 150   2024-06-20    [30, 60, 120]        sym_freq_9 : ['SHV']
# 151                 [15, 30, 60, 120]    sym_freq_12: []
# 152                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 153   2024-06-18    [30, 60, 120]        sym_freq_9 : ['SHV']
# 154                 [15, 30, 60, 120]    sym_freq_12: []
# 155                 [30, 60, 120]        sym_freq_8 : ['FTSM']
#
#
# 156   2024-06-17    [30, 60, 120]        sym_freq_9 : ['SHV']
# 157                 [15, 30, 60, 120]    sym_freq_12: []
# 158                 [30, 60, 120]        sym_freq_8 : ['FTSM']

# %% [markdown]
# #### Create iterable z_items of date_lookback_symfreq and picks<br>Add picks to df_model_top_picks if dlb_sym_freq match criteria_model_top_picks and _syms has symbol(s)

# %%
print(f'before add len(df_model_top_picks): {len(df_model_top_picks)}')

# Combine date_lookback_symfreq and picks into a single iterable
z_items = zip(date_lookback_symfreq, picks)

# Iterate through each combined item
for i, item in enumerate(z_items):
    # Unpack the date, lookback, feature, counter, and symbols
    _date, _days_lookback, _sym_freq, _counter, _syms = (
        item[0][0],
        item[0][1][0],  # Accessing nested tuple elements
        item[0][1][1],
        item[1][0],
        item[1][1],
    )

    len_df_model_top_picks = len(df_model_top_picks)

    # Print the current item's details for inspection
    print(f"{i}, {_date}, {_days_lookback}, {_sym_freq}, {_syms}")

    # Create a tuple for model criteria matching
    dlb_sym_freq = (_days_lookback, _sym_freq)

    # Add data to the DataFrame if the criteria are met and symbols exist
    if dlb_sym_freq in criteria_model_top_picks and _syms:
        row_add = [_date, _days_lookback, _sym_freq, _syms]
        df_model_top_picks.loc[len_df_model_top_picks] = row_add  # Append row using index
        print(f"\nAdded row {len_df_model_top_picks} to df_model_top_picks:\n{row_add}\n")

print(f'after add len(df_model_top_picks): {len(df_model_top_picks)}')
# Out:
# before add len(df_model_top_picks): 1629
# 0, 2024-08-30, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1629 to df_model_top_picks:
# ['2024-08-30', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 1, 2024-08-30, [15, 30, 60, 120], sym_freq_12, []
# 2, 2024-08-30, [30, 60, 120], sym_freq_8, []
# 3, 2024-08-29, [30, 60, 120], sym_freq_9, []
# 4, 2024-08-29, [15, 30, 60, 120], sym_freq_12, []
# 5, 2024-08-29, [30, 60, 120], sym_freq_8, ['SHV']
#
# Added row 1630 to df_model_top_picks:
# ['2024-08-29', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 6, 2024-08-28, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1631 to df_model_top_picks:
# ['2024-08-28', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 7, 2024-08-28, [15, 30, 60, 120], sym_freq_12, []
# 8, 2024-08-28, [30, 60, 120], sym_freq_8, []
# 9, 2024-08-27, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1632 to df_model_top_picks:
# ['2024-08-27', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 10, 2024-08-27, [15, 30, 60, 120], sym_freq_12, []
# 11, 2024-08-27, [30, 60, 120], sym_freq_8, []
# 12, 2024-08-26, [30, 60, 120], sym_freq_9, []
# 13, 2024-08-26, [15, 30, 60, 120], sym_freq_12, []
# 14, 2024-08-26, [30, 60, 120], sym_freq_8, ['SHV']
#
# Added row 1633 to df_model_top_picks:
# ['2024-08-26', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 15, 2024-08-23, [30, 60, 120], sym_freq_9, []
# 16, 2024-08-23, [15, 30, 60, 120], sym_freq_12, []
# 17, 2024-08-23, [30, 60, 120], sym_freq_8, ['SHV']
#
# Added row 1634 to df_model_top_picks:
# ['2024-08-23', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 18, 2024-08-22, [30, 60, 120], sym_freq_9, []
# 19, 2024-08-22, [15, 30, 60, 120], sym_freq_12, []
# 20, 2024-08-22, [30, 60, 120], sym_freq_8, ['SHV']
#
# Added row 1635 to df_model_top_picks:
# ['2024-08-22', [30, 60, 120], 'sym_freq_8', ['SHV']]
#
# 21, 2024-08-21, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1636 to df_model_top_picks:
# ['2024-08-21', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 22, 2024-08-21, [15, 30, 60, 120], sym_freq_12, []
# 23, 2024-08-21, [30, 60, 120], sym_freq_8, []
# 24, 2024-08-20, [30, 60, 120], sym_freq_9, []
# 25, 2024-08-20, [15, 30, 60, 120], sym_freq_12, []
# 26, 2024-08-20, [30, 60, 120], sym_freq_8, ['LUMN', 'SHV']
#
# Added row 1637 to df_model_top_picks:
# ['2024-08-20', [30, 60, 120], 'sym_freq_8', ['LUMN', 'SHV']]
#
# 27, 2024-08-19, [30, 60, 120], sym_freq_9, []
# 28, 2024-08-19, [15, 30, 60, 120], sym_freq_12, []
# 29, 2024-08-19, [30, 60, 120], sym_freq_8, ['LUMN', 'SHV']
#
# Added row 1638 to df_model_top_picks:
# ['2024-08-19', [30, 60, 120], 'sym_freq_8', ['LUMN', 'SHV']]
#
# 30, 2024-08-16, [30, 60, 120], sym_freq_9, []
# 31, 2024-08-16, [15, 30, 60, 120], sym_freq_12, []
# 32, 2024-08-16, [30, 60, 120], sym_freq_8, ['LUMN', 'SHV']
#
# Added row 1639 to df_model_top_picks:
# ['2024-08-16', [30, 60, 120], 'sym_freq_8', ['LUMN', 'SHV']]
#
# 33, 2024-08-15, [30, 60, 120], sym_freq_9, []
# 34, 2024-08-15, [15, 30, 60, 120], sym_freq_12, []
# 35, 2024-08-15, [30, 60, 120], sym_freq_8, ['LUMN', 'SHV']
#
# Added row 1640 to df_model_top_picks:
# ['2024-08-15', [30, 60, 120], 'sym_freq_8', ['LUMN', 'SHV']]
#
# 36, 2024-08-14, [30, 60, 120], sym_freq_9, []
# 37, 2024-08-14, [15, 30, 60, 120], sym_freq_12, []
# 38, 2024-08-14, [30, 60, 120], sym_freq_8, ['LMT', 'LUMN', 'SHV']
#
# Added row 1641 to df_model_top_picks:
# ['2024-08-14', [30, 60, 120], 'sym_freq_8', ['LMT', 'LUMN', 'SHV']]
#
# 39, 2024-08-13, [30, 60, 120], sym_freq_9, []
# 40, 2024-08-13, [15, 30, 60, 120], sym_freq_12, []
# 41, 2024-08-13, [30, 60, 120], sym_freq_8, ['LUMN', 'SHV']
#
# Added row 1642 to df_model_top_picks:
# ['2024-08-13', [30, 60, 120], 'sym_freq_8', ['LUMN', 'SHV']]
#
# 42, 2024-08-12, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1643 to df_model_top_picks:
# ['2024-08-12', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 43, 2024-08-12, [15, 30, 60, 120], sym_freq_12, []
# 44, 2024-08-12, [30, 60, 120], sym_freq_8, ['LMT']
#
# Added row 1644 to df_model_top_picks:
# ['2024-08-12', [30, 60, 120], 'sym_freq_8', ['LMT']]
#
# 45, 2024-08-09, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1645 to df_model_top_picks:
# ['2024-08-09', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 46, 2024-08-09, [15, 30, 60, 120], sym_freq_12, []
# 47, 2024-08-09, [30, 60, 120], sym_freq_8, ['FTSM', 'LMT', 'LUMN', 'VTR']
#
# Added row 1646 to df_model_top_picks:
# ['2024-08-09', [30, 60, 120], 'sym_freq_8', ['FTSM', 'LMT', 'LUMN', 'VTR']]
#
# 48, 2024-08-08, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1647 to df_model_top_picks:
# ['2024-08-08', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 49, 2024-08-08, [15, 30, 60, 120], sym_freq_12, []
# 50, 2024-08-08, [30, 60, 120], sym_freq_8, ['FTSM', 'LUMN', 'VTR']
#
# Added row 1648 to df_model_top_picks:
# ['2024-08-08', [30, 60, 120], 'sym_freq_8', ['FTSM', 'LUMN', 'VTR']]
#
# 51, 2024-08-07, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1649 to df_model_top_picks:
# ['2024-08-07', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 52, 2024-08-07, [15, 30, 60, 120], sym_freq_12, []
# 53, 2024-08-07, [30, 60, 120], sym_freq_8, ['FTSM', 'LMT', 'LUMN', 'VTR']
#
# Added row 1650 to df_model_top_picks:
# ['2024-08-07', [30, 60, 120], 'sym_freq_8', ['FTSM', 'LMT', 'LUMN', 'VTR']]
#
# 54, 2024-08-06, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1651 to df_model_top_picks:
# ['2024-08-06', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 55, 2024-08-06, [15, 30, 60, 120], sym_freq_12, []
# 56, 2024-08-06, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1652 to df_model_top_picks:
# ['2024-08-06', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 57, 2024-08-05, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1653 to df_model_top_picks:
# ['2024-08-05', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 58, 2024-08-05, [15, 30, 60, 120], sym_freq_12, []
# 59, 2024-08-05, [30, 60, 120], sym_freq_8, []
# 60, 2024-08-02, [30, 60, 120], sym_freq_9, []
# 61, 2024-08-02, [15, 30, 60, 120], sym_freq_12, []
# 62, 2024-08-02, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1654 to df_model_top_picks:
# ['2024-08-02', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 63, 2024-08-01, [30, 60, 120], sym_freq_9, []
# 64, 2024-08-01, [15, 30, 60, 120], sym_freq_12, []
# 65, 2024-08-01, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1655 to df_model_top_picks:
# ['2024-08-01', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 66, 2024-07-31, [30, 60, 120], sym_freq_9, []
# 67, 2024-07-31, [15, 30, 60, 120], sym_freq_12, []
# 68, 2024-07-31, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1656 to df_model_top_picks:
# ['2024-07-31', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 69, 2024-07-30, [30, 60, 120], sym_freq_9, []
# 70, 2024-07-30, [15, 30, 60, 120], sym_freq_12, []
# 71, 2024-07-30, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1657 to df_model_top_picks:
# ['2024-07-30', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 72, 2024-07-29, [30, 60, 120], sym_freq_9, []
# 73, 2024-07-29, [15, 30, 60, 120], sym_freq_12, []
# 74, 2024-07-29, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1658 to df_model_top_picks:
# ['2024-07-29', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 75, 2024-07-26, [30, 60, 120], sym_freq_9, []
# 76, 2024-07-26, [15, 30, 60, 120], sym_freq_12, []
# 77, 2024-07-26, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1659 to df_model_top_picks:
# ['2024-07-26', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 78, 2024-07-25, [30, 60, 120], sym_freq_9, []
# 79, 2024-07-25, [15, 30, 60, 120], sym_freq_12, []
# 80, 2024-07-25, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1660 to df_model_top_picks:
# ['2024-07-25', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 81, 2024-07-24, [30, 60, 120], sym_freq_9, []
# 82, 2024-07-24, [15, 30, 60, 120], sym_freq_12, []
# 83, 2024-07-24, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1661 to df_model_top_picks:
# ['2024-07-24', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 84, 2024-07-23, [30, 60, 120], sym_freq_9, []
# 85, 2024-07-23, [15, 30, 60, 120], sym_freq_12, []
# 86, 2024-07-23, [30, 60, 120], sym_freq_8, ['FTSM', 'SHV']
#
# Added row 1662 to df_model_top_picks:
# ['2024-07-23', [30, 60, 120], 'sym_freq_8', ['FTSM', 'SHV']]
#
# 87, 2024-07-22, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1663 to df_model_top_picks:
# ['2024-07-22', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 88, 2024-07-22, [15, 30, 60, 120], sym_freq_12, []
# 89, 2024-07-22, [30, 60, 120], sym_freq_8, ['FTSM', 'LNTH']
#
# Added row 1664 to df_model_top_picks:
# ['2024-07-22', [30, 60, 120], 'sym_freq_8', ['FTSM', 'LNTH']]
#
# 90, 2024-07-19, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1665 to df_model_top_picks:
# ['2024-07-19', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 91, 2024-07-19, [15, 30, 60, 120], sym_freq_12, []
# 92, 2024-07-19, [30, 60, 120], sym_freq_8, ['FTSM', 'LNTH']
#
# Added row 1666 to df_model_top_picks:
# ['2024-07-19', [30, 60, 120], 'sym_freq_8', ['FTSM', 'LNTH']]
#
# 93, 2024-07-18, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1667 to df_model_top_picks:
# ['2024-07-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 94, 2024-07-18, [15, 30, 60, 120], sym_freq_12, []
# 95, 2024-07-18, [30, 60, 120], sym_freq_8, ['FTSM', 'LNTH']
#
# Added row 1668 to df_model_top_picks:
# ['2024-07-18', [30, 60, 120], 'sym_freq_8', ['FTSM', 'LNTH']]
#
# 96, 2024-07-17, [30, 60, 120], sym_freq_9, ['LNTH', 'SHV']
#
# Added row 1669 to df_model_top_picks:
# ['2024-07-17', [30, 60, 120], 'sym_freq_9', ['LNTH', 'SHV']]
#
# 97, 2024-07-17, [15, 30, 60, 120], sym_freq_12, []
# 98, 2024-07-17, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1670 to df_model_top_picks:
# ['2024-07-17', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 99, 2024-07-16, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1671 to df_model_top_picks:
# ['2024-07-16', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 100, 2024-07-16, [15, 30, 60, 120], sym_freq_12, []
# 101, 2024-07-16, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1672 to df_model_top_picks:
# ['2024-07-16', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 102, 2024-07-15, [30, 60, 120], sym_freq_9, ['LNTH', 'SHV']
#
# Added row 1673 to df_model_top_picks:
# ['2024-07-15', [30, 60, 120], 'sym_freq_9', ['LNTH', 'SHV']]
#
# 103, 2024-07-15, [15, 30, 60, 120], sym_freq_12, ['LNTH']
#
# Added row 1674 to df_model_top_picks:
# ['2024-07-15', [15, 30, 60, 120], 'sym_freq_12', ['LNTH']]
#
# 104, 2024-07-15, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1675 to df_model_top_picks:
# ['2024-07-15', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 105, 2024-07-12, [30, 60, 120], sym_freq_9, ['LNTH', 'SHV']
#
# Added row 1676 to df_model_top_picks:
# ['2024-07-12', [30, 60, 120], 'sym_freq_9', ['LNTH', 'SHV']]
#
# 106, 2024-07-12, [15, 30, 60, 120], sym_freq_12, ['LNTH']
#
# Added row 1677 to df_model_top_picks:
# ['2024-07-12', [15, 30, 60, 120], 'sym_freq_12', ['LNTH']]
#
# 107, 2024-07-12, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1678 to df_model_top_picks:
# ['2024-07-12', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 108, 2024-07-11, [30, 60, 120], sym_freq_9, ['LNTH', 'SHV']
#
# Added row 1679 to df_model_top_picks:
# ['2024-07-11', [30, 60, 120], 'sym_freq_9', ['LNTH', 'SHV']]
#
# 109, 2024-07-11, [15, 30, 60, 120], sym_freq_12, ['LNTH']
#
# Added row 1680 to df_model_top_picks:
# ['2024-07-11', [15, 30, 60, 120], 'sym_freq_12', ['LNTH']]
#
# 110, 2024-07-11, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1681 to df_model_top_picks:
# ['2024-07-11', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 111, 2024-07-10, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1682 to df_model_top_picks:
# ['2024-07-10', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 112, 2024-07-10, [15, 30, 60, 120], sym_freq_12, []
# 113, 2024-07-10, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1683 to df_model_top_picks:
# ['2024-07-10', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 114, 2024-07-09, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1684 to df_model_top_picks:
# ['2024-07-09', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 115, 2024-07-09, [15, 30, 60, 120], sym_freq_12, []
# 116, 2024-07-09, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1685 to df_model_top_picks:
# ['2024-07-09', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 117, 2024-07-08, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1686 to df_model_top_picks:
# ['2024-07-08', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 118, 2024-07-08, [15, 30, 60, 120], sym_freq_12, []
# 119, 2024-07-08, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1687 to df_model_top_picks:
# ['2024-07-08', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 120, 2024-07-05, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1688 to df_model_top_picks:
# ['2024-07-05', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 121, 2024-07-05, [15, 30, 60, 120], sym_freq_12, []
# 122, 2024-07-05, [30, 60, 120], sym_freq_8, []
# 123, 2024-07-03, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1689 to df_model_top_picks:
# ['2024-07-03', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 124, 2024-07-03, [15, 30, 60, 120], sym_freq_12, []
# 125, 2024-07-03, [30, 60, 120], sym_freq_8, []
# 126, 2024-07-02, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1690 to df_model_top_picks:
# ['2024-07-02', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 127, 2024-07-02, [15, 30, 60, 120], sym_freq_12, []
# 128, 2024-07-02, [30, 60, 120], sym_freq_8, []
# 129, 2024-07-01, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1691 to df_model_top_picks:
# ['2024-07-01', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 130, 2024-07-01, [15, 30, 60, 120], sym_freq_12, []
# 131, 2024-07-01, [30, 60, 120], sym_freq_8, []
# 132, 2024-06-28, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1692 to df_model_top_picks:
# ['2024-06-28', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 133, 2024-06-28, [15, 30, 60, 120], sym_freq_12, []
# 134, 2024-06-28, [30, 60, 120], sym_freq_8, []
# 135, 2024-06-27, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1693 to df_model_top_picks:
# ['2024-06-27', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 136, 2024-06-27, [15, 30, 60, 120], sym_freq_12, []
# 137, 2024-06-27, [30, 60, 120], sym_freq_8, []
# 138, 2024-06-26, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1694 to df_model_top_picks:
# ['2024-06-26', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 139, 2024-06-26, [15, 30, 60, 120], sym_freq_12, ['SHV']
#
# Added row 1695 to df_model_top_picks:
# ['2024-06-26', [15, 30, 60, 120], 'sym_freq_12', ['SHV']]
#
# 140, 2024-06-26, [30, 60, 120], sym_freq_8, []
# 141, 2024-06-25, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1696 to df_model_top_picks:
# ['2024-06-25', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 142, 2024-06-25, [15, 30, 60, 120], sym_freq_12, []
# 143, 2024-06-25, [30, 60, 120], sym_freq_8, []
# 144, 2024-06-24, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1697 to df_model_top_picks:
# ['2024-06-24', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 145, 2024-06-24, [15, 30, 60, 120], sym_freq_12, []
# 146, 2024-06-24, [30, 60, 120], sym_freq_8, []
# 147, 2024-06-21, [30, 60, 120], sym_freq_9, ['FTSM', 'SHV']
#
# Added row 1698 to df_model_top_picks:
# ['2024-06-21', [30, 60, 120], 'sym_freq_9', ['FTSM', 'SHV']]
#
# 148, 2024-06-21, [15, 30, 60, 120], sym_freq_12, []
# 149, 2024-06-21, [30, 60, 120], sym_freq_8, []
# 150, 2024-06-20, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1699 to df_model_top_picks:
# ['2024-06-20', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 151, 2024-06-20, [15, 30, 60, 120], sym_freq_12, []
# 152, 2024-06-20, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1700 to df_model_top_picks:
# ['2024-06-20', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 153, 2024-06-18, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1701 to df_model_top_picks:
# ['2024-06-18', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 154, 2024-06-18, [15, 30, 60, 120], sym_freq_12, []
# 155, 2024-06-18, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1702 to df_model_top_picks:
# ['2024-06-18', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# 156, 2024-06-17, [30, 60, 120], sym_freq_9, ['SHV']
#
# Added row 1703 to df_model_top_picks:
# ['2024-06-17', [30, 60, 120], 'sym_freq_9', ['SHV']]
#
# 157, 2024-06-17, [15, 30, 60, 120], sym_freq_12, []
# 158, 2024-06-17, [30, 60, 120], sym_freq_8, ['FTSM']
#
# Added row 1704 to df_model_top_picks:
# ['2024-06-17', [30, 60, 120], 'sym_freq_8', ['FTSM']]
#
# after add len(df_model_top_picks): 1705

# %%
# Convert all data types in the DataFrame to strings
df_model_top_picks = df_model_top_picks.astype(str)

# Remove any duplicate rows, keeping the last occurrence of each
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')

# Sort the DataFrame by 'date' (descending), 'days_lookback' (descending), and 'syms_freq' (descending)
df_model_top_picks = df_model_top_picks.sort_values(
    by=['date', 'days_lookback', 'syms_freq'], ascending=False
)

# Reset the index of the DataFrame, dropping the old index
df_model_top_picks = df_model_top_picks.reset_index(drop=True)

print(f'df_model_top_picks:\n{df_model_top_picks}')
# Out:
# df_model_top_picks:
#             date  days_lookback   syms_freq   symbols
# 0     2024-08-30  [30, 60, 120]  sym_freq_9   ['SHV']
# 1     2024-08-29  [30, 60, 120]  sym_freq_8   ['SHV']
# 2     2024-08-28  [30, 60, 120]  sym_freq_9   ['SHV']
# 3     2024-08-27  [30, 60, 120]  sym_freq_9   ['SHV']
# 4     2024-08-26  [30, 60, 120]  sym_freq_8   ['SHV']
# ...          ...            ...         ...       ...
# 1700  2018-07-12  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1701  2018-07-11  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1702  2018-07-10  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1703  2018-07-09  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1704  2018-07-06  [30, 60, 120]  sym_freq_8  ['TNDM']
#
# [1705 rows x 4 columns]

# %% [markdown]
# #### Cleanup df_model_top_picks<br>- convert data to str<br>- drop duplicates, keep last value<br>- sort date, newest first<br>- re-index

# %%
# Convert all data types in the DataFrame to strings
df_model_top_picks = df_model_top_picks.astype(str)

# Remove any duplicate rows, keeping the last occurrence of each
df_model_top_picks = df_model_top_picks.drop_duplicates(keep='last')

# Sort the DataFrame by 'date' (descending), 'days_lookback' (descending), and 'syms_freq' (descending)
df_model_top_picks = df_model_top_picks.sort_values(
    by=['date', 'days_lookback', 'syms_freq'], ascending=False
)

# Reset the index of the DataFrame, dropping the old index
df_model_top_picks = df_model_top_picks.reset_index(drop=True)

# Save the DataFrame to a pickle file
pickle_dump(df_model_top_picks, path_data_dump, fp_df_model_top_picks)

# Print the length of the DataFrame
print(f'Length of df_model_top_picks: {len(df_model_top_picks)}')

# Print the file path and contents of the DataFrame
print(f'File path: {fp_df_model_top_picks}\nDataFrame contents:\n{df_model_top_picks}')
# Out:
# Length of df_model_top_picks: 1705
# File path: df_model_top_picks
# DataFrame contents:
#             date  days_lookback   syms_freq   symbols
# 0     2024-08-30  [30, 60, 120]  sym_freq_9   ['SHV']
# 1     2024-08-29  [30, 60, 120]  sym_freq_8   ['SHV']
# 2     2024-08-28  [30, 60, 120]  sym_freq_9   ['SHV']
# 3     2024-08-27  [30, 60, 120]  sym_freq_9   ['SHV']
# 4     2024-08-26  [30, 60, 120]  sym_freq_8   ['SHV']
# ...          ...            ...         ...       ...
# 1700  2018-07-12  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1701  2018-07-11  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1702  2018-07-10  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1703  2018-07-09  [30, 60, 120]  sym_freq_8  ['TNDM']
# 1704  2018-07-06  [30, 60, 120]  sym_freq_8  ['TNDM']
#
# [1705 rows x 4 columns]

# %%
print(f'{fp_df_model_top_picks}.head(20):\n{df_model_top_picks.head(20)}')
# Out:
# df_model_top_picks.head(20):
#           date  days_lookback   syms_freq                        symbols
# 0   2024-08-30  [30, 60, 120]  sym_freq_9                        ['SHV']
# 1   2024-08-29  [30, 60, 120]  sym_freq_8                        ['SHV']
# 2   2024-08-28  [30, 60, 120]  sym_freq_9                        ['SHV']
# 3   2024-08-27  [30, 60, 120]  sym_freq_9                        ['SHV']
# 4   2024-08-26  [30, 60, 120]  sym_freq_8                        ['SHV']
# 5   2024-08-23  [30, 60, 120]  sym_freq_8                        ['SHV']
# 6   2024-08-22  [30, 60, 120]  sym_freq_8                        ['SHV']
# 7   2024-08-21  [30, 60, 120]  sym_freq_9                        ['SHV']
# 8   2024-08-20  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 9   2024-08-19  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 10  2024-08-16  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 11  2024-08-15  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 12  2024-08-14  [30, 60, 120]  sym_freq_8         ['LMT', 'LUMN', 'SHV']
# 13  2024-08-13  [30, 60, 120]  sym_freq_8                ['LUMN', 'SHV']
# 14  2024-08-12  [30, 60, 120]  sym_freq_9                        ['SHV']
# 15  2024-08-12  [30, 60, 120]  sym_freq_8                        ['LMT']
# 16  2024-08-09  [30, 60, 120]  sym_freq_9                        ['SHV']
# 17  2024-08-09  [30, 60, 120]  sym_freq_8  ['FTSM', 'LMT', 'LUMN', 'V...
# 18  2024-08-08  [30, 60, 120]  sym_freq_9                        ['SHV']
# 19  2024-08-08  [30, 60, 120]  sym_freq_8        ['FTSM', 'LUMN', 'VTR']
