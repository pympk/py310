# %% [markdown]
# ### Read Excel file, extract the data from column A into a list, and treat first line as a header

# %%
import pandas as pd


# Set the path to the directory containing the Excel file
path_lumen_docs = "../langchain/docs/lumen/docs/"
excel_filename = "lumen_sitemapXML.xlsx"

# Define a helper function to flatten a nested list
def fatten_list(nested_list):
    return [item for sublist in nested_list for item in sublist]

# Construct the file path of the Excel file
file = path_lumen_docs + excel_filename

# Extract the data from Excel file column A, first line as a header
df = pd.read_excel(file, usecols='A', header=0)

# Convert the data frame to a list
column_A = df.values.tolist()

# Create a list of unique URLs by flattening the list and removing duplicates
lumen_urls = sorted(fatten_list(column_A))

# Print the length of the lumen_urls list
print(f'len(lumen_urls): {len(lumen_urls)}')

# Print the lumen_urls list
print(lumen_urls)

# %% [markdown]
# https://colab.research.google.com/drive/1f_1HeD1mK_wXfjgvY4VGNFKSQBE5Imeh?usp=sharing#scrollTo=jm2nTHTtVTp0

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader(lumen_urls)
data = loader.load()

# %%
data[0:3]
_data = data

# %%
import sys
sys.path.append('../..')
from py3810.myUtils import pickle_dump, pickle_load

path_lumen_docs = '..\langchain\docs\lumen\docs\\'

# %%
data = pickle_load(filename_pickle='lumen_data', path_pickle_dump=path_lumen_docs)
# pickle_dump(file_to_pickle=data, filename_pickle='lumen_data', path_pickle_dump=path_lumen_docs)

# %%
# Concatenate all the pages into a single string
str_text = ''
for page in data:
  str_text += page.page_content

# %%
# C:\Users\ping\AppData\Roaming\nltk_data\corpora\words\en
import nltk
nltk.download('words')
from nltk.corpus import words

def find_misspelled_words(text):
  my_words = set(text.split())
  english_words = set(words.words())
  return [word for word in my_words if word.lower() not in english_words]
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\ping\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
l_misspelled_words = find_misspelled_words(str_text)
print(f'l_misspelled_words, len={len(l_misspelled_words)}:\n{l_misspelled_words}')
# Out:
# l_misspelled_words, len=5755:
# ['source.', 'control?”', 'Dry,', 'Stybel', 'ceiling.', 'thicker', 'difference.', 'Brides', 'adolescents', 'swings,', 'intervals', 'PATIENTS?', 'dysphoriaPrimary', 'Individuals:', 'At-Risk', 'Previously,', 'Thursday', 'anyone.', '78%.', 'centers', 'healthier', 'clearest', 'Retinoscopy/autorefractor', 'participated', 'Makeup:', 'alignment,', 'issues,', 'touchpoints', 'significant,', 'Health,', 'Britannica,', 'became,', 'drops.', 'side,', 'ADULTS:', 'eyelidDecreased', 'Blinking.', 'scheduled', 'bigger,', 'holds', 'beat.', 'headlights.', 'NeurolensesAs', 'Conversely,', 'replacing', 'dark,', 'myopic),', 'Ortho-K?”', 'UsThis', 'normal”', 'interests.', 'focusing', 'solutions.', 'millimeter.', 'Essentially,', 'Curable?', 'evaluations.', 'options,', 'objectives', 'variations', '“Nature', 'Hands', 'accomplishes', 'stagnant,', 'technique.', 'disease,', 'menu.', 'vision-threatening', 'school,', 'dosed', 'surfaces.', 'Dr.', 'Notably,', 'friends', '(grows', '21', '*For', 'Eyes’', '“yes.”', 'places', 'resources', 'described', "I've", 'activity.', 'goggles.', '60', 'climates).', 'glare,', 'love.', 'Maps', 'drinking.', 'Moisturize', 'eye,”', 'signs', 'Well-Balanced', 'spinach,', 'capacity,', 'essential.', '(4)', 'child!', 'Curbside', 'short-term', 'worsened,', 'clinics', 'circadian', 'advances', 'retina,', 'KnowVision', 'info', 'Treehouse', "didn't", 'researchers', 'measures', 'Screenings', 'contraceptives', '“aspheric,”', 'Custom?', 'vessels', 'reviews', 'Visit?”', 'help.', 'materials', 'eyesBlurred', 'OK.If', '1989-1994.systematic', '100%', 'specialists', 'By:', 'hayfever', 'Doctor?', 'legs', 'glasses,', 'intravitreal', 'saltwater,', 'workshop,', 'Headsets', 'projector)', 'ones', 'foods,', 'summarize,', 'Diagnosed?', 'communities', 'this,', 'cured;', 'particles.Light', '-All', 'surfaces,', 'processes', 'safe.', 'pertains', 'Resolutions', 'blog,', 'restroom,', 'year,', 'prepares', 'COVID-19', 'pressure.', 'techniques', 'today!', 'experts', 'Exposure:', 'YearHow', 'wanted', 'on-the-go', 'exam.', 'health.', 'pool,', 'approved.', 'heard', 'arms,', 'LinksHome', 'meters.', 'pre-teens', 'Michelle', 'enzymes', 'healtheye', 'grooms', 'performed', 'May;120(5):1080-5', 'teaming.', 'trash.', 'Found"]Top', 'limits', 'squinting.', '(more', 'learns', 'doctors.', '1.5-2.5', 'parking:', 'Neurolens®', 'season!', '{Please', 'drive.', 'wind.', 'sunscreen', 'misaligned,', 'iLux', 'has', 'run.', 'inserts', 'uncomfortable.', 'seeds', 'epidemic.', 'painRedness', 'optometrist!', 'Presbyopia.', 'Time4', '“It', 'waking,', 'occurs', 'Preparing', 'contacts.Wash', 'County.', 'guards', 'details,', 'happens', 'seems', 'Impacts', 'Age?', 'time,', 'progresses', 'exercise,', 'visit.', 'successfully:', 'down,', 'reserves,', 'deeper', 'organ,', 'out-of-focus.', 'SitemapSitemap', 'Associations', 'prioritize', '(nearsightedness).', 'TV?', 'modified,', 'water.', 'From,', '17,', '1940s,', 'differences.', 'visits,', 'repeatedly.', 'best.', 'care.', 'proportions,', 'child.', 'deteriorated', 'loss.', 'addressing', 'restores', 'morning,', 'lint.', 'smartphone', 'fitting.', 'think.', 'describes', 'Pasadena,', 'We’re', 'makeup,', 'scheduling', 'Tramanh', 'less-sensitive', 'candidates', 'studies–have', 'science-backed', 'plugs', 'leads', 'fast.', 'designated', '15,', 'borrowed', 'problems.', '-Traditional', 'athletes,', 'you.', 'cells', 'ophthalmologists', '(AACG)', 'healthy.', 'indoors,', 'sty.Injuries', 'You’ll', 'VisionEye', 'we’re', 'abrasion,', 'grittiness,', 'Minimally,', 'fingers,', 'complaining', 'Eyes5', 'lenses?”', '(driving,', 'NURTURE?', 'corresponds', 'doctors', 'audiovisual', 'minutes,', 'outcome.', 'tears.', 'naturally,', 'sores', 'Sunglasses', 'school.', 'ducts.', 'Doctors', 'cotton,', 'Putting', 'tools.', 'Wear:', 'and,', 'books,', 'misalignments', 'parents', 'System®', 'High-index', 'open,', 'High-Quality', 'shape—which', 'wearers.', 'GearHow', 'areas,', 'assessed,', 'Noemi', 'environment.', 'worsening.', 'eyewear.', 'secretes', 'Contacts', 'covid-19', '“acquired”).', 'c ...

# %%
def remove_trailing_chars(items, chars):
  for i, item in enumerate(items):
    for char in chars:
      item = item.rstrip(char)
    items[i] = item

  return items

# Example usage
chars = [".", ",", ":", "'"]
items = ['apple.', 'banana:', 'cherry"', 'a.apple', '.apple']
print(remove_trailing_chars(items, chars))
# Out:
# ['apple', 'banana', 'cherry"', 'a.apple', '.apple']

# %%
chars = [".", ",", ":", "'", '"', '”', '?', ')']
l_misspelled_words = remove_trailing_chars(l_misspelled_words, chars)
print(f'l_misspelled_words, len={len(l_misspelled_words)}:\n{l_misspelled_words}')
# Out:
# l_misspelled_words, len=3233:
# ['control', 'Grains', 'low-light', '20', 'carotenoids', 'Stybel', 'Appointment?Do', 'Beijing', 'modifying', 'ChoiceApril', 'thicker', 'membranes', 'Disturbances', 'frame-fitting', 'Cosmetics', 'Brides', 'GlaucomaEssential', 'occurring', 'seconds', 'adolescents', 'typing', 'intervals', 'fruits', 'dysphoriaPrimary', '91024Call', 'At-Risk', 'MadeUnderstanding', 'recipes', 'Wraparound', 'Google', 'Thanh', 'goodies', 'Thursday', 'develops', '40', 'life-changing', 'TV', 'Aimee', 'centers', 'Preservatives', 'Forms', 'healthier', '10-12', 'clearest', 'Retinoscopy/autorefractor', 'won’t', '“the', 'Concerns', 'dissolves', 'participated', 'jobs', 'K.G', 'rubs', '10-20%', 'touchpoints', 'indicates', 'encouraged', 'Embedded', '50', '5-year-olds', 'it.', 'safest', 'problemsPrimary', 'elongates', 'Long-Term', 'hygienePrimary', 'keratitisRedness', 'treats', 'paramedics', 'eyelidDecreased', 'environments', 'Limits', 'scheduled', 'letting', '(Ortho-K', 'adjusting', 'Types', 'hill!', 'holds', 'DoctorWatery', 'Denise', 'non-pathologic', 'NeurolensesAs', 'Healthy', 'degenerationMyopic', 'MiSight', '9:45', 'irritated', 'replacing', 'Ortho-K', 'steps', 'classifications', 'UsThis', 'normal', 'doctor’s', '“cybersickness', 'eyebrows', 'Women', 'High-Index', 'Don’t', 'trees', 'readouts', 'focusing', 'categories', 'gives', 'Foods', 'viruses', 'care!', 'weakened', 'disoriented', 'roads', 'four-year', 'drinks', 'pineapples', 'objectives', 'variations', '“Nature', 'Snellen', 'packs', "you're", 'prescriptionPrimary', 'Hands', 'accomplishes', 'ExamsOur', 'shows', 'particles', 'fats', 'Wearers10', 'you’ll', 'impairing', 'lessening', 'achieved', 'EyewearElevate', '“custom', '(PD', 'vision-threatening', 'dosed', 'impact-resistant', 'TreeHouse', 'haven’t', 'hands.Clean', 'Fogging', 'prescription’s', 'radiates', 'Disrupting', 'CampaignGlobal', 'SunSigns', 'friends', 'glaucoma1', 'demands', 'UsWe', 'leary', '(grows', '21', '(AKA', 'figures', 'orthokeratology', 'PrecautionsVideo', '*For', '118(10', 'Eyes’', 'Post-COVID', '“yes.', 'differs', 'opting', 'places', 'resources', 'Britannica', 'described', "I've", 'barriers', '5m', 'screens', '60', 'far-away', '(having', 'dimensions', 'studying', 'car—but', '6', 'Prevented', 'INCREASED', 'Maps', '(While', 'cheese;', 'age-related', 'migraineurs', 'Good-quality', 'Lubricating', '1-2', 'Moisturize', '8-15', 'To?Optometrist', 'allergens', '(it’s', 'specialty-lens', 'eye,', 'explains', 'signs', 'neurolens®', 'individuals', 'Well-Balanced', 'marketed', 'Eyes?Dry', 'Employees', 'properly–and', 'disinfected', '/', 'powers', 'splashes', 'recommended', 'hues', 'Nurture', 'misaligned', 'moves', 'high-performance', 'child!', 'Curbside', 'performance-based', '(puncta', 'short-term', 'teenagers', '(1', '921-019914', '(This', 'gone.Never', 'Increased', 'ornaments', 'Hoshizaki', 'clinics', 'circadian', 'demands—be', 'advances', 'Saturday', '(AM', 'stored', 'saltwater', 'We’ve', 'Decreased', 'Avoiding', 'VS', 'KnowVision', 'sun’s', 'info', 'preservatives', 'Treehouse', "didn't", '60%', 'neurons', 'researchers', 'measures', 'Screenings', 'contraceptives', '“aspheric,', 'pmCopyright', 'coughing', 'vessels', '(NOCSAE', 'reviews', 'including', 'Visit', 'options.Jordan', 'adenovirus', 'modalities', 'detachment.Eye', '112(8', 'PPE', 'side-effects', 'restoring', 'pain/tension', 'high-index', 'family-owned', 'materials', 'DiseaseMyopia', 'eyesBlurred', 'CVS', 'Sci', '1989-1994.systematic', 'OK.If', 'restructured', 'staggering;', '100%', 'specialists', 'hayfever', 'scratch-resistant', 'gloves', 'legs', 'halos', 'License', 'releasing', 'intravitreal', 'state-of-the-art', 'slightest', 'handwashing', '(AOA', '…', 'DEVICES', '“20/20/20', 'AppointmentMyopia', 'reviewing', 'Headsets', 'ExamsTrust', 'Launches', 'ones', 'obtained', 'servings', 'changesPrimary', 'make!', 'after-school', 'wiping', 'rids', 'that’s', 'bends', 'communities', 'screenshot', 'loved', 'featuring', 'doesn’t', 'cured;', '-All', 'particles.Light', 'Pasadena', 'Year’s', 'lenses!', 'mod ...

# %%
str_misspelled_words = " ".join(l_misspelled_words)

# %%
l_misspelled_words = find_misspelled_words(str_misspelled_words)
print(f'l_misspelled_words, len={len(l_misspelled_words)}:\n{l_misspelled_words}')
# Out:
# l_misspelled_words, len=3199:
# ['Grains', 'low-light', '20', 'carotenoids', 'Stybel', 'Appointment?Do', 'Beijing', 'modifying', 'ChoiceApril', 'thicker', 'membranes', 'Disturbances', 'frame-fitting', 'Cosmetics', 'Brides', 'GlaucomaEssential', 'occurring', 'seconds', 'adolescents', 'typing', 'intervals', 'fruits', 'dysphoriaPrimary', '91024Call', 'At-Risk', 'MadeUnderstanding', 'recipes', 'Wraparound', 'Google', 'Thanh', 'goodies', 'Thursday', 'develops', '40', 'life-changing', 'TV', 'Aimee', 'centers', 'Preservatives', 'Forms', 'television.', 'healthier', '10-12', 'clearest', 'Retinoscopy/autorefractor', 'won’t', '“the', 'Concerns', 'dissolves', 'participated', 'jobs', 'K.G', 'rubs', '10-20%', 'touchpoints', 'indicates', 'encouraged', 'Embedded', '50', '5-year-olds', 'safest', 'problemsPrimary', 'elongates', 'Long-Term', 'wraparound', 'environments', 'hygienePrimary', 'keratitisRedness', 'treats', 'paramedics', 'adjusting', 'Limits', 'eyelidDecreased', 'letting', '(Ortho-K', 'scheduled', 'Types', 'hill!', 'holds', 'DoctorWatery', 'Denise', 'non-pathologic', 'NeurolensesAs', 'degenerationMyopic', '9:45', 'MiSight', 'irritated', 'replacing', 'steps', 'classifications', 'UsThis', 'doctor’s', 'eyebrows', 'Women', 'High-Index', 'Don’t', 'trees', 'readouts', 'focusing', 'categories', 'gives', 'Foods', 'viruses', 'care!', 'weakened', 'disoriented', 'roads', 'four-year', 'drinks', 'pineapples', 'objectives', 'variations', '“Nature', 'Snellen', 'packs', "you're", 'prescriptionPrimary', 'Hands', 'accomplishes', 'ExamsOur', 'shows', 'particles', 'fats', 'Wearers10', 'you’ll', 'impairing', 'lessening', 'achieved', 'EyewearElevate', '(PD', 'vision-threatening', 'dosed', 'impact-resistant', 'TreeHouse', 'haven’t', 'hands.Clean', 'Fogging', 'prescription’s', 'radiates', 'Disrupting', 'CampaignGlobal', 'SunSigns', 'friends', 'glaucoma1', 'demands', 'UsWe', 'leary', '(grows', '21', '(AKA', 'figures', 'orthokeratology', 'PrecautionsVideo', '“cybersickness', '*For', '118(10', 'Eyes’', 'Post-COVID', 'differs', 'opting', 'places', '5m', 'resources', 'Britannica', 'described', "I've", 'barriers', 'screens', '60', 'far-away', '(having', 'car—but', 'dimensions', 'studying', '6', 'rapidly.', 'Prevented', 'INCREASED', 'Maps', '(While', 'cheese;', 'age-related', 'migraineurs', 'Good-quality', 'Lubricating', '1-2', 'Moisturize', '8-15', 'To?Optometrist', 'allergens', '(it’s', 'specialty-lens', 'explains', 'signs', 'neurolens®', 'individuals', 'Well-Balanced', 'marketed', 'Eyes?Dry', 'Employees', 'properly–and', '/', 'disinfected', 'powers', 'splashes', 'recommended', '“cures', 'hues', 'moves', 'misaligned', 'high-performance', 'child!', 'Curbside', '(puncta', 'performance-based', 'teenagers', 'short-term', '(1', '921-019914', '(This', 'gone.Never', 'Increased', 'ornaments', 'Hoshizaki', 'clinics', 'circadian', 'demands—be', 'advances', 'Saturday', '(AM', 'stored', 'saltwater', 'We’ve', 'Decreased', 'Avoiding', 'VS', 'KnowVision', 'sun’s', 'info', 'preservatives', 'Treehouse', "didn't", '60%', 'neurons', 'researchers', 'measures', 'Screenings', 'contraceptives', 'pmCopyright', 'coughing', '(NOCSAE', 'vessels', 'including', 'options.Jordan', 'reviews', 'modalities', 'adenovirus', 'detachment.Eye', '112(8', 'PPE', 'side-effects', 'restoring', 'pain/tension', 'high-index', 'family-owned', 'materials', 'DiseaseMyopia', 'eyesBlurred', 'CVS', 'Sci', '1989-1994.systematic', 'OK.If', 'restructured', 'staggering;', '100%', 'specialists', 'hayfever', 'scratch-resistant', 'gloves', '“E300', 'legs', 'halos', 'glasses,', 'releasing', 'intravitreal', 'state-of-the-art', 'slightest', '(AOA', 'handwashing', '…', 'DEVICES', '“20/20/20', 'AppointmentMyopia', 'reviewing', 'Headsets', 'ExamsTrust', 'Launches', 'ones', 'obtained', 'servings', 'changesPrimary', 'life,', 'make!', 'after-school', 'rids', 'that’s', 'bends', 'communities', 'screenshot', 'loved', 'featuring', 'doesn’t', 'cured;', '-All', 'particles.Light', 'Pasadena', 'Year’s', 'lenses!', 'modified', 'November', 'FDA-', 'Mailing', 'Answering',  ...

# %%
def separate_item_on_chars(items, chars):
  rtn_list = []
  for i, item in enumerate(items):
    print(f'item: {item}')
    for char in chars:
      if char in item:
        my_list = item.split(char)
        print(f'my_list before split: {my_list}')        
        my_list[0] = my_list[0] + char
        print(f'char: {char}')
        print(f'my_list[0]: {my_list[0]}')
        print(f'my_list after split: {my_list}')      
        rtn_list.append(my_list)
        print(' ')

  return rtn_list

# Example usage
chars = [".", ",", ":", "'"]
items = ['apple.app', 'banana:ban', 'cherry"che', 'a.apple', '.apple']
print(separate_item_on_chars(items, chars))
# Out:
# item: apple.app
# my_list before split: ['apple', 'app']
# char: .
# my_list[0]: apple.
# my_list after split: ['apple.', 'app']
#
# item: banana:ban
# my_list before split: ['banana', 'ban']
# char: :
# my_list[0]: banana:
# my_list after split: ['banana:', 'ban']
#
# item: cherry"che
# item: a.apple
# my_list before split: ['a', 'apple']
# char: .
# my_list[0]: a.
# my_list after split: ['a.', 'apple']
#
# item: .apple
# my_list before split: ['', 'apple']
# char: .
# my_list[0]: .
# my_list after split: ['.', 'apple']
#
# [['apple.', 'app'], ['banana:', 'ban'], ['a.', 'apple'], ['.', 'apple']]

# %%
separate

# %%
sep_char = '?'
my_list = ['Appointment?Do']
my_list[0].split(sep_char)
# my_list = my_list[0].split(sep_char)
# my_list[0] = my_list[0] + sep_char
# print(my_list)
# Out:
# ['Appointment', 'Do']

# %%
my_words = set(text.split())
english_words = set(words.words())

# %%
misspelled_w = []
for word in my_words:
  if word.lower() not in english_words:
    misspelled_w.append(word)

print(f'len(misspelled_w): {len(misspelled_w)}')                        
# print(f'len(misspelled_w): {len(misspelled_w)}')
misspelled_w

# %%
word = 'By'
english_words = set(words.words('en'))
if word.lower() not in english_words:
  print(f'{word} NOT in english_words')
else:
  print(f'{word} IN english_words')

# %%
print(f'len(misspelled_words): {len(misspelled_words)}')
misspelled_words

# %%
misspelled_words = remove_trailing_char(misspelled_words, '.')

# %%
def combine_items(items):
  return " ".join(items)

# Example usage
items = ["hello", "world"]
print(combine_items(items))  # Output: "hello world"

# %%
str_misspelled_words = combine_items(misspelled_words)
misspelled_words = find_misspelled_words(str_misspelled_words)
print(f'len(misspelled_words): {len(misspelled_words)}')
misspelled_words

# %%
my_text = set(text.split())
my_text

# %%
# Concatenate all the pages into a single string
text = ''
for page in data:
  text += page.page_content

print(f'len(text) before removing HTML tangs: {len(text)}')
# Clean the text by removing any HTML tags
import re

text = re.sub(r'\n+', '\n', text)  # replace \n\n\n..\n with \n
text = re.sub(r'\xa0', ' ', text)# replace '\xa0' with ' '
# replace all occurrences of the newline character \n that are followed by
# a word character (\w) with a space character " ". The strip() method
# remove any leading or trailing whitespace from the string.
text = re.sub(r'\n(?=\w)', ' ', text).strip()
text = re.sub(r'\n', ' ', text)  
text = re.sub(r' +(?=\s)', ' ', text)  

print(f'len(text) after  removing HTML tangs: {len(text)}')

# # Optionally, you can also remove any stopwords or punctuation
# from nltk.corpus import stopwords
# text = ' '.join([word for word in text.split() if word.lower() not in stopwords.words('english')])
# text = text.translate(str.maketrans('', '', string.punctuation))

# %%
print(f'len(text) before removing HTML tangs: {len(text)}')
text = re.sub(r'\n', ' ', text)  # replace \n\n\n..\n with \n
print(f'len(text) after  removing HTML tangs: {len(text)}')

# %%
text = "  hello\nworld  "
text = re.sub(r'\n(?=\w)', ' ', text).strip()
print(text)  # Output: "hello world"

# %%
import re

# The (?=\w) pattern is a positive lookahead assertion that matches a position in the string
# where the next character is a word character.
pattern = r'\b\w+(?=\s+\d+(\W+|$))'

text = 'The quick brown fox jumps over the 12345 lazy dog.'

matches = re.findall(pattern, text)

print(matches)  # Output: ['jumps', 'over', 'the']

# %%
# Load the data from a website
loader = WebBaseLoader('https://example.com')
pages = loader.load()

# Concatenate all the pages into a single string
text = ''
for page in pages:
    text += page.page_content

# Clean the text by removing any HTML tags
import re
text = re.sub(r'<.*?>', '', text)

# Optionally, you can also remove any stopwords or punctuation
from nltk.corpus import stopwords
text = ' '.join([word for word in text.split() if word.lower() not in stopwords.words('english')])
text = text.translate(str.maketrans('', '', string.punctuation))
